# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader
import pandas as pd
from sklearn.preprocessing import MinMaxScaler
import matplotlib.pyplot as plt
import numpy as np
import random
import os
import seaborn as sns


# Set random seed for reproducibility
seed = 42  # You can choose any integer here

# Set seed for NumPy
np.random.seed(seed)

# Set seed for Python's random module
random.seed(seed)

# Set seed for PyTorch
torch.manual_seed(seed)

# For GPU (if using CUDA)
if torch.cuda.is_available():
    torch.cuda.manual_seed(seed)
    torch.cuda.manual_seed_all(seed)  # For multi-GPU setups

# Set deterministic behavior for reproducibility in case of CUDA operations
torch.backends.cudnn.deterministic = True
torch.backends.cudnn.benchmark = False




dataset_dir = "datasets/no_comm/"

# Directory containing the saved CSV files
output_dir = dataset_dir + "training_outputs/"

# Load one of the CSV files for EDA (e.g., user_0_outputs.csv)
csv_file = os.path.join(output_dir, "user_1_outputs.csv")
df = pd.read_csv(csv_file)

# Quick overview of the data
print("Data Overview:")
print(df.head())
print("\nData Summary:")
print(df.describe())

# Check for missing values
print("\nMissing Values:")
print(df.isnull().sum())

# Distribution of the target variable (y)
sns.countplot(x="y", data=df)
plt.title("Target Variable Distribution")
plt.show()

# Correlation heatmap of features
correlation_matrix = df.iloc[:, :-1].corr()  # Exclude the target column
plt.figure(figsize=(12, 10))
sns.heatmap(correlation_matrix, cmap="coolwarm", center=0)
plt.title("Feature Correlation Heatmap")
plt.show()
# Out:
# Data Overview:
#    Feature_1  Feature_2  Feature_3  Feature_4  Feature_5  Feature_6  \
# 0        0.0   0.000000   2.427324        0.0   0.000000   0.000000
# 1        0.0   0.427090   1.163418        0.0   0.178713   0.413166
# 2        0.0   0.000000   2.095180        0.0   0.000000   0.000000
# 3        0.0   0.157136   3.609239        0.0   0.000000   0.182261
# 4        0.0   2.231131   1.165798        0.0   0.981523   2.230717
#
#    Feature_7  Feature_8  Feature_9  Feature_10  ...  Feature_248  Feature_249  \
# 0   0.000000   0.763855   0.000000    0.000000  ...    -1.592660    -1.397809
# 1   0.175270   0.794933   0.627405    0.461691  ...    -1.962592    -1.452488
# 2   0.000000   0.670203   0.000000    0.000000  ...    -1.373927    -0.924505
# 3   0.009697   1.396447   0.057795    0.213247  ...     0.654818    -0.822407
# 4   0.809156   2.806526   3.018401    2.545619  ...     3.052901     1.972201
#
#    Feature_250  Feature_251  Feature_252  Feature_253  Feature_254  \
# 0     0.023165     1.121107    -0.851685    -0.757659    -0.060895
# 1     0.039978     1.459249    -1.594860    -0.972583    -0.264299
# 2     1.852382     0.852163     1.165901     1.097879     0.008920
# 3    -0.712063    -2.135010     2.392082    -0.223696     0.837794
# 4    -1.520203    -3.621065    -0.730071    -2.076510    -1.538100
#
#    Feature_255  Feature_256     y
# 0    -0.482635    -1.982693  19.0
# 1    -0.249734    -1.615554  19.0
# 2    -1.821918    -1.379264  22.0
# 3    -1.848053    -0.666927  17.0
# 4     0.353249     2.013438  11.0
#
# [5 rows x 257 columns]
#
# Data Summary:
#        Feature_1    Feature_2    Feature_3    Feature_4    Feature_5  \
# count     1729.0  1729.000000  1729.000000  1729.000000  1729.000000
# mean         0.0     0.735354     2.170556     0.015320     0.285868
# std          0.0     0.720206     1.321380     0.045479     0.347628
# min          0.0     0.000000     0.000000     0.000000     0.000000
# 25%          0.0     0.151771     1.242436     0.000000     0.000000
# 50%          0.0     0.523094     1.978576     0.000000     0.171081
# 75%          0.0     1.067831     3.249154     0.000000     0.451306
# max          0.0     3.388823     5.613220     0.204794     1.508188
#
#          Feature_6    Feature_7    Feature_8    Feature_9   Feature_10  ...  \
# count  1729.000000  1729.000000  1729.000000  1729.000000  1729.000000  ...
# mean      0.738261     0.261748     1.494263     0.976723     0.841353  ...
# std       0.713494     0.272633     0.653327     1.004861     0.814570  ...
# min       0.000000     0.000000     0.298954     0.000000     0.000000  ...
# 25%       0.181926     0.022026     1.022588     0.095390     0.213247  ...
# 50%       0.523857     0.186780     1.407066     0.695694     0.594108  ...
# 75%       1.082329     0.390076     1.814744     1.461713     1.239956  ...
# max       3.387750     1.233443     4.201824     4.600913     3.881645  ...
#
#        Feature_248  Feature_249  Feature_250  Feature_251  Feature_252  \
# count  1729.000000  1729.000000  1729.000000  1729.000000  1729.000000
# mean      0.666921    -0.300697    -0.376396    -1.279916     0.166535
# std       1.504751     1.216515     1.593494     1.451501     1.603865
# min      -4.751606    -4.122119    -3.894967    -5.161763    -3.717653
# 25%      -0.483589    -0.877740    -1.484418    -2.173479    -1.180783
# 50%       0.984675    -0.433756    -0.603738    -1.611854     0.172930
# 75%       1.756572     0.134825     0.177452    -0.717330     1.508765
# max       3.566294     3.326209     5.393246     2.273761     4.260859
#
#        Feature_253  Feature_254  Feature_255  Feature_256            y
# count  1729.000000  1729.000000  1729.000000  1729.000000  1729.000000
# mean     -0.789709    -0.338264    -0.520803     0.413280    15.186235
# std       1.047715     0.882098     1.004738     1.493140     5.019063
# min      -3.140517    -2.953035    -2.981000    -2.401864     2.000000
# 25%      -1.457134    -0.951254    -1.417228    -0.627088    14.000000
# 50%      -0.604308    -0.470251    -0.560128     0.020059    16.000000
# 75%      -0.253853     0.555784     0.267075     1.596923    17.000000
# max       2.929004     1.255433     1.526845     5.069533    30.000000
#
# [8 rows x 257 columns]
#
# Missing Values:
# Feature_1      0
# Feature_2      0
# Feature_3      0
# Feature_4      0
# Feature_5      0
#               ..
# Feature_253    0
# Feature_254    0
# Feature_255    0
# Feature_256    0
# y              0
# Length: 257, dtype: int64

# %%
no_users = 20
# Define the Multinomial Logistic Regression model
class MultinomialLogisticRegression(nn.Module):
    def __init__(self, input_size, num_classes):
        super(MultinomialLogisticRegression, self).__init__()
        self.linear = nn.Linear(input_size, num_classes)

    def forward(self, x):
        return self.linear(x)

# Custom dataset to load the data from CSV
class CustomDataset(Dataset):
    def __init__(self,  csv_file, modality=["pos_height", "images"], scaler=None, zero_prob=0.5):
        self.data = pd.read_csv(csv_file)
        if "images" in modality and "pos_height" in modality:
            self.X = self.data.iloc[:, :-1].values  # Features
            mask = np.ones(self.X.shape)  # Initialize mask
            mask[:, 128:-1] = np.random.choice([0, 1], size=self.X[:, 128:-1].shape, p=[zero_prob, 1 - zero_prob])
            self.X *= mask  # Apply mask to zero out features
        elif "images" in modality:
            self.X = self.data.iloc[:, 128:-1].values  # Features
            mask = np.random.choice([0, 1], size=self.X.shape, p=[zero_prob, 1 - zero_prob])  # Create a binary mask
            self.X *= mask  # Apply mask
        else:
            self.X = self.data.iloc[:, 0:128].values  # Features

        self.y = self.data.iloc[:, -1].values   # Labels

        # If a scaler is provided, use it to transform the features
        if scaler:
            self.X = scaler.transform(self.X)
        else:
            # Fit the scaler on the training data and transform
            self.scaler = MinMaxScaler(feature_range=(-1, 1))
            self.X = self.scaler.fit_transform(self.X)

    def __len__(self):
        return len(self.data)

    def __getitem__(self, idx):
        X = torch.tensor(self.X[idx], dtype=torch.float32)
        y = torch.tensor(self.y[idx], dtype=torch.long)  # Use long for classification targets
        return X, y

# %%
# Configuration
no_users = 20  # Example: Number of users
available_modalities = ["pos_height", "images"]
modality_size = {"pos_height": 128, "images": 128}
group_definitions = {
    1: ["pos_height"],        # Group 1: Only pos_height
    2: ["images"],            # Group 2: Only images
    3: ["pos_height", "images"]  # Group 3: Both modalities
}

# Assign each user to a group randomly
user_groups = [random.choice([1, 2, 3]) for _ in range(no_users)]

# Assign modalities to users based on their group
user_modalities = [group_definitions[group] for group in user_groups]

# Compute output sizes for each user based on their modalities
output_sizes = [sum(modality_size[modality] for modality in user_modality) for user_modality in user_modalities]

# Store models (placeholders for actual models)
all_models = []

# Example output (for verification)
print(f"User Groups: {user_groups[:10]}")  # Show first 10 users' groups
print(f"User Modalities: {user_modalities[:10]}")  # Show first 10 users' modalities
print(f"Output Sizes: {output_sizes[:10]}")  # Show first 10 users' output sizes
# Out:
# User Groups: [3, 1, 1, 3, 2, 1, 1, 1, 3, 1]
# User Modalities: [['pos_height', 'images'], ['pos_height'], ['pos_height'], ['pos_height', 'images'], ['images'], ['pos_height'], ['pos_height'], ['pos_height'], ['pos_height', 'images'], ['pos_height']]
# Output Sizes: [256, 128, 128, 256, 128, 128, 128, 128, 256, 128]

# %%
no_users = 20
# List to store DataLoader objects for each user
train_loaders = []
val_loaders = []
test_loaders = []
scaler = None
# Loop over each user
zero_prob=0.8
dataset_dir = "datasets/FL/"
for user_idx in range(no_users):
    scaler = None
    # Define file paths for each user dynamically
    train_file = dataset_dir + f"training_outputs/user_{user_idx}_outputs.csv"
    val_file = dataset_dir + f"val_outputs/user_{user_idx}_outputs.csv"
    test_file = dataset_dir + f"test_outputs/user_{user_idx}_outputs.csv"

    # Load training data and fit the scaler on it (only once for each user)
    train_data = pd.read_csv(train_file)
    
    if scaler is None:
        scaler = MinMaxScaler(feature_range=(-1, 1))
        # Fit the scaler on the first user's training data
        if "images" in user_modalities[user_idx] and "pos_height" in user_modalities[user_idx]:
            temp = train_data.iloc[:, :-1].values  # Features
        elif "images" in user_modalities[user_idx]:
            temp = train_data.iloc[:, 128:-1].values  # Features
        else:
            temp = train_data.iloc[:, 0:128].values  # Features
        scaler.fit(temp)  # Fit scaler only on training features

    # Create datasets using the same scaler for all data
    train_dataset = CustomDataset(train_file, scaler=scaler, modality=user_modalities[user_idx], zero_prob=0.5)
    val_dataset = CustomDataset(val_file, scaler=scaler, modality=user_modalities[user_idx], zero_prob=0.5)
    test_dataset = CustomDataset(test_file, scaler=scaler, modality=user_modalities[user_idx], zero_prob=0.5)

    # Create DataLoader for training, validation, and testing for each user
    batch_size = 64
    train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=False)
    val_loader = DataLoader(val_dataset, batch_size=batch_size, shuffle=False)
    test_loader = DataLoader(test_dataset, batch_size=batch_size, shuffle=False)

    # Append each user's DataLoader to the respective lists
    train_loaders.append(train_loader)
    val_loaders.append(val_loader)
    test_loaders.append(test_loader)

# %%
# Initialize model, loss function, and optimizer for multiple users
input_sizes = output_sizes  # Number of features
num_classes = 64
classifiers = [MultinomialLogisticRegression(input_size, num_classes) for input_size, _ in zip(input_sizes, range(no_users))]
#classifiers = [MultinomialLogisticRegression(input_size, num_classes).cuda() for _ in range(no_users)]
optimizers = [optim.Adam(model.parameters(), lr=0.001) for model in classifiers]
criterion = nn.CrossEntropyLoss()
# Training parameters
num_epochs = 50

# %%
# Group assignments (use the previously defined user_groups)
group_losses = {1: [], 2: [], 3: []}
group_accuracies = {1: [], 2: [], 3: []}

# Initialize dictionaries to track metrics for each group
group_train_loss_histories = {1: [], 2: [], 3: []}
group_train_accuracy_histories = {1: [], 2: [], 3: []}
group_val_loss_histories = {1: [], 2: [], 3: []}
group_val_accuracy_histories = {1: [], 2: [], 3: []}

# Training loop
for epoch in range(num_epochs):
    # Temporary dictionaries for this epoch
    epoch_group_train_losses = {1: [], 2: [], 3: []}
    epoch_group_train_accuracies = {1: [], 2: [], 3: []}
    epoch_group_val_losses = {1: [], 2: [], 3: []}
    epoch_group_val_accuracies = {1: [], 2: [], 3: []}

    for user_id, (model, optimizer) in enumerate(zip(classifiers, optimizers)):
        group = user_groups[user_id]  # Get the group of the user

        # Training phase
        model.train()
        epoch_train_loss = 0.0
        correct_train_predictions = 0
        total_train_samples = 0

        for X_batch, y_batch in train_loaders[user_id]:
            outputs = model(X_batch)
            loss = criterion(outputs, y_batch)

            optimizer.zero_grad()
            loss.backward()
            optimizer.step()

            epoch_train_loss += loss.item()
            _, predicted = torch.max(outputs, dim=1)
            correct_train_predictions += (predicted == y_batch).sum().item()
            total_train_samples += y_batch.size(0)

        avg_train_loss = epoch_train_loss / len(train_loaders[user_id])
        train_accuracy = correct_train_predictions / total_train_samples

        # Validation phase
        model.eval()
        epoch_val_loss = 0.0
        correct_val_predictions = 0
        total_val_samples = 0

        with torch.no_grad():
            for X_batch, y_batch in val_loaders[user_id]:
                outputs = model(X_batch)
                loss = criterion(outputs, y_batch)

                epoch_val_loss += loss.item()
                _, predicted = torch.max(outputs, dim=1)
                correct_val_predictions += (predicted == y_batch).sum().item()
                total_val_samples += y_batch.size(0)

        avg_val_loss = epoch_val_loss / len(val_loaders[user_id])
        val_accuracy = correct_val_predictions / total_val_samples

        # Assign metrics to the respective group
        epoch_group_train_losses[group].append(avg_train_loss)
        epoch_group_train_accuracies[group].append(train_accuracy)
        epoch_group_val_losses[group].append(avg_val_loss)
        epoch_group_val_accuracies[group].append(val_accuracy)

    # Calculate averages for this epoch and store them
    for group in [1, 2, 3]:
        group_train_loss_histories[group].append(np.mean(epoch_group_train_losses[group]))
        group_train_accuracy_histories[group].append(np.mean(epoch_group_train_accuracies[group]))
        group_val_loss_histories[group].append(np.mean(epoch_group_val_losses[group]))
        group_val_accuracy_histories[group].append(np.mean(epoch_group_val_accuracies[group]))

    # Print group-wise average metrics
    print(f"Epoch [{epoch+1}/{num_epochs}] Group Metrics:")
    for group in [1, 2, 3]:
        print(f"  Group {group} - Train Loss: {np.mean(epoch_group_train_losses[group]):.4f}, Train Accuracy: {np.mean(epoch_group_train_accuracies[group]):.4f}")
        print(f"  Group {group} - Val Loss: {np.mean(epoch_group_val_losses[group]):.4f}, Val Accuracy: {np.mean(epoch_group_val_accuracies[group]):.4f}")
# Out:
# C:\Users\aghalkha21\AppData\Local\Temp\ipykernel_2384\3432764924.py:42: DeprecationWarning: an integer is required (got type numpy.float64).  Implicit conversion to integers using __int__ is deprecated, and may be removed in a future version of Python.
#   y = torch.tensor(self.y[idx], dtype=torch.long)  # Use long for classification targets
# Epoch [1/50] Group Metrics:
#   Group 1 - Train Loss: 3.8340, Train Accuracy: 0.0622
#   Group 1 - Val Loss: 3.6607, Val Accuracy: 0.0912
#   Group 2 - Train Loss: 3.7169, Train Accuracy: 0.2042
#   Group 2 - Val Loss: 3.2830, Val Accuracy: 0.3782
#   Group 3 - Train Loss: 3.4675, Train Accuracy: 0.2244
#   Group 3 - Val Loss: 2.9622, Val Accuracy: 0.3915
# Epoch [2/50] Group Metrics:
#   Group 1 - Train Loss: 3.6184, Train Accuracy: 0.1163
#   Group 1 - Val Loss: 3.6176, Val Accuracy: 0.1392
#   Group 2 - Train Loss: 2.9230, Train Accuracy: 0.4681
#   Group 2 - Val Loss: 2.6750, Val Accuracy: 0.4695
#   Group 3 - Train Loss: 2.6596, Train Accuracy: 0.4576
#   Group 3 - Val Loss: 2.3938, Val Accuracy: 0.5050
# Epoch [3/50] Group Metrics:
#   Group 1 - Train Loss: 3.5782, Train Accuracy: 0.1734
#   Group 1 - Val Loss: 3.5813, Val Accuracy: 0.2020
#   Group 2 - Train Loss: 2.3963, Train Accuracy: 0.5397
#   Group 2 - Val Loss: 2.2843, Val Accuracy: 0.5181
#   Group 3 - Train Loss: 2.1759, Train Accuracy: 0.5513
#   Group 3 - Val Loss: 2.0024, Val Accuracy: 0.5905
# Epoch [4/50] Group Metrics:
#   Group 1 - Train Loss: 3.5430, Train Accuracy: 0.2146
#   Group 1 - Val Loss: 3.5483, Val Accuracy: 0.2238
#   Group 2 - Train Loss: 2.0526, Train Accuracy: 0.5745
#   Group 2 - Val Loss: 2.0283, Val Accuracy: 0.5351
#   Group 3 - Train Loss: 1.8535, Train Accuracy: 0.6134
#   Group 3 - Val Loss: 1.7499, Val Accuracy: 0.6362
# Epoch [5/50] Group Metrics:
#   Group 1 - Train Loss: 3.5108, Train Accuracy: 0.2320
#   Group 1 - Val Loss: 3.5170, Val Accuracy: 0.2380
#   Group 2 - Train Loss: 1.8220, Train Accuracy: 0.5932
#   Group 2 - Val Loss: 1.8472, Val Accuracy: 0.5590
#   Group 3 - Train Loss: 1.6412, Train Accuracy: 0.6474
#   Group 3 - Val Loss: 1.5813, Val Accuracy: 0.6594
# Epoch [6/50] Group Metrics:
#   Group 1 - Train Loss: 3.4804, Train Accuracy: 0.2404
#   Group 1 - Val Loss: 3.4866, Val Accuracy: 0.2450
#   Group 2 - Train Loss: 1.6554, Train Accuracy: 0.6166
#   Group 2 - Val Loss: 1.7085, Val Accuracy: 0.5812
#   Group 3 - Train Loss: 1.4909, Train Accuracy: 0.6671
#   Group 3 - Val Loss: 1.4583, Val Accuracy: 0.6748
# Epoch [7/50] Group Metrics:
#   Group 1 - Train Loss: 3.4510, Train Accuracy: 0.2478
#   Group 1 - Val Loss: 3.4570, Val Accuracy: 0.2514
#   Group 2 - Train Loss: 1.5269, Train Accuracy: 0.6408
#   Group 2 - Val Loss: 1.5975, Val Accuracy: 0.6022
#   Group 3 - Train Loss: 1.3770, Train Accuracy: 0.6842
#   Group 3 - Val Loss: 1.3637, Val Accuracy: 0.6873
# Epoch [8/50] Group Metrics:
#   Group 1 - Train Loss: 3.4223, Train Accuracy: 0.2539
#   Group 1 - Val Loss: 3.4279, Val Accuracy: 0.2608
#   Group 2 - Train Loss: 1.4236, Train Accuracy: 0.6592
#   Group 2 - Val Loss: 1.5060, Val Accuracy: 0.6221
#   Group 3 - Train Loss: 1.2867, Train Accuracy: 0.7000
#   Group 3 - Val Loss: 1.2882, Val Accuracy: 0.6959
# Epoch [9/50] Group Metrics:
#   Group 1 - Train Loss: 3.3940, Train Accuracy: 0.2588
#   Group 1 - Val Loss: 3.3993, Val Accuracy: 0.2646
#   Group 2 - Train Loss: 1.3382, Train Accuracy: 0.6794
#   Group 2 - Val Loss: 1.4293, Val Accuracy: 0.6432
#   Group 3 - Train Loss: 1.2129, Train Accuracy: 0.7111
#   Group 3 - Val Loss: 1.2263, Val Accuracy: 0.7060
# Epoch [10/50] Group Metrics:
#   Group 1 - Train Loss: 3.3661, Train Accuracy: 0.2626
#   Group 1 - Val Loss: 3.3711, Val Accuracy: 0.2657
#   Group 2 - Train Loss: 1.2662, Train Accuracy: 0.6972
#   Group 2 - Val Loss: 1.3640, Val Accuracy: 0.6572
#   Group 3 - Train Loss: 1.1511, Train Accuracy: 0.7219
#   Group 3 - Val Loss: 1.1744, Val Accuracy: 0.7120
# Epoch [11/50] Group Metrics:
#   Group 1 - Train Loss: 3.3385, Train Accuracy: 0.2654
#   Group 1 - Val Loss: 3.3432, Val Accuracy: 0.2668
#   Group 2 - Train Loss: 1.2044, Train Accuracy: 0.7121
#   Group 2 - Val Loss: 1.3077, Val Accuracy: 0.6671
#   Group 3 - Train Loss: 1.0984, Train Accuracy: 0.7302
#   Group 3 - Val Loss: 1.1303, Val Accuracy: 0.7182
# Epoch [12/50] Group Metrics:
#   Group 1 - Train Loss: 3.3112, Train Accuracy: 0.2677
#   Group 1 - Val Loss: 3.3158, Val Accuracy: 0.2690
#   Group 2 - Train Loss: 1.1508, Train Accuracy: 0.7235
#   Group 2 - Val Loss: 1.2587, Val Accuracy: 0.6753
#   Group 3 - Train Loss: 1.0526, Train Accuracy: 0.7380
#   Group 3 - Val Loss: 1.0922, Val Accuracy: 0.7242
# Epoch [13/50] Group Metrics:
#   Group 1 - Train Loss: 3.2844, Train Accuracy: 0.2695
#   Group 1 - Val Loss: 3.2887, Val Accuracy: 0.2707
#   Group 2 - Train Loss: 1.1036, Train Accuracy: 0.7312
#   Group 2 - Val Loss: 1.2156, Val Accuracy: 0.6858
#   Group 3 - Train Loss: 1.0125, Train Accuracy: 0.7459
#   Group 3 - Val Loss: 1.0589, Val Accuracy: 0.7285
# Epoch [14/50] Group Metrics:
#   Group 1 - Train Loss: 3.2579, Train Accuracy: 0.2717
#   Group 1 - Val Loss: 3.2620, Val Accuracy: 0.2723
#   Group 2 - Train Loss: 1.0618, Train Accuracy: 0.7393
#   Group 2 - Val Loss: 1.1774, Val Accuracy: 0.6946
#   Group 3 - Train Loss: 0.9768, Train Accuracy: 0.7518
#   Group 3 - Val Loss: 1.0296, Val Accuracy: 0.7352
# Epoch [15/50] Group Metrics:
#   Group 1 - Train Loss: 3.2318, Train Accuracy: 0.2733
#   Group 1 - Val Loss: 3.2358, Val Accuracy: 0.2750
#   Group 2 - Train Loss: 1.0244, Train Accuracy: 0.7487
#   Group 2 - Val Loss: 1.1433, Val Accuracy: 0.6987
#   Group 3 - Train Loss: 0.9449, Train Accuracy: 0.7585
#   Group 3 - Val Loss: 1.0036, Val Accuracy: 0.7396
# Epoch [16/50] Group Metrics:
#   Group 1 - Train Loss: 3.2061, Train Accuracy: 0.2746
#   Group 1 - Val Loss: 3.2100, Val Accuracy: 0.2767
#   Group 2 - Train Loss: 0.9906, Train Accuracy: 0.7543
#   Group 2 - Val Loss: 1.1127, Val Accuracy: 0.7010
#   Group 3 - Train Loss: 0.9160, Train Accuracy: 0.7644
#   Group 3 - Val Loss: 0.9803, Val Accuracy: 0.7431
# Epoch [17/50] Group Metrics:
#   Group 1 - Train Loss: 3.1808, Train Accuracy: 0.2765
#   Group 1 - Val Loss: 3.1846, Val Accuracy: 0.2779
#   Group 2 - Train Loss: 0.9600, Train Accuracy: 0.7587
#   Group 2 - Val Loss: 1.0851, Val Accuracy: 0.7080
#   Group 3 - Train Loss: 0.8898, Train Accuracy: 0.7694
#   Group 3 - Val Loss: 0.9593, Val Accuracy: 0.7460
# Epoch [18/50] Group Metrics:
#   Group 1 - Train Loss: 3.1560, Train Accuracy: 0.2783
#   Group 1 - Val Loss: 3.1597, Val Accuracy: 0.2790
#   Group 2 - Train Loss: 0.9321, Train Accuracy: 0.7628
#   Group 2 - Val Loss: 1.0599, Val Accuracy: 0.7121
#   Group 3 - Train Loss: 0.8658, Train Accuracy: 0.7750
#   Group 3 - Val Loss: 0.9404, Val Accuracy: 0.7481
# Epoch [19/50] Group Metrics:
#   Group 1 - Train Loss: 3.1317, Train Accuracy: 0.2797
#   Group 1 - Val Loss: 3.1353, Val Accuracy: 0.2793
#   Group 2 - Train Loss: 0.9065, Train Accuracy: 0.7674
#   Group 2 - Val Loss: 1.0370, Val Accuracy: 0.7162
#   Group 3 - Train Loss: 0.8438, Train Accuracy: 0.7800
#   Group 3 - Val Loss: 0.9231, Val Accuracy: 0.7510
# Epoch [20/50] Group Metrics:
#   Group 1 - Train Loss: 3.1078, Train Accuracy: 0.2808
#   Group 1 - Val Loss: 3.1114, Val Accuracy: 0.2807
#   Group 2 - Train Loss: 0.8828, Train Accuracy: 0.7704
#   Group 2 - Val Loss: 1.0159, Val Accuracy: 0.7221
#   Group 3 - Train Loss: 0.8234, Train Accuracy: 0.7835
#   Group 3 - Val Loss: 0.9074, Val Accuracy: 0.7535
# Epoch [21/50] Group Metrics:
#   Group 1 - Train Loss: 3.0845, Train Accuracy: 0.2811
#   Group 1 - Val Loss: 3.0880, Val Accuracy: 0.2858
#   Group 2 - Train Loss: 0.8609, Train Accuracy: 0.7736
#   Group 2 - Val Loss: 0.9965, Val Accuracy: 0.7256
#   Group 3 - Train Loss: 0.8045, Train Accuracy: 0.7881
#   Group 3 - Val Loss: 0.8930, Val Accuracy: 0.7547
# Epoch [22/50] Group Metrics:
#   Group 1 - Train Loss: 3.0616, Train Accuracy: 0.2824
#   Group 1 - Val Loss: 3.0650, Val Accuracy: 0.2860
#   Group 2 - Train Loss: 0.8406, Train Accuracy: 0.7771
#   Group 2 - Val Loss: 0.9786, Val Accuracy: 0.7274
#   Group 3 - Train Loss: 0.7868, Train Accuracy: 0.7919
#   Group 3 - Val Loss: 0.8797, Val Accuracy: 0.7580
# Epoch [23/50] Group Metrics:
#   Group 1 - Train Loss: 3.0392, Train Accuracy: 0.2833
#   Group 1 - Val Loss: 3.0426, Val Accuracy: 0.2860
#   Group 2 - Train Loss: 0.8216, Train Accuracy: 0.7803
#   Group 2 - Val Loss: 0.9621, Val Accuracy: 0.7320
#   Group 3 - Train Loss: 0.7704, Train Accuracy: 0.7964
#   Group 3 - Val Loss: 0.8675, Val Accuracy: 0.7597
# Epoch [24/50] Group Metrics:
#   Group 1 - Train Loss: 3.0173, Train Accuracy: 0.2841
#   Group 1 - Val Loss: 3.0207, Val Accuracy: 0.2872
#   Group 2 - Train Loss: 0.8038, Train Accuracy: 0.7856
#   Group 2 - Val Loss: 0.9466, Val Accuracy: 0.7344
#   Group 3 - Train Loss: 0.7549, Train Accuracy: 0.7994
#   Group 3 - Val Loss: 0.8562, Val Accuracy: 0.7624
# Epoch [25/50] Group Metrics:
#   Group 1 - Train Loss: 2.9959, Train Accuracy: 0.2842
#   Group 1 - Val Loss: 2.9993, Val Accuracy: 0.2868
#   Group 2 - Train Loss: 0.7871, Train Accuracy: 0.7899
#   Group 2 - Val Loss: 0.9323, Val Accuracy: 0.7373
#   Group 3 - Train Loss: 0.7404, Train Accuracy: 0.8038
#   Group 3 - Val Loss: 0.8457, Val Accuracy: 0.7636
# Epoch [26/50] Group Metrics:
#   Group 1 - Train Loss: 2.9750, Train Accuracy: 0.2851
#   Group 1 - Val Loss: 2.9783, Val Accuracy: 0.2859
#   Group 2 - Train Loss: 0.7714, Train Accuracy: 0.7943
#   Group 2 - Val Loss: 0.9188, Val Accuracy: 0.7391
#   Group 3 - Train Loss: 0.7266, Train Accuracy: 0.8077
#   Group 3 - Val Loss: 0.8359, Val Accuracy: 0.7664
# Epoch [27/50] Group Metrics:
#   Group 1 - Train Loss: 2.9546, Train Accuracy: 0.2853
#   Group 1 - Val Loss: 2.9579, Val Accuracy: 0.2852
#   Group 2 - Train Loss: 0.7566, Train Accuracy: 0.7955
#   Group 2 - Val Loss: 0.9063, Val Accuracy: 0.7414
#   Group 3 - Train Loss: 0.7137, Train Accuracy: 0.8114
#   Group 3 - Val Loss: 0.8268, Val Accuracy: 0.7683
# Epoch [28/50] Group Metrics:
#   Group 1 - Train Loss: 2.9347, Train Accuracy: 0.2857
#   Group 1 - Val Loss: 2.9381, Val Accuracy: 0.2847
#   Group 2 - Train Loss: 0.7426, Train Accuracy: 0.7990
#   Group 2 - Val Loss: 0.8944, Val Accuracy: 0.7437
#   Group 3 - Train Loss: 0.7014, Train Accuracy: 0.8134
#   Group 3 - Val Loss: 0.8183, Val Accuracy: 0.7696
# Epoch [29/50] Group Metrics:
#   Group 1 - Train Loss: 2.9153, Train Accuracy: 0.2856
#   Group 1 - Val Loss: 2.9187, Val Accuracy: 0.2848
#   Group 2 - Train Loss: 0.7292, Train Accuracy: 0.8019
#   Group 2 - Val Loss: 0.8833, Val Accuracy: 0.7478
#   Group 3 - Train Loss: 0.6897, Train Accuracy: 0.8160
#   Group 3 - Val Loss: 0.8104, Val Accuracy: 0.7708
# Epoch [30/50] Group Metrics:
#   Group 1 - Train Loss: 2.8964, Train Accuracy: 0.2853
#   Group 1 - Val Loss: 2.8998, Val Accuracy: 0.2846
#   Group 2 - Train Loss: 0.7166, Train Accuracy: 0.8037
#   Group 2 - Val Loss: 0.8729, Val Accuracy: 0.7519
#   Group 3 - Train Loss: 0.6785, Train Accuracy: 0.8180
#   Group 3 - Val Loss: 0.8029, Val Accuracy: 0.7718
# Epoch [31/50] Group Metrics:
#   Group 1 - Train Loss: 2.8780, Train Accuracy: 0.2853
#   Group 1 - Val Loss: 2.8814, Val Accuracy: 0.2843
#   Group 2 - Train Loss: 0.7046, Train Accuracy: 0.8066
#   Group 2 - Val Loss: 0.8630, Val Accuracy: 0.7537
#   Group 3 - Train Loss: 0.6679, Train Accuracy: 0.8208
#   Group 3 - Val Loss: 0.7959, Val Accuracy: 0.7731
# Epoch [32/50] Group Metrics:
#   Group 1 - Train Loss: 2.8600, Train Accuracy: 0.2854
#   Group 1 - Val Loss: 2.8635, Val Accuracy: 0.2841
#   Group 2 - Train Loss: 0.6931, Train Accuracy: 0.8110
#   Group 2 - Val Loss: 0.8537, Val Accuracy: 0.7595
#   Group 3 - Train Loss: 0.6578, Train Accuracy: 0.8238
#   Group 3 - Val Loss: 0.7894, Val Accuracy: 0.7759
# Epoch [33/50] Group Metrics:
#   Group 1 - Train Loss: 2.8426, Train Accuracy: 0.2850
#   Group 1 - Val Loss: 2.8461, Val Accuracy: 0.2839
#   Group 2 - Train Loss: 0.6821, Train Accuracy: 0.8151
#   Group 2 - Val Loss: 0.8449, Val Accuracy: 0.7607
#   Group 3 - Train Loss: 0.6481, Train Accuracy: 0.8266
#   Group 3 - Val Loss: 0.7832, Val Accuracy: 0.7764
# Epoch [34/50] Group Metrics:
#   Group 1 - Train Loss: 2.8256, Train Accuracy: 0.2851
#   Group 1 - Val Loss: 2.8292, Val Accuracy: 0.2842
#   Group 2 - Train Loss: 0.6716, Train Accuracy: 0.8172
#   Group 2 - Val Loss: 0.8365, Val Accuracy: 0.7619
#   Group 3 - Train Loss: 0.6388, Train Accuracy: 0.8289
#   Group 3 - Val Loss: 0.7774, Val Accuracy: 0.7763
# Epoch [35/50] Group Metrics:
#   Group 1 - Train Loss: 2.8091, Train Accuracy: 0.2852
#   Group 1 - Val Loss: 2.8127, Val Accuracy: 0.2845
#   Group 2 - Train Loss: 0.6616, Train Accuracy: 0.8207
#   Group 2 - Val Loss: 0.8286, Val Accuracy: 0.7619
#   Group 3 - Train Loss: 0.6299, Train Accuracy: 0.8319
#   Group 3 - Val Loss: 0.7719, Val Accuracy: 0.7778
# Epoch [36/50] Group Metrics:
#   Group 1 - Train Loss: 2.7931, Train Accuracy: 0.2846
#   Group 1 - Val Loss: 2.7967, Val Accuracy: 0.2840
#   Group 2 - Train Loss: 0.6519, Train Accuracy: 0.8253
#   Group 2 - Val Loss: 0.8210, Val Accuracy: 0.7630
#   Group 3 - Train Loss: 0.6213, Train Accuracy: 0.8342
#   Group 3 - Val Loss: 0.7667, Val Accuracy: 0.7781
# Epoch [37/50] Group Metrics:
#   Group 1 - Train Loss: 2.7775, Train Accuracy: 0.2851
#   Group 1 - Val Loss: 2.7812, Val Accuracy: 0.2838
#   Group 2 - Train Loss: 0.6427, Train Accuracy: 0.8280
#   Group 2 - Val Loss: 0.8138, Val Accuracy: 0.7642
#   Group 3 - Train Loss: 0.6131, Train Accuracy: 0.8374
#   Group 3 - Val Loss: 0.7617, Val Accuracy: 0.7793
# Epoch [38/50] Group Metrics:
#   Group 1 - Train Loss: 2.7623, Train Accuracy: 0.2848
#   Group 1 - Val Loss: 2.7661, Val Accuracy: 0.2836
#   Group 2 - Train Loss: 0.6338, Train Accuracy: 0.8312
#   Group 2 - Val Loss: 0.8070, Val Accuracy: 0.7654
#   Group 3 - Train Loss: 0.6051, Train Accuracy: 0.8397
#   Group 3 - Val Loss: 0.7571, Val Accuracy: 0.7800
# Epoch [39/50] Group Metrics:
#   Group 1 - Train Loss: 2.7476, Train Accuracy: 0.2850
#   Group 1 - Val Loss: 2.7514, Val Accuracy: 0.2836
#   Group 2 - Train Loss: 0.6252, Train Accuracy: 0.8332
#   Group 2 - Val Loss: 0.8005, Val Accuracy: 0.7660
#   Group 3 - Train Loss: 0.5975, Train Accuracy: 0.8424
#   Group 3 - Val Loss: 0.7527, Val Accuracy: 0.7815
# Epoch [40/50] Group Metrics:
#   Group 1 - Train Loss: 2.7333, Train Accuracy: 0.2853
#   Group 1 - Val Loss: 2.7372, Val Accuracy: 0.2833
#   Group 2 - Train Loss: 0.6169, Train Accuracy: 0.8353
#   Group 2 - Val Loss: 0.7943, Val Accuracy: 0.7666
#   Group 3 - Train Loss: 0.5901, Train Accuracy: 0.8449
#   Group 3 - Val Loss: 0.7485, Val Accuracy: 0.7818
# Epoch [41/50] Group Metrics:
#   Group 1 - Train Loss: 2.7194, Train Accuracy: 0.2853
#   Group 1 - Val Loss: 2.7234, Val Accuracy: 0.2823
#   Group 2 - Train Loss: 0.6089, Train Accuracy: 0.8376
#   Group 2 - Val Loss: 0.7884, Val Accuracy: 0.7672
#   Group 3 - Train Loss: 0.5829, Train Accuracy: 0.8466
#   Group 3 - Val Loss: 0.7445, Val Accuracy: 0.7828
# Epoch [42/50] Group Metrics:
#   Group 1 - Train Loss: 2.7060, Train Accuracy: 0.2852
#   Group 1 - Val Loss: 2.7100, Val Accuracy: 0.2822
#   Group 2 - Train Loss: 0.6012, Train Accuracy: 0.8397
#   Group 2 - Val Loss: 0.7827, Val Accuracy: 0.7718
#   Group 3 - Train Loss: 0.5760, Train Accuracy: 0.8482
#   Group 3 - Val Loss: 0.7407, Val Accuracy: 0.7832
# Epoch [43/50] Group Metrics:
#   Group 1 - Train Loss: 2.6929, Train Accuracy: 0.2845
#   Group 1 - Val Loss: 2.6970, Val Accuracy: 0.2822
#   Group 2 - Train Loss: 0.5938, Train Accuracy: 0.8420
#   Group 2 - Val Loss: 0.7773, Val Accuracy: 0.7736
#   Group 3 - Train Loss: 0.5693, Train Accuracy: 0.8496
#   Group 3 - Val Loss: 0.7371, Val Accuracy: 0.7835
# Epoch [44/50] Group Metrics:
#   Group 1 - Train Loss: 2.6802, Train Accuracy: 0.2848
#   Group 1 - Val Loss: 2.6844, Val Accuracy: 0.2822
#   Group 2 - Train Loss: 0.5865, Train Accuracy: 0.8447
#   Group 2 - Val Loss: 0.7721, Val Accuracy: 0.7742
#   Group 3 - Train Loss: 0.5629, Train Accuracy: 0.8530
#   Group 3 - Val Loss: 0.7337, Val Accuracy: 0.7843
# Epoch [45/50] Group Metrics:
#   Group 1 - Train Loss: 2.6679, Train Accuracy: 0.2849
#   Group 1 - Val Loss: 2.6722, Val Accuracy: 0.2826
#   Group 2 - Train Loss: 0.5796, Train Accuracy: 0.8447
#   Group 2 - Val Loss: 0.7671, Val Accuracy: 0.7748
#   Group 3 - Train Loss: 0.5566, Train Accuracy: 0.8545
#   Group 3 - Val Loss: 0.7305, Val Accuracy: 0.7845
# Epoch [46/50] Group Metrics:
#   Group 1 - Train Loss: 2.6560, Train Accuracy: 0.2852
#   Group 1 - Val Loss: 2.6603, Val Accuracy: 0.2825
#   Group 2 - Train Loss: 0.5728, Train Accuracy: 0.8453
#   Group 2 - Val Loss: 0.7624, Val Accuracy: 0.7765
#   Group 3 - Train Loss: 0.5505, Train Accuracy: 0.8562
#   Group 3 - Val Loss: 0.7274, Val Accuracy: 0.7852
# Epoch [47/50] Group Metrics:
#   Group 1 - Train Loss: 2.6444, Train Accuracy: 0.2845
#   Group 1 - Val Loss: 2.6488, Val Accuracy: 0.2834
#   Group 2 - Train Loss: 0.5662, Train Accuracy: 0.8476
#   Group 2 - Val Loss: 0.7578, Val Accuracy: 0.7765
#   Group 3 - Train Loss: 0.5446, Train Accuracy: 0.8577
#   Group 3 - Val Loss: 0.7244, Val Accuracy: 0.7853
# Epoch [48/50] Group Metrics:
#   Group 1 - Train Loss: 2.6331, Train Accuracy: 0.2842
#   Group 1 - Val Loss: 2.6376, Val Accuracy: 0.2830
#   Group 2 - Train Loss: 0.5598, Train Accuracy: 0.8493
#   Group 2 - Val Loss: 0.7534, Val Accuracy: 0.7789
#   Group 3 - Train Loss: 0.5388, Train Accuracy: 0.8598
#   Group 3 - Val Loss: 0.7216, Val Accuracy: 0.7862
# Epoch [49/50] Group Metrics:
#   Group 1 - Train Loss: 2.6222, Train Accuracy: 0.2843
#   Group 1 - Val Loss: 2.6268, Val Accuracy: 0.2824
#   Group 2 - Train Loss: 0.5537, Train Accuracy: 0.8523
#   Group 2 - Val Loss: 0.7492, Val Accuracy: 0.7794
#   Group 3 - Train Loss: 0.5332, Train Accuracy: 0.8616
#   Group 3 - Val Loss: 0.7189, Val Accuracy: 0.7860
# Epoch [50/50] Group Metrics:
#   Group 1 - Train Loss: 2.6117, Train Accuracy: 0.2845
#   Group 1 - Val Loss: 2.6163, Val Accuracy: 0.2819
#   Group 2 - Train Loss: 0.5476, Train Accuracy: 0.8552
#   Group 2 - Val Loss: 0.7452, Val Accuracy: 0.7795
#   Group 3 - Train Loss: 0.5278, Train Accuracy: 0.8628
#   Group 3 - Val Loss: 0.7164, Val Accuracy: 0.7863

# %%
# Convert metrics to numpy arrays for easy manipulation
group_train_loss_histories = {k: np.array(v) for k, v in group_train_loss_histories.items()}
group_train_accuracy_histories = {k: np.array(v) for k, v in group_train_accuracy_histories.items()}
group_val_loss_histories = {k: np.array(v) for k, v in group_val_loss_histories.items()}
group_val_accuracy_histories = {k: np.array(v) for k, v in group_val_accuracy_histories.items()}

# Calculate means and standard deviations for each group
group_train_loss_mean = {k: v.mean(axis=1) for k, v in group_train_loss_histories.items()}
group_train_loss_std = {k: v.std(axis=1) for k, v in group_train_loss_histories.items()}
group_val_loss_mean = {k: v.mean(axis=1) for k, v in group_val_loss_histories.items()}
group_val_loss_std = {k: v.std(axis=1) for k, v in group_val_loss_histories.items()}

group_train_acc_mean = {k: v.mean(axis=1) for k, v in group_train_accuracy_histories.items()}
group_train_acc_std = {k: v.std(axis=1) for k, v in group_train_accuracy_histories.items()}
group_val_acc_mean = {k: v.mean(axis=1) for k, v in group_val_accuracy_histories.items()}
group_val_acc_std = {k: v.std(axis=1) for k, v in group_val_accuracy_histories.items()}

# Plot metrics for each group
plt.figure(figsize=(18, 12))

for group in [1, 2, 3]:
    # Loss plot
    plt.subplot(3, 2, (group - 1) * 2 + 1)
    plt.plot(range(1, num_epochs + 1), group_train_loss_mean[group], label=f"Group {group} Train Loss", color="blue")
    plt.fill_between(range(1, num_epochs + 1), 
                     group_train_loss_mean[group] - group_train_loss_std[group], 
                     group_train_loss_mean[group] + group_train_loss_std[group], 
                     color="blue", alpha=0.2)
    plt.plot(range(1, num_epochs + 1), group_val_loss_mean[group], label=f"Group {group} Validation Loss", color="red")
    plt.fill_between(range(1, num_epochs + 1), 
                     group_val_loss_mean[group] - group_val_loss_std[group], 
                     group_val_loss_mean[group] + group_val_loss_std[group], 
                     color="red", alpha=0.2)
    plt.title(f"Group {group} Loss over Epochs (with Std Dev)")
    plt.xlabel("Epoch")
    plt.ylabel("Loss")
    plt.legend()
    plt.grid()

    # Accuracy plot
    plt.subplot(3, 2, (group - 1) * 2 + 2)
    plt.plot(range(1, num_epochs + 1), group_train_acc_mean[group], label=f"Group {group} Train Accuracy", color="orange")
    plt.fill_between(range(1, num_epochs + 1), 
                     group_train_acc_mean[group] - group_train_acc_std[group], 
                     group_train_acc_mean[group] + group_train_acc_std[group], 
                     color="orange", alpha=0.2)
    plt.plot(range(1, num_epochs + 1), group_val_acc_mean[group], label=f"Group {group} Validation Accuracy", color="green")
    plt.fill_between(range(1, num_epochs + 1), 
                     group_val_acc_mean[group] - group_val_acc_std[group], 
                     group_val_acc_mean[group] + group_val_acc_std[group], 
                     color="green", alpha=0.2)
    plt.title(f"Group {group} Accuracy over Epochs (with Std Dev)")
    plt.xlabel("Epoch")
    plt.ylabel("Accuracy")
    plt.legend()
    plt.grid()

plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[15], line 35
#      32 for group in [1, 2, 3]:
#      33     # Loss plot
#      34     plt.subplot(3, 2, (group - 1) * 2 + 1)
# ---> 35     plt.plot(range(1, num_epochs + 1), group_train_loss_mean[group], label=f"Group {group} Train Loss", color="blue")
#      36     plt.fill_between(range(1, num_epochs + 1),
#      37                      group_train_loss_mean[group] - group_train_loss_std[group],
#      38                      group_train_loss_mean[group] + group_train_loss_std[group],
#      39                      color="blue", alpha=0.2)
#      40     plt.plot(range(1, num_epochs + 1), group_val_loss_mean[group], label=f"Group {group} Validation Loss", color="red")
#
# File ~\AppData\Local\anaconda3\envs\fmtl_sheaves\lib\site-packages\matplotlib\pyplot.py:3794, in plot(scalex, scaley, data, *args, **kwargs)
#    3786 @_copy_docstring_and_deprecators(Axes.plot)
#    3787 def plot(
#    3788     *args: float | ArrayLike | str,
#    (...)
#    3792     **kwargs,
#    3793 ) -> list[Line2D]:
# -> 3794     return gca().plot(
#    3795         *args,
#    3796         scalex=scalex,
#    3797         scaley=scaley,
#    3798         **({"data": data} if data is not None else {}),
#    3799         **kwargs,
#    3800     )
#
# File ~\AppData\Local\anaconda3\envs\fmtl_sheaves\lib\site-packages\matplotlib\axes\_axes.py:1779, in Axes.plot(self, scalex, scaley, data, *args, **kwargs)
#    1536 """
#    1537 Plot y versus x as lines and/or markers.
#    1538
#    (...)
#    1776 (``'green'``) or hex strings (``'#008000'``).
#    1777 """
#    1778 kwargs = cbook.normalize_kwargs(kwargs, mlines.Line2D)
# -> 1779 lines = [*self._get_lines(self, *args, data=data, **kwargs)]
#    1780 for line in lines:
#    1781     self.add_line(line)
#
# File ~\AppData\Local\anaconda3\envs\fmtl_sheaves\lib\site-packages\matplotlib\axes\_base.py:296, in _process_plot_var_args.__call__(self, axes, data, *args, **kwargs)
#     294     this += args[0],
#     295     args = args[1:]
# --> 296 yield from self._plot_args(
#     297     axes, this, kwargs, ambiguous_fmt_datakey=ambiguous_fmt_datakey)
#
# File ~\AppData\Local\anaconda3\envs\fmtl_sheaves\lib\site-packages\matplotlib\axes\_base.py:486, in _process_plot_var_args._plot_args(self, axes, tup, kwargs, return_kwargs, ambiguous_fmt_datakey)
#     483     axes.yaxis.update_units(y)
#     485 if x.shape[0] != y.shape[0]:
# --> 486     raise ValueError(f"x and y must have same first dimension, but "
#     487                      f"have shapes {x.shape} and {y.shape}")
#     488 if x.ndim > 2 or y.ndim > 2:
#     489     raise ValueError(f"x and y can be no greater than 2D, but have "
#     490                      f"shapes {x.shape} and {y.shape}")
#
# ValueError: x and y must have same first dimension, but have shapes (50,) and (1,)

# %%
# Track metrics across all users
test_loss_histories = []
test_accuracy_histories = []
#train_loss_histories = []
#train_accuracy_histories = []

# Testing loop for all users
user_test_losses = []
user_test_accuracies = []
user_train_losses = []
user_train_accuracies = []

with torch.no_grad():  # Disable gradient computation for testing
    for user_id, model in enumerate(classifiers):
        model.eval()

        # Test metrics
        epoch_test_loss = 0.0
        correct_test_predictions = 0
        total_test_samples = 0

        # Train metrics (optional, for post-training evaluation on training data)
        epoch_train_loss = 0.0
        correct_train_predictions = 0
        total_train_samples = 0

        # Evaluate on test set
        for X_batch, y_batch in test_loaders[user_id]:  # Assuming test_loader is a list of loaders for users
            #X_batch, y_batch = X_batch.cuda(), y_batch.cuda()
            outputs = model(X_batch)
            loss = criterion(outputs, y_batch)

            epoch_test_loss += loss.item()
            _, predicted = torch.max(outputs, dim=1)
            correct_test_predictions += (predicted == y_batch).sum().item()
            total_test_samples += y_batch.size(0)
        # Evaluate on training set
        for X_batch, y_batch in train_loaders[user_id]:  # Assuming train_loader is available per user
            #X_batch, y_batch = X_batch.cuda(), y_batch.cuda()
            outputs = model(X_batch)
            loss = criterion(outputs, y_batch)

            epoch_train_loss += loss.item()
            _, predicted = torch.max(outputs, dim=1)
            correct_train_predictions += (predicted == y_batch).sum().item()
            total_train_samples += y_batch.size(0)

        # Calculate averages
        avg_test_loss = epoch_test_loss / len(test_loaders[user_id])
        test_accuracy = correct_test_predictions / total_test_samples

        avg_train_loss = epoch_train_loss / len(train_loaders[user_id])
        train_accuracy = correct_train_predictions / total_train_samples

        # Store metrics for each user
        user_test_losses.append(avg_test_loss)
        user_test_accuracies.append(test_accuracy)
        user_train_losses.append(avg_train_loss)
        user_train_accuracies.append(train_accuracy)


# Store the average metrics across all users
test_loss_histories.append(user_test_losses)
test_accuracy_histories.append(user_test_accuracies)
#train_loss_histories.append(user_train_losses)
#train_accuracy_histories.append(user_train_accuracies)

# Print average metrics
print(f"\nAverage Test Loss: {np.mean(user_test_losses):.4f}, Average Test Accuracy: {np.mean(user_test_accuracies):.4f}")
print(f"\nAverage Train Loss: {np.mean(user_train_losses):.4f}, Average Train Accuracy: {np.mean(user_train_accuracies):.4f}")

# Convert metrics to numpy arrays for plotting
test_loss_histories = np.array(test_loss_histories)
test_accuracy_histories = np.array(test_accuracy_histories)
train_loss_histories = np.array(train_loss_histories)
train_accuracy_histories = np.array(train_accuracy_histories)

# Calculate means and standard deviations
test_loss_mean = test_loss_histories.mean(axis=1)
test_loss_std = test_loss_histories.std(axis=1)
test_acc_mean = test_accuracy_histories.mean(axis=1)
test_acc_std = test_accuracy_histories.std(axis=1)

train_loss_mean = train_loss_histories.mean(axis=1)
train_loss_std = train_loss_histories.std(axis=1)
train_acc_mean = train_accuracy_histories.mean(axis=1)
train_acc_std = train_accuracy_histories.std(axis=1)

# Box plot for final train and test loss
plt.figure(figsize=(12, 6))

# Loss box plot
plt.subplot(1, 2, 1)
plt.boxplot([train_loss_histories[-1], test_loss_histories[-1]], labels=["Train Loss", "Test Loss"])
plt.title("Loss Distribution Across Users")
plt.ylabel("Loss")
plt.grid()

# Accuracy box plot
plt.subplot(1, 2, 2)
plt.boxplot([train_accuracy_histories[-1], test_accuracy_histories[-1]], labels=["Train Accuracy", "Test Accuracy"])
plt.title("Accuracy Distribution Across Users")
plt.ylabel("Accuracy")
plt.ylim([0, 1])  # Ensure y-axis is between 0 and 1 for accuracy
plt.grid()

plt.tight_layout()
plt.show()

# %%
# Images only
'''
Test Loss: 0.4364, Test Accuracy: 0.8521

Train Loss: 0.4047, Train Accuracy: 0.8687

'''

# %%
import json

metrics = {
    "train_loss_histories": train_loss_histories.tolist(),
    "train_accuracy_histories": train_accuracy_histories.tolist(),
    "val_loss_histories": val_loss_histories.tolist(),
    "val_accuracy_histories": val_accuracy_histories.tolist(),
    "test_loss_histories": test_loss_histories.tolist(),
    "test_accuracy_histories": test_accuracy_histories.tolist(),
}

with open("metrics.json", "w") as f:
    json.dump(metrics, f)
print("Metrics saved to metrics.json")

# %%
# Load metrics from JSON file
with open("metrics.json", "r") as f:
    metrics = json.load(f)

# Convert lists back to numpy arrays
train_loss_histories = np.array(metrics["train_loss_histories"])
train_accuracy_histories = np.array(metrics["train_accuracy_histories"])
val_loss_histories = np.array(metrics["val_loss_histories"])
val_accuracy_histories = np.array(metrics["val_accuracy_histories"])
test_loss_histories = np.array(metrics["test_loss_histories"])
test_accuracy_histories = np.array(metrics["test_accuracy_histories"])

# Print shapes to confirm loading
print("Train Loss Histories Shape:", train_loss_histories.shape)
print("Train Accuracy Histories Shape:", train_accuracy_histories.shape)
print("Validation Loss Histories Shape:", val_loss_histories.shape)
print("Validation Accuracy Histories Shape:", val_accuracy_histories.shape)
print("Test Loss Histories Shape:", test_loss_histories.shape)
print("Test Accuracy Histories Shape:", test_accuracy_histories.shape)
