# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader
import pandas as pd
from sklearn.preprocessing import MinMaxScaler
import matplotlib.pyplot as plt
import numpy as np
import random
import os
import seaborn as sns


# Set random seed for reproducibility
seed = 42  # You can choose any integer here

# Set seed for NumPy
np.random.seed(seed)

# Set seed for Python's random module
random.seed(seed)

# Set seed for PyTorch
torch.manual_seed(seed)

# For GPU (if using CUDA)
if torch.cuda.is_available():
    torch.cuda.manual_seed(seed)
    torch.cuda.manual_seed_all(seed)  # For multi-GPU setups

# Set deterministic behavior for reproducibility in case of CUDA operations
torch.backends.cudnn.deterministic = True
torch.backends.cudnn.benchmark = False




dataset_dir = "datasets/no_comm/"

# Directory containing the saved CSV files
output_dir = dataset_dir + "training_outputs/"

# Load one of the CSV files for EDA (e.g., user_0_outputs.csv)
csv_file = os.path.join(output_dir, "user_1_outputs.csv")
df = pd.read_csv(csv_file)

# Quick overview of the data
print("Data Overview:")
print(df.head())
print("\nData Summary:")
print(df.describe())

# Check for missing values
print("\nMissing Values:")
print(df.isnull().sum())

# Distribution of the target variable (y)
sns.countplot(x="y", data=df)
plt.title("Target Variable Distribution")
plt.show()

# Correlation heatmap of features
correlation_matrix = df.iloc[:, :-1].corr()  # Exclude the target column
plt.figure(figsize=(12, 10))
sns.heatmap(correlation_matrix, cmap="coolwarm", center=0)
plt.title("Feature Correlation Heatmap")
plt.show()
# Out:
# Data Overview:
#    Feature_1  Feature_2  Feature_3  Feature_4  Feature_5  Feature_6  \
# 0        0.0   0.000000   2.427324        0.0   0.000000   0.000000
# 1        0.0   0.427090   1.163418        0.0   0.178713   0.413166
# 2        0.0   0.000000   2.095180        0.0   0.000000   0.000000
# 3        0.0   0.157136   3.609239        0.0   0.000000   0.182261
# 4        0.0   2.231131   1.165798        0.0   0.981523   2.230717
#
#    Feature_7  Feature_8  Feature_9  Feature_10  ...  Feature_248  Feature_249  \
# 0   0.000000   0.763855   0.000000    0.000000  ...    -1.592660    -1.397809
# 1   0.175270   0.794933   0.627405    0.461691  ...    -1.962592    -1.452488
# 2   0.000000   0.670203   0.000000    0.000000  ...    -1.373927    -0.924505
# 3   0.009697   1.396447   0.057795    0.213247  ...     0.654818    -0.822407
# 4   0.809156   2.806526   3.018401    2.545619  ...     3.052901     1.972201
#
#    Feature_250  Feature_251  Feature_252  Feature_253  Feature_254  \
# 0     0.023165     1.121107    -0.851685    -0.757659    -0.060895
# 1     0.039978     1.459249    -1.594860    -0.972583    -0.264299
# 2     1.852382     0.852163     1.165901     1.097879     0.008920
# 3    -0.712063    -2.135010     2.392082    -0.223696     0.837794
# 4    -1.520203    -3.621065    -0.730071    -2.076510    -1.538100
#
#    Feature_255  Feature_256     y
# 0    -0.482635    -1.982693  19.0
# 1    -0.249734    -1.615554  19.0
# 2    -1.821918    -1.379264  22.0
# 3    -1.848053    -0.666927  17.0
# 4     0.353249     2.013438  11.0
#
# [5 rows x 257 columns]
#
# Data Summary:
#        Feature_1    Feature_2    Feature_3    Feature_4    Feature_5  \
# count     1729.0  1729.000000  1729.000000  1729.000000  1729.000000
# mean         0.0     0.735354     2.170556     0.015320     0.285868
# std          0.0     0.720206     1.321380     0.045479     0.347628
# min          0.0     0.000000     0.000000     0.000000     0.000000
# 25%          0.0     0.151771     1.242436     0.000000     0.000000
# 50%          0.0     0.523094     1.978576     0.000000     0.171081
# 75%          0.0     1.067831     3.249154     0.000000     0.451306
# max          0.0     3.388823     5.613220     0.204794     1.508188
#
#          Feature_6    Feature_7    Feature_8    Feature_9   Feature_10  ...  \
# count  1729.000000  1729.000000  1729.000000  1729.000000  1729.000000  ...
# mean      0.738261     0.261748     1.494263     0.976723     0.841353  ...
# std       0.713494     0.272633     0.653327     1.004861     0.814570  ...
# min       0.000000     0.000000     0.298954     0.000000     0.000000  ...
# 25%       0.181926     0.022026     1.022588     0.095390     0.213247  ...
# 50%       0.523857     0.186780     1.407066     0.695694     0.594108  ...
# 75%       1.082329     0.390076     1.814744     1.461713     1.239956  ...
# max       3.387750     1.233443     4.201824     4.600913     3.881645  ...
#
#        Feature_248  Feature_249  Feature_250  Feature_251  Feature_252  \
# count  1729.000000  1729.000000  1729.000000  1729.000000  1729.000000
# mean      0.666921    -0.300697    -0.376396    -1.279916     0.166535
# std       1.504751     1.216515     1.593494     1.451501     1.603865
# min      -4.751606    -4.122119    -3.894967    -5.161763    -3.717653
# 25%      -0.483589    -0.877740    -1.484418    -2.173479    -1.180783
# 50%       0.984675    -0.433756    -0.603738    -1.611854     0.172930
# 75%       1.756572     0.134825     0.177452    -0.717330     1.508765
# max       3.566294     3.326209     5.393246     2.273761     4.260859
#
#        Feature_253  Feature_254  Feature_255  Feature_256            y
# count  1729.000000  1729.000000  1729.000000  1729.000000  1729.000000
# mean     -0.789709    -0.338264    -0.520803     0.413280    15.186235
# std       1.047715     0.882098     1.004738     1.493140     5.019063
# min      -3.140517    -2.953035    -2.981000    -2.401864     2.000000
# 25%      -1.457134    -0.951254    -1.417228    -0.627088    14.000000
# 50%      -0.604308    -0.470251    -0.560128     0.020059    16.000000
# 75%      -0.253853     0.555784     0.267075     1.596923    17.000000
# max       2.929004     1.255433     1.526845     5.069533    30.000000
#
# [8 rows x 257 columns]
#
# Missing Values:
# Feature_1      0
# Feature_2      0
# Feature_3      0
# Feature_4      0
# Feature_5      0
#               ..
# Feature_253    0
# Feature_254    0
# Feature_255    0
# Feature_256    0
# y              0
# Length: 257, dtype: int64

# %%
no_users = 20
# Define the Multinomial Logistic Regression model
class MultinomialLogisticRegression(nn.Module):
    def __init__(self, input_size, num_classes):
        super(MultinomialLogisticRegression, self).__init__()
        self.linear = nn.Linear(input_size, num_classes)

    def forward(self, x):
        return self.linear(x)

# Custom dataset to load the data from CSV
class CustomDataset(Dataset):
    def __init__(self,  csv_file, modality=["pos_height", "images"], scaler=None, zero_prob=0.5):
        self.data = pd.read_csv(csv_file)
        if "images" in modality and "pos_height" in modality:
            self.X = self.data.iloc[:, :-1].values  # Features
            mask = np.ones(self.X.shape)  # Initialize mask
            mask[:, 128:-1] = np.random.choice([0, 1], size=self.X[:, 128:-1].shape, p=[zero_prob, 1 - zero_prob])
            self.X *= mask  # Apply mask to zero out features
        elif "images" in modality:
            self.X = self.data.iloc[:, 128:-1].values  # Features
            mask = np.random.choice([0, 1], size=self.X.shape, p=[zero_prob, 1 - zero_prob])  # Create a binary mask
            self.X *= mask  # Apply mask
        else:
            self.X = self.data.iloc[:, 0:128].values  # Features

        self.y = self.data.iloc[:, -1].values   # Labels

        # If a scaler is provided, use it to transform the features
        if scaler:
            self.X = scaler.transform(self.X)
        else:
            # Fit the scaler on the training data and transform
            self.scaler = MinMaxScaler(feature_range=(-1, 1))
            self.X = self.scaler.fit_transform(self.X)

    def __len__(self):
        return len(self.data)

    def __getitem__(self, idx):
        X = torch.tensor(self.X[idx], dtype=torch.float32)
        y = torch.tensor(self.y[idx], dtype=torch.long)  # Use long for classification targets
        return X, y

# %%
# Configuration
no_users = 20  # Example: Number of users
available_modalities = ["pos_height", "images"]
modality_size = {"pos_height": 128, "images": 128}
group_definitions = {
    1: ["pos_height"],        # Group 1: Only pos_height
    2: ["images"],            # Group 2: Only images
    3: ["pos_height", "images"]  # Group 3: Both modalities
}

# Assign each user to a group randomly
user_groups = [random.choice([1, 2, 3]) for _ in range(no_users)]

# Assign modalities to users based on their group
user_modalities = [group_definitions[group] for group in user_groups]

# Compute output sizes for each user based on their modalities
output_sizes = [sum(modality_size[modality] for modality in user_modality) for user_modality in user_modalities]

# Store models (placeholders for actual models)
all_models = []

# Example output (for verification)
print(f"User Groups: {user_groups[:10]}")  # Show first 10 users' groups
print(f"User Modalities: {user_modalities[:10]}")  # Show first 10 users' modalities
print(f"Output Sizes: {output_sizes[:10]}")  # Show first 10 users' output sizes
# Out:
# User Groups: [3, 1, 1, 3, 2, 1, 1, 1, 3, 1]
# User Modalities: [['pos_height', 'images'], ['pos_height'], ['pos_height'], ['pos_height', 'images'], ['images'], ['pos_height'], ['pos_height'], ['pos_height'], ['pos_height', 'images'], ['pos_height']]
# Output Sizes: [256, 128, 128, 256, 128, 128, 128, 128, 256, 128]

# %%
no_users = 20
# List to store DataLoader objects for each user
train_loaders = []
val_loaders = []
test_loaders = []
scaler = None
# Loop over each user
zero_prob=0.9
dataset_dir = "datasets/no_comm/"
for user_idx in range(no_users):
    scaler = None
    # Define file paths for each user dynamically
    train_file = dataset_dir + f"training_outputs/user_{user_idx}_outputs.csv"
    val_file = dataset_dir + f"val_outputs/user_{user_idx}_outputs.csv"
    test_file = dataset_dir + f"test_outputs/user_{user_idx}_outputs.csv"

    # Load training data and fit the scaler on it (only once for each user)
    train_data = pd.read_csv(train_file)
    
    if scaler is None:
        scaler = MinMaxScaler(feature_range=(-1, 1))
        # Fit the scaler on the first user's training data
        if "images" in user_modalities[user_idx] and "pos_height" in user_modalities[user_idx]:
            temp = train_data.iloc[:, :-1].values  # Features
        elif "images" in user_modalities[user_idx]:
            temp = train_data.iloc[:, 128:-1].values  # Features
        else:
            temp = train_data.iloc[:, 0:128].values  # Features
        scaler.fit(temp)  # Fit scaler only on training features

    # Create datasets using the same scaler for all data
    train_dataset = CustomDataset(train_file, scaler=scaler, modality=user_modalities[user_idx], zero_prob=0.5)
    val_dataset = CustomDataset(val_file, scaler=scaler, modality=user_modalities[user_idx], zero_prob=0.5)
    test_dataset = CustomDataset(test_file, scaler=scaler, modality=user_modalities[user_idx], zero_prob=0.5)

    # Create DataLoader for training, validation, and testing for each user
    batch_size = 64
    train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=False)
    val_loader = DataLoader(val_dataset, batch_size=batch_size, shuffle=False)
    test_loader = DataLoader(test_dataset, batch_size=batch_size, shuffle=False)

    # Append each user's DataLoader to the respective lists
    train_loaders.append(train_loader)
    val_loaders.append(val_loader)
    test_loaders.append(test_loader)

# %%
# Initialize model, loss function, and optimizer for multiple users
input_sizes = output_sizes  # Number of features
num_classes = 64
classifiers = [MultinomialLogisticRegression(input_size, num_classes).cuda() for input_size, _ in zip(input_sizes, range(no_users))]
#classifiers = [MultinomialLogisticRegression(input_size, num_classes).cuda() for _ in range(no_users)]
optimizers = [optim.SGD(model.parameters(), lr=0.01) for model in classifiers]
criterion = nn.CrossEntropyLoss()
# Training parameters
num_epochs = 100

# %%
# Group assignments (use the previously defined user_groups)
group_losses = {1: [], 2: [], 3: []}
group_accuracies = {1: [], 2: [], 3: []}

# Initialize dictionaries to track metrics for each group
group_train_loss_histories = {1: [], 2: [], 3: []}
group_train_accuracy_histories = {1: [], 2: [], 3: []}
group_val_loss_histories = {1: [], 2: [], 3: []}
group_val_accuracy_histories = {1: [], 2: [], 3: []}

# Training loop
for epoch in range(num_epochs):
    # Temporary dictionaries for this epoch
    epoch_group_train_losses = {1: [], 2: [], 3: []}
    epoch_group_train_accuracies = {1: [], 2: [], 3: []}
    epoch_group_val_losses = {1: [], 2: [], 3: []}
    epoch_group_val_accuracies = {1: [], 2: [], 3: []}

    for user_id, (model, optimizer) in enumerate(zip(classifiers, optimizers)):
        group = user_groups[user_id]  # Get the group of the user

        # Training phase
        model.train()
        epoch_train_loss = 0.0
        correct_train_predictions = 0
        total_train_samples = 0

        for X_batch, y_batch in train_loaders[user_id]:
            X_batch, y_batch = X_batch.cuda(), y_batch.cuda()
            outputs = model(X_batch)
            loss = criterion(outputs, y_batch)

            optimizer.zero_grad()
            loss.backward()
            optimizer.step()

            epoch_train_loss += loss.item()
            _, predicted = torch.max(outputs, dim=1)
            correct_train_predictions += (predicted == y_batch).sum().item()
            total_train_samples += y_batch.size(0)

        avg_train_loss = epoch_train_loss / len(train_loaders[user_id])
        train_accuracy = correct_train_predictions / total_train_samples

        # Validation phase
        model.eval()
        epoch_val_loss = 0.0
        correct_val_predictions = 0
        total_val_samples = 0

        with torch.no_grad():
            for X_batch, y_batch in val_loaders[user_id]:
                X_batch, y_batch = X_batch.cuda(), y_batch.cuda()
                outputs = model(X_batch)
                loss = criterion(outputs, y_batch)

                epoch_val_loss += loss.item()
                _, predicted = torch.max(outputs, dim=1)
                correct_val_predictions += (predicted == y_batch).sum().item()
                total_val_samples += y_batch.size(0)

        avg_val_loss = epoch_val_loss / len(val_loaders[user_id])
        val_accuracy = correct_val_predictions / total_val_samples

        # Assign metrics to the respective group
        epoch_group_train_losses[group].append(avg_train_loss)
        epoch_group_train_accuracies[group].append(train_accuracy)
        epoch_group_val_losses[group].append(avg_val_loss)
        epoch_group_val_accuracies[group].append(val_accuracy)

    # Calculate averages for this epoch and store them
    for group in [1, 2, 3]:
        group_train_loss_histories[group].append(np.mean(epoch_group_train_losses[group]))
        group_train_accuracy_histories[group].append(np.mean(epoch_group_train_accuracies[group]))
        group_val_loss_histories[group].append(np.mean(epoch_group_val_losses[group]))
        group_val_accuracy_histories[group].append(np.mean(epoch_group_val_accuracies[group]))

    # Print group-wise average metrics
    print(f"Epoch [{epoch+1}/{num_epochs}] Group Metrics:")
    for group in [1, 2, 3]:
        print(f"  Group {group} - Train Loss: {np.mean(epoch_group_train_losses[group]):.4f}, Train Accuracy: {np.mean(epoch_group_train_accuracies[group]):.4f}")
        print(f"  Group {group} - Val Loss: {np.mean(epoch_group_val_losses[group]):.4f}, Val Accuracy: {np.mean(epoch_group_val_accuracies[group]):.4f}")
# Out:
# C:\Users\abdu_\AppData\Local\Temp\ipykernel_28552\3432764924.py:42: DeprecationWarning: an integer is required (got type numpy.float64).  Implicit conversion to integers using __int__ is deprecated, and may be removed in a future version of Python.
#   y = torch.tensor(self.y[idx], dtype=torch.long)  # Use long for classification targets
# Epoch [1/100] Group Metrics:
#   Group 1 - Train Loss: 4.0989, Train Accuracy: 0.0449
#   Group 1 - Val Loss: 3.9824, Val Accuracy: 0.0923
#   Group 2 - Train Loss: 3.9971, Train Accuracy: 0.1387
#   Group 2 - Val Loss: 3.8298, Val Accuracy: 0.2425
#   Group 3 - Train Loss: 3.9418, Train Accuracy: 0.1576
#   Group 3 - Val Loss: 3.6641, Val Accuracy: 0.2983
# Epoch [2/100] Group Metrics:
#   Group 1 - Train Loss: 3.8972, Train Accuracy: 0.1146
#   Group 1 - Val Loss: 3.8304, Val Accuracy: 0.1345
#   Group 2 - Train Loss: 3.6285, Train Accuracy: 0.2896
#   Group 2 - Val Loss: 3.5161, Val Accuracy: 0.2877
#   Group 3 - Train Loss: 3.4615, Train Accuracy: 0.3363
#   Group 3 - Val Loss: 3.2489, Val Accuracy: 0.3585
# Epoch [3/100] Group Metrics:
#   Group 1 - Train Loss: 3.7670, Train Accuracy: 0.1720
#   Group 1 - Val Loss: 3.7343, Val Accuracy: 0.1912
#   Group 2 - Train Loss: 3.3233, Train Accuracy: 0.3145
#   Group 2 - Val Loss: 3.2710, Val Accuracy: 0.3006
#   Group 3 - Train Loss: 3.0992, Train Accuracy: 0.3665
#   Group 3 - Val Loss: 2.9472, Val Accuracy: 0.3766
# Epoch [4/100] Group Metrics:
#   Group 1 - Train Loss: 3.6835, Train Accuracy: 0.2090
#   Group 1 - Val Loss: 3.6705, Val Accuracy: 0.2113
#   Group 2 - Train Loss: 3.0919, Train Accuracy: 0.3294
#   Group 2 - Val Loss: 3.0901, Val Accuracy: 0.3176
#   Group 3 - Train Loss: 2.8417, Train Accuracy: 0.3837
#   Group 3 - Val Loss: 2.7345, Val Accuracy: 0.3937
# Epoch [5/100] Group Metrics:
#   Group 1 - Train Loss: 3.6265, Train Accuracy: 0.2228
#   Group 1 - Val Loss: 3.6238, Val Accuracy: 0.2261
#   Group 2 - Train Loss: 2.9201, Train Accuracy: 0.3508
#   Group 2 - Val Loss: 2.9523, Val Accuracy: 0.3363
#   Group 3 - Train Loss: 2.6589, Train Accuracy: 0.3994
#   Group 3 - Val Loss: 2.5801, Val Accuracy: 0.4104
# Epoch [6/100] Group Metrics:
#   Group 1 - Train Loss: 3.5835, Train Accuracy: 0.2346
#   Group 1 - Val Loss: 3.5865, Val Accuracy: 0.2386
#   Group 2 - Train Loss: 2.7863, Train Accuracy: 0.3728
#   Group 2 - Val Loss: 2.8402, Val Accuracy: 0.3627
#   Group 3 - Train Loss: 2.5226, Train Accuracy: 0.4174
#   Group 3 - Val Loss: 2.4614, Val Accuracy: 0.4264
# Epoch [7/100] Group Metrics:
#   Group 1 - Train Loss: 3.5483, Train Accuracy: 0.2432
#   Group 1 - Val Loss: 3.5546, Val Accuracy: 0.2485
#   Group 2 - Train Loss: 2.6756, Train Accuracy: 0.3947
#   Group 2 - Val Loss: 2.7442, Val Accuracy: 0.3855
#   Group 3 - Train Loss: 2.4148, Train Accuracy: 0.4333
#   Group 3 - Val Loss: 2.3653, Val Accuracy: 0.4426
# Epoch [8/100] Group Metrics:
#   Group 1 - Train Loss: 3.5178, Train Accuracy: 0.2480
#   Group 1 - Val Loss: 3.5260, Val Accuracy: 0.2520
#   Group 2 - Train Loss: 2.5800, Train Accuracy: 0.4099
#   Group 2 - Val Loss: 2.6597, Val Accuracy: 0.3942
#   Group 3 - Train Loss: 2.3251, Train Accuracy: 0.4489
#   Group 3 - Val Loss: 2.2840, Val Accuracy: 0.4573
# Epoch [9/100] Group Metrics:
#   Group 1 - Train Loss: 3.4904, Train Accuracy: 0.2522
#   Group 1 - Val Loss: 3.4998, Val Accuracy: 0.2537
#   Group 2 - Train Loss: 2.4954, Train Accuracy: 0.4231
#   Group 2 - Val Loss: 2.5843, Val Accuracy: 0.4077
#   Group 3 - Train Loss: 2.2477, Train Accuracy: 0.4662
#   Group 3 - Val Loss: 2.2132, Val Accuracy: 0.4715
# Epoch [10/100] Group Metrics:
#   Group 1 - Train Loss: 3.4650, Train Accuracy: 0.2555
#   Group 1 - Val Loss: 3.4753, Val Accuracy: 0.2554
#   Group 2 - Train Loss: 2.4196, Train Accuracy: 0.4383
#   Group 2 - Val Loss: 2.5162, Val Accuracy: 0.4217
#   Group 3 - Train Loss: 2.1793, Train Accuracy: 0.4809
#   Group 3 - Val Loss: 2.1503, Val Accuracy: 0.4857
# Epoch [11/100] Group Metrics:
#   Group 1 - Train Loss: 3.4413, Train Accuracy: 0.2576
#   Group 1 - Val Loss: 3.4520, Val Accuracy: 0.2549
#   Group 2 - Train Loss: 2.3510, Train Accuracy: 0.4524
#   Group 2 - Val Loss: 2.4545, Val Accuracy: 0.4293
#   Group 3 - Train Loss: 2.1178, Train Accuracy: 0.4943
#   Group 3 - Val Loss: 2.0936, Val Accuracy: 0.4991
# Epoch [12/100] Group Metrics:
#   Group 1 - Train Loss: 3.4187, Train Accuracy: 0.2591
#   Group 1 - Val Loss: 3.4296, Val Accuracy: 0.2600
#   Group 2 - Train Loss: 2.2887, Train Accuracy: 0.4658
#   Group 2 - Val Loss: 2.3980, Val Accuracy: 0.4416
#   Group 3 - Train Loss: 2.0619, Train Accuracy: 0.5061
#   Group 3 - Val Loss: 2.0421, Val Accuracy: 0.5122
# Epoch [13/100] Group Metrics:
#   Group 1 - Train Loss: 3.3971, Train Accuracy: 0.2606
#   Group 1 - Val Loss: 3.4081, Val Accuracy: 0.2621
#   Group 2 - Train Loss: 2.2316, Train Accuracy: 0.4769
#   Group 2 - Val Loss: 2.3461, Val Accuracy: 0.4521
#   Group 3 - Train Loss: 2.0108, Train Accuracy: 0.5197
#   Group 3 - Val Loss: 1.9948, Val Accuracy: 0.5230
# Epoch [14/100] Group Metrics:
#   Group 1 - Train Loss: 3.3762, Train Accuracy: 0.2622
#   Group 1 - Val Loss: 3.3873, Val Accuracy: 0.2624
#   Group 2 - Train Loss: 2.1792, Train Accuracy: 0.4857
#   Group 2 - Val Loss: 2.2983, Val Accuracy: 0.4609
#   Group 3 - Train Loss: 1.9636, Train Accuracy: 0.5321
#   Group 3 - Val Loss: 1.9513, Val Accuracy: 0.5327
# Epoch [15/100] Group Metrics:
#   Group 1 - Train Loss: 3.3560, Train Accuracy: 0.2633
#   Group 1 - Val Loss: 3.3670, Val Accuracy: 0.2629
#   Group 2 - Train Loss: 2.1308, Train Accuracy: 0.4991
#   Group 2 - Val Loss: 2.2539, Val Accuracy: 0.4673
#   Group 3 - Train Loss: 1.9200, Train Accuracy: 0.5442
#   Group 3 - Val Loss: 1.9111, Val Accuracy: 0.5436
# Epoch [16/100] Group Metrics:
#   Group 1 - Train Loss: 3.3364, Train Accuracy: 0.2636
#   Group 1 - Val Loss: 3.3472, Val Accuracy: 0.2622
#   Group 2 - Train Loss: 2.0860, Train Accuracy: 0.5088
#   Group 2 - Val Loss: 2.2126, Val Accuracy: 0.4720
#   Group 3 - Train Loss: 1.8795, Train Accuracy: 0.5530
#   Group 3 - Val Loss: 1.8737, Val Accuracy: 0.5580
# Epoch [17/100] Group Metrics:
#   Group 1 - Train Loss: 3.3172, Train Accuracy: 0.2638
#   Group 1 - Val Loss: 3.3280, Val Accuracy: 0.2614
#   Group 2 - Train Loss: 2.0443, Train Accuracy: 0.5178
#   Group 2 - Val Loss: 2.1740, Val Accuracy: 0.4790
#   Group 3 - Train Loss: 1.8418, Train Accuracy: 0.5645
#   Group 3 - Val Loss: 1.8389, Val Accuracy: 0.5674
# Epoch [18/100] Group Metrics:
#   Group 1 - Train Loss: 3.2985, Train Accuracy: 0.2635
#   Group 1 - Val Loss: 3.3091, Val Accuracy: 0.2639
#   Group 2 - Train Loss: 2.0054, Train Accuracy: 0.5266
#   Group 2 - Val Loss: 2.1378, Val Accuracy: 0.4854
#   Group 3 - Train Loss: 1.8066, Train Accuracy: 0.5734
#   Group 3 - Val Loss: 1.8063, Val Accuracy: 0.5764
# Epoch [19/100] Group Metrics:
#   Group 1 - Train Loss: 3.2803, Train Accuracy: 0.2627
#   Group 1 - Val Loss: 3.2906, Val Accuracy: 0.2640
#   Group 2 - Train Loss: 1.9691, Train Accuracy: 0.5356
#   Group 2 - Val Loss: 2.1039, Val Accuracy: 0.4936
#   Group 3 - Train Loss: 1.7736, Train Accuracy: 0.5806
#   Group 3 - Val Loss: 1.7758, Val Accuracy: 0.5827
# Epoch [20/100] Group Metrics:
#   Group 1 - Train Loss: 3.2624, Train Accuracy: 0.2633
#   Group 1 - Val Loss: 3.2725, Val Accuracy: 0.2642
#   Group 2 - Train Loss: 1.9350, Train Accuracy: 0.5438
#   Group 2 - Val Loss: 2.0719, Val Accuracy: 0.4994
#   Group 3 - Train Loss: 1.7426, Train Accuracy: 0.5891
#   Group 3 - Val Loss: 1.7472, Val Accuracy: 0.5886
# Epoch [21/100] Group Metrics:
#   Group 1 - Train Loss: 3.2448, Train Accuracy: 0.2639
#   Group 1 - Val Loss: 3.2547, Val Accuracy: 0.2648
#   Group 2 - Train Loss: 1.9030, Train Accuracy: 0.5517
#   Group 2 - Val Loss: 2.0417, Val Accuracy: 0.5064
#   Group 3 - Train Loss: 1.7134, Train Accuracy: 0.5968
#   Group 3 - Val Loss: 1.7203, Val Accuracy: 0.5965
# Epoch [22/100] Group Metrics:
#   Group 1 - Train Loss: 3.2276, Train Accuracy: 0.2643
#   Group 1 - Val Loss: 3.2373, Val Accuracy: 0.2647
#   Group 2 - Train Loss: 1.8728, Train Accuracy: 0.5567
#   Group 2 - Val Loss: 2.0132, Val Accuracy: 0.5094
#   Group 3 - Train Loss: 1.6860, Train Accuracy: 0.6039
#   Group 3 - Val Loss: 1.6949, Val Accuracy: 0.6037
# Epoch [23/100] Group Metrics:
#   Group 1 - Train Loss: 3.2108, Train Accuracy: 0.2644
#   Group 1 - Val Loss: 3.2203, Val Accuracy: 0.2651
#   Group 2 - Train Loss: 1.8443, Train Accuracy: 0.5608
#   Group 2 - Val Loss: 1.9861, Val Accuracy: 0.5140
#   Group 3 - Train Loss: 1.6601, Train Accuracy: 0.6111
#   Group 3 - Val Loss: 1.6709, Val Accuracy: 0.6097
# Epoch [24/100] Group Metrics:
#   Group 1 - Train Loss: 3.1942, Train Accuracy: 0.2644
#   Group 1 - Val Loss: 3.2035, Val Accuracy: 0.2646
#   Group 2 - Train Loss: 1.8173, Train Accuracy: 0.5654
#   Group 2 - Val Loss: 1.9604, Val Accuracy: 0.5187
#   Group 3 - Train Loss: 1.6355, Train Accuracy: 0.6192
#   Group 3 - Val Loss: 1.6482, Val Accuracy: 0.6161
# Epoch [25/100] Group Metrics:
#   Group 1 - Train Loss: 3.1780, Train Accuracy: 0.2648
#   Group 1 - Val Loss: 3.1871, Val Accuracy: 0.2668
#   Group 2 - Train Loss: 1.7917, Train Accuracy: 0.5719
#   Group 2 - Val Loss: 1.9359, Val Accuracy: 0.5240
#   Group 3 - Train Loss: 1.6123, Train Accuracy: 0.6255
#   Group 3 - Val Loss: 1.6268, Val Accuracy: 0.6210
# Epoch [26/100] Group Metrics:
#   Group 1 - Train Loss: 3.1621, Train Accuracy: 0.2648
#   Group 1 - Val Loss: 3.1711, Val Accuracy: 0.2665
#   Group 2 - Train Loss: 1.7673, Train Accuracy: 0.5786
#   Group 2 - Val Loss: 1.9126, Val Accuracy: 0.5263
#   Group 3 - Train Loss: 1.5903, Train Accuracy: 0.6304
#   Group 3 - Val Loss: 1.6064, Val Accuracy: 0.6268
# Epoch [27/100] Group Metrics:
#   Group 1 - Train Loss: 3.1465, Train Accuracy: 0.2654
#   Group 1 - Val Loss: 3.1553, Val Accuracy: 0.2665
#   Group 2 - Train Loss: 1.7442, Train Accuracy: 0.5853
#   Group 2 - Val Loss: 1.8904, Val Accuracy: 0.5310
#   Group 3 - Train Loss: 1.5694, Train Accuracy: 0.6356
#   Group 3 - Val Loss: 1.5870, Val Accuracy: 0.6319
# Epoch [28/100] Group Metrics:
#   Group 1 - Train Loss: 3.1313, Train Accuracy: 0.2659
#   Group 1 - Val Loss: 3.1399, Val Accuracy: 0.2664
#   Group 2 - Train Loss: 1.7221, Train Accuracy: 0.5885
#   Group 2 - Val Loss: 1.8691, Val Accuracy: 0.5351
#   Group 3 - Train Loss: 1.5495, Train Accuracy: 0.6413
#   Group 3 - Val Loss: 1.5686, Val Accuracy: 0.6354
# Epoch [29/100] Group Metrics:
#   Group 1 - Train Loss: 3.1163, Train Accuracy: 0.2661
#   Group 1 - Val Loss: 3.1248, Val Accuracy: 0.2657
#   Group 2 - Train Loss: 1.7011, Train Accuracy: 0.5938
#   Group 2 - Val Loss: 1.8487, Val Accuracy: 0.5415
#   Group 3 - Train Loss: 1.5305, Train Accuracy: 0.6469
#   Group 3 - Val Loss: 1.5511, Val Accuracy: 0.6386
# Epoch [30/100] Group Metrics:
#   Group 1 - Train Loss: 3.1017, Train Accuracy: 0.2665
#   Group 1 - Val Loss: 3.1100, Val Accuracy: 0.2660
#   Group 2 - Train Loss: 1.6809, Train Accuracy: 0.5991
#   Group 2 - Val Loss: 1.8292, Val Accuracy: 0.5468
#   Group 3 - Train Loss: 1.5124, Train Accuracy: 0.6504
#   Group 3 - Val Loss: 1.5343, Val Accuracy: 0.6436
# Epoch [31/100] Group Metrics:
#   Group 1 - Train Loss: 3.0874, Train Accuracy: 0.2657
#   Group 1 - Val Loss: 3.0956, Val Accuracy: 0.2680
#   Group 2 - Train Loss: 1.6616, Train Accuracy: 0.6037
#   Group 2 - Val Loss: 1.8105, Val Accuracy: 0.5508
#   Group 3 - Train Loss: 1.4951, Train Accuracy: 0.6541
#   Group 3 - Val Loss: 1.5183, Val Accuracy: 0.6458
# Epoch [32/100] Group Metrics:
#   Group 1 - Train Loss: 3.0734, Train Accuracy: 0.2660
#   Group 1 - Val Loss: 3.0815, Val Accuracy: 0.2677
#   Group 2 - Train Loss: 1.6431, Train Accuracy: 0.6093
#   Group 2 - Val Loss: 1.7925, Val Accuracy: 0.5526
#   Group 3 - Train Loss: 1.4786, Train Accuracy: 0.6576
#   Group 3 - Val Loss: 1.5030, Val Accuracy: 0.6510
# Epoch [33/100] Group Metrics:
#   Group 1 - Train Loss: 3.0598, Train Accuracy: 0.2659
#   Group 1 - Val Loss: 3.0677, Val Accuracy: 0.2669
#   Group 2 - Train Loss: 1.6254, Train Accuracy: 0.6140
#   Group 2 - Val Loss: 1.7751, Val Accuracy: 0.5573
#   Group 3 - Train Loss: 1.4628, Train Accuracy: 0.6607
#   Group 3 - Val Loss: 1.4884, Val Accuracy: 0.6552
# Epoch [34/100] Group Metrics:
#   Group 1 - Train Loss: 3.0464, Train Accuracy: 0.2668
#   Group 1 - Val Loss: 3.0543, Val Accuracy: 0.2669
#   Group 2 - Train Loss: 1.6083, Train Accuracy: 0.6190
#   Group 2 - Val Loss: 1.7584, Val Accuracy: 0.5614
#   Group 3 - Train Loss: 1.4476, Train Accuracy: 0.6646
#   Group 3 - Val Loss: 1.4744, Val Accuracy: 0.6567
# Epoch [35/100] Group Metrics:
#   Group 1 - Train Loss: 3.0334, Train Accuracy: 0.2676
#   Group 1 - Val Loss: 3.0412, Val Accuracy: 0.2666
#   Group 2 - Train Loss: 1.5919, Train Accuracy: 0.6251
#   Group 2 - Val Loss: 1.7424, Val Accuracy: 0.5666
#   Group 3 - Train Loss: 1.4331, Train Accuracy: 0.6682
#   Group 3 - Val Loss: 1.4610, Val Accuracy: 0.6577
# Epoch [36/100] Group Metrics:
#   Group 1 - Train Loss: 3.0207, Train Accuracy: 0.2680
#   Group 1 - Val Loss: 3.0284, Val Accuracy: 0.2665
#   Group 2 - Train Loss: 1.5761, Train Accuracy: 0.6254
#   Group 2 - Val Loss: 1.7268, Val Accuracy: 0.5690
#   Group 3 - Train Loss: 1.4191, Train Accuracy: 0.6711
#   Group 3 - Val Loss: 1.4480, Val Accuracy: 0.6597
# Epoch [37/100] Group Metrics:
#   Group 1 - Train Loss: 3.0084, Train Accuracy: 0.2687
#   Group 1 - Val Loss: 3.0160, Val Accuracy: 0.2664
#   Group 2 - Train Loss: 1.5608, Train Accuracy: 0.6295
#   Group 2 - Val Loss: 1.7118, Val Accuracy: 0.5742
#   Group 3 - Train Loss: 1.4056, Train Accuracy: 0.6742
#   Group 3 - Val Loss: 1.4356, Val Accuracy: 0.6619
# Epoch [38/100] Group Metrics:
#   Group 1 - Train Loss: 2.9963, Train Accuracy: 0.2680
#   Group 1 - Val Loss: 3.0039, Val Accuracy: 0.2661
#   Group 2 - Train Loss: 1.5461, Train Accuracy: 0.6345
#   Group 2 - Val Loss: 1.6973, Val Accuracy: 0.5771
#   Group 3 - Train Loss: 1.3927, Train Accuracy: 0.6767
#   Group 3 - Val Loss: 1.4237, Val Accuracy: 0.6645
# Epoch [39/100] Group Metrics:
#   Group 1 - Train Loss: 2.9846, Train Accuracy: 0.2674
#   Group 1 - Val Loss: 2.9921, Val Accuracy: 0.2654
#   Group 2 - Train Loss: 1.5318, Train Accuracy: 0.6371
#   Group 2 - Val Loss: 1.6833, Val Accuracy: 0.5818
#   Group 3 - Train Loss: 1.3802, Train Accuracy: 0.6790
#   Group 3 - Val Loss: 1.4122, Val Accuracy: 0.6676
# Epoch [40/100] Group Metrics:
#   Group 1 - Train Loss: 2.9732, Train Accuracy: 0.2679
#   Group 1 - Val Loss: 2.9807, Val Accuracy: 0.2641
#   Group 2 - Train Loss: 1.5181, Train Accuracy: 0.6406
#   Group 2 - Val Loss: 1.6697, Val Accuracy: 0.5836
#   Group 3 - Train Loss: 1.3682, Train Accuracy: 0.6816
#   Group 3 - Val Loss: 1.4011, Val Accuracy: 0.6691
# Epoch [41/100] Group Metrics:
#   Group 1 - Train Loss: 2.9621, Train Accuracy: 0.2680
#   Group 1 - Val Loss: 2.9695, Val Accuracy: 0.2644
#   Group 2 - Train Loss: 1.5048, Train Accuracy: 0.6429
#   Group 2 - Val Loss: 1.6565, Val Accuracy: 0.5876
#   Group 3 - Train Loss: 1.3566, Train Accuracy: 0.6828
#   Group 3 - Val Loss: 1.3904, Val Accuracy: 0.6709
# Epoch [42/100] Group Metrics:
#   Group 1 - Train Loss: 2.9514, Train Accuracy: 0.2687
#   Group 1 - Val Loss: 2.9587, Val Accuracy: 0.2648
#   Group 2 - Train Loss: 1.4919, Train Accuracy: 0.6459
#   Group 2 - Val Loss: 1.6437, Val Accuracy: 0.5882
#   Group 3 - Train Loss: 1.3454, Train Accuracy: 0.6852
#   Group 3 - Val Loss: 1.3801, Val Accuracy: 0.6741
# Epoch [43/100] Group Metrics:
#   Group 1 - Train Loss: 2.9409, Train Accuracy: 0.2690
#   Group 1 - Val Loss: 2.9482, Val Accuracy: 0.2654
#   Group 2 - Train Loss: 1.4794, Train Accuracy: 0.6482
#   Group 2 - Val Loss: 1.6313, Val Accuracy: 0.5917
#   Group 3 - Train Loss: 1.3345, Train Accuracy: 0.6876
#   Group 3 - Val Loss: 1.3701, Val Accuracy: 0.6766
# Epoch [44/100] Group Metrics:
#   Group 1 - Train Loss: 2.9307, Train Accuracy: 0.2690
#   Group 1 - Val Loss: 2.9380, Val Accuracy: 0.2661
#   Group 2 - Train Loss: 1.4672, Train Accuracy: 0.6529
#   Group 2 - Val Loss: 1.6193, Val Accuracy: 0.5958
#   Group 3 - Train Loss: 1.3241, Train Accuracy: 0.6891
#   Group 3 - Val Loss: 1.3605, Val Accuracy: 0.6795
# Epoch [45/100] Group Metrics:
#   Group 1 - Train Loss: 2.9209, Train Accuracy: 0.2696
#   Group 1 - Val Loss: 2.9281, Val Accuracy: 0.2653
#   Group 2 - Train Loss: 1.4554, Train Accuracy: 0.6558
#   Group 2 - Val Loss: 1.6076, Val Accuracy: 0.5994
#   Group 3 - Train Loss: 1.3139, Train Accuracy: 0.6910
#   Group 3 - Val Loss: 1.3511, Val Accuracy: 0.6823
# Epoch [46/100] Group Metrics:
#   Group 1 - Train Loss: 2.9113, Train Accuracy: 0.2699
#   Group 1 - Val Loss: 2.9185, Val Accuracy: 0.2650
#   Group 2 - Train Loss: 1.4440, Train Accuracy: 0.6587
#   Group 2 - Val Loss: 1.5962, Val Accuracy: 0.6040
#   Group 3 - Train Loss: 1.3041, Train Accuracy: 0.6931
#   Group 3 - Val Loss: 1.3421, Val Accuracy: 0.6832
# Epoch [47/100] Group Metrics:
#   Group 1 - Train Loss: 2.9020, Train Accuracy: 0.2695
#   Group 1 - Val Loss: 2.9092, Val Accuracy: 0.2648
#   Group 2 - Train Loss: 1.4329, Train Accuracy: 0.6622
#   Group 2 - Val Loss: 1.5851, Val Accuracy: 0.6081
#   Group 3 - Train Loss: 1.2945, Train Accuracy: 0.6951
#   Group 3 - Val Loss: 1.3333, Val Accuracy: 0.6838
# Epoch [48/100] Group Metrics:
#   Group 1 - Train Loss: 2.8930, Train Accuracy: 0.2693
#   Group 1 - Val Loss: 2.9002, Val Accuracy: 0.2653
#   Group 2 - Train Loss: 1.4221, Train Accuracy: 0.6634
#   Group 2 - Val Loss: 1.5743, Val Accuracy: 0.6087
#   Group 3 - Train Loss: 1.2853, Train Accuracy: 0.6965
#   Group 3 - Val Loss: 1.3248, Val Accuracy: 0.6860
# Epoch [49/100] Group Metrics:
#   Group 1 - Train Loss: 2.8842, Train Accuracy: 0.2692
#   Group 1 - Val Loss: 2.8914, Val Accuracy: 0.2660
#   Group 2 - Train Loss: 1.4116, Train Accuracy: 0.6660
#   Group 2 - Val Loss: 1.5638, Val Accuracy: 0.6110
#   Group 3 - Train Loss: 1.2763, Train Accuracy: 0.6977
#   Group 3 - Val Loss: 1.3166, Val Accuracy: 0.6880
# Epoch [50/100] Group Metrics:
#   Group 1 - Train Loss: 2.8757, Train Accuracy: 0.2690
#   Group 1 - Val Loss: 2.8829, Val Accuracy: 0.2664
#   Group 2 - Train Loss: 1.4013, Train Accuracy: 0.6689
#   Group 2 - Val Loss: 1.5535, Val Accuracy: 0.6128
#   Group 3 - Train Loss: 1.2675, Train Accuracy: 0.6997
#   Group 3 - Val Loss: 1.3086, Val Accuracy: 0.6902
# Epoch [51/100] Group Metrics:
#   Group 1 - Train Loss: 2.8675, Train Accuracy: 0.2694
#   Group 1 - Val Loss: 2.8747, Val Accuracy: 0.2667
#   Group 2 - Train Loss: 1.3914, Train Accuracy: 0.6707
#   Group 2 - Val Loss: 1.5435, Val Accuracy: 0.6151
#   Group 3 - Train Loss: 1.2590, Train Accuracy: 0.7014
#   Group 3 - Val Loss: 1.3008, Val Accuracy: 0.6914
# Epoch [52/100] Group Metrics:
#   Group 1 - Train Loss: 2.8595, Train Accuracy: 0.2693
#   Group 1 - Val Loss: 2.8667, Val Accuracy: 0.2672
#   Group 2 - Train Loss: 1.3816, Train Accuracy: 0.6725
#   Group 2 - Val Loss: 1.5338, Val Accuracy: 0.6186
#   Group 3 - Train Loss: 1.2508, Train Accuracy: 0.7027
#   Group 3 - Val Loss: 1.2932, Val Accuracy: 0.6927
# Epoch [53/100] Group Metrics:
#   Group 1 - Train Loss: 2.8518, Train Accuracy: 0.2688
#   Group 1 - Val Loss: 2.8590, Val Accuracy: 0.2681
#   Group 2 - Train Loss: 1.3722, Train Accuracy: 0.6751
#   Group 2 - Val Loss: 1.5243, Val Accuracy: 0.6186
#   Group 3 - Train Loss: 1.2427, Train Accuracy: 0.7043
#   Group 3 - Val Loss: 1.2859, Val Accuracy: 0.6944
# Epoch [54/100] Group Metrics:
#   Group 1 - Train Loss: 2.8443, Train Accuracy: 0.2686
#   Group 1 - Val Loss: 2.8515, Val Accuracy: 0.2703
#   Group 2 - Train Loss: 1.3629, Train Accuracy: 0.6783
#   Group 2 - Val Loss: 1.5150, Val Accuracy: 0.6204
#   Group 3 - Train Loss: 1.2349, Train Accuracy: 0.7056
#   Group 3 - Val Loss: 1.2787, Val Accuracy: 0.6952
# Epoch [55/100] Group Metrics:
#   Group 1 - Train Loss: 2.8370, Train Accuracy: 0.2693
#   Group 1 - Val Loss: 2.8442, Val Accuracy: 0.2718
#   Group 2 - Train Loss: 1.3539, Train Accuracy: 0.6798
#   Group 2 - Val Loss: 1.5059, Val Accuracy: 0.6233
#   Group 3 - Train Loss: 1.2273, Train Accuracy: 0.7070
#   Group 3 - Val Loss: 1.2718, Val Accuracy: 0.6961
# Epoch [56/100] Group Metrics:
#   Group 1 - Train Loss: 2.8299, Train Accuracy: 0.2698
#   Group 1 - Val Loss: 2.8371, Val Accuracy: 0.2718
#   Group 2 - Train Loss: 1.3451, Train Accuracy: 0.6818
#   Group 2 - Val Loss: 1.4971, Val Accuracy: 0.6251
#   Group 3 - Train Loss: 1.2198, Train Accuracy: 0.7086
#   Group 3 - Val Loss: 1.2650, Val Accuracy: 0.6974
# Epoch [57/100] Group Metrics:
#   Group 1 - Train Loss: 2.8230, Train Accuracy: 0.2692
#   Group 1 - Val Loss: 2.8302, Val Accuracy: 0.2713
#   Group 2 - Train Loss: 1.3365, Train Accuracy: 0.6844
#   Group 2 - Val Loss: 1.4884, Val Accuracy: 0.6280
#   Group 3 - Train Loss: 1.2126, Train Accuracy: 0.7097
#   Group 3 - Val Loss: 1.2584, Val Accuracy: 0.6981
# Epoch [58/100] Group Metrics:
#   Group 1 - Train Loss: 2.8163, Train Accuracy: 0.2693
#   Group 1 - Val Loss: 2.8235, Val Accuracy: 0.2713
#   Group 2 - Train Loss: 1.3281, Train Accuracy: 0.6865
#   Group 2 - Val Loss: 1.4799, Val Accuracy: 0.6303
#   Group 3 - Train Loss: 1.2055, Train Accuracy: 0.7109
#   Group 3 - Val Loss: 1.2519, Val Accuracy: 0.6988
# Epoch [59/100] Group Metrics:
#   Group 1 - Train Loss: 2.8098, Train Accuracy: 0.2697
#   Group 1 - Val Loss: 2.8171, Val Accuracy: 0.2716
#   Group 2 - Train Loss: 1.3199, Train Accuracy: 0.6882
#   Group 2 - Val Loss: 1.4716, Val Accuracy: 0.6309
#   Group 3 - Train Loss: 1.1986, Train Accuracy: 0.7119
#   Group 3 - Val Loss: 1.2456, Val Accuracy: 0.7006
# Epoch [60/100] Group Metrics:
#   Group 1 - Train Loss: 2.8035, Train Accuracy: 0.2696
#   Group 1 - Val Loss: 2.8108, Val Accuracy: 0.2719
#   Group 2 - Train Loss: 1.3119, Train Accuracy: 0.6903
#   Group 2 - Val Loss: 1.4635, Val Accuracy: 0.6321
#   Group 3 - Train Loss: 1.1919, Train Accuracy: 0.7131
#   Group 3 - Val Loss: 1.2395, Val Accuracy: 0.7008
# Epoch [61/100] Group Metrics:
#   Group 1 - Train Loss: 2.7974, Train Accuracy: 0.2699
#   Group 1 - Val Loss: 2.8046, Val Accuracy: 0.2723
#   Group 2 - Train Loss: 1.3040, Train Accuracy: 0.6917
#   Group 2 - Val Loss: 1.4556, Val Accuracy: 0.6338
#   Group 3 - Train Loss: 1.1853, Train Accuracy: 0.7140
#   Group 3 - Val Loss: 1.2335, Val Accuracy: 0.7018
# Epoch [62/100] Group Metrics:
#   Group 1 - Train Loss: 2.7914, Train Accuracy: 0.2701
#   Group 1 - Val Loss: 2.7987, Val Accuracy: 0.2731
#   Group 2 - Train Loss: 1.2963, Train Accuracy: 0.6941
#   Group 2 - Val Loss: 1.4479, Val Accuracy: 0.6379
#   Group 3 - Train Loss: 1.1788, Train Accuracy: 0.7145
#   Group 3 - Val Loss: 1.2277, Val Accuracy: 0.7028
# Epoch [63/100] Group Metrics:
#   Group 1 - Train Loss: 2.7856, Train Accuracy: 0.2704
#   Group 1 - Val Loss: 2.7929, Val Accuracy: 0.2730
#   Group 2 - Train Loss: 1.2888, Train Accuracy: 0.6958
#   Group 2 - Val Loss: 1.4403, Val Accuracy: 0.6385
#   Group 3 - Train Loss: 1.1725, Train Accuracy: 0.7156
#   Group 3 - Val Loss: 1.2219, Val Accuracy: 0.7041
# Epoch [64/100] Group Metrics:
#   Group 1 - Train Loss: 2.7799, Train Accuracy: 0.2697
#   Group 1 - Val Loss: 2.7872, Val Accuracy: 0.2731
#   Group 2 - Train Loss: 1.2815, Train Accuracy: 0.6970
#   Group 2 - Val Loss: 1.4328, Val Accuracy: 0.6403
#   Group 3 - Train Loss: 1.1664, Train Accuracy: 0.7167
#   Group 3 - Val Loss: 1.2164, Val Accuracy: 0.7053
# Epoch [65/100] Group Metrics:
#   Group 1 - Train Loss: 2.7744, Train Accuracy: 0.2693
#   Group 1 - Val Loss: 2.7817, Val Accuracy: 0.2728
#   Group 2 - Train Loss: 1.2743, Train Accuracy: 0.6999
#   Group 2 - Val Loss: 1.4255, Val Accuracy: 0.6414
#   Group 3 - Train Loss: 1.1603, Train Accuracy: 0.7180
#   Group 3 - Val Loss: 1.2109, Val Accuracy: 0.7065
# Epoch [66/100] Group Metrics:
#   Group 1 - Train Loss: 2.7690, Train Accuracy: 0.2688
#   Group 1 - Val Loss: 2.7764, Val Accuracy: 0.2729
#   Group 2 - Train Loss: 1.2672, Train Accuracy: 0.7020
#   Group 2 - Val Loss: 1.4184, Val Accuracy: 0.6420
#   Group 3 - Train Loss: 1.1544, Train Accuracy: 0.7196
#   Group 3 - Val Loss: 1.2055, Val Accuracy: 0.7071
# Epoch [67/100] Group Metrics:
#   Group 1 - Train Loss: 2.7638, Train Accuracy: 0.2685
#   Group 1 - Val Loss: 2.7712, Val Accuracy: 0.2729
#   Group 2 - Train Loss: 1.2603, Train Accuracy: 0.7025
#   Group 2 - Val Loss: 1.4114, Val Accuracy: 0.6461
#   Group 3 - Train Loss: 1.1486, Train Accuracy: 0.7209
#   Group 3 - Val Loss: 1.2003, Val Accuracy: 0.7083
# Epoch [68/100] Group Metrics:
#   Group 1 - Train Loss: 2.7587, Train Accuracy: 0.2683
#   Group 1 - Val Loss: 2.7661, Val Accuracy: 0.2725
#   Group 2 - Train Loss: 1.2535, Train Accuracy: 0.7040
#   Group 2 - Val Loss: 1.4045, Val Accuracy: 0.6461
#   Group 3 - Train Loss: 1.1430, Train Accuracy: 0.7212
#   Group 3 - Val Loss: 1.1952, Val Accuracy: 0.7088
# Epoch [69/100] Group Metrics:
#   Group 1 - Train Loss: 2.7537, Train Accuracy: 0.2687
#   Group 1 - Val Loss: 2.7611, Val Accuracy: 0.2727
#   Group 2 - Train Loss: 1.2469, Train Accuracy: 0.7055
#   Group 2 - Val Loss: 1.3978, Val Accuracy: 0.6485
#   Group 3 - Train Loss: 1.1374, Train Accuracy: 0.7220
#   Group 3 - Val Loss: 1.1902, Val Accuracy: 0.7092
# Epoch [70/100] Group Metrics:
#   Group 1 - Train Loss: 2.7488, Train Accuracy: 0.2687
#   Group 1 - Val Loss: 2.7562, Val Accuracy: 0.2723
#   Group 2 - Train Loss: 1.2403, Train Accuracy: 0.7072
#   Group 2 - Val Loss: 1.3912, Val Accuracy: 0.6485
#   Group 3 - Train Loss: 1.1320, Train Accuracy: 0.7232
#   Group 3 - Val Loss: 1.1853, Val Accuracy: 0.7107
# Epoch [71/100] Group Metrics:
#   Group 1 - Train Loss: 2.7440, Train Accuracy: 0.2691
#   Group 1 - Val Loss: 2.7515, Val Accuracy: 0.2704
#   Group 2 - Train Loss: 1.2340, Train Accuracy: 0.7093
#   Group 2 - Val Loss: 1.3847, Val Accuracy: 0.6496
#   Group 3 - Train Loss: 1.1267, Train Accuracy: 0.7238
#   Group 3 - Val Loss: 1.1805, Val Accuracy: 0.7110
# Epoch [72/100] Group Metrics:
#   Group 1 - Train Loss: 2.7393, Train Accuracy: 0.2693
#   Group 1 - Val Loss: 2.7468, Val Accuracy: 0.2699
#   Group 2 - Train Loss: 1.2277, Train Accuracy: 0.7104
#   Group 2 - Val Loss: 1.3783, Val Accuracy: 0.6514
#   Group 3 - Train Loss: 1.1214, Train Accuracy: 0.7245
#   Group 3 - Val Loss: 1.1758, Val Accuracy: 0.7125
# Epoch [73/100] Group Metrics:
#   Group 1 - Train Loss: 2.7348, Train Accuracy: 0.2692
#   Group 1 - Val Loss: 2.7423, Val Accuracy: 0.2694
#   Group 2 - Train Loss: 1.2215, Train Accuracy: 0.7122
#   Group 2 - Val Loss: 1.3721, Val Accuracy: 0.6525
#   Group 3 - Train Loss: 1.1163, Train Accuracy: 0.7257
#   Group 3 - Val Loss: 1.1711, Val Accuracy: 0.7137
# Epoch [74/100] Group Metrics:
#   Group 1 - Train Loss: 2.7303, Train Accuracy: 0.2690
#   Group 1 - Val Loss: 2.7379, Val Accuracy: 0.2695
#   Group 2 - Train Loss: 1.2155, Train Accuracy: 0.7134
#   Group 2 - Val Loss: 1.3660, Val Accuracy: 0.6531
#   Group 3 - Train Loss: 1.1112, Train Accuracy: 0.7264
#   Group 3 - Val Loss: 1.1666, Val Accuracy: 0.7140
# Epoch [75/100] Group Metrics:
#   Group 1 - Train Loss: 2.7259, Train Accuracy: 0.2689
#   Group 1 - Val Loss: 2.7335, Val Accuracy: 0.2695
#   Group 2 - Train Loss: 1.2096, Train Accuracy: 0.7151
#   Group 2 - Val Loss: 1.3600, Val Accuracy: 0.6549
#   Group 3 - Train Loss: 1.1063, Train Accuracy: 0.7274
#   Group 3 - Val Loss: 1.1622, Val Accuracy: 0.7140
# Epoch [76/100] Group Metrics:
#   Group 1 - Train Loss: 2.7216, Train Accuracy: 0.2688
#   Group 1 - Val Loss: 2.7292, Val Accuracy: 0.2699
#   Group 2 - Train Loss: 1.2038, Train Accuracy: 0.7154
#   Group 2 - Val Loss: 1.3541, Val Accuracy: 0.6555
#   Group 3 - Train Loss: 1.1014, Train Accuracy: 0.7288
#   Group 3 - Val Loss: 1.1578, Val Accuracy: 0.7145
# Epoch [77/100] Group Metrics:
#   Group 1 - Train Loss: 2.7174, Train Accuracy: 0.2689
#   Group 1 - Val Loss: 2.7250, Val Accuracy: 0.2695
#   Group 2 - Train Loss: 1.1980, Train Accuracy: 0.7166
#   Group 2 - Val Loss: 1.3483, Val Accuracy: 0.6566
#   Group 3 - Train Loss: 1.0967, Train Accuracy: 0.7300
#   Group 3 - Val Loss: 1.1535, Val Accuracy: 0.7150
# Epoch [78/100] Group Metrics:
#   Group 1 - Train Loss: 2.7132, Train Accuracy: 0.2687
#   Group 1 - Val Loss: 2.7209, Val Accuracy: 0.2695
#   Group 2 - Train Loss: 1.1924, Train Accuracy: 0.7175
#   Group 2 - Val Loss: 1.3426, Val Accuracy: 0.6572
#   Group 3 - Train Loss: 1.0920, Train Accuracy: 0.7303
#   Group 3 - Val Loss: 1.1493, Val Accuracy: 0.7155
# Epoch [79/100] Group Metrics:
#   Group 1 - Train Loss: 2.7092, Train Accuracy: 0.2688
#   Group 1 - Val Loss: 2.7169, Val Accuracy: 0.2697
#   Group 2 - Train Loss: 1.1869, Train Accuracy: 0.7195
#   Group 2 - Val Loss: 1.3370, Val Accuracy: 0.6572
#   Group 3 - Train Loss: 1.0874, Train Accuracy: 0.7311
#   Group 3 - Val Loss: 1.1452, Val Accuracy: 0.7159
# Epoch [80/100] Group Metrics:
#   Group 1 - Train Loss: 2.7052, Train Accuracy: 0.2692
#   Group 1 - Val Loss: 2.7130, Val Accuracy: 0.2698
#   Group 2 - Train Loss: 1.1815, Train Accuracy: 0.7210
#   Group 2 - Val Loss: 1.3315, Val Accuracy: 0.6584
#   Group 3 - Train Loss: 1.0828, Train Accuracy: 0.7322
#   Group 3 - Val Loss: 1.1412, Val Accuracy: 0.7162
# Epoch [81/100] Group Metrics:
#   Group 1 - Train Loss: 2.7013, Train Accuracy: 0.2692
#   Group 1 - Val Loss: 2.7091, Val Accuracy: 0.2695
#   Group 2 - Train Loss: 1.1762, Train Accuracy: 0.7233
#   Group 2 - Val Loss: 1.3261, Val Accuracy: 0.6595
#   Group 3 - Train Loss: 1.0784, Train Accuracy: 0.7329
#   Group 3 - Val Loss: 1.1372, Val Accuracy: 0.7172
# Epoch [82/100] Group Metrics:
#   Group 1 - Train Loss: 2.6974, Train Accuracy: 0.2691
#   Group 1 - Val Loss: 2.7053, Val Accuracy: 0.2694
#   Group 2 - Train Loss: 1.1709, Train Accuracy: 0.7251
#   Group 2 - Val Loss: 1.3208, Val Accuracy: 0.6613
#   Group 3 - Train Loss: 1.0740, Train Accuracy: 0.7336
#   Group 3 - Val Loss: 1.1333, Val Accuracy: 0.7177
# Epoch [83/100] Group Metrics:
#   Group 1 - Train Loss: 2.6936, Train Accuracy: 0.2692
#   Group 1 - Val Loss: 2.7015, Val Accuracy: 0.2692
#   Group 2 - Train Loss: 1.1658, Train Accuracy: 0.7256
#   Group 2 - Val Loss: 1.3156, Val Accuracy: 0.6613
#   Group 3 - Train Loss: 1.0697, Train Accuracy: 0.7347
#   Group 3 - Val Loss: 1.1294, Val Accuracy: 0.7179
# Epoch [84/100] Group Metrics:
#   Group 1 - Train Loss: 2.6899, Train Accuracy: 0.2693
#   Group 1 - Val Loss: 2.6978, Val Accuracy: 0.2690
#   Group 2 - Train Loss: 1.1607, Train Accuracy: 0.7265
#   Group 2 - Val Loss: 1.3104, Val Accuracy: 0.6619
#   Group 3 - Train Loss: 1.0655, Train Accuracy: 0.7357
#   Group 3 - Val Loss: 1.1257, Val Accuracy: 0.7187
# Epoch [85/100] Group Metrics:
#   Group 1 - Train Loss: 2.6863, Train Accuracy: 0.2695
#   Group 1 - Val Loss: 2.6942, Val Accuracy: 0.2689
#   Group 2 - Train Loss: 1.1557, Train Accuracy: 0.7274
#   Group 2 - Val Loss: 1.3054, Val Accuracy: 0.6625
#   Group 3 - Train Loss: 1.0613, Train Accuracy: 0.7362
#   Group 3 - Val Loss: 1.1219, Val Accuracy: 0.7190
# Epoch [86/100] Group Metrics:
#   Group 1 - Train Loss: 2.6827, Train Accuracy: 0.2697
#   Group 1 - Val Loss: 2.6906, Val Accuracy: 0.2690
#   Group 2 - Train Loss: 1.1508, Train Accuracy: 0.7292
#   Group 2 - Val Loss: 1.3004, Val Accuracy: 0.6648
#   Group 3 - Train Loss: 1.0572, Train Accuracy: 0.7367
#   Group 3 - Val Loss: 1.1183, Val Accuracy: 0.7199
# Epoch [87/100] Group Metrics:
#   Group 1 - Train Loss: 2.6791, Train Accuracy: 0.2700
#   Group 1 - Val Loss: 2.6871, Val Accuracy: 0.2690
#   Group 2 - Train Loss: 1.1460, Train Accuracy: 0.7300
#   Group 2 - Val Loss: 1.2955, Val Accuracy: 0.6660
#   Group 3 - Train Loss: 1.0532, Train Accuracy: 0.7374
#   Group 3 - Val Loss: 1.1147, Val Accuracy: 0.7202
# Epoch [88/100] Group Metrics:
#   Group 1 - Train Loss: 2.6756, Train Accuracy: 0.2700
#   Group 1 - Val Loss: 2.6836, Val Accuracy: 0.2688
#   Group 2 - Train Loss: 1.1412, Train Accuracy: 0.7306
#   Group 2 - Val Loss: 1.2907, Val Accuracy: 0.6660
#   Group 3 - Train Loss: 1.0492, Train Accuracy: 0.7382
#   Group 3 - Val Loss: 1.1112, Val Accuracy: 0.7205
# Epoch [89/100] Group Metrics:
#   Group 1 - Train Loss: 2.6721, Train Accuracy: 0.2702
#   Group 1 - Val Loss: 2.6802, Val Accuracy: 0.2685
#   Group 2 - Train Loss: 1.1366, Train Accuracy: 0.7315
#   Group 2 - Val Loss: 1.2860, Val Accuracy: 0.6666
#   Group 3 - Train Loss: 1.0453, Train Accuracy: 0.7386
#   Group 3 - Val Loss: 1.1077, Val Accuracy: 0.7209
# Epoch [90/100] Group Metrics:
#   Group 1 - Train Loss: 2.6687, Train Accuracy: 0.2703
#   Group 1 - Val Loss: 2.6769, Val Accuracy: 0.2685
#   Group 2 - Train Loss: 1.1319, Train Accuracy: 0.7324
#   Group 2 - Val Loss: 1.2814, Val Accuracy: 0.6689
#   Group 3 - Train Loss: 1.0414, Train Accuracy: 0.7389
#   Group 3 - Val Loss: 1.1043, Val Accuracy: 0.7212
# Epoch [91/100] Group Metrics:
#   Group 1 - Train Loss: 2.6654, Train Accuracy: 0.2707
#   Group 1 - Val Loss: 2.6735, Val Accuracy: 0.2684
#   Group 2 - Train Loss: 1.1274, Train Accuracy: 0.7333
#   Group 2 - Val Loss: 1.2768, Val Accuracy: 0.6701
#   Group 3 - Train Loss: 1.0376, Train Accuracy: 0.7398
#   Group 3 - Val Loss: 1.1009, Val Accuracy: 0.7221
# Epoch [92/100] Group Metrics:
#   Group 1 - Train Loss: 2.6621, Train Accuracy: 0.2705
#   Group 1 - Val Loss: 2.6703, Val Accuracy: 0.2687
#   Group 2 - Train Loss: 1.1230, Train Accuracy: 0.7341
#   Group 2 - Val Loss: 1.2723, Val Accuracy: 0.6713
#   Group 3 - Train Loss: 1.0339, Train Accuracy: 0.7403
#   Group 3 - Val Loss: 1.0976, Val Accuracy: 0.7224
# Epoch [93/100] Group Metrics:
#   Group 1 - Train Loss: 2.6588, Train Accuracy: 0.2707
#   Group 1 - Val Loss: 2.6671, Val Accuracy: 0.2687
#   Group 2 - Train Loss: 1.1186, Train Accuracy: 0.7344
#   Group 2 - Val Loss: 1.2678, Val Accuracy: 0.6718
#   Group 3 - Train Loss: 1.0302, Train Accuracy: 0.7406
#   Group 3 - Val Loss: 1.0944, Val Accuracy: 0.7226
# Epoch [94/100] Group Metrics:
#   Group 1 - Train Loss: 2.6556, Train Accuracy: 0.2707
#   Group 1 - Val Loss: 2.6639, Val Accuracy: 0.2685
#   Group 2 - Train Loss: 1.1142, Train Accuracy: 0.7347
#   Group 2 - Val Loss: 1.2635, Val Accuracy: 0.6718
#   Group 3 - Train Loss: 1.0266, Train Accuracy: 0.7412
#   Group 3 - Val Loss: 1.0912, Val Accuracy: 0.7232
# Epoch [95/100] Group Metrics:
#   Group 1 - Train Loss: 2.6524, Train Accuracy: 0.2708
#   Group 1 - Val Loss: 2.6607, Val Accuracy: 0.2686
#   Group 2 - Train Loss: 1.1100, Train Accuracy: 0.7350
#   Group 2 - Val Loss: 1.2592, Val Accuracy: 0.6736
#   Group 3 - Train Loss: 1.0230, Train Accuracy: 0.7419
#   Group 3 - Val Loss: 1.0880, Val Accuracy: 0.7241
# Epoch [96/100] Group Metrics:
#   Group 1 - Train Loss: 2.6493, Train Accuracy: 0.2708
#   Group 1 - Val Loss: 2.6576, Val Accuracy: 0.2685
#   Group 2 - Train Loss: 1.1057, Train Accuracy: 0.7359
#   Group 2 - Val Loss: 1.2549, Val Accuracy: 0.6748
#   Group 3 - Train Loss: 1.0195, Train Accuracy: 0.7425
#   Group 3 - Val Loss: 1.0849, Val Accuracy: 0.7251
# Epoch [97/100] Group Metrics:
#   Group 1 - Train Loss: 2.6462, Train Accuracy: 0.2707
#   Group 1 - Val Loss: 2.6546, Val Accuracy: 0.2684
#   Group 2 - Train Loss: 1.1016, Train Accuracy: 0.7362
#   Group 2 - Val Loss: 1.2507, Val Accuracy: 0.6748
#   Group 3 - Train Loss: 1.0160, Train Accuracy: 0.7429
#   Group 3 - Val Loss: 1.0818, Val Accuracy: 0.7257
# Epoch [98/100] Group Metrics:
#   Group 1 - Train Loss: 2.6431, Train Accuracy: 0.2707
#   Group 1 - Val Loss: 2.6515, Val Accuracy: 0.2684
#   Group 2 - Train Loss: 1.0975, Train Accuracy: 0.7368
#   Group 2 - Val Loss: 1.2466, Val Accuracy: 0.6759
#   Group 3 - Train Loss: 1.0125, Train Accuracy: 0.7434
#   Group 3 - Val Loss: 1.0788, Val Accuracy: 0.7257
# Epoch [99/100] Group Metrics:
#   Group 1 - Train Loss: 2.6401, Train Accuracy: 0.2709
#   Group 1 - Val Loss: 2.6486, Val Accuracy: 0.2684
#   Group 2 - Train Loss: 1.0935, Train Accuracy: 0.7385
#   Group 2 - Val Loss: 1.2426, Val Accuracy: 0.6759
#   Group 3 - Train Loss: 1.0091, Train Accuracy: 0.7438
#   Group 3 - Val Loss: 1.0758, Val Accuracy: 0.7259
# Epoch [100/100] Group Metrics:
#   Group 1 - Train Loss: 2.6371, Train Accuracy: 0.2710
#   Group 1 - Val Loss: 2.6456, Val Accuracy: 0.2680
#   Group 2 - Train Loss: 1.0895, Train Accuracy: 0.7391
#   Group 2 - Val Loss: 1.2386, Val Accuracy: 0.6777
#   Group 3 - Train Loss: 1.0058, Train Accuracy: 0.7443
#   Group 3 - Val Loss: 1.0729, Val Accuracy: 0.7266

# %%
# Convert metrics to numpy arrays for easy manipulation
group_train_loss_histories = {k: np.array(v) for k, v in group_train_loss_histories.items()}
group_train_accuracy_histories = {k: np.array(v) for k, v in group_train_accuracy_histories.items()}
group_val_loss_histories = {k: np.array(v) for k, v in group_val_loss_histories.items()}
group_val_accuracy_histories = {k: np.array(v) for k, v in group_val_accuracy_histories.items()}

# Handle potential one-dimensional arrays
group_train_loss_mean = {k: v.mean(axis=0) if v.ndim > 1 else v for k, v in group_train_loss_histories.items()}
group_train_loss_std = {k: v.std(axis=0) if v.ndim > 1 else np.zeros_like(v) for k, v in group_train_loss_histories.items()}
group_val_loss_mean = {k: v.mean(axis=0) if v.ndim > 1 else v for k, v in group_val_loss_histories.items()}
group_val_loss_std = {k: v.std(axis=0) if v.ndim > 1 else np.zeros_like(v) for k, v in group_val_loss_histories.items()}

group_train_acc_mean = {k: v.mean(axis=0) if v.ndim > 1 else v for k, v in group_train_accuracy_histories.items()}
group_train_acc_std = {k: v.std(axis=0) if v.ndim > 1 else np.zeros_like(v) for k, v in group_train_accuracy_histories.items()}
group_val_acc_mean = {k: v.mean(axis=0) if v.ndim > 1 else v for k, v in group_val_accuracy_histories.items()}
group_val_acc_std = {k: v.std(axis=0) if v.ndim > 1 else np.zeros_like(v) for k, v in group_val_accuracy_histories.items()}

# Combined Plot for All Modalities
plt.figure(figsize=(12, 6))

# Loss Plot
plt.subplot(1, 2, 1)
for group in [1, 2, 3]:
    plt.plot(range(1, num_epochs + 1), group_train_loss_mean[group], label=f"Group {group} Train Loss")
    plt.fill_between(range(1, num_epochs + 1), 
                     group_train_loss_mean[group] - group_train_loss_std[group], 
                     group_train_loss_mean[group] + group_train_loss_std[group], 
                     alpha=0.2)
    plt.plot(range(1, num_epochs + 1), group_val_loss_mean[group], label=f"Group {group} Validation Loss", linestyle="dashed")
    plt.fill_between(range(1, num_epochs + 1), 
                     group_val_loss_mean[group] - group_val_loss_std[group], 
                     group_val_loss_mean[group] + group_val_loss_std[group], 
                     alpha=0.2)

plt.title("Loss over Epochs for All Groups")
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.legend()
plt.grid()

# Accuracy Plot
plt.subplot(1, 2, 2)
for group in [1, 2, 3]:
    plt.plot(range(1, num_epochs + 1), group_train_acc_mean[group], label=f"Group {group} Train Accuracy")
    plt.fill_between(range(1, num_epochs + 1), 
                     group_train_acc_mean[group] - group_train_acc_std[group], 
                     group_train_acc_mean[group] + group_train_acc_std[group], 
                     alpha=0.2)
    plt.plot(range(1, num_epochs + 1), group_val_acc_mean[group], label=f"Group {group} Validation Accuracy", linestyle="dashed")
    plt.fill_between(range(1, num_epochs + 1), 
                     group_val_acc_mean[group] - group_val_acc_std[group], 
                     group_val_acc_mean[group] + group_val_acc_std[group], 
                     alpha=0.2)

plt.title("Accuracy over Epochs for All Groups")
plt.xlabel("Epoch")
plt.ylabel("Accuracy")
plt.ylim([0, 1])  # Ensure y-axis is between 0 and 1 for accuracy
plt.legend()
plt.grid()

plt.tight_layout()
plt.show()

# %%
# Combined Plot for All Modalities
plt.figure(figsize=(12, 6))

# Loss Plot
plt.subplot(1, 2, 1)
for group in [1, 2, 3]:
    plt.plot(range(1, num_epochs + 1), group_train_loss_mean[group], label=f"Group {group} Train Loss")
    plt.fill_between(range(1, num_epochs + 1), 
                     group_train_loss_mean[group] - group_train_loss_std[group], 
                     group_train_loss_mean[group] + group_train_loss_std[group], 
                     alpha=0.2)
    plt.plot(range(1, num_epochs + 1), group_val_loss_mean[group], label=f"Group {group} Validation Loss", linestyle="dashed")
    plt.fill_between(range(1, num_epochs + 1), 
                     group_val_loss_mean[group] - group_val_loss_std[group], 
                     group_val_loss_mean[group] + group_val_loss_std[group], 
                     alpha=0.2)

plt.title("Loss over Epochs for All Groups")
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.legend()
plt.grid()

# Accuracy Plot
plt.subplot(1, 2, 2)
for group in [1, 2, 3]:
    plt.plot(range(1, num_epochs + 1), group_train_acc_mean[group], label=f"Group {group} Train Accuracy")
    plt.fill_between(range(1, num_epochs + 1), 
                     group_train_acc_mean[group] - group_train_acc_std[group], 
                     group_train_acc_mean[group] + group_train_acc_std[group], 
                     alpha=0.2)
    plt.plot(range(1, num_epochs + 1), group_val_acc_mean[group], label=f"Group {group} Validation Accuracy", linestyle="dashed")
    plt.fill_between(range(1, num_epochs + 1), 
                     group_val_acc_mean[group] - group_val_acc_std[group], 
                     group_val_acc_mean[group] + group_val_acc_std[group], 
                     alpha=0.2)

plt.title("Accuracy over Epochs for All Groups")
plt.xlabel("Epoch")
plt.ylabel("Accuracy")
plt.ylim([0, 1])  # Ensure y-axis is between 0 and 1 for accuracy
plt.legend()
plt.grid()

plt.tight_layout()
plt.show()

# %%
# Track metrics across all groups
group_test_loss_histories = {group: [] for group in range(1, num_groups + 1)}
group_test_accuracy_histories = {group: [] for group in range(1, num_groups + 1)}
group_train_loss_histories = {group: [] for group in range(1, num_groups + 1)}
group_train_accuracy_histories = {group: [] for group in range(1, num_groups + 1)}

with torch.no_grad():  # Disable gradient computation for testing
    for group in range(1, num_groups + 1):
        user_test_losses = []
        user_test_accuracies = []
        user_train_losses = []
        user_train_accuracies = []

        for user_id, model in enumerate(classifiers_by_group[group]):
            model.eval()

            # Test metrics
            epoch_test_loss = 0.0
            correct_test_predictions = 0
            total_test_samples = 0

            # Train metrics (optional, for post-training evaluation on training data)
            epoch_train_loss = 0.0
            correct_train_predictions = 0
            total_train_samples = 0

            # Evaluate on test set
            for X_batch, y_batch in test_loaders_by_group[group][user_id]:
                X_batch, y_batch = X_batch.cuda(), y_batch.cuda()
                outputs = model(X_batch)
                loss = criterion(outputs, y_batch)

                epoch_test_loss += loss.item()
                _, predicted = torch.max(outputs, dim=1)
                correct_test_predictions += (predicted == y_batch).sum().item()
                total_test_samples += y_batch.size(0)

            # Evaluate on training set
            for X_batch, y_batch in train_loaders_by_group[group][user_id]:
                X_batch, y_batch = X_batch.cuda(), y_batch.cuda()
                outputs = model(X_batch)
                loss = criterion(outputs, y_batch)

                epoch_train_loss += loss.item()
                _, predicted = torch.max(outputs, dim=1)
                correct_train_predictions += (predicted == y_batch).sum().item()
                total_train_samples += y_batch.size(0)

            # Calculate averages
            avg_test_loss = epoch_test_loss / len(test_loaders_by_group[group][user_id])
            test_accuracy = correct_test_predictions / total_test_samples

            avg_train_loss = epoch_train_loss / len(train_loaders_by_group[group][user_id])
            train_accuracy = correct_train_predictions / total_train_samples

            # Store metrics for each user
            user_test_losses.append(avg_test_loss)
            user_test_accuracies.append(test_accuracy)
            user_train_losses.append(avg_train_loss)
            user_train_accuracies.append(train_accuracy)

        # Store group-level metrics
        group_test_loss_histories[group].append(np.mean(user_test_losses))
        group_test_accuracy_histories[group].append(np.mean(user_test_accuracies))
        group_train_loss_histories[group].append(np.mean(user_train_losses))
        group_train_accuracy_histories[group].append(np.mean(user_train_accuracies))

# Convert metrics to numpy arrays for plotting
group_test_loss_histories = {group: np.array(values) for group, values in group_test_loss_histories.items()}
group_test_accuracy_histories = {group: np.array(values) for group, values in group_test_accuracy_histories.items()}
group_train_loss_histories = {group: np.array(values) for group, values in group_train_loss_histories.items()}
group_train_accuracy_histories = {group: np.array(values) for group, values in group_train_accuracy_histories.items()}

# Plot results for all groups
plt.figure(figsize=(12, 6))

# Test Loss and Accuracy
plt.subplot(1, 2, 1)
for group in range(1, num_groups + 1):
    plt.plot(range(1, len(group_test_loss_histories[group]) + 1), group_test_loss_histories[group], label=f"Group {group} Test Loss")
plt.title("Test Loss Across Groups")
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.legend()
plt.grid()

plt.subplot(1, 2, 2)
for group in range(1, num_groups + 1):
    plt.plot(range(1, len(group_test_accuracy_histories[group]) + 1), group_test_accuracy_histories[group], label=f"Group {group} Test Accuracy")
plt.title("Test Accuracy Across Groups")
plt.xlabel("Epoch")
plt.ylabel("Accuracy")
plt.legend()
plt.grid()

plt.tight_layout()
plt.show()
# Out:
# C:\Users\abdu_\AppData\Local\Temp\ipykernel_28552\3432764924.py:42: DeprecationWarning: an integer is required (got type numpy.float64).  Implicit conversion to integers using __int__ is deprecated, and may be removed in a future version of Python.
#   y = torch.tensor(self.y[idx], dtype=torch.long)  # Use long for classification targets
# Average Test Loss: 1.9840, Average Test Accuracy: 0.4621
#
# Average Train Loss: 1.9077, Average Train Accuracy: 0.4841
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[9], line 75
#      73 test_loss_histories = np.array(test_loss_histories)
#      74 test_accuracy_histories = np.array(test_accuracy_histories)
# ---> 75 train_loss_histories = np.array(train_loss_histories)
#      76 train_accuracy_histories = np.array(train_accuracy_histories)
#      78 # Calculate means and standard deviations
#
# NameError: name 'train_loss_histories' is not defined

# %%
# Images only
'''
Test Loss: 0.4364, Test Accuracy: 0.8521

Train Loss: 0.4047, Train Accuracy: 0.8687

'''

# %%
import json

metrics = {
    "train_loss_histories": train_loss_histories.tolist(),
    "train_accuracy_histories": train_accuracy_histories.tolist(),
    "val_loss_histories": val_loss_histories.tolist(),
    "val_accuracy_histories": val_accuracy_histories.tolist(),
    "test_loss_histories": test_loss_histories.tolist(),
    "test_accuracy_histories": test_accuracy_histories.tolist(),
}

with open("No_Comm_Metrics.json", "w") as f:
    json.dump(metrics, f)
print("No_Comm_Metrics.json")

# %%
# Load metrics from JSON file
with open("metrics.json", "r") as f:
    metrics = json.load(f)

# Convert lists back to numpy arrays
train_loss_histories = np.array(metrics["train_loss_histories"])
train_accuracy_histories = np.array(metrics["train_accuracy_histories"])
val_loss_histories = np.array(metrics["val_loss_histories"])
val_accuracy_histories = np.array(metrics["val_accuracy_histories"])
test_loss_histories = np.array(metrics["test_loss_histories"])
test_accuracy_histories = np.array(metrics["test_accuracy_histories"])

# Print shapes to confirm loading
print("Train Loss Histories Shape:", train_loss_histories.shape)
print("Train Accuracy Histories Shape:", train_accuracy_histories.shape)
print("Validation Loss Histories Shape:", val_loss_histories.shape)
print("Validation Accuracy Histories Shape:", val_accuracy_histories.shape)
print("Test Loss Histories Shape:", test_loss_histories.shape)
print("Test Accuracy Histories Shape:", test_accuracy_histories.shape)
