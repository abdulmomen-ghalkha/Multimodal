# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader
import pandas as pd
from sklearn.preprocessing import MinMaxScaler
import matplotlib.pyplot as plt
import numpy as np
import random
import os
import seaborn as sns


# Set random seed for reproducibility
seed = 42  # You can choose any integer here

# Set seed for NumPy
np.random.seed(seed)

# Set seed for Python's random module
random.seed(seed)

# Set seed for PyTorch
torch.manual_seed(seed)

# For GPU (if using CUDA)
if torch.cuda.is_available():
    torch.cuda.manual_seed(seed)
    torch.cuda.manual_seed_all(seed)  # For multi-GPU setups

# Set deterministic behavior for reproducibility in case of CUDA operations
torch.backends.cudnn.deterministic = True
torch.backends.cudnn.benchmark = False




dataset_dir = "datasets/no_comm/"

# Directory containing the saved CSV files
output_dir = dataset_dir + "training_outputs/"

# Load one of the CSV files for EDA (e.g., user_0_outputs.csv)
csv_file = os.path.join(output_dir, "user_1_outputs.csv")
df = pd.read_csv(csv_file)

# Quick overview of the data
print("Data Overview:")
print(df.head())
print("\nData Summary:")
print(df.describe())

# Check for missing values
print("\nMissing Values:")
print(df.isnull().sum())

# Distribution of the target variable (y)
sns.countplot(x="y", data=df)
plt.title("Target Variable Distribution")
plt.show()

# Correlation heatmap of features
correlation_matrix = df.iloc[:, :-1].corr()  # Exclude the target column
plt.figure(figsize=(12, 10))
sns.heatmap(correlation_matrix, cmap="coolwarm", center=0)
plt.title("Feature Correlation Heatmap")
plt.show()
# Out:
# Data Overview:
#    Feature_1  Feature_2  Feature_3  Feature_4  Feature_5  Feature_6  \
# 0        0.0   0.000000   2.427324        0.0   0.000000   0.000000
# 1        0.0   0.427090   1.163418        0.0   0.178713   0.413166
# 2        0.0   0.000000   2.095180        0.0   0.000000   0.000000
# 3        0.0   0.157136   3.609239        0.0   0.000000   0.182261
# 4        0.0   2.231131   1.165798        0.0   0.981523   2.230717
#
#    Feature_7  Feature_8  Feature_9  Feature_10  ...  Feature_248  Feature_249  \
# 0   0.000000   0.763855   0.000000    0.000000  ...    -1.592660    -1.397809
# 1   0.175270   0.794933   0.627405    0.461691  ...    -1.962592    -1.452488
# 2   0.000000   0.670203   0.000000    0.000000  ...    -1.373927    -0.924505
# 3   0.009697   1.396447   0.057795    0.213247  ...     0.654818    -0.822407
# 4   0.809156   2.806526   3.018401    2.545619  ...     3.052901     1.972201
#
#    Feature_250  Feature_251  Feature_252  Feature_253  Feature_254  \
# 0     0.023165     1.121107    -0.851685    -0.757659    -0.060895
# 1     0.039978     1.459249    -1.594860    -0.972583    -0.264299
# 2     1.852382     0.852163     1.165901     1.097879     0.008920
# 3    -0.712063    -2.135010     2.392082    -0.223696     0.837794
# 4    -1.520203    -3.621065    -0.730071    -2.076510    -1.538100
#
#    Feature_255  Feature_256     y
# 0    -0.482635    -1.982693  19.0
# 1    -0.249734    -1.615554  19.0
# 2    -1.821918    -1.379264  22.0
# 3    -1.848053    -0.666927  17.0
# 4     0.353249     2.013438  11.0
#
# [5 rows x 257 columns]
#
# Data Summary:
#        Feature_1    Feature_2    Feature_3    Feature_4    Feature_5  \
# count     1729.0  1729.000000  1729.000000  1729.000000  1729.000000
# mean         0.0     0.735354     2.170556     0.015320     0.285868
# std          0.0     0.720206     1.321380     0.045479     0.347628
# min          0.0     0.000000     0.000000     0.000000     0.000000
# 25%          0.0     0.151771     1.242436     0.000000     0.000000
# 50%          0.0     0.523094     1.978576     0.000000     0.171081
# 75%          0.0     1.067831     3.249154     0.000000     0.451306
# max          0.0     3.388823     5.613220     0.204794     1.508188
#
#          Feature_6    Feature_7    Feature_8    Feature_9   Feature_10  ...  \
# count  1729.000000  1729.000000  1729.000000  1729.000000  1729.000000  ...
# mean      0.738261     0.261748     1.494263     0.976723     0.841353  ...
# std       0.713494     0.272633     0.653327     1.004861     0.814570  ...
# min       0.000000     0.000000     0.298954     0.000000     0.000000  ...
# 25%       0.181926     0.022026     1.022588     0.095390     0.213247  ...
# 50%       0.523857     0.186780     1.407066     0.695694     0.594108  ...
# 75%       1.082329     0.390076     1.814744     1.461713     1.239956  ...
# max       3.387750     1.233443     4.201824     4.600913     3.881645  ...
#
#        Feature_248  Feature_249  Feature_250  Feature_251  Feature_252  \
# count  1729.000000  1729.000000  1729.000000  1729.000000  1729.000000
# mean      0.666921    -0.300697    -0.376396    -1.279916     0.166535
# std       1.504751     1.216515     1.593494     1.451501     1.603865
# min      -4.751606    -4.122119    -3.894967    -5.161763    -3.717653
# 25%      -0.483589    -0.877740    -1.484418    -2.173479    -1.180783
# 50%       0.984675    -0.433756    -0.603738    -1.611854     0.172930
# 75%       1.756572     0.134825     0.177452    -0.717330     1.508765
# max       3.566294     3.326209     5.393246     2.273761     4.260859
#
#        Feature_253  Feature_254  Feature_255  Feature_256            y
# count  1729.000000  1729.000000  1729.000000  1729.000000  1729.000000
# mean     -0.789709    -0.338264    -0.520803     0.413280    15.186235
# std       1.047715     0.882098     1.004738     1.493140     5.019063
# min      -3.140517    -2.953035    -2.981000    -2.401864     2.000000
# 25%      -1.457134    -0.951254    -1.417228    -0.627088    14.000000
# 50%      -0.604308    -0.470251    -0.560128     0.020059    16.000000
# 75%      -0.253853     0.555784     0.267075     1.596923    17.000000
# max       2.929004     1.255433     1.526845     5.069533    30.000000
#
# [8 rows x 257 columns]
#
# Missing Values:
# Feature_1      0
# Feature_2      0
# Feature_3      0
# Feature_4      0
# Feature_5      0
#               ..
# Feature_253    0
# Feature_254    0
# Feature_255    0
# Feature_256    0
# y              0
# Length: 257, dtype: int64

# %%
no_users = 20
# Define the Multinomial Logistic Regression model
class MultinomialLogisticRegression(nn.Module):
    def __init__(self, input_size, num_classes):
        super(MultinomialLogisticRegression, self).__init__()
        self.linear = nn.Linear(input_size, num_classes)

    def forward(self, x):
        return self.linear(x)

# Custom dataset to load the data from CSV
class CustomDataset(Dataset):
    def __init__(self,  csv_file, modality=["pos_height", "images"], scaler=None, zero_prob=0.5):
        self.data = pd.read_csv(csv_file)
        if "images" in modality and "pos_height" in modality:
            self.X = self.data.iloc[:, :-1].values  # Features
            mask = np.ones(self.X.shape)  # Initialize mask
            mask[:, 128:-1] = np.random.choice([0, 1], size=self.X[:, 128:-1].shape, p=[zero_prob, 1 - zero_prob])
            self.X *= mask  # Apply mask to zero out features
        elif "images" in modality:
            self.X = self.data.iloc[:, 128:-1].values  # Features
            mask = np.random.choice([0, 1], size=self.X.shape, p=[zero_prob, 1 - zero_prob])  # Create a binary mask
            self.X *= mask  # Apply mask
        else:
            self.X = self.data.iloc[:, 0:128].values  # Features

        self.y = self.data.iloc[:, -1].values   # Labels

        # If a scaler is provided, use it to transform the features
        if scaler:
            self.X = scaler.transform(self.X)
        else:
            # Fit the scaler on the training data and transform
            self.scaler = MinMaxScaler(feature_range=(-1, 1))
            self.X = self.scaler.fit_transform(self.X)

    def __len__(self):
        return len(self.data)

    def __getitem__(self, idx):
        X = torch.tensor(self.X[idx], dtype=torch.float32)
        y = torch.tensor(self.y[idx], dtype=torch.long)  # Use long for classification targets
        return X, y

# %%
# Configuration
no_users = 20  # Example: Number of users
available_modalities = ["pos_height", "images"]
modality_size = {"pos_height": 128, "images": 128}
group_definitions = {
    1: ["pos_height"],        # Group 1: Only pos_height
    2: ["images"],            # Group 2: Only images
    3: ["pos_height", "images"]  # Group 3: Both modalities
}

# Assign each user to a group randomly
user_groups = [random.choice([1, 2, 3]) for _ in range(no_users)]

# Assign modalities to users based on their group
user_modalities = [group_definitions[group] for group in user_groups]

# Compute output sizes for each user based on their modalities
output_sizes = [sum(modality_size[modality] for modality in user_modality) for user_modality in user_modalities]

# Store models (placeholders for actual models)
all_models = []

# Example output (for verification)
print(f"User Groups: {user_groups[:10]}")  # Show first 10 users' groups
print(f"User Modalities: {user_modalities[:10]}")  # Show first 10 users' modalities
print(f"Output Sizes: {output_sizes[:10]}")  # Show first 10 users' output sizes
# Out:
# User Groups: [3, 1, 1, 3, 2, 1, 1, 1, 3, 1]
# User Modalities: [['pos_height', 'images'], ['pos_height'], ['pos_height'], ['pos_height', 'images'], ['images'], ['pos_height'], ['pos_height'], ['pos_height'], ['pos_height', 'images'], ['pos_height']]
# Output Sizes: [256, 128, 128, 256, 128, 128, 128, 128, 256, 128]

# %%
no_users = 20
# List to store DataLoader objects for each user
train_loaders = []
val_loaders = []
test_loaders = []
scaler = None
# Loop over each user
zero_prob=0.9
dataset_dir = "datasets/no_comm/"
for user_idx in range(no_users):
    scaler = None
    # Define file paths for each user dynamically
    train_file = dataset_dir + f"training_outputs/user_{user_idx}_outputs.csv"
    val_file = dataset_dir + f"val_outputs/user_{user_idx}_outputs.csv"
    test_file = dataset_dir + f"test_outputs/user_{user_idx}_outputs.csv"

    # Load training data and fit the scaler on it (only once for each user)
    train_data = pd.read_csv(train_file)
    
    if scaler is None:
        scaler = MinMaxScaler(feature_range=(-1, 1))
        # Fit the scaler on the first user's training data
        if "images" in user_modalities[user_idx] and "pos_height" in user_modalities[user_idx]:
            temp = train_data.iloc[:, :-1].values  # Features
        elif "images" in user_modalities[user_idx]:
            temp = train_data.iloc[:, 128:-1].values  # Features
        else:
            temp = train_data.iloc[:, 0:128].values  # Features
        scaler.fit(temp)  # Fit scaler only on training features

    # Create datasets using the same scaler for all data
    train_dataset = CustomDataset(train_file, scaler=scaler, modality=user_modalities[user_idx], zero_prob=0.5)
    val_dataset = CustomDataset(val_file, scaler=scaler, modality=user_modalities[user_idx], zero_prob=0.5)
    test_dataset = CustomDataset(test_file, scaler=scaler, modality=user_modalities[user_idx], zero_prob=0.5)

    # Create DataLoader for training, validation, and testing for each user
    batch_size = 64
    train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=False)
    val_loader = DataLoader(val_dataset, batch_size=batch_size, shuffle=False)
    test_loader = DataLoader(test_dataset, batch_size=batch_size, shuffle=False)

    # Append each user's DataLoader to the respective lists
    train_loaders.append(train_loader)
    val_loaders.append(val_loader)
    test_loaders.append(test_loader)

# %%
# Initialize model, loss function, and optimizer for multiple users
input_sizes = output_sizes  # Number of features
num_classes = 64
classifiers = [MultinomialLogisticRegression(input_size, num_classes) for input_size, _ in zip(input_sizes, range(no_users))]
#classifiers = [MultinomialLogisticRegression(input_size, num_classes).cuda() for _ in range(no_users)]
optimizers = [optim.SGD(model.parameters(), lr=0.01) for model in classifiers]
criterion = nn.CrossEntropyLoss()
# Training parameters
num_epochs = 100

# %%
# Group assignments (use the previously defined user_groups)
group_losses = {1: [], 2: [], 3: []}
group_accuracies = {1: [], 2: [], 3: []}

# Initialize dictionaries to track metrics for each group
group_train_loss_histories = {1: [], 2: [], 3: []}
group_train_accuracy_histories = {1: [], 2: [], 3: []}
group_val_loss_histories = {1: [], 2: [], 3: []}
group_val_accuracy_histories = {1: [], 2: [], 3: []}
lambda_reg = 0.01
eta = 0.01
from utils import cross_entropy_loss_with_l2
# Training loop
for epoch in range(num_epochs):
    # Temporary dictionaries for this epoch
    epoch_group_train_losses = {1: [], 2: [], 3: []}
    epoch_group_train_accuracies = {1: [], 2: [], 3: []}
    epoch_group_val_losses = {1: [], 2: [], 3: []}
    epoch_group_val_accuracies = {1: [], 2: [], 3: []}

    for user_id, (model, optimizer) in enumerate(zip(classifiers, optimizers)):
        group = user_groups[user_id]  # Get the group of the user

        # Training phase
        model.train()
        epoch_train_loss = 0.0
        correct_train_predictions = 0
        total_train_samples = 0

        for X_batch, y_batch in train_loaders[user_id]:
            #X_batch, y_batch = X_batch.cuda(), y_batch.cuda()
            outputs = model(X_batch)
            loss = criterion(outputs, y_batch)

            optimizer.zero_grad()
            loss.backward()
            optimizer.step()

            epoch_train_loss += loss.item()
            _, predicted = torch.max(outputs, dim=1)
            correct_train_predictions += (predicted == y_batch).sum().item()
            total_train_samples += y_batch.size(0)

        avg_train_loss = epoch_train_loss / len(train_loaders[user_id])
        train_accuracy = correct_train_predictions / total_train_samples

        # Validation phase
        model.eval()
        epoch_val_loss = 0.0
        correct_val_predictions = 0
        total_val_samples = 0

        with torch.no_grad():
            for X_batch, y_batch in val_loaders[user_id]:
                #X_batch, y_batch = X_batch.cuda(), y_batch.cuda()
                outputs = model(X_batch)
                loss = criterion(outputs, y_batch)

                epoch_val_loss += loss.item()
                _, predicted = torch.max(outputs, dim=1)
                correct_val_predictions += (predicted == y_batch).sum().item()
                total_val_samples += y_batch.size(0)

        avg_val_loss = epoch_val_loss / len(val_loaders[user_id])
        val_accuracy = correct_val_predictions / total_val_samples

        # Assign metrics to the respective group
        epoch_group_train_losses[group].append(avg_train_loss)
        epoch_group_train_accuracies[group].append(train_accuracy)
        epoch_group_val_losses[group].append(avg_val_loss)
        epoch_group_val_accuracies[group].append(val_accuracy)

    # Calculate averages for this epoch and store them
    for group in [1, 2, 3]:
        #group_train_loss_histories[group].append(np.mean(epoch_group_train_losses[group]))
        #group_train_accuracy_histories[group].append(np.mean(epoch_group_train_accuracies[group]))
        #group_val_loss_histories[group].append(np.mean(epoch_group_val_losses[group]))
        #group_val_accuracy_histories[group].append(np.mean(epoch_group_val_accuracies[group]))
        group_train_loss_histories[group].append(epoch_group_train_losses[group])
        group_train_accuracy_histories[group].append(epoch_group_train_accuracies[group])
        group_val_loss_histories[group].append(epoch_group_val_losses[group])
        group_val_accuracy_histories[group].append(epoch_group_val_accuracies[group])

    # Print group-wise average metrics
    print(f"Epoch [{epoch+1}/{num_epochs}] Group Metrics:")
    for group in [1, 2, 3]:
        print(f"  Group {group} - Train Loss: {np.mean(epoch_group_train_losses[group]):.4f}, Train Accuracy: {np.mean(epoch_group_train_accuracies[group]):.4f}")
        print(f"  Group {group} - Val Loss: {np.mean(epoch_group_val_losses[group]):.4f}, Val Accuracy: {np.mean(epoch_group_val_accuracies[group]):.4f}")
# Out:
# C:\Users\aghalkha21\AppData\Local\Temp\ipykernel_41568\3432764924.py:42: DeprecationWarning: an integer is required (got type numpy.float64).  Implicit conversion to integers using __int__ is deprecated, and may be removed in a future version of Python.
#   y = torch.tensor(self.y[idx], dtype=torch.long)  # Use long for classification targets
# Epoch [1/100] Group Metrics:
#   Group 1 - Train Loss: 3.7494, Train Accuracy: 0.1682
#   Group 1 - Val Loss: 3.2882, Val Accuracy: 0.2653
#   Group 2 - Train Loss: 3.9865, Train Accuracy: 0.1633
#   Group 2 - Val Loss: 3.7907, Val Accuracy: 0.2754
#   Group 3 - Train Loss: 3.6213, Train Accuracy: 0.2092
#   Group 3 - Val Loss: 3.1057, Val Accuracy: 0.2774
# Epoch [2/100] Group Metrics:
#   Group 1 - Train Loss: 3.0821, Train Accuracy: 0.2613
#   Group 1 - Val Loss: 2.8975, Val Accuracy: 0.2739
#   Group 2 - Train Loss: 3.5639, Train Accuracy: 0.2887
#   Group 2 - Val Loss: 3.4433, Val Accuracy: 0.2667
#   Group 3 - Train Loss: 2.8993, Train Accuracy: 0.2821
#   Group 3 - Val Loss: 2.7004, Val Accuracy: 0.3190
# Epoch [3/100] Group Metrics:
#   Group 1 - Train Loss: 2.7979, Train Accuracy: 0.2750
#   Group 1 - Val Loss: 2.6976, Val Accuracy: 0.2916
#   Group 2 - Train Loss: 3.2355, Train Accuracy: 0.2864
#   Group 2 - Val Loss: 3.1949, Val Accuracy: 0.2625
#   Group 3 - Train Loss: 2.5920, Train Accuracy: 0.3310
#   Group 3 - Val Loss: 2.4764, Val Accuracy: 0.3646
# Epoch [4/100] Group Metrics:
#   Group 1 - Train Loss: 2.6324, Train Accuracy: 0.2934
#   Group 1 - Val Loss: 2.5702, Val Accuracy: 0.3045
#   Group 2 - Train Loss: 3.0087, Train Accuracy: 0.2861
#   Group 2 - Val Loss: 3.0259, Val Accuracy: 0.2625
#   Group 3 - Train Loss: 2.4015, Train Accuracy: 0.3669
#   Group 3 - Val Loss: 2.3244, Val Accuracy: 0.3896
# Epoch [5/100] Group Metrics:
#   Group 1 - Train Loss: 2.5220, Train Accuracy: 0.3005
#   Group 1 - Val Loss: 2.4813, Val Accuracy: 0.3046
#   Group 2 - Train Loss: 2.8502, Train Accuracy: 0.2876
#   Group 2 - Val Loss: 2.8997, Val Accuracy: 0.2655
#   Group 3 - Train Loss: 2.2650, Train Accuracy: 0.3917
#   Group 3 - Val Loss: 2.2101, Val Accuracy: 0.4114
# Epoch [6/100] Group Metrics:
#   Group 1 - Train Loss: 2.4425, Train Accuracy: 0.3066
#   Group 1 - Val Loss: 2.4150, Val Accuracy: 0.3139
#   Group 2 - Train Loss: 2.7275, Train Accuracy: 0.2934
#   Group 2 - Val Loss: 2.7955, Val Accuracy: 0.2754
#   Group 3 - Train Loss: 2.1588, Train Accuracy: 0.4157
#   Group 3 - Val Loss: 2.1186, Val Accuracy: 0.4357
# Epoch [7/100] Group Metrics:
#   Group 1 - Train Loss: 2.3820, Train Accuracy: 0.3125
#   Group 1 - Val Loss: 2.3631, Val Accuracy: 0.3151
#   Group 2 - Train Loss: 2.6245, Train Accuracy: 0.3072
#   Group 2 - Val Loss: 2.7051, Val Accuracy: 0.2977
#   Group 3 - Train Loss: 2.0719, Train Accuracy: 0.4390
#   Group 3 - Val Loss: 2.0423, Val Accuracy: 0.4590
# Epoch [8/100] Group Metrics:
#   Group 1 - Train Loss: 2.3337, Train Accuracy: 0.3146
#   Group 1 - Val Loss: 2.3208, Val Accuracy: 0.3187
#   Group 2 - Train Loss: 2.5350, Train Accuracy: 0.3321
#   Group 2 - Val Loss: 2.6253, Val Accuracy: 0.3217
#   Group 3 - Train Loss: 1.9982, Train Accuracy: 0.4653
#   Group 3 - Val Loss: 1.9769, Val Accuracy: 0.4789
# Epoch [9/100] Group Metrics:
#   Group 1 - Train Loss: 2.2940, Train Accuracy: 0.3181
#   Group 1 - Val Loss: 2.2853, Val Accuracy: 0.3199
#   Group 2 - Train Loss: 2.4558, Train Accuracy: 0.3552
#   Group 2 - Val Loss: 2.5540, Val Accuracy: 0.3452
#   Group 3 - Train Loss: 1.9342, Train Accuracy: 0.4857
#   Group 3 - Val Loss: 1.9195, Val Accuracy: 0.4976
# Epoch [10/100] Group Metrics:
#   Group 1 - Train Loss: 2.2603, Train Accuracy: 0.3215
#   Group 1 - Val Loss: 2.2549, Val Accuracy: 0.3240
#   Group 2 - Train Loss: 2.3850, Train Accuracy: 0.3728
#   Group 2 - Val Loss: 2.4898, Val Accuracy: 0.3586
#   Group 3 - Train Loss: 1.8775, Train Accuracy: 0.5097
#   Group 3 - Val Loss: 1.8684, Val Accuracy: 0.5169
# Epoch [11/100] Group Metrics:
#   Group 1 - Train Loss: 2.2311, Train Accuracy: 0.3254
#   Group 1 - Val Loss: 2.2283, Val Accuracy: 0.3272
#   Group 2 - Train Loss: 2.3211, Train Accuracy: 0.3868
#   Group 2 - Val Loss: 2.4316, Val Accuracy: 0.3791
#   Group 3 - Train Loss: 1.8267, Train Accuracy: 0.5273
#   Group 3 - Val Loss: 1.8225, Val Accuracy: 0.5313
# Epoch [12/100] Group Metrics:
#   Group 1 - Train Loss: 2.2055, Train Accuracy: 0.3281
#   Group 1 - Val Loss: 2.2048, Val Accuracy: 0.3291
#   Group 2 - Train Loss: 2.2631, Train Accuracy: 0.4023
#   Group 2 - Val Loss: 2.3782, Val Accuracy: 0.3908
#   Group 3 - Train Loss: 1.7807, Train Accuracy: 0.5453
#   Group 3 - Val Loss: 1.7808, Val Accuracy: 0.5443
# Epoch [13/100] Group Metrics:
#   Group 1 - Train Loss: 2.1826, Train Accuracy: 0.3318
#   Group 1 - Val Loss: 2.1837, Val Accuracy: 0.3304
#   Group 2 - Train Loss: 2.2099, Train Accuracy: 0.4146
#   Group 2 - Val Loss: 2.3291, Val Accuracy: 0.4019
#   Group 3 - Train Loss: 1.7387, Train Accuracy: 0.5595
#   Group 3 - Val Loss: 1.7427, Val Accuracy: 0.5560
# Epoch [14/100] Group Metrics:
#   Group 1 - Train Loss: 2.1620, Train Accuracy: 0.3346
#   Group 1 - Val Loss: 2.1646, Val Accuracy: 0.3318
#   Group 2 - Train Loss: 2.1608, Train Accuracy: 0.4307
#   Group 2 - Val Loss: 2.2836, Val Accuracy: 0.4107
#   Group 3 - Train Loss: 1.7001, Train Accuracy: 0.5731
#   Group 3 - Val Loss: 1.7076, Val Accuracy: 0.5684
# Epoch [15/100] Group Metrics:
#   Group 1 - Train Loss: 2.1434, Train Accuracy: 0.3368
#   Group 1 - Val Loss: 2.1472, Val Accuracy: 0.3341
#   Group 2 - Train Loss: 2.1152, Train Accuracy: 0.4468
#   Group 2 - Val Loss: 2.2412, Val Accuracy: 0.4229
#   Group 3 - Train Loss: 1.6644, Train Accuracy: 0.5857
#   Group 3 - Val Loss: 1.6751, Val Accuracy: 0.5779
# Epoch [16/100] Group Metrics:
#   Group 1 - Train Loss: 2.1263, Train Accuracy: 0.3396
#   Group 1 - Val Loss: 2.1313, Val Accuracy: 0.3368
#   Group 2 - Train Loss: 2.0728, Train Accuracy: 0.4614
#   Group 2 - Val Loss: 2.2015, Val Accuracy: 0.4352
#   Group 3 - Train Loss: 1.6313, Train Accuracy: 0.5978
#   Group 3 - Val Loss: 1.6449, Val Accuracy: 0.5891
# Epoch [17/100] Group Metrics:
#   Group 1 - Train Loss: 2.1106, Train Accuracy: 0.3420
#   Group 1 - Val Loss: 2.1166, Val Accuracy: 0.3391
#   Group 2 - Train Loss: 2.0331, Train Accuracy: 0.4707
#   Group 2 - Val Loss: 2.1643, Val Accuracy: 0.4458
#   Group 3 - Train Loss: 1.6004, Train Accuracy: 0.6090
#   Group 3 - Val Loss: 1.6168, Val Accuracy: 0.5987
# Epoch [18/100] Group Metrics:
#   Group 1 - Train Loss: 2.0961, Train Accuracy: 0.3439
#   Group 1 - Val Loss: 2.1030, Val Accuracy: 0.3425
#   Group 2 - Train Loss: 1.9959, Train Accuracy: 0.4860
#   Group 2 - Val Loss: 2.1293, Val Accuracy: 0.4627
#   Group 3 - Train Loss: 1.5715, Train Accuracy: 0.6174
#   Group 3 - Val Loss: 1.5905, Val Accuracy: 0.6079
# Epoch [19/100] Group Metrics:
#   Group 1 - Train Loss: 2.0826, Train Accuracy: 0.3453
#   Group 1 - Val Loss: 2.0903, Val Accuracy: 0.3459
#   Group 2 - Train Loss: 1.9609, Train Accuracy: 0.5003
#   Group 2 - Val Loss: 2.0963, Val Accuracy: 0.4744
#   Group 3 - Train Loss: 1.5443, Train Accuracy: 0.6255
#   Group 3 - Val Loss: 1.5657, Val Accuracy: 0.6142
# Epoch [20/100] Group Metrics:
#   Group 1 - Train Loss: 2.0700, Train Accuracy: 0.3468
#   Group 1 - Val Loss: 2.0784, Val Accuracy: 0.3483
#   Group 2 - Train Loss: 1.9279, Train Accuracy: 0.5129
#   Group 2 - Val Loss: 2.0651, Val Accuracy: 0.4843
#   Group 3 - Train Loss: 1.5188, Train Accuracy: 0.6327
#   Group 3 - Val Loss: 1.5424, Val Accuracy: 0.6217
# Epoch [21/100] Group Metrics:
#   Group 1 - Train Loss: 2.0582, Train Accuracy: 0.3486
#   Group 1 - Val Loss: 2.0673, Val Accuracy: 0.3508
#   Group 2 - Train Loss: 1.8967, Train Accuracy: 0.5225
#   Group 2 - Val Loss: 2.0356, Val Accuracy: 0.4931
#   Group 3 - Train Loss: 1.4947, Train Accuracy: 0.6387
#   Group 3 - Val Loss: 1.5205, Val Accuracy: 0.6276
# Epoch [22/100] Group Metrics:
#   Group 1 - Train Loss: 2.0471, Train Accuracy: 0.3501
#   Group 1 - Val Loss: 2.0569, Val Accuracy: 0.3521
#   Group 2 - Train Loss: 1.8671, Train Accuracy: 0.5334
#   Group 2 - Val Loss: 2.0076, Val Accuracy: 0.5048
#   Group 3 - Train Loss: 1.4719, Train Accuracy: 0.6444
#   Group 3 - Val Loss: 1.4996, Val Accuracy: 0.6333
# Epoch [23/100] Group Metrics:
#   Group 1 - Train Loss: 2.0367, Train Accuracy: 0.3514
#   Group 1 - Val Loss: 2.0470, Val Accuracy: 0.3526
#   Group 2 - Train Loss: 1.8390, Train Accuracy: 0.5453
#   Group 2 - Val Loss: 1.9809, Val Accuracy: 0.5148
#   Group 3 - Train Loss: 1.4502, Train Accuracy: 0.6516
#   Group 3 - Val Loss: 1.4799, Val Accuracy: 0.6393
# Epoch [24/100] Group Metrics:
#   Group 1 - Train Loss: 2.0268, Train Accuracy: 0.3532
#   Group 1 - Val Loss: 2.0377, Val Accuracy: 0.3539
#   Group 2 - Train Loss: 1.8123, Train Accuracy: 0.5506
#   Group 2 - Val Loss: 1.9555, Val Accuracy: 0.5223
#   Group 3 - Train Loss: 1.4297, Train Accuracy: 0.6569
#   Group 3 - Val Loss: 1.4612, Val Accuracy: 0.6435
# Epoch [25/100] Group Metrics:
#   Group 1 - Train Loss: 2.0175, Train Accuracy: 0.3548
#   Group 1 - Val Loss: 2.0288, Val Accuracy: 0.3556
#   Group 2 - Train Loss: 1.7868, Train Accuracy: 0.5585
#   Group 2 - Val Loss: 1.9313, Val Accuracy: 0.5270
#   Group 3 - Train Loss: 1.4102, Train Accuracy: 0.6619
#   Group 3 - Val Loss: 1.4433, Val Accuracy: 0.6485
# Epoch [26/100] Group Metrics:
#   Group 1 - Train Loss: 2.0087, Train Accuracy: 0.3565
#   Group 1 - Val Loss: 2.0204, Val Accuracy: 0.3574
#   Group 2 - Train Loss: 1.7625, Train Accuracy: 0.5655
#   Group 2 - Val Loss: 1.9082, Val Accuracy: 0.5346
#   Group 3 - Train Loss: 1.3915, Train Accuracy: 0.6655
#   Group 3 - Val Loss: 1.4263, Val Accuracy: 0.6520
# Epoch [27/100] Group Metrics:
#   Group 1 - Train Loss: 2.0003, Train Accuracy: 0.3579
#   Group 1 - Val Loss: 2.0124, Val Accuracy: 0.3581
#   Group 2 - Train Loss: 1.7392, Train Accuracy: 0.5728
#   Group 2 - Val Loss: 1.8860, Val Accuracy: 0.5417
#   Group 3 - Train Loss: 1.3737, Train Accuracy: 0.6695
#   Group 3 - Val Loss: 1.4101, Val Accuracy: 0.6569
# Epoch [28/100] Group Metrics:
#   Group 1 - Train Loss: 1.9922, Train Accuracy: 0.3591
#   Group 1 - Val Loss: 2.0048, Val Accuracy: 0.3599
#   Group 2 - Train Loss: 1.7169, Train Accuracy: 0.5796
#   Group 2 - Val Loss: 1.8648, Val Accuracy: 0.5498
#   Group 3 - Train Loss: 1.3567, Train Accuracy: 0.6754
#   Group 3 - Val Loss: 1.3946, Val Accuracy: 0.6604
# Epoch [29/100] Group Metrics:
#   Group 1 - Train Loss: 1.9846, Train Accuracy: 0.3606
#   Group 1 - Val Loss: 1.9975, Val Accuracy: 0.3618
#   Group 2 - Train Loss: 1.6956, Train Accuracy: 0.5848
#   Group 2 - Val Loss: 1.8444, Val Accuracy: 0.5569
#   Group 3 - Train Loss: 1.3404, Train Accuracy: 0.6796
#   Group 3 - Val Loss: 1.3797, Val Accuracy: 0.6650
# Epoch [30/100] Group Metrics:
#   Group 1 - Train Loss: 1.9773, Train Accuracy: 0.3619
#   Group 1 - Val Loss: 1.9905, Val Accuracy: 0.3627
#   Group 2 - Train Loss: 1.6750, Train Accuracy: 0.5913
#   Group 2 - Val Loss: 1.8248, Val Accuracy: 0.5650
#   Group 3 - Train Loss: 1.3248, Train Accuracy: 0.6836
#   Group 3 - Val Loss: 1.3654, Val Accuracy: 0.6682
# Epoch [31/100] Group Metrics:
#   Group 1 - Train Loss: 1.9702, Train Accuracy: 0.3634
#   Group 1 - Val Loss: 1.9839, Val Accuracy: 0.3632
#   Group 2 - Train Loss: 1.6553, Train Accuracy: 0.5977
#   Group 2 - Val Loss: 1.8060, Val Accuracy: 0.5715
#   Group 3 - Train Loss: 1.3098, Train Accuracy: 0.6883
#   Group 3 - Val Loss: 1.3518, Val Accuracy: 0.6726
# Epoch [32/100] Group Metrics:
#   Group 1 - Train Loss: 1.9635, Train Accuracy: 0.3643
#   Group 1 - Val Loss: 1.9774, Val Accuracy: 0.3643
#   Group 2 - Train Loss: 1.6363, Train Accuracy: 0.6045
#   Group 2 - Val Loss: 1.7879, Val Accuracy: 0.5767
#   Group 3 - Train Loss: 1.2954, Train Accuracy: 0.6922
#   Group 3 - Val Loss: 1.3386, Val Accuracy: 0.6754
# Epoch [33/100] Group Metrics:
#   Group 1 - Train Loss: 1.9571, Train Accuracy: 0.3654
#   Group 1 - Val Loss: 1.9713, Val Accuracy: 0.3654
#   Group 2 - Train Loss: 1.6180, Train Accuracy: 0.6129
#   Group 2 - Val Loss: 1.7704, Val Accuracy: 0.5808
#   Group 3 - Train Loss: 1.2816, Train Accuracy: 0.6966
#   Group 3 - Val Loss: 1.3260, Val Accuracy: 0.6784
# Epoch [34/100] Group Metrics:
#   Group 1 - Train Loss: 1.9508, Train Accuracy: 0.3663
#   Group 1 - Val Loss: 1.9653, Val Accuracy: 0.3670
#   Group 2 - Train Loss: 1.6003, Train Accuracy: 0.6179
#   Group 2 - Val Loss: 1.7535, Val Accuracy: 0.5826
#   Group 3 - Train Loss: 1.2682, Train Accuracy: 0.7006
#   Group 3 - Val Loss: 1.3138, Val Accuracy: 0.6811
# Epoch [35/100] Group Metrics:
#   Group 1 - Train Loss: 1.9449, Train Accuracy: 0.3675
#   Group 1 - Val Loss: 1.9596, Val Accuracy: 0.3679
#   Group 2 - Train Loss: 1.5832, Train Accuracy: 0.6214
#   Group 2 - Val Loss: 1.7372, Val Accuracy: 0.5884
#   Group 3 - Train Loss: 1.2554, Train Accuracy: 0.7043
#   Group 3 - Val Loss: 1.3021, Val Accuracy: 0.6836
# Epoch [36/100] Group Metrics:
#   Group 1 - Train Loss: 1.9391, Train Accuracy: 0.3687
#   Group 1 - Val Loss: 1.9541, Val Accuracy: 0.3689
#   Group 2 - Train Loss: 1.5668, Train Accuracy: 0.6249
#   Group 2 - Val Loss: 1.7215, Val Accuracy: 0.5913
#   Group 3 - Train Loss: 1.2430, Train Accuracy: 0.7078
#   Group 3 - Val Loss: 1.2908, Val Accuracy: 0.6856
# Epoch [37/100] Group Metrics:
#   Group 1 - Train Loss: 1.9335, Train Accuracy: 0.3697
#   Group 1 - Val Loss: 1.9488, Val Accuracy: 0.3699
#   Group 2 - Train Loss: 1.5508, Train Accuracy: 0.6305
#   Group 2 - Val Loss: 1.7063, Val Accuracy: 0.5966
#   Group 3 - Train Loss: 1.2310, Train Accuracy: 0.7107
#   Group 3 - Val Loss: 1.2799, Val Accuracy: 0.6877
# Epoch [38/100] Group Metrics:
#   Group 1 - Train Loss: 1.9281, Train Accuracy: 0.3708
#   Group 1 - Val Loss: 1.9436, Val Accuracy: 0.3707
#   Group 2 - Train Loss: 1.5354, Train Accuracy: 0.6346
#   Group 2 - Val Loss: 1.6916, Val Accuracy: 0.6013
#   Group 3 - Train Loss: 1.2194, Train Accuracy: 0.7126
#   Group 3 - Val Loss: 1.2694, Val Accuracy: 0.6924
# Epoch [39/100] Group Metrics:
#   Group 1 - Train Loss: 1.9229, Train Accuracy: 0.3717
#   Group 1 - Val Loss: 1.9386, Val Accuracy: 0.3716
#   Group 2 - Train Loss: 1.5205, Train Accuracy: 0.6395
#   Group 2 - Val Loss: 1.6773, Val Accuracy: 0.6054
#   Group 3 - Train Loss: 1.2083, Train Accuracy: 0.7154
#   Group 3 - Val Loss: 1.2592, Val Accuracy: 0.6948
# Epoch [40/100] Group Metrics:
#   Group 1 - Train Loss: 1.9179, Train Accuracy: 0.3721
#   Group 1 - Val Loss: 1.9338, Val Accuracy: 0.3726
#   Group 2 - Train Loss: 1.5060, Train Accuracy: 0.6430
#   Group 2 - Val Loss: 1.6635, Val Accuracy: 0.6089
#   Group 3 - Train Loss: 1.1974, Train Accuracy: 0.7178
#   Group 3 - Val Loss: 1.2494, Val Accuracy: 0.6961
# Epoch [41/100] Group Metrics:
#   Group 1 - Train Loss: 1.9130, Train Accuracy: 0.3729
#   Group 1 - Val Loss: 1.9291, Val Accuracy: 0.3733
#   Group 2 - Train Loss: 1.4919, Train Accuracy: 0.6474
#   Group 2 - Val Loss: 1.6501, Val Accuracy: 0.6136
#   Group 3 - Train Loss: 1.1869, Train Accuracy: 0.7198
#   Group 3 - Val Loss: 1.2399, Val Accuracy: 0.6993
# Epoch [42/100] Group Metrics:
#   Group 1 - Train Loss: 1.9083, Train Accuracy: 0.3744
#   Group 1 - Val Loss: 1.9246, Val Accuracy: 0.3746
#   Group 2 - Train Loss: 1.4783, Train Accuracy: 0.6515
#   Group 2 - Val Loss: 1.6371, Val Accuracy: 0.6153
#   Group 3 - Train Loss: 1.1768, Train Accuracy: 0.7221
#   Group 3 - Val Loss: 1.2306, Val Accuracy: 0.7010
# Epoch [43/100] Group Metrics:
#   Group 1 - Train Loss: 1.9037, Train Accuracy: 0.3750
#   Group 1 - Val Loss: 1.9202, Val Accuracy: 0.3755
#   Group 2 - Train Loss: 1.4651, Train Accuracy: 0.6541
#   Group 2 - Val Loss: 1.6245, Val Accuracy: 0.6188
#   Group 3 - Train Loss: 1.1669, Train Accuracy: 0.7246
#   Group 3 - Val Loss: 1.2217, Val Accuracy: 0.7030
# Epoch [44/100] Group Metrics:
#   Group 1 - Train Loss: 1.8992, Train Accuracy: 0.3759
#   Group 1 - Val Loss: 1.9159, Val Accuracy: 0.3765
#   Group 2 - Train Loss: 1.4523, Train Accuracy: 0.6585
#   Group 2 - Val Loss: 1.6122, Val Accuracy: 0.6264
#   Group 3 - Train Loss: 1.1574, Train Accuracy: 0.7265
#   Group 3 - Val Loss: 1.2130, Val Accuracy: 0.7055
# Epoch [45/100] Group Metrics:
#   Group 1 - Train Loss: 1.8949, Train Accuracy: 0.3765
#   Group 1 - Val Loss: 1.9117, Val Accuracy: 0.3774
#   Group 2 - Train Loss: 1.4398, Train Accuracy: 0.6603
#   Group 2 - Val Loss: 1.6003, Val Accuracy: 0.6282
#   Group 3 - Train Loss: 1.1481, Train Accuracy: 0.7288
#   Group 3 - Val Loss: 1.2046, Val Accuracy: 0.7073
# Epoch [46/100] Group Metrics:
#   Group 1 - Train Loss: 1.8907, Train Accuracy: 0.3772
#   Group 1 - Val Loss: 1.9077, Val Accuracy: 0.3783
#   Group 2 - Train Loss: 1.4276, Train Accuracy: 0.6638
#   Group 2 - Val Loss: 1.5887, Val Accuracy: 0.6328
#   Group 3 - Train Loss: 1.1391, Train Accuracy: 0.7308
#   Group 3 - Val Loss: 1.1965, Val Accuracy: 0.7093
# Epoch [47/100] Group Metrics:
#   Group 1 - Train Loss: 1.8866, Train Accuracy: 0.3783
#   Group 1 - Val Loss: 1.9038, Val Accuracy: 0.3792
#   Group 2 - Train Loss: 1.4158, Train Accuracy: 0.6670
#   Group 2 - Val Loss: 1.5774, Val Accuracy: 0.6352
#   Group 3 - Train Loss: 1.1303, Train Accuracy: 0.7327
#   Group 3 - Val Loss: 1.1885, Val Accuracy: 0.7115
# Epoch [48/100] Group Metrics:
#   Group 1 - Train Loss: 1.8826, Train Accuracy: 0.3792
#   Group 1 - Val Loss: 1.8999, Val Accuracy: 0.3797
#   Group 2 - Train Loss: 1.4043, Train Accuracy: 0.6702
#   Group 2 - Val Loss: 1.5665, Val Accuracy: 0.6392
#   Group 3 - Train Loss: 1.1218, Train Accuracy: 0.7343
#   Group 3 - Val Loss: 1.1808, Val Accuracy: 0.7123
# Epoch [49/100] Group Metrics:
#   Group 1 - Train Loss: 1.8787, Train Accuracy: 0.3797
#   Group 1 - Val Loss: 1.8962, Val Accuracy: 0.3804
#   Group 2 - Train Loss: 1.3931, Train Accuracy: 0.6726
#   Group 2 - Val Loss: 1.5558, Val Accuracy: 0.6404
#   Group 3 - Train Loss: 1.1135, Train Accuracy: 0.7359
#   Group 3 - Val Loss: 1.1733, Val Accuracy: 0.7132
# Epoch [50/100] Group Metrics:
#   Group 1 - Train Loss: 1.8749, Train Accuracy: 0.3805
#   Group 1 - Val Loss: 1.8926, Val Accuracy: 0.3813
#   Group 2 - Train Loss: 1.3822, Train Accuracy: 0.6740
#   Group 2 - Val Loss: 1.5454, Val Accuracy: 0.6387
#   Group 3 - Train Loss: 1.1054, Train Accuracy: 0.7378
#   Group 3 - Val Loss: 1.1660, Val Accuracy: 0.7152
# Epoch [51/100] Group Metrics:
#   Group 1 - Train Loss: 1.8712, Train Accuracy: 0.3816
#   Group 1 - Val Loss: 1.8890, Val Accuracy: 0.3823
#   Group 2 - Train Loss: 1.3716, Train Accuracy: 0.6767
#   Group 2 - Val Loss: 1.5353, Val Accuracy: 0.6416
#   Group 3 - Train Loss: 1.0975, Train Accuracy: 0.7393
#   Group 3 - Val Loss: 1.1589, Val Accuracy: 0.7172
# Epoch [52/100] Group Metrics:
#   Group 1 - Train Loss: 1.8675, Train Accuracy: 0.3822
#   Group 1 - Val Loss: 1.8855, Val Accuracy: 0.3833
#   Group 2 - Train Loss: 1.3612, Train Accuracy: 0.6808
#   Group 2 - Val Loss: 1.5254, Val Accuracy: 0.6433
#   Group 3 - Train Loss: 1.0898, Train Accuracy: 0.7413
#   Group 3 - Val Loss: 1.1520, Val Accuracy: 0.7178
# Epoch [53/100] Group Metrics:
#   Group 1 - Train Loss: 1.8640, Train Accuracy: 0.3828
#   Group 1 - Val Loss: 1.8822, Val Accuracy: 0.3831
#   Group 2 - Train Loss: 1.3511, Train Accuracy: 0.6825
#   Group 2 - Val Loss: 1.5158, Val Accuracy: 0.6451
#   Group 3 - Train Loss: 1.0824, Train Accuracy: 0.7431
#   Group 3 - Val Loss: 1.1453, Val Accuracy: 0.7187
# Epoch [54/100] Group Metrics:
#   Group 1 - Train Loss: 1.8606, Train Accuracy: 0.3838
#   Group 1 - Val Loss: 1.8789, Val Accuracy: 0.3843
#   Group 2 - Train Loss: 1.3413, Train Accuracy: 0.6851
#   Group 2 - Val Loss: 1.5064, Val Accuracy: 0.6469
#   Group 3 - Train Loss: 1.0751, Train Accuracy: 0.7446
#   Group 3 - Val Loss: 1.1388, Val Accuracy: 0.7200
# Epoch [55/100] Group Metrics:
#   Group 1 - Train Loss: 1.8572, Train Accuracy: 0.3842
#   Group 1 - Val Loss: 1.8756, Val Accuracy: 0.3849
#   Group 2 - Train Loss: 1.3316, Train Accuracy: 0.6881
#   Group 2 - Val Loss: 1.4972, Val Accuracy: 0.6492
#   Group 3 - Train Loss: 1.0680, Train Accuracy: 0.7464
#   Group 3 - Val Loss: 1.1324, Val Accuracy: 0.7208
# Epoch [56/100] Group Metrics:
#   Group 1 - Train Loss: 1.8539, Train Accuracy: 0.3850
#   Group 1 - Val Loss: 1.8725, Val Accuracy: 0.3848
#   Group 2 - Train Loss: 1.3222, Train Accuracy: 0.6907
#   Group 2 - Val Loss: 1.4882, Val Accuracy: 0.6498
#   Group 3 - Train Loss: 1.0610, Train Accuracy: 0.7476
#   Group 3 - Val Loss: 1.1262, Val Accuracy: 0.7218
# Epoch [57/100] Group Metrics:
#   Group 1 - Train Loss: 1.8507, Train Accuracy: 0.3860
#   Group 1 - Val Loss: 1.8694, Val Accuracy: 0.3859
#   Group 2 - Train Loss: 1.3130, Train Accuracy: 0.6922
#   Group 2 - Val Loss: 1.4795, Val Accuracy: 0.6533
#   Group 3 - Train Loss: 1.0542, Train Accuracy: 0.7491
#   Group 3 - Val Loss: 1.1201, Val Accuracy: 0.7223
# Epoch [58/100] Group Metrics:
#   Group 1 - Train Loss: 1.8475, Train Accuracy: 0.3865
#   Group 1 - Val Loss: 1.8664, Val Accuracy: 0.3861
#   Group 2 - Train Loss: 1.3041, Train Accuracy: 0.6948
#   Group 2 - Val Loss: 1.4709, Val Accuracy: 0.6545
#   Group 3 - Train Loss: 1.0476, Train Accuracy: 0.7500
#   Group 3 - Val Loss: 1.1142, Val Accuracy: 0.7235
# Epoch [59/100] Group Metrics:
#   Group 1 - Train Loss: 1.8444, Train Accuracy: 0.3873
#   Group 1 - Val Loss: 1.8634, Val Accuracy: 0.3869
#   Group 2 - Train Loss: 1.2953, Train Accuracy: 0.6951
#   Group 2 - Val Loss: 1.4625, Val Accuracy: 0.6545
#   Group 3 - Train Loss: 1.0411, Train Accuracy: 0.7514
#   Group 3 - Val Loss: 1.1084, Val Accuracy: 0.7247
# Epoch [60/100] Group Metrics:
#   Group 1 - Train Loss: 1.8414, Train Accuracy: 0.3877
#   Group 1 - Val Loss: 1.8605, Val Accuracy: 0.3875
#   Group 2 - Train Loss: 1.2867, Train Accuracy: 0.6971
#   Group 2 - Val Loss: 1.4544, Val Accuracy: 0.6550
#   Group 3 - Train Loss: 1.0348, Train Accuracy: 0.7531
#   Group 3 - Val Loss: 1.1027, Val Accuracy: 0.7252
# Epoch [61/100] Group Metrics:
#   Group 1 - Train Loss: 1.8384, Train Accuracy: 0.3884
#   Group 1 - Val Loss: 1.8577, Val Accuracy: 0.3877
#   Group 2 - Train Loss: 1.2783, Train Accuracy: 0.6998
#   Group 2 - Val Loss: 1.4464, Val Accuracy: 0.6574
#   Group 3 - Train Loss: 1.0286, Train Accuracy: 0.7546
#   Group 3 - Val Loss: 1.0972, Val Accuracy: 0.7259
# Epoch [62/100] Group Metrics:
#   Group 1 - Train Loss: 1.8355, Train Accuracy: 0.3889
#   Group 1 - Val Loss: 1.8549, Val Accuracy: 0.3887
#   Group 2 - Train Loss: 1.2701, Train Accuracy: 0.7021
#   Group 2 - Val Loss: 1.4386, Val Accuracy: 0.6591
#   Group 3 - Train Loss: 1.0226, Train Accuracy: 0.7556
#   Group 3 - Val Loss: 1.0918, Val Accuracy: 0.7269
# Epoch [63/100] Group Metrics:
#   Group 1 - Train Loss: 1.8327, Train Accuracy: 0.3899
#   Group 1 - Val Loss: 1.8522, Val Accuracy: 0.3893
#   Group 2 - Train Loss: 1.2620, Train Accuracy: 0.7044
#   Group 2 - Val Loss: 1.4309, Val Accuracy: 0.6626
#   Group 3 - Train Loss: 1.0166, Train Accuracy: 0.7565
#   Group 3 - Val Loss: 1.0865, Val Accuracy: 0.7277
# Epoch [64/100] Group Metrics:
#   Group 1 - Train Loss: 1.8299, Train Accuracy: 0.3905
#   Group 1 - Val Loss: 1.8495, Val Accuracy: 0.3894
#   Group 2 - Train Loss: 1.2542, Train Accuracy: 0.7059
#   Group 2 - Val Loss: 1.4234, Val Accuracy: 0.6626
#   Group 3 - Train Loss: 1.0108, Train Accuracy: 0.7575
#   Group 3 - Val Loss: 1.0814, Val Accuracy: 0.7294
# Epoch [65/100] Group Metrics:
#   Group 1 - Train Loss: 1.8271, Train Accuracy: 0.3912
#   Group 1 - Val Loss: 1.8469, Val Accuracy: 0.3901
#   Group 2 - Train Loss: 1.2465, Train Accuracy: 0.7062
#   Group 2 - Val Loss: 1.4161, Val Accuracy: 0.6638
#   Group 3 - Train Loss: 1.0052, Train Accuracy: 0.7582
#   Group 3 - Val Loss: 1.0764, Val Accuracy: 0.7310
# Epoch [66/100] Group Metrics:
#   Group 1 - Train Loss: 1.8244, Train Accuracy: 0.3918
#   Group 1 - Val Loss: 1.8443, Val Accuracy: 0.3906
#   Group 2 - Train Loss: 1.2389, Train Accuracy: 0.7082
#   Group 2 - Val Loss: 1.4089, Val Accuracy: 0.6656
#   Group 3 - Train Loss: 0.9996, Train Accuracy: 0.7594
#   Group 3 - Val Loss: 1.0714, Val Accuracy: 0.7319
# Epoch [67/100] Group Metrics:
#   Group 1 - Train Loss: 1.8218, Train Accuracy: 0.3922
#   Group 1 - Val Loss: 1.8418, Val Accuracy: 0.3914
#   Group 2 - Train Loss: 1.2315, Train Accuracy: 0.7091
#   Group 2 - Val Loss: 1.4018, Val Accuracy: 0.6673
#   Group 3 - Train Loss: 0.9942, Train Accuracy: 0.7606
#   Group 3 - Val Loss: 1.0666, Val Accuracy: 0.7329
# Epoch [68/100] Group Metrics:
#   Group 1 - Train Loss: 1.8192, Train Accuracy: 0.3926
#   Group 1 - Val Loss: 1.8393, Val Accuracy: 0.3918
#   Group 2 - Train Loss: 1.2242, Train Accuracy: 0.7117
#   Group 2 - Val Loss: 1.3949, Val Accuracy: 0.6679
#   Group 3 - Train Loss: 0.9888, Train Accuracy: 0.7614
#   Group 3 - Val Loss: 1.0619, Val Accuracy: 0.7339
# Epoch [69/100] Group Metrics:
#   Group 1 - Train Loss: 1.8166, Train Accuracy: 0.3933
#   Group 1 - Val Loss: 1.8368, Val Accuracy: 0.3924
#   Group 2 - Train Loss: 1.2171, Train Accuracy: 0.7147
#   Group 2 - Val Loss: 1.3881, Val Accuracy: 0.6691
#   Group 3 - Train Loss: 0.9836, Train Accuracy: 0.7619
#   Group 3 - Val Loss: 1.0573, Val Accuracy: 0.7342
# Epoch [70/100] Group Metrics:
#   Group 1 - Train Loss: 1.8141, Train Accuracy: 0.3940
#   Group 1 - Val Loss: 1.8344, Val Accuracy: 0.3931
#   Group 2 - Train Loss: 1.2101, Train Accuracy: 0.7167
#   Group 2 - Val Loss: 1.3815, Val Accuracy: 0.6726
#   Group 3 - Train Loss: 0.9784, Train Accuracy: 0.7634
#   Group 3 - Val Loss: 1.0527, Val Accuracy: 0.7342
# Epoch [71/100] Group Metrics:
#   Group 1 - Train Loss: 1.8116, Train Accuracy: 0.3949
#   Group 1 - Val Loss: 1.8321, Val Accuracy: 0.3941
#   Group 2 - Train Loss: 1.2032, Train Accuracy: 0.7185
#   Group 2 - Val Loss: 1.3750, Val Accuracy: 0.6749
#   Group 3 - Train Loss: 0.9734, Train Accuracy: 0.7639
#   Group 3 - Val Loss: 1.0483, Val Accuracy: 0.7349
# Epoch [72/100] Group Metrics:
#   Group 1 - Train Loss: 1.8092, Train Accuracy: 0.3953
#   Group 1 - Val Loss: 1.8298, Val Accuracy: 0.3945
#   Group 2 - Train Loss: 1.1965, Train Accuracy: 0.7220
#   Group 2 - Val Loss: 1.3686, Val Accuracy: 0.6761
#   Group 3 - Train Loss: 0.9685, Train Accuracy: 0.7646
#   Group 3 - Val Loss: 1.0439, Val Accuracy: 0.7361
# Epoch [73/100] Group Metrics:
#   Group 1 - Train Loss: 1.8068, Train Accuracy: 0.3958
#   Group 1 - Val Loss: 1.8275, Val Accuracy: 0.3947
#   Group 2 - Train Loss: 1.1899, Train Accuracy: 0.7243
#   Group 2 - Val Loss: 1.3623, Val Accuracy: 0.6773
#   Group 3 - Train Loss: 0.9636, Train Accuracy: 0.7656
#   Group 3 - Val Loss: 1.0397, Val Accuracy: 0.7367
# Epoch [74/100] Group Metrics:
#   Group 1 - Train Loss: 1.8045, Train Accuracy: 0.3964
#   Group 1 - Val Loss: 1.8253, Val Accuracy: 0.3948
#   Group 2 - Train Loss: 1.1834, Train Accuracy: 0.7258
#   Group 2 - Val Loss: 1.3562, Val Accuracy: 0.6796
#   Group 3 - Train Loss: 0.9589, Train Accuracy: 0.7664
#   Group 3 - Val Loss: 1.0355, Val Accuracy: 0.7371
# Epoch [75/100] Group Metrics:
#   Group 1 - Train Loss: 1.8022, Train Accuracy: 0.3969
#   Group 1 - Val Loss: 1.8231, Val Accuracy: 0.3951
#   Group 2 - Train Loss: 1.1771, Train Accuracy: 0.7264
#   Group 2 - Val Loss: 1.3501, Val Accuracy: 0.6814
#   Group 3 - Train Loss: 0.9542, Train Accuracy: 0.7669
#   Group 3 - Val Loss: 1.0314, Val Accuracy: 0.7372
# Epoch [76/100] Group Metrics:
#   Group 1 - Train Loss: 1.7999, Train Accuracy: 0.3977
#   Group 1 - Val Loss: 1.8209, Val Accuracy: 0.3957
#   Group 2 - Train Loss: 1.1708, Train Accuracy: 0.7261
#   Group 2 - Val Loss: 1.3442, Val Accuracy: 0.6808
#   Group 3 - Train Loss: 0.9496, Train Accuracy: 0.7674
#   Group 3 - Val Loss: 1.0274, Val Accuracy: 0.7374
# Epoch [77/100] Group Metrics:
#   Group 1 - Train Loss: 1.7977, Train Accuracy: 0.3985
#   Group 1 - Val Loss: 1.8188, Val Accuracy: 0.3962
#   Group 2 - Train Loss: 1.1646, Train Accuracy: 0.7278
#   Group 2 - Val Loss: 1.3383, Val Accuracy: 0.6808
#   Group 3 - Train Loss: 0.9451, Train Accuracy: 0.7682
#   Group 3 - Val Loss: 1.0235, Val Accuracy: 0.7379
# Epoch [78/100] Group Metrics:
#   Group 1 - Train Loss: 1.7954, Train Accuracy: 0.3989
#   Group 1 - Val Loss: 1.8167, Val Accuracy: 0.3970
#   Group 2 - Train Loss: 1.1586, Train Accuracy: 0.7284
#   Group 2 - Val Loss: 1.3326, Val Accuracy: 0.6808
#   Group 3 - Train Loss: 0.9407, Train Accuracy: 0.7689
#   Group 3 - Val Loss: 1.0196, Val Accuracy: 0.7381
# Epoch [79/100] Group Metrics:
#   Group 1 - Train Loss: 1.7933, Train Accuracy: 0.3993
#   Group 1 - Val Loss: 1.8146, Val Accuracy: 0.3972
#   Group 2 - Train Loss: 1.1527, Train Accuracy: 0.7302
#   Group 2 - Val Loss: 1.3270, Val Accuracy: 0.6814
#   Group 3 - Train Loss: 0.9363, Train Accuracy: 0.7701
#   Group 3 - Val Loss: 1.0158, Val Accuracy: 0.7396
# Epoch [80/100] Group Metrics:
#   Group 1 - Train Loss: 1.7911, Train Accuracy: 0.3998
#   Group 1 - Val Loss: 1.8126, Val Accuracy: 0.3975
#   Group 2 - Train Loss: 1.1468, Train Accuracy: 0.7310
#   Group 2 - Val Loss: 1.3214, Val Accuracy: 0.6831
#   Group 3 - Train Loss: 0.9321, Train Accuracy: 0.7710
#   Group 3 - Val Loss: 1.0121, Val Accuracy: 0.7401
# Epoch [81/100] Group Metrics:
#   Group 1 - Train Loss: 1.7890, Train Accuracy: 0.4002
#   Group 1 - Val Loss: 1.8106, Val Accuracy: 0.3980
#   Group 2 - Train Loss: 1.1411, Train Accuracy: 0.7328
#   Group 2 - Val Loss: 1.3160, Val Accuracy: 0.6837
#   Group 3 - Train Loss: 0.9279, Train Accuracy: 0.7715
#   Group 3 - Val Loss: 1.0084, Val Accuracy: 0.7407
# Epoch [82/100] Group Metrics:
#   Group 1 - Train Loss: 1.7869, Train Accuracy: 0.4009
#   Group 1 - Val Loss: 1.8086, Val Accuracy: 0.3987
#   Group 2 - Train Loss: 1.1354, Train Accuracy: 0.7334
#   Group 2 - Val Loss: 1.3106, Val Accuracy: 0.6860
#   Group 3 - Train Loss: 0.9237, Train Accuracy: 0.7719
#   Group 3 - Val Loss: 1.0048, Val Accuracy: 0.7412
# Epoch [83/100] Group Metrics:
#   Group 1 - Train Loss: 1.7849, Train Accuracy: 0.4013
#   Group 1 - Val Loss: 1.8067, Val Accuracy: 0.3991
#   Group 2 - Train Loss: 1.1299, Train Accuracy: 0.7348
#   Group 2 - Val Loss: 1.3053, Val Accuracy: 0.6884
#   Group 3 - Train Loss: 0.9197, Train Accuracy: 0.7735
#   Group 3 - Val Loss: 1.0013, Val Accuracy: 0.7414
# Epoch [84/100] Group Metrics:
#   Group 1 - Train Loss: 1.7829, Train Accuracy: 0.4020
#   Group 1 - Val Loss: 1.8047, Val Accuracy: 0.3996
#   Group 2 - Train Loss: 1.1244, Train Accuracy: 0.7354
#   Group 2 - Val Loss: 1.3001, Val Accuracy: 0.6895
#   Group 3 - Train Loss: 0.9157, Train Accuracy: 0.7742
#   Group 3 - Val Loss: 0.9978, Val Accuracy: 0.7412
# Epoch [85/100] Group Metrics:
#   Group 1 - Train Loss: 1.7809, Train Accuracy: 0.4024
#   Group 1 - Val Loss: 1.8029, Val Accuracy: 0.4005
#   Group 2 - Train Loss: 1.1190, Train Accuracy: 0.7360
#   Group 2 - Val Loss: 1.2950, Val Accuracy: 0.6907
#   Group 3 - Train Loss: 0.9117, Train Accuracy: 0.7746
#   Group 3 - Val Loss: 0.9944, Val Accuracy: 0.7424
# Epoch [86/100] Group Metrics:
#   Group 1 - Train Loss: 1.7789, Train Accuracy: 0.4032
#   Group 1 - Val Loss: 1.8010, Val Accuracy: 0.4014
#   Group 2 - Train Loss: 1.1137, Train Accuracy: 0.7398
#   Group 2 - Val Loss: 1.2900, Val Accuracy: 0.6907
#   Group 3 - Train Loss: 0.9079, Train Accuracy: 0.7749
#   Group 3 - Val Loss: 0.9911, Val Accuracy: 0.7431
# Epoch [87/100] Group Metrics:
#   Group 1 - Train Loss: 1.7770, Train Accuracy: 0.4041
#   Group 1 - Val Loss: 1.7992, Val Accuracy: 0.4018
#   Group 2 - Train Loss: 1.1085, Train Accuracy: 0.7413
#   Group 2 - Val Loss: 1.2851, Val Accuracy: 0.6913
#   Group 3 - Train Loss: 0.9041, Train Accuracy: 0.7753
#   Group 3 - Val Loss: 0.9878, Val Accuracy: 0.7446
# Epoch [88/100] Group Metrics:
#   Group 1 - Train Loss: 1.7751, Train Accuracy: 0.4047
#   Group 1 - Val Loss: 1.7973, Val Accuracy: 0.4025
#   Group 2 - Train Loss: 1.1033, Train Accuracy: 0.7419
#   Group 2 - Val Loss: 1.2802, Val Accuracy: 0.6930
#   Group 3 - Train Loss: 0.9003, Train Accuracy: 0.7759
#   Group 3 - Val Loss: 0.9846, Val Accuracy: 0.7444
# Epoch [89/100] Group Metrics:
#   Group 1 - Train Loss: 1.7732, Train Accuracy: 0.4053
#   Group 1 - Val Loss: 1.7956, Val Accuracy: 0.4029
#   Group 2 - Train Loss: 1.0983, Train Accuracy: 0.7421
#   Group 2 - Val Loss: 1.2754, Val Accuracy: 0.6936
#   Group 3 - Train Loss: 0.8966, Train Accuracy: 0.7770
#   Group 3 - Val Loss: 0.9814, Val Accuracy: 0.7451
# Epoch [90/100] Group Metrics:
#   Group 1 - Train Loss: 1.7713, Train Accuracy: 0.4061
#   Group 1 - Val Loss: 1.7938, Val Accuracy: 0.4034
#   Group 2 - Train Loss: 1.0933, Train Accuracy: 0.7439
#   Group 2 - Val Loss: 1.2707, Val Accuracy: 0.6960
#   Group 3 - Train Loss: 0.8930, Train Accuracy: 0.7777
#   Group 3 - Val Loss: 0.9782, Val Accuracy: 0.7454
# Epoch [91/100] Group Metrics:
#   Group 1 - Train Loss: 1.7695, Train Accuracy: 0.4064
#   Group 1 - Val Loss: 1.7920, Val Accuracy: 0.4039
#   Group 2 - Train Loss: 1.0884, Train Accuracy: 0.7454
#   Group 2 - Val Loss: 1.2660, Val Accuracy: 0.6995
#   Group 3 - Train Loss: 0.8894, Train Accuracy: 0.7786
#   Group 3 - Val Loss: 0.9752, Val Accuracy: 0.7456
# Epoch [92/100] Group Metrics:
#   Group 1 - Train Loss: 1.7677, Train Accuracy: 0.4070
#   Group 1 - Val Loss: 1.7903, Val Accuracy: 0.4044
#   Group 2 - Train Loss: 1.0835, Train Accuracy: 0.7468
#   Group 2 - Val Loss: 1.2615, Val Accuracy: 0.6995
#   Group 3 - Train Loss: 0.8859, Train Accuracy: 0.7793
#   Group 3 - Val Loss: 0.9721, Val Accuracy: 0.7456
# Epoch [93/100] Group Metrics:
#   Group 1 - Train Loss: 1.7659, Train Accuracy: 0.4077
#   Group 1 - Val Loss: 1.7886, Val Accuracy: 0.4050
#   Group 2 - Train Loss: 1.0788, Train Accuracy: 0.7477
#   Group 2 - Val Loss: 1.2569, Val Accuracy: 0.7001
#   Group 3 - Train Loss: 0.8824, Train Accuracy: 0.7800
#   Group 3 - Val Loss: 0.9692, Val Accuracy: 0.7463
# Epoch [94/100] Group Metrics:
#   Group 1 - Train Loss: 1.7641, Train Accuracy: 0.4080
#   Group 1 - Val Loss: 1.7870, Val Accuracy: 0.4053
#   Group 2 - Train Loss: 1.0741, Train Accuracy: 0.7497
#   Group 2 - Val Loss: 1.2525, Val Accuracy: 0.7042
#   Group 3 - Train Loss: 0.8790, Train Accuracy: 0.7803
#   Group 3 - Val Loss: 0.9662, Val Accuracy: 0.7469
# Epoch [95/100] Group Metrics:
#   Group 1 - Train Loss: 1.7624, Train Accuracy: 0.4084
#   Group 1 - Val Loss: 1.7853, Val Accuracy: 0.4058
#   Group 2 - Train Loss: 1.0694, Train Accuracy: 0.7503
#   Group 2 - Val Loss: 1.2481, Val Accuracy: 0.7059
#   Group 3 - Train Loss: 0.8756, Train Accuracy: 0.7808
#   Group 3 - Val Loss: 0.9634, Val Accuracy: 0.7474
# Epoch [96/100] Group Metrics:
#   Group 1 - Train Loss: 1.7606, Train Accuracy: 0.4088
#   Group 1 - Val Loss: 1.7837, Val Accuracy: 0.4063
#   Group 2 - Train Loss: 1.0649, Train Accuracy: 0.7506
#   Group 2 - Val Loss: 1.2438, Val Accuracy: 0.7065
#   Group 3 - Train Loss: 0.8723, Train Accuracy: 0.7813
#   Group 3 - Val Loss: 0.9605, Val Accuracy: 0.7474
# Epoch [97/100] Group Metrics:
#   Group 1 - Train Loss: 1.7589, Train Accuracy: 0.4092
#   Group 1 - Val Loss: 1.7821, Val Accuracy: 0.4066
#   Group 2 - Train Loss: 1.0604, Train Accuracy: 0.7521
#   Group 2 - Val Loss: 1.2395, Val Accuracy: 0.7071
#   Group 3 - Train Loss: 0.8690, Train Accuracy: 0.7821
#   Group 3 - Val Loss: 0.9577, Val Accuracy: 0.7479
# Epoch [98/100] Group Metrics:
#   Group 1 - Train Loss: 1.7572, Train Accuracy: 0.4096
#   Group 1 - Val Loss: 1.7805, Val Accuracy: 0.4070
#   Group 2 - Train Loss: 1.0559, Train Accuracy: 0.7532
#   Group 2 - Val Loss: 1.2353, Val Accuracy: 0.7077
#   Group 3 - Train Loss: 0.8658, Train Accuracy: 0.7825
#   Group 3 - Val Loss: 0.9550, Val Accuracy: 0.7488
# Epoch [99/100] Group Metrics:
#   Group 1 - Train Loss: 1.7556, Train Accuracy: 0.4101
#   Group 1 - Val Loss: 1.7789, Val Accuracy: 0.4078
#   Group 2 - Train Loss: 1.0515, Train Accuracy: 0.7541
#   Group 2 - Val Loss: 1.2312, Val Accuracy: 0.7083
#   Group 3 - Train Loss: 0.8626, Train Accuracy: 0.7831
#   Group 3 - Val Loss: 0.9523, Val Accuracy: 0.7493
# Epoch [100/100] Group Metrics:
#   Group 1 - Train Loss: 1.7539, Train Accuracy: 0.4104
#   Group 1 - Val Loss: 1.7773, Val Accuracy: 0.4078
#   Group 2 - Train Loss: 1.0472, Train Accuracy: 0.7550
#   Group 2 - Val Loss: 1.2271, Val Accuracy: 0.7088
#   Group 3 - Train Loss: 0.8595, Train Accuracy: 0.7836
#   Group 3 - Val Loss: 0.9496, Val Accuracy: 0.7498

# %%
# Convert metrics to numpy arrays for easy manipulation
group_train_loss_histories = {k: np.array(v) for k, v in group_train_loss_histories.items()}
group_train_accuracy_histories = {k: np.array(v) for k, v in group_train_accuracy_histories.items()}
group_val_loss_histories = {k: np.array(v) for k, v in group_val_loss_histories.items()}
group_val_accuracy_histories = {k: np.array(v) for k, v in group_val_accuracy_histories.items()}

# Handle potential one-dimensional arrays
group_train_loss_mean = {k: v.mean(axis=1) if v.ndim > 1 else v for k, v in group_train_loss_histories.items()}
group_train_loss_std = {k: v.std(axis=1) if v.ndim > 1 else np.zeros_like(v) for k, v in group_train_loss_histories.items()}
group_val_loss_mean = {k: v.mean(axis=1) if v.ndim > 1 else v for k, v in group_val_loss_histories.items()}
group_val_loss_std = {k: v.std(axis=1) if v.ndim > 1 else np.zeros_like(v) for k, v in group_val_loss_histories.items()}

group_train_acc_mean = {k: v.mean(axis=1) if v.ndim > 1 else v for k, v in group_train_accuracy_histories.items()}
group_train_acc_std = {k: v.std(axis=1) if v.ndim > 1 else np.zeros_like(v) for k, v in group_train_accuracy_histories.items()}
group_val_acc_mean = {k: v.mean(axis=1) if v.ndim > 1 else v for k, v in group_val_accuracy_histories.items()}
group_val_acc_std = {k: v.std(axis=1) if v.ndim > 1 else np.zeros_like(v) for k, v in group_val_accuracy_histories.items()}

# Combined Plot for All Modalities
plt.figure(figsize=(12, 6))

# Loss Plot
plt.subplot(1, 2, 1)
for group in [1, 2, 3]:
    plt.plot(range(1, num_epochs + 1), group_train_loss_mean[group], label=f"Group {group} Train Loss")
    plt.fill_between(range(1, num_epochs + 1), 
                     group_train_loss_mean[group] - group_train_loss_std[group], 
                     group_train_loss_mean[group] + group_train_loss_std[group], 
                     alpha=0.2)
    plt.plot(range(1, num_epochs + 1), group_val_loss_mean[group], label=f"Group {group} Validation Loss", linestyle="dashed")
    plt.fill_between(range(1, num_epochs + 1), 
                     group_val_loss_mean[group] - group_val_loss_std[group], 
                     group_val_loss_mean[group] + group_val_loss_std[group], 
                     alpha=0.2)

plt.title("Loss over Epochs for All Groups")
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.legend()
plt.grid()

# Accuracy Plot
plt.subplot(1, 2, 2)
for group in [1, 2, 3]:
    plt.plot(range(1, num_epochs + 1), group_train_acc_mean[group], label=f"Group {group} Train Accuracy")
    plt.fill_between(range(1, num_epochs + 1), 
                     group_train_acc_mean[group] - group_train_acc_std[group], 
                     group_train_acc_mean[group] + group_train_acc_std[group], 
                     alpha=0.2)
    plt.plot(range(1, num_epochs + 1), group_val_acc_mean[group], label=f"Group {group} Validation Accuracy", linestyle="dashed")
    plt.fill_between(range(1, num_epochs + 1), 
                     group_val_acc_mean[group] - group_val_acc_std[group], 
                     group_val_acc_mean[group] + group_val_acc_std[group], 
                     alpha=0.2)

plt.title("Accuracy over Epochs for All Groups")
plt.xlabel("Epoch")
plt.ylabel("Accuracy")
plt.ylim([0, 1])  # Ensure y-axis is between 0 and 1 for accuracy
plt.legend()
plt.grid()

plt.tight_layout()
plt.show()

# %%
# Combined Plot for All Modalities
plt.figure(figsize=(12, 6))

# Loss Plot
plt.subplot(1, 2, 1)
for group in [1, 2, 3]:
    plt.plot(range(1, num_epochs + 1), group_train_loss_mean[group], label=f"Group {group} Train Loss")
    plt.fill_between(range(1, num_epochs + 1), 
                     group_train_loss_mean[group] - group_train_loss_std[group], 
                     group_train_loss_mean[group] + group_train_loss_std[group], 
                     alpha=0.2)
    plt.plot(range(1, num_epochs + 1), group_val_loss_mean[group], label=f"Group {group} Validation Loss", linestyle="dashed")
    plt.fill_between(range(1, num_epochs + 1), 
                     group_val_loss_mean[group] - group_val_loss_std[group], 
                     group_val_loss_mean[group] + group_val_loss_std[group], 
                     alpha=0.2)

plt.title("Loss over Epochs for All Groups")
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.legend()
plt.grid()

# Accuracy Plot
plt.subplot(1, 2, 2)
for group in [1, 2, 3]:
    plt.plot(range(1, num_epochs + 1), group_train_acc_mean[group], label=f"Group {group} Train Accuracy")
    plt.fill_between(range(1, num_epochs + 1), 
                     group_train_acc_mean[group] - group_train_acc_std[group], 
                     group_train_acc_mean[group] + group_train_acc_std[group], 
                     alpha=0.2)
    plt.plot(range(1, num_epochs + 1), group_val_acc_mean[group], label=f"Group {group} Validation Accuracy", linestyle="dashed")
    plt.fill_between(range(1, num_epochs + 1), 
                     group_val_acc_mean[group] - group_val_acc_std[group], 
                     group_val_acc_mean[group] + group_val_acc_std[group], 
                     alpha=0.2)

plt.title("Accuracy over Epochs for All Groups")
plt.xlabel("Epoch")
plt.ylabel("Accuracy")
plt.ylim([0, 1])  # Ensure y-axis is between 0 and 1 for accuracy
plt.legend()
plt.grid()

plt.tight_layout()
plt.show()

# %%
# Track metrics across all groups
'''
group_test_loss_histories = {group: [] for group in range(1, num_groups + 1)}
group_test_accuracy_histories = {group: [] for group in range(1, num_groups + 1)}
group_train_loss_histories = {group: [] for group in range(1, num_groups + 1)}
group_train_accuracy_histories = {group: [] for group in range(1, num_groups + 1)}

with torch.no_grad():  # Disable gradient computation for testing
    for group in range(1, num_groups + 1):
        user_test_losses = []
        user_test_accuracies = []
        user_train_losses = []
        user_train_accuracies = []

        for user_id, model in enumerate(classifiers_by_group[group]):
            model.eval()

            # Test metrics
            epoch_test_loss = 0.0
            correct_test_predictions = 0
            total_test_samples = 0

            # Train metrics (optional, for post-training evaluation on training data)
            epoch_train_loss = 0.0
            correct_train_predictions = 0
            total_train_samples = 0

            # Evaluate on test set
            for X_batch, y_batch in test_loaders_by_group[group][user_id]:
                X_batch, y_batch = X_batch.cuda(), y_batch.cuda()
                outputs = model(X_batch)
                loss = criterion(outputs, y_batch)

                epoch_test_loss += loss.item()
                _, predicted = torch.max(outputs, dim=1)
                correct_test_predictions += (predicted == y_batch).sum().item()
                total_test_samples += y_batch.size(0)

            # Evaluate on training set
            for X_batch, y_batch in train_loaders_by_group[group][user_id]:
                X_batch, y_batch = X_batch.cuda(), y_batch.cuda()
                outputs = model(X_batch)
                loss = criterion(outputs, y_batch)

                epoch_train_loss += loss.item()
                _, predicted = torch.max(outputs, dim=1)
                correct_train_predictions += (predicted == y_batch).sum().item()
                total_train_samples += y_batch.size(0)

            # Calculate averages
            avg_test_loss = epoch_test_loss / len(test_loaders_by_group[group][user_id])
            test_accuracy = correct_test_predictions / total_test_samples

            avg_train_loss = epoch_train_loss / len(train_loaders_by_group[group][user_id])
            train_accuracy = correct_train_predictions / total_train_samples

            # Store metrics for each user
            user_test_losses.append(avg_test_loss)
            user_test_accuracies.append(test_accuracy)
            user_train_losses.append(avg_train_loss)
            user_train_accuracies.append(train_accuracy)

        # Store group-level metrics
        group_test_loss_histories[group].append(np.mean(user_test_losses))
        group_test_accuracy_histories[group].append(np.mean(user_test_accuracies))
        group_train_loss_histories[group].append(np.mean(user_train_losses))
        group_train_accuracy_histories[group].append(np.mean(user_train_accuracies))

# Convert metrics to numpy arrays for plotting
group_test_loss_histories = {group: np.array(values) for group, values in group_test_loss_histories.items()}
group_test_accuracy_histories = {group: np.array(values) for group, values in group_test_accuracy_histories.items()}
group_train_loss_histories = {group: np.array(values) for group, values in group_train_loss_histories.items()}
group_train_accuracy_histories = {group: np.array(values) for group, values in group_train_accuracy_histories.items()}

# Plot results for all groups
plt.figure(figsize=(12, 6))

# Test Loss and Accuracy
plt.subplot(1, 2, 1)
for group in range(1, num_groups + 1):
    plt.plot(range(1, len(group_test_loss_histories[group]) + 1), group_test_loss_histories[group], label=f"Group {group} Test Loss")
plt.title("Test Loss Across Groups")
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.legend()
plt.grid()

plt.subplot(1, 2, 2)
for group in range(1, num_groups + 1):
    plt.plot(range(1, len(group_test_accuracy_histories[group]) + 1), group_test_accuracy_histories[group], label=f"Group {group} Test Accuracy")
plt.title("Test Accuracy Across Groups")
plt.xlabel("Epoch")
plt.ylabel("Accuracy")
plt.legend()
plt.grid()

plt.tight_layout()
plt.show()
'''
# Out:
# '\ngroup_test_loss_histories = {group: [] for group in range(1, num_groups + 1)}\ngroup_test_accuracy_histories = {group: [] for group in range(1, num_groups + 1)}\ngroup_train_loss_histories = {group: [] for group in range(1, num_groups + 1)}\ngroup_train_accuracy_histories = {group: [] for group in range(1, num_groups + 1)}\n\nwith torch.no_grad():  # Disable gradient computation for testing\n    for group in range(1, num_groups + 1):\n        user_test_losses = []\n        user_test_accuracies = []\n        user_train_losses = []\n        user_train_accuracies = []\n\n        for user_id, model in enumerate(classifiers_by_group[group]):\n            model.eval()\n\n            # Test metrics\n            epoch_test_loss = 0.0\n            correct_test_predictions = 0\n            total_test_samples = 0\n\n            # Train metrics (optional, for post-training evaluation on training data)\n            epoch_train_loss = 0.0\n            correct_train_predictions = 0\n            total_train_samples = 0\n\n            # Evaluate on test set\n            for X_batch, y_batch in test_loaders_by_group[group][user_id]:\n                X_batch, y_batch = X_batch.cuda(), y_batch.cuda()\n                outputs = model(X_batch)\n                loss = criterion(outputs, y_batch)\n\n                epoch_test_loss += loss.item()\n                _, predicted = torch.max(outputs, dim=1)\n                correct_test_predictions += (predicted == y_batch).sum().item()\n                total_test_samples += y_batch.size(0)\n\n            # Evaluate on training set\n            for X_batch, y_batch in train_loaders_by_group[group][user_id]:\n                X_batch, y_batch = X_batch.cuda(), y_batch.cuda()\n                outputs = model(X_batch)\n                loss = criterion(outputs, y_batch)\n\n                epoch_train_loss += loss.item()\n                _, predicted = torch.max(outputs, dim=1)\n                correct_train_predictions += (predicted == y_batch).sum().item()\n                total_train_samples += y_batch.size(0)\n\n            # Calculate averages\n            avg_test_loss = epoch_test_loss / len(test_loaders_by_group[group][user_id])\n            test_accuracy = correct_test_predictions / total_test_samples\n\n            avg_train_loss = epoch_train_loss / len(train_loaders_by_group[group][user_id])\n            train_accuracy = correct_train_predictions / total_train_samples\n\n            # Store metrics for each user\n            user_test_losses.append(avg_test_loss)\n            user_test_accuracies.append(test_accuracy)\n            user_train_losses.append(avg_train_loss)\n            user_train_accuracies.append(train_accuracy)\n\n        # Store group-level metrics\n        group_test_loss_histories[group].append(np.mean(user_test_losses))\n        group_test_accuracy_histories[group].append(np.mean(user_test_accuracies))\n        group_train_loss_histories[group].append(np.mean(user_train_losses))\n        group_train_accuracy_histories[group].append(np.mean(user_train_accuracies))\n\n# Convert metrics to numpy arrays for plotting\ngroup_test_loss_histories = {group: np.array(values) for group, values in group_test_loss_histories.items()}\ngroup_test_accuracy_histories = {group: np.array(values) for group, values in group_test_accuracy_histories.items()}\ngroup_train_loss_histories = {group: np.array(values) for group, values in group_train_loss_histories.items()}\ngroup_train_accuracy_histories = {group: np.array(values) for group, values in group_train_accuracy_histories.items()}\n\n# Plot results for all groups\nplt.figure(figsize=(12, 6))\n\n# Test Loss and Accuracy\nplt.subplot(1, 2, 1)\nfor group in range(1, num_groups + 1):\n    plt.plot(range(1, len(group_test_loss_histories[group]) + 1), group_test_loss_histories[group], label=f"Group {group} Test Loss")\nplt.title("Test Loss Across Groups")\nplt.xlabel("Epoch")\nplt.ylabel("Loss")\nplt.legend()\nplt.grid()\n\nplt.subplot(1, 2, 2)\nfor ...

# %%
# Images only
'''
Test Loss: 0.4364, Test Accuracy: 0.8521

Train Loss: 0.4047, Train Accuracy: 0.8687

'''
# Out:
# '\nTest Loss: 0.4364, Test Accuracy: 0.8521\n\nTrain Loss: 0.4047, Train Accuracy: 0.8687\n\n'

# %%
import json
import os

# Define the save directory


# Prepare data to save as JSON
data_to_save = {
    "group_train_loss_mean": group_train_loss_mean,
    "group_train_loss_std": group_train_loss_std,
    "group_val_loss_mean": group_val_loss_mean,
    "group_val_loss_std": group_val_loss_std,
    "group_train_acc_mean": group_train_acc_mean,
    "group_train_acc_std": group_train_acc_std,
    "group_val_acc_mean": group_val_acc_mean,
    "group_val_acc_std": group_val_acc_std
}

# Save the data to a JSON file
with open('No_Comm_Metrics.json', 'w') as f:
    json.dump(data_to_save, f)

print("No_Comm_Metrics.json'.")

# %%
import json

metrics = {
    "train_loss_histories": train_loss_histories.tolist(),
    "train_accuracy_histories": train_accuracy_histories.tolist(),
    "val_loss_histories": val_loss_histories.tolist(),
    "val_accuracy_histories": val_accuracy_histories.tolist(),
    #"test_loss_histories": test_loss_histories.tolist(),
    #"test_accuracy_histories": test_accuracy_histories.tolist(),
}

with open("No_Comm_Metrics.json", "w") as f:
    json.dump(metrics, f)
print("No_Comm_Metrics.json")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[13], line 4
#       1 import json
#       3 metrics = {
# ----> 4     "train_loss_histories": train_loss_histories.tolist(),
#       5     "train_accuracy_histories": train_accuracy_histories.tolist(),
#       6     "val_loss_histories": val_loss_histories.tolist(),
#       7     "val_accuracy_histories": val_accuracy_histories.tolist(),
#       8     #"test_loss_histories": test_loss_histories.tolist(),
#       9     #"test_accuracy_histories": test_accuracy_histories.tolist(),
#      10 }
#      12 with open("No_Comm_Metrics.json", "w") as f:
#      13     json.dump(metrics, f)
#
# NameError: name 'train_loss_histories' is not defined

# %%
# Load metrics from JSON file
with open("metrics.json", "r") as f:
    metrics = json.load(f)

# Convert lists back to numpy arrays
train_loss_histories = np.array(metrics["train_loss_histories"])
train_accuracy_histories = np.array(metrics["train_accuracy_histories"])
val_loss_histories = np.array(metrics["val_loss_histories"])
val_accuracy_histories = np.array(metrics["val_accuracy_histories"])
#test_loss_histories = np.array(metrics["test_loss_histories"])
#test_accuracy_histories = np.array(metrics["test_accuracy_histories"])

# Print shapes to confirm loading
print("Train Loss Histories Shape:", train_loss_histories.shape)
print("Train Accuracy Histories Shape:", train_accuracy_histories.shape)
print("Validation Loss Histories Shape:", val_loss_histories.shape)
print("Validation Accuracy Histories Shape:", val_accuracy_histories.shape)
print("Test Loss Histories Shape:", test_loss_histories.shape)
print("Test Accuracy Histories Shape:", test_accuracy_histories.shape)
