# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader
import pandas as pd
from sklearn.preprocessing import MinMaxScaler
import matplotlib.pyplot as plt
import numpy as np
import random
import os
import seaborn as sns


# Set random seed for reproducibility
seed = 42  # You can choose any integer here

# Set seed for NumPy
np.random.seed(seed)

# Set seed for Python's random module
random.seed(seed)

# Set seed for PyTorch
torch.manual_seed(seed)

# For GPU (if using CUDA)
if torch.cuda.is_available():
    torch.cuda.manual_seed(seed)
    torch.cuda.manual_seed_all(seed)  # For multi-GPU setups

# Set deterministic behavior for reproducibility in case of CUDA operations
torch.backends.cudnn.deterministic = True
torch.backends.cudnn.benchmark = False






# Directory containing the saved CSV files
output_dir = "training_outputs/"

# Load one of the CSV files for EDA (e.g., user_0_outputs.csv)
csv_file = os.path.join(output_dir, "user_1_outputs.csv")
df = pd.read_csv(csv_file)

# Quick overview of the data
print("Data Overview:")
print(df.head())
print("\nData Summary:")
print(df.describe())

# Check for missing values
print("\nMissing Values:")
print(df.isnull().sum())

# Distribution of the target variable (y)
sns.countplot(x="y", data=df)
plt.title("Target Variable Distribution")
plt.show()

# Correlation heatmap of features
correlation_matrix = df.iloc[:, :-1].corr()  # Exclude the target column
plt.figure(figsize=(12, 10))
sns.heatmap(correlation_matrix, cmap="coolwarm", center=0)
plt.title("Feature Correlation Heatmap")
plt.show()
# Out:
# Data Overview:
#    Feature_1  Feature_2  Feature_3  Feature_4  Feature_5  Feature_6  \
# 0   0.421776   0.574011   0.599583   0.479369   0.509436   0.519414
# 1   0.086067   0.148184   0.152437   0.115488   0.161196   0.144720
# 2   0.280018   0.396211   0.411088   0.327705   0.365325   0.362988
# 3   0.044752   0.091481   0.096576   0.066178   0.111749   0.093948
# 4   0.435670   0.591882   0.617901   0.494919   0.525206   0.535559
#
#    Feature_7  Feature_8  Feature_9  Feature_10  ...  Feature_248  Feature_249  \
# 0   0.574690   0.495442   0.531326    0.494106  ...     3.955962    -2.599507
# 1   0.154916   0.172746   0.145424    0.130367  ...     1.416205     2.409825
# 2   0.399500   0.365175   0.371011    0.344062  ...    -1.774577     0.417372
# 3   0.097663   0.119082   0.093101    0.079053  ...     1.845771    -6.682148
# 4   0.592540   0.511974   0.548630    0.510616  ...    -1.638498     0.237464
#
#    Feature_250  Feature_251  Feature_252  Feature_253  Feature_254  \
# 0    -2.824028     3.207343     4.481820     1.760355    -2.045409
# 1    -2.830098    -3.205759    -1.286574    -1.929583     0.048257
# 2    -3.529148    -4.411303    -1.539506     0.036647     1.178073
# 3    -7.002194     3.167593     1.947836    -0.662846    -2.204346
# 4    -4.354047    -3.189678    -0.677657     0.038237     0.150186
#
#    Feature_255  Feature_256     y
# 0     6.664976     4.071818  23.0
# 1    -4.021476    -4.118016   7.0
# 2    -5.434262    -1.844758  12.0
# 3    11.817616     2.560292   2.0
# 4    -3.505348    -1.192597  12.0
#
# [5 rows x 257 columns]
#
# Data Summary:
#          Feature_1    Feature_2    Feature_3    Feature_4    Feature_5  \
# count  1729.000000  1729.000000  1729.000000  1729.000000  1729.000000
# mean      0.503102     0.674750     0.707234     0.565522     0.591406
# std       0.305822     0.384478     0.406551     0.328657     0.313896
# min       0.040039     0.084679     0.089876     0.060135     0.105939
# 25%       0.275733     0.390899     0.405013     0.322962     0.359840
# 50%       0.445770     0.602072     0.631017     0.502874     0.532985
# 75%       0.721456     0.954447     0.998675     0.805611     0.824830
# max       1.447435     1.856605     1.962084     1.575722     1.553191
#
#          Feature_6    Feature_7    Feature_8    Feature_9   Feature_10  ...  \
# count  1729.000000  1729.000000  1729.000000  1729.000000  1729.000000  ...
# mean      0.608498     0.673942     0.569111     0.623129     0.579362  ...
# std       0.339073     0.379179     0.287768     0.348985     0.327059  ...
# min       0.087753     0.090232     0.112562     0.086922     0.072819  ...
# 25%       0.358084     0.393996     0.357970     0.365209     0.339269  ...
# 50%       0.543714     0.601505     0.515482     0.556710     0.518578  ...
# 75%       0.855919     0.951629     0.787679     0.879350     0.823242  ...
# max       1.651032     1.838824     1.441685     1.695318     1.580941  ...
#
#        Feature_248  Feature_249  Feature_250  Feature_251  Feature_252  \
# count  1729.000000  1729.000000  1729.000000  1729.000000  1729.000000
# mean     -0.179522     0.104686    -3.325056     0.442679     4.043367
# std       2.487278     2.804332     5.085966     3.206815     3.063741
# min      -5.532766    -8.463725   -17.685698    -6.389508    -3.330691
# 25%      -1.666154    -1.179140    -7.675362    -2.562989     2.318085
# 50%      -0.127184    -0.203104    -2.434041     1.114942     3.471254
# 75%       1.280784     2.183245     1.319390     3.193357     6.589784
# max       5.373166     5.942785     4.209180     7.024929    10.306907
#
#        Feature_253  Feature_254  Feature_255  Feature_256            y
# count  1729.000000  1729.000000  1729.000000  1729.000000  1729.000000
# mean      0.261881     0.339557    -1.901711    -0.273255    15.186235
# std       1.247827     2.890773     5.637610     2.653296     5.019063
# min      -3.612994    -6.173142   -11.681425    -6.553059     2.000000
# 25%      -0.676439    -1.840066    -6.520148    -2.467818    14.000000
# 50%       0.623744     0.028661    -3.652000    -0.247093    16.000000
# 75%       1.339245     2.587435     2.879085     1.459362    17.000000
# max       2.689319     6.010867    13.742585     7.049729    30.000000
#
# [8 rows x 257 columns]
#
# Missing Values:
# Feature_1      0
# Feature_2      0
# Feature_3      0
# Feature_4      0
# Feature_5      0
#               ..
# Feature_253    0
# Feature_254    0
# Feature_255    0
# Feature_256    0
# y              0
# Length: 257, dtype: int64

# %%
# Define the Multinomial Logistic Regression model
class MultinomialLogisticRegression(nn.Module):
    def __init__(self, input_size, num_classes):
        super(MultinomialLogisticRegression, self).__init__()
        self.linear = nn.Linear(input_size, num_classes)

    def forward(self, x):
        return self.linear(x)

# Custom dataset to load the data from CSV
class CustomDataset(Dataset):
    def __init__(self, csv_file, scaler=None):
        self.data = pd.read_csv(csv_file)
        self.X = self.data.iloc[:, :-1].values  # Features
        self.y = self.data.iloc[:, -1].values   # Labels

        # If a scaler is provided, use it to transform the features
        if scaler:
            self.X = scaler.transform(self.X)
        else:
            # Fit the scaler on the training data and transform
            self.scaler = MinMaxScaler(feature_range=(-1, 1))
            self.X = self.scaler.fit_transform(self.X)

    def __len__(self):
        return len(self.data)

    def __getitem__(self, idx):
        X = torch.tensor(self.X[idx], dtype=torch.float32)
        y = torch.tensor(self.y[idx], dtype=torch.long)  # Use long for classification targets
        return X, y

# %%
no_users = 20
# List to store DataLoader objects for each user
train_loaders = []
val_loaders = []
test_loaders = []
scaler = None
# Loop over each user
for user_idx in range(no_users):
    # Define file paths for each user dynamically
    train_file = f"training_outputs/user_{user_idx}_outputs.csv"
    val_file = f"val_outputs/user_{user_idx}_outputs.csv"
    test_file = f"test_outputs/user_{user_idx}_outputs.csv"

    # Load training data and fit the scaler on it (only once for each user)
    train_data = pd.read_csv(train_file)
    
    if scaler is None:
        # Fit the scaler on the first user's training data
        scaler = MinMaxScaler(feature_range=(-1, 1))
        scaler.fit(train_data.iloc[:, :-1].values)  # Fit scaler only on training features

    # Create datasets using the same scaler for all data
    train_dataset = CustomDataset(train_file, scaler=scaler)
    val_dataset = CustomDataset(val_file, scaler=scaler)
    test_dataset = CustomDataset(test_file, scaler=scaler)

    # Create DataLoader for training, validation, and testing for each user
    batch_size = 64
    train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=False)
    val_loader = DataLoader(val_dataset, batch_size=batch_size, shuffle=False)
    test_loader = DataLoader(test_dataset, batch_size=batch_size, shuffle=False)

    # Append each user's DataLoader to the respective lists
    train_loaders.append(train_loader)
    val_loaders.append(val_loader)
    test_loaders.append(test_loader)

# %%
# Initialize model, loss function, and optimizer for multiple users
input_size = 256  # Number of features
num_classes = 64
classifiers = [MultinomialLogisticRegression(input_size, num_classes).cuda() for _ in range(no_users)]
optimizers = [optim.Adam(model.parameters(), lr=0.001) for model in classifiers]
criterion = nn.CrossEntropyLoss()
# Training parameters
num_epochs = 100

# Track metrics across all users
train_loss_histories = []
val_loss_histories = []
train_accuracy_histories = []
val_accuracy_histories = []

# Training loop
for epoch in range(num_epochs):
    user_train_losses = []
    user_val_losses = []
    user_train_accuracies = []
    user_val_accuracies = []

    for user_id, (model, optimizer) in enumerate(zip(classifiers, optimizers)):
        # Training phase
        model.train()
        epoch_train_loss = 0.0
        correct_train_predictions = 0
        total_train_samples = 0

        for X_batch, y_batch in train_loaders[user_id]:  # Assuming train_loader is a list of loaders for users
            X_batch, y_batch = X_batch.cuda(), y_batch.cuda()
            outputs = model(X_batch)
            loss = criterion(outputs, y_batch)

            optimizer.zero_grad()
            loss.backward()
            optimizer.step()

            epoch_train_loss += loss.item()
            _, predicted = torch.max(outputs, dim=1)
            correct_train_predictions += (predicted == y_batch).sum().item()
            total_train_samples += y_batch.size(0)

        avg_train_loss = epoch_train_loss / len(train_loaders[user_id])
        train_accuracy = correct_train_predictions / total_train_samples

        # Validation phase
        model.eval()
        epoch_val_loss = 0.0
        correct_val_predictions = 0
        total_val_samples = 0

        with torch.no_grad():
            for X_batch, y_batch in val_loaders[user_id]:  # Assuming val_loader is a list of loaders for users
                X_batch, y_batch = X_batch.cuda(), y_batch.cuda()
                outputs = model(X_batch)
                loss = criterion(outputs, y_batch)

                epoch_val_loss += loss.item()
                _, predicted = torch.max(outputs, dim=1)
                correct_val_predictions += (predicted == y_batch).sum().item()
                total_val_samples += y_batch.size(0)

        avg_val_loss = epoch_val_loss / len(val_loaders[user_id])
        val_accuracy = correct_val_predictions / total_val_samples

        user_train_losses.append(avg_train_loss)
        user_train_accuracies.append(train_accuracy)
        user_val_losses.append(avg_val_loss)
        user_val_accuracies.append(val_accuracy)

    # Store the averages and standard deviations across users
    train_loss_histories.append(user_train_losses)
    train_accuracy_histories.append(user_train_accuracies)
    val_loss_histories.append(user_val_losses)
    val_accuracy_histories.append(user_val_accuracies)

    # Print average metrics
    print(f"Epoch [{epoch+1}/{num_epochs}], Avg Train Loss: {np.mean(user_train_losses):.4f}, Avg Train Accuracy: {np.mean(user_train_accuracies):.4f}")
    print(f"Epoch [{epoch+1}/{num_epochs}], Avg Val Loss: {np.mean(user_val_losses):.4f}, Avg Val Accuracy: {np.mean(user_val_accuracies):.4f}")
# Out:
# C:\Users\abdu_\AppData\Local\Temp\ipykernel_10836\2584759438.py:30: DeprecationWarning: an integer is required (got type numpy.float64).  Implicit conversion to integers using __int__ is deprecated, and may be removed in a future version of Python.
#   y = torch.tensor(self.y[idx], dtype=torch.long)  # Use long for classification targets
# Epoch [1/100], Avg Train Loss: 2.8192, Avg Train Accuracy: 0.4132
# Epoch [1/100], Avg Val Loss: 1.8398, Avg Val Accuracy: 0.6168
# Epoch [2/100], Avg Train Loss: 1.4589, Avg Train Accuracy: 0.6799
# Epoch [2/100], Avg Val Loss: 1.2208, Avg Val Accuracy: 0.7219
# Epoch [3/100], Avg Train Loss: 1.0682, Avg Train Accuracy: 0.7440
# Epoch [3/100], Avg Val Loss: 0.9918, Avg Val Accuracy: 0.7525
# Epoch [4/100], Avg Train Loss: 0.9004, Avg Train Accuracy: 0.7693
# Epoch [4/100], Avg Val Loss: 0.8735, Avg Val Accuracy: 0.7701
# Epoch [5/100], Avg Train Loss: 0.8044, Avg Train Accuracy: 0.7857
# Epoch [5/100], Avg Val Loss: 0.7991, Avg Val Accuracy: 0.7846
# Epoch [6/100], Avg Train Loss: 0.7406, Avg Train Accuracy: 0.7979
# Epoch [6/100], Avg Val Loss: 0.7474, Avg Val Accuracy: 0.7954
# Epoch [7/100], Avg Train Loss: 0.6946, Avg Train Accuracy: 0.8081
# Epoch [7/100], Avg Val Loss: 0.7092, Avg Val Accuracy: 0.8034
# Epoch [8/100], Avg Train Loss: 0.6596, Avg Train Accuracy: 0.8156
# Epoch [8/100], Avg Val Loss: 0.6797, Avg Val Accuracy: 0.8079
# Epoch [9/100], Avg Train Loss: 0.6320, Avg Train Accuracy: 0.8214
# Epoch [9/100], Avg Val Loss: 0.6563, Avg Val Accuracy: 0.8129
# Epoch [10/100], Avg Train Loss: 0.6096, Avg Train Accuracy: 0.8261
# Epoch [10/100], Avg Val Loss: 0.6371, Avg Val Accuracy: 0.8161
# Epoch [11/100], Avg Train Loss: 0.5910, Avg Train Accuracy: 0.8300
# Epoch [11/100], Avg Val Loss: 0.6212, Avg Val Accuracy: 0.8181
# Epoch [12/100], Avg Train Loss: 0.5753, Avg Train Accuracy: 0.8337
# Epoch [12/100], Avg Val Loss: 0.6078, Avg Val Accuracy: 0.8207
# Epoch [13/100], Avg Train Loss: 0.5618, Avg Train Accuracy: 0.8368
# Epoch [13/100], Avg Val Loss: 0.5963, Avg Val Accuracy: 0.8226
# Epoch [14/100], Avg Train Loss: 0.5500, Avg Train Accuracy: 0.8394
# Epoch [14/100], Avg Val Loss: 0.5863, Avg Val Accuracy: 0.8247
# Epoch [15/100], Avg Train Loss: 0.5397, Avg Train Accuracy: 0.8416
# Epoch [15/100], Avg Val Loss: 0.5775, Avg Val Accuracy: 0.8269
# Epoch [16/100], Avg Train Loss: 0.5306, Avg Train Accuracy: 0.8436
# Epoch [16/100], Avg Val Loss: 0.5698, Avg Val Accuracy: 0.8281
# Epoch [17/100], Avg Train Loss: 0.5224, Avg Train Accuracy: 0.8449
# Epoch [17/100], Avg Val Loss: 0.5629, Avg Val Accuracy: 0.8305
# Epoch [18/100], Avg Train Loss: 0.5151, Avg Train Accuracy: 0.8461
# Epoch [18/100], Avg Val Loss: 0.5568, Avg Val Accuracy: 0.8321
# Epoch [19/100], Avg Train Loss: 0.5084, Avg Train Accuracy: 0.8475
# Epoch [19/100], Avg Val Loss: 0.5512, Avg Val Accuracy: 0.8331
# Epoch [20/100], Avg Train Loss: 0.5024, Avg Train Accuracy: 0.8488
# Epoch [20/100], Avg Val Loss: 0.5462, Avg Val Accuracy: 0.8339
# Epoch [21/100], Avg Train Loss: 0.4968, Avg Train Accuracy: 0.8500
# Epoch [21/100], Avg Val Loss: 0.5416, Avg Val Accuracy: 0.8356
# Epoch [22/100], Avg Train Loss: 0.4917, Avg Train Accuracy: 0.8505
# Epoch [22/100], Avg Val Loss: 0.5375, Avg Val Accuracy: 0.8363
# Epoch [23/100], Avg Train Loss: 0.4870, Avg Train Accuracy: 0.8515
# Epoch [23/100], Avg Val Loss: 0.5336, Avg Val Accuracy: 0.8373
# Epoch [24/100], Avg Train Loss: 0.4826, Avg Train Accuracy: 0.8519
# Epoch [24/100], Avg Val Loss: 0.5301, Avg Val Accuracy: 0.8378
# Epoch [25/100], Avg Train Loss: 0.4785, Avg Train Accuracy: 0.8526
# Epoch [25/100], Avg Val Loss: 0.5268, Avg Val Accuracy: 0.8387
# Epoch [26/100], Avg Train Loss: 0.4747, Avg Train Accuracy: 0.8532
# Epoch [26/100], Avg Val Loss: 0.5238, Avg Val Accuracy: 0.8393
# Epoch [27/100], Avg Train Loss: 0.4712, Avg Train Accuracy: 0.8535
# Epoch [27/100], Avg Val Loss: 0.5210, Avg Val Accuracy: 0.8398
# Epoch [28/100], Avg Train Loss: 0.4678, Avg Train Accuracy: 0.8542
# Epoch [28/100], Avg Val Loss: 0.5183, Avg Val Accuracy: 0.8405
# Epoch [29/100], Avg Train Loss: 0.4647, Avg Train Accuracy: 0.8551
# Epoch [29/100], Avg Val Loss: 0.5159, Avg Val Accuracy: 0.8412
# Epoch [30/100], Avg Train Loss: 0.4617, Avg Train Accuracy: 0.8555
# Epoch [30/100], Avg Val Loss: 0.5136, Avg Val Accuracy: 0.8416
# Epoch [31/100], Avg Train Loss: 0.4589, Avg Train Accuracy: 0.8559
# Epoch [31/100], Avg Val Loss: 0.5114, Avg Val Accuracy: 0.8420
# Epoch [32/100], Avg Train Loss: 0.4563, Avg Train Accuracy: 0.8564
# Epoch [32/100], Avg Val Loss: 0.5094, Avg Val Accuracy: 0.8423
# Epoch [33/100], Avg Train Loss: 0.4537, Avg Train Accuracy: 0.8568
# Epoch [33/100], Avg Val Loss: 0.5074, Avg Val Accuracy: 0.8425
# Epoch [34/100], Avg Train Loss: 0.4513, Avg Train Accuracy: 0.8572
# Epoch [34/100], Avg Val Loss: 0.5056, Avg Val Accuracy: 0.8432
# Epoch [35/100], Avg Train Loss: 0.4491, Avg Train Accuracy: 0.8574
# Epoch [35/100], Avg Val Loss: 0.5039, Avg Val Accuracy: 0.8436
# Epoch [36/100], Avg Train Loss: 0.4469, Avg Train Accuracy: 0.8579
# Epoch [36/100], Avg Val Loss: 0.5023, Avg Val Accuracy: 0.8440
# Epoch [37/100], Avg Train Loss: 0.4448, Avg Train Accuracy: 0.8584
# Epoch [37/100], Avg Val Loss: 0.5007, Avg Val Accuracy: 0.8443
# Epoch [38/100], Avg Train Loss: 0.4428, Avg Train Accuracy: 0.8587
# Epoch [38/100], Avg Val Loss: 0.4993, Avg Val Accuracy: 0.8445
# Epoch [39/100], Avg Train Loss: 0.4409, Avg Train Accuracy: 0.8592
# Epoch [39/100], Avg Val Loss: 0.4979, Avg Val Accuracy: 0.8448
# Epoch [40/100], Avg Train Loss: 0.4391, Avg Train Accuracy: 0.8598
# Epoch [40/100], Avg Val Loss: 0.4965, Avg Val Accuracy: 0.8449
# Epoch [41/100], Avg Train Loss: 0.4373, Avg Train Accuracy: 0.8601
# Epoch [41/100], Avg Val Loss: 0.4953, Avg Val Accuracy: 0.8452
# Epoch [42/100], Avg Train Loss: 0.4356, Avg Train Accuracy: 0.8604
# Epoch [42/100], Avg Val Loss: 0.4941, Avg Val Accuracy: 0.8455
# Epoch [43/100], Avg Train Loss: 0.4340, Avg Train Accuracy: 0.8606
# Epoch [43/100], Avg Val Loss: 0.4929, Avg Val Accuracy: 0.8457
# Epoch [44/100], Avg Train Loss: 0.4324, Avg Train Accuracy: 0.8609
# Epoch [44/100], Avg Val Loss: 0.4918, Avg Val Accuracy: 0.8462
# Epoch [45/100], Avg Train Loss: 0.4309, Avg Train Accuracy: 0.8613
# Epoch [45/100], Avg Val Loss: 0.4907, Avg Val Accuracy: 0.8464
# Epoch [46/100], Avg Train Loss: 0.4295, Avg Train Accuracy: 0.8616
# Epoch [46/100], Avg Val Loss: 0.4897, Avg Val Accuracy: 0.8466
# Epoch [47/100], Avg Train Loss: 0.4281, Avg Train Accuracy: 0.8618
# Epoch [47/100], Avg Val Loss: 0.4887, Avg Val Accuracy: 0.8469
# Epoch [48/100], Avg Train Loss: 0.4267, Avg Train Accuracy: 0.8617
# Epoch [48/100], Avg Val Loss: 0.4878, Avg Val Accuracy: 0.8470
# Epoch [49/100], Avg Train Loss: 0.4254, Avg Train Accuracy: 0.8619
# Epoch [49/100], Avg Val Loss: 0.4869, Avg Val Accuracy: 0.8470
# Epoch [50/100], Avg Train Loss: 0.4241, Avg Train Accuracy: 0.8621
# Epoch [50/100], Avg Val Loss: 0.4861, Avg Val Accuracy: 0.8473
# Epoch [51/100], Avg Train Loss: 0.4229, Avg Train Accuracy: 0.8623
# Epoch [51/100], Avg Val Loss: 0.4852, Avg Val Accuracy: 0.8475
# Epoch [52/100], Avg Train Loss: 0.4217, Avg Train Accuracy: 0.8622
# Epoch [52/100], Avg Val Loss: 0.4844, Avg Val Accuracy: 0.8477
# Epoch [53/100], Avg Train Loss: 0.4205, Avg Train Accuracy: 0.8625
# Epoch [53/100], Avg Val Loss: 0.4837, Avg Val Accuracy: 0.8476
# Epoch [54/100], Avg Train Loss: 0.4194, Avg Train Accuracy: 0.8627
# Epoch [54/100], Avg Val Loss: 0.4829, Avg Val Accuracy: 0.8477
# Epoch [55/100], Avg Train Loss: 0.4183, Avg Train Accuracy: 0.8627
# Epoch [55/100], Avg Val Loss: 0.4822, Avg Val Accuracy: 0.8480
# Epoch [56/100], Avg Train Loss: 0.4172, Avg Train Accuracy: 0.8630
# Epoch [56/100], Avg Val Loss: 0.4815, Avg Val Accuracy: 0.8480
# Epoch [57/100], Avg Train Loss: 0.4162, Avg Train Accuracy: 0.8631
# Epoch [57/100], Avg Val Loss: 0.4808, Avg Val Accuracy: 0.8481
# Epoch [58/100], Avg Train Loss: 0.4152, Avg Train Accuracy: 0.8633
# Epoch [58/100], Avg Val Loss: 0.4802, Avg Val Accuracy: 0.8483
# Epoch [59/100], Avg Train Loss: 0.4142, Avg Train Accuracy: 0.8635
# Epoch [59/100], Avg Val Loss: 0.4796, Avg Val Accuracy: 0.8484
# Epoch [60/100], Avg Train Loss: 0.4132, Avg Train Accuracy: 0.8638
# Epoch [60/100], Avg Val Loss: 0.4790, Avg Val Accuracy: 0.8486
# Epoch [61/100], Avg Train Loss: 0.4123, Avg Train Accuracy: 0.8643
# Epoch [61/100], Avg Val Loss: 0.4784, Avg Val Accuracy: 0.8489
# Epoch [62/100], Avg Train Loss: 0.4113, Avg Train Accuracy: 0.8644
# Epoch [62/100], Avg Val Loss: 0.4778, Avg Val Accuracy: 0.8491
# Epoch [63/100], Avg Train Loss: 0.4105, Avg Train Accuracy: 0.8647
# Epoch [63/100], Avg Val Loss: 0.4773, Avg Val Accuracy: 0.8491
# Epoch [64/100], Avg Train Loss: 0.4096, Avg Train Accuracy: 0.8649
# Epoch [64/100], Avg Val Loss: 0.4768, Avg Val Accuracy: 0.8494
# Epoch [65/100], Avg Train Loss: 0.4087, Avg Train Accuracy: 0.8652
# Epoch [65/100], Avg Val Loss: 0.4762, Avg Val Accuracy: 0.8496
# Epoch [66/100], Avg Train Loss: 0.4079, Avg Train Accuracy: 0.8654
# Epoch [66/100], Avg Val Loss: 0.4757, Avg Val Accuracy: 0.8495
# Epoch [67/100], Avg Train Loss: 0.4071, Avg Train Accuracy: 0.8655
# Epoch [67/100], Avg Val Loss: 0.4753, Avg Val Accuracy: 0.8494
# Epoch [68/100], Avg Train Loss: 0.4063, Avg Train Accuracy: 0.8656
# Epoch [68/100], Avg Val Loss: 0.4748, Avg Val Accuracy: 0.8493
# Epoch [69/100], Avg Train Loss: 0.4055, Avg Train Accuracy: 0.8659
# Epoch [69/100], Avg Val Loss: 0.4744, Avg Val Accuracy: 0.8493
# Epoch [70/100], Avg Train Loss: 0.4047, Avg Train Accuracy: 0.8662
# Epoch [70/100], Avg Val Loss: 0.4739, Avg Val Accuracy: 0.8494
# Epoch [71/100], Avg Train Loss: 0.4040, Avg Train Accuracy: 0.8663
# Epoch [71/100], Avg Val Loss: 0.4735, Avg Val Accuracy: 0.8496
# Epoch [72/100], Avg Train Loss: 0.4033, Avg Train Accuracy: 0.8663
# Epoch [72/100], Avg Val Loss: 0.4731, Avg Val Accuracy: 0.8497
# Epoch [73/100], Avg Train Loss: 0.4025, Avg Train Accuracy: 0.8665
# Epoch [73/100], Avg Val Loss: 0.4727, Avg Val Accuracy: 0.8498
# Epoch [74/100], Avg Train Loss: 0.4018, Avg Train Accuracy: 0.8666
# Epoch [74/100], Avg Val Loss: 0.4723, Avg Val Accuracy: 0.8501
# Epoch [75/100], Avg Train Loss: 0.4012, Avg Train Accuracy: 0.8668
# Epoch [75/100], Avg Val Loss: 0.4719, Avg Val Accuracy: 0.8502
# Epoch [76/100], Avg Train Loss: 0.4005, Avg Train Accuracy: 0.8669
# Epoch [76/100], Avg Val Loss: 0.4715, Avg Val Accuracy: 0.8503
# Epoch [77/100], Avg Train Loss: 0.3998, Avg Train Accuracy: 0.8669
# Epoch [77/100], Avg Val Loss: 0.4712, Avg Val Accuracy: 0.8502
# Epoch [78/100], Avg Train Loss: 0.3992, Avg Train Accuracy: 0.8671
# Epoch [78/100], Avg Val Loss: 0.4708, Avg Val Accuracy: 0.8503
# Epoch [79/100], Avg Train Loss: 0.3985, Avg Train Accuracy: 0.8672
# Epoch [79/100], Avg Val Loss: 0.4705, Avg Val Accuracy: 0.8507
# Epoch [80/100], Avg Train Loss: 0.3979, Avg Train Accuracy: 0.8673
# Epoch [80/100], Avg Val Loss: 0.4702, Avg Val Accuracy: 0.8506
# Epoch [81/100], Avg Train Loss: 0.3973, Avg Train Accuracy: 0.8674
# Epoch [81/100], Avg Val Loss: 0.4698, Avg Val Accuracy: 0.8507
# Epoch [82/100], Avg Train Loss: 0.3967, Avg Train Accuracy: 0.8675
# Epoch [82/100], Avg Val Loss: 0.4695, Avg Val Accuracy: 0.8508
# Epoch [83/100], Avg Train Loss: 0.3961, Avg Train Accuracy: 0.8678
# Epoch [83/100], Avg Val Loss: 0.4692, Avg Val Accuracy: 0.8508
# Epoch [84/100], Avg Train Loss: 0.3955, Avg Train Accuracy: 0.8679
# Epoch [84/100], Avg Val Loss: 0.4689, Avg Val Accuracy: 0.8507
# Epoch [85/100], Avg Train Loss: 0.3949, Avg Train Accuracy: 0.8680
# Epoch [85/100], Avg Val Loss: 0.4686, Avg Val Accuracy: 0.8505
# Epoch [86/100], Avg Train Loss: 0.3944, Avg Train Accuracy: 0.8682
# Epoch [86/100], Avg Val Loss: 0.4683, Avg Val Accuracy: 0.8507
# Epoch [87/100], Avg Train Loss: 0.3938, Avg Train Accuracy: 0.8684
# Epoch [87/100], Avg Val Loss: 0.4681, Avg Val Accuracy: 0.8507
# Epoch [88/100], Avg Train Loss: 0.3933, Avg Train Accuracy: 0.8684
# Epoch [88/100], Avg Val Loss: 0.4678, Avg Val Accuracy: 0.8507
# Epoch [89/100], Avg Train Loss: 0.3927, Avg Train Accuracy: 0.8686
# Epoch [89/100], Avg Val Loss: 0.4675, Avg Val Accuracy: 0.8508
# Epoch [90/100], Avg Train Loss: 0.3922, Avg Train Accuracy: 0.8686
# Epoch [90/100], Avg Val Loss: 0.4673, Avg Val Accuracy: 0.8508
# Epoch [91/100], Avg Train Loss: 0.3917, Avg Train Accuracy: 0.8688
# Epoch [91/100], Avg Val Loss: 0.4670, Avg Val Accuracy: 0.8511
# Epoch [92/100], Avg Train Loss: 0.3912, Avg Train Accuracy: 0.8689
# Epoch [92/100], Avg Val Loss: 0.4668, Avg Val Accuracy: 0.8511
# Epoch [93/100], Avg Train Loss: 0.3907, Avg Train Accuracy: 0.8690
# Epoch [93/100], Avg Val Loss: 0.4665, Avg Val Accuracy: 0.8512
# Epoch [94/100], Avg Train Loss: 0.3902, Avg Train Accuracy: 0.8691
# Epoch [94/100], Avg Val Loss: 0.4663, Avg Val Accuracy: 0.8515
# Epoch [95/100], Avg Train Loss: 0.3897, Avg Train Accuracy: 0.8691
# Epoch [95/100], Avg Val Loss: 0.4661, Avg Val Accuracy: 0.8515
# Epoch [96/100], Avg Train Loss: 0.3892, Avg Train Accuracy: 0.8692
# Epoch [96/100], Avg Val Loss: 0.4659, Avg Val Accuracy: 0.8515
# Epoch [97/100], Avg Train Loss: 0.3887, Avg Train Accuracy: 0.8693
# Epoch [97/100], Avg Val Loss: 0.4656, Avg Val Accuracy: 0.8517
# Epoch [98/100], Avg Train Loss: 0.3882, Avg Train Accuracy: 0.8693
# Epoch [98/100], Avg Val Loss: 0.4654, Avg Val Accuracy: 0.8518
# Epoch [99/100], Avg Train Loss: 0.3878, Avg Train Accuracy: 0.8695
# Epoch [99/100], Avg Val Loss: 0.4652, Avg Val Accuracy: 0.8518
# Epoch [100/100], Avg Train Loss: 0.3873, Avg Train Accuracy: 0.8697
# Epoch [100/100], Avg Val Loss: 0.4650, Avg Val Accuracy: 0.8519

# %%
# Convert metrics to numpy arrays for easy manipulation
train_loss_histories = np.array(train_loss_histories)
train_accuracy_histories = np.array(train_accuracy_histories)
val_loss_histories = np.array(val_loss_histories)
val_accuracy_histories = np.array(val_accuracy_histories)

# Calculate means and standard deviations
train_loss_mean = train_loss_histories.mean(axis=1)
train_loss_std = train_loss_histories.std(axis=1)
val_loss_mean = val_loss_histories.mean(axis=1)
val_loss_std = val_loss_histories.std(axis=1)

train_acc_mean = train_accuracy_histories.mean(axis=1)
train_acc_std = train_accuracy_histories.std(axis=1)
val_acc_mean = val_accuracy_histories.mean(axis=1)
val_acc_std = val_accuracy_histories.std(axis=1)

# Plot metrics
plt.figure(figsize=(12, 6))

# Loss plot
plt.subplot(1, 2, 1)
plt.plot(range(1, num_epochs + 1), train_loss_mean, label="Train Loss", color="blue")
plt.fill_between(range(1, num_epochs + 1), train_loss_mean - train_loss_std, train_loss_mean + train_loss_std, color="blue", alpha=0.2)
plt.plot(range(1, num_epochs + 1), val_loss_mean, label="Validation Loss", color="red")
plt.fill_between(range(1, num_epochs + 1), val_loss_mean - val_loss_std, val_loss_mean + val_loss_std, color="red", alpha=0.2)
plt.title("Loss over Epochs (with Std Dev)")
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.legend()
plt.grid()

# Accuracy plot
plt.subplot(1, 2, 2)
plt.plot(range(1, num_epochs + 1), train_acc_mean, label="Train Accuracy", color="orange")
plt.fill_between(range(1, num_epochs + 1), train_acc_mean - train_acc_std, train_acc_mean + train_acc_std, color="orange", alpha=0.2)
plt.plot(range(1, num_epochs + 1), val_acc_mean, label="Validation Accuracy", color="green")
plt.fill_between(range(1, num_epochs + 1), val_acc_mean - val_acc_std, val_acc_mean + val_acc_std, color="green", alpha=0.2)
plt.title("Accuracy over Epochs (with Std Dev)")
plt.xlabel("Epoch")
plt.ylabel("Accuracy")
plt.legend()
plt.grid()

plt.tight_layout()
plt.show()

# %%
# Track metrics across all users
test_loss_histories = []
test_accuracy_histories = []
train_loss_histories = []
train_accuracy_histories = []

# Testing loop for all users
user_test_losses = []
user_test_accuracies = []
user_train_losses = []
user_train_accuracies = []

with torch.no_grad():  # Disable gradient computation for testing
    for user_id, model in enumerate(classifiers):
        model.eval()

        # Test metrics
        epoch_test_loss = 0.0
        correct_test_predictions = 0
        total_test_samples = 0

        # Train metrics (optional, for post-training evaluation on training data)
        epoch_train_loss = 0.0
        correct_train_predictions = 0
        total_train_samples = 0

        # Evaluate on test set
        for X_batch, y_batch in test_loaders[user_id]:  # Assuming test_loader is a list of loaders for users
            X_batch, y_batch = X_batch.cuda(), y_batch.cuda()
            outputs = model(X_batch)
            loss = criterion(outputs, y_batch)

            epoch_test_loss += loss.item()
            _, predicted = torch.max(outputs, dim=1)
            correct_test_predictions += (predicted == y_batch).sum().item()
            total_test_samples += y_batch.size(0)

        # Evaluate on training set
        for X_batch, y_batch in train_loaders[user_id]:  # Assuming train_loader is available per user
            X_batch, y_batch = X_batch.cuda(), y_batch.cuda()
            outputs = model(X_batch)
            loss = criterion(outputs, y_batch)

            epoch_train_loss += loss.item()
            _, predicted = torch.max(outputs, dim=1)
            correct_train_predictions += (predicted == y_batch).sum().item()
            total_train_samples += y_batch.size(0)

        # Calculate averages
        avg_test_loss = epoch_test_loss / len(test_loaders[user_id])
        test_accuracy = correct_test_predictions / total_test_samples

        avg_train_loss = epoch_train_loss / len(train_loaders[user_id])
        train_accuracy = correct_train_predictions / total_train_samples

        # Store metrics for each user
        user_test_losses.append(avg_test_loss)
        user_test_accuracies.append(test_accuracy)
        user_train_losses.append(avg_train_loss)
        user_train_accuracies.append(train_accuracy)

# Store the average metrics across all users
test_loss_histories.append(user_test_losses)
test_accuracy_histories.append(user_test_accuracies)
train_loss_histories.append(user_train_losses)
train_accuracy_histories.append(user_train_accuracies)

# Print average metrics
print(f"\nAverage Test Loss: {np.mean(user_test_losses):.4f}, Average Test Accuracy: {np.mean(user_test_accuracies):.4f}")
print(f"\nAverage Train Loss: {np.mean(user_train_losses):.4f}, Average Train Accuracy: {np.mean(user_train_accuracies):.4f}")

# Convert metrics to numpy arrays for plotting
test_loss_histories = np.array(test_loss_histories)
test_accuracy_histories = np.array(test_accuracy_histories)
train_loss_histories = np.array(train_loss_histories)
train_accuracy_histories = np.array(train_accuracy_histories)

# Calculate means and standard deviations
test_loss_mean = test_loss_histories.mean(axis=1)
test_loss_std = test_loss_histories.std(axis=1)
test_acc_mean = test_accuracy_histories.mean(axis=1)
test_acc_std = test_accuracy_histories.std(axis=1)

train_loss_mean = train_loss_histories.mean(axis=1)
train_loss_std = train_loss_histories.std(axis=1)
train_acc_mean = train_accuracy_histories.mean(axis=1)
train_acc_std = train_accuracy_histories.std(axis=1)

# Plot metrics
plt.figure(figsize=(12, 6))

# Loss plot
plt.subplot(1, 2, 1)
plt.bar(['Train Loss', 'Test Loss'], [train_loss_mean[-1], test_loss_mean[-1]], 
        yerr=[train_loss_std[-1], test_loss_std[-1]], capsize=5, color=['orange', 'blue'])
plt.title("Final Loss (Mean ± Std Dev)")
plt.ylabel("Loss")
plt.grid()

# Accuracy plot
plt.subplot(1, 2, 2)
plt.bar(['Train Accuracy', 'Test Accuracy'], [train_acc_mean[-1], test_acc_mean[-1]], 
        yerr=[train_acc_std[-1], test_acc_std[-1]], capsize=5, color=['orange', 'blue'])
plt.title("Final Accuracy (Mean ± Std Dev)")
plt.ylabel("Accuracy")
plt.ylim([0, 1])  # Ensure y-axis is between 0 and 1
plt.grid()

plt.tight_layout()
plt.show()
# Out:
# C:\Users\abdu_\AppData\Local\Temp\ipykernel_10836\2584759438.py:30: DeprecationWarning: an integer is required (got type numpy.float64).  Implicit conversion to integers using __int__ is deprecated, and may be removed in a future version of Python.
#   y = torch.tensor(self.y[idx], dtype=torch.long)  # Use long for classification targets
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[11], line 50
#      47     total_train_samples += y_batch.size(0)
#      49 # Calculate averages
# ---> 50 avg_test_loss = epoch_test_loss / len(test_loader[user_id])
#      51 test_accuracy = correct_test_predictions / total_test_samples
#      53 avg_train_loss = epoch_train_loss / len(train_loader[user_id])
#
# TypeError: 'DataLoader' object is not subscriptable

# %%
# Images only
'''
Test Loss: 0.4364, Test Accuracy: 0.8521

Train Loss: 0.4047, Train Accuracy: 0.8687

'''
# Out:
# '\nTest Loss: 0.4364, Test Accuracy: 0.8521\n\nTrain Loss: 0.4047, Train Accuracy: 0.8687\n\n'
