# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader
import pandas as pd
from sklearn.preprocessing import MinMaxScaler
import matplotlib.pyplot as plt
import numpy as np
import random
import os
import seaborn as sns


# Set random seed for reproducibility
seed = 42  # You can choose any integer here

# Set seed for NumPy
np.random.seed(seed)

# Set seed for Python's random module
random.seed(seed)

# Set seed for PyTorch
torch.manual_seed(seed)

# For GPU (if using CUDA)
if torch.cuda.is_available():
    torch.cuda.manual_seed(seed)
    torch.cuda.manual_seed_all(seed)  # For multi-GPU setups

# Set deterministic behavior for reproducibility in case of CUDA operations
torch.backends.cudnn.deterministic = True
torch.backends.cudnn.benchmark = False




dataset_dir = "datasets/no_comm_20/"

# Directory containing the saved CSV files
output_dir = dataset_dir + "training_outputs/"

# Load one of the CSV files for EDA (e.g., user_0_outputs.csv)
csv_file = os.path.join(output_dir, "user_1_outputs.csv")
df = pd.read_csv(csv_file)

# Quick overview of the data
print("Data Overview:")
print(df.head())
print("\nData Summary:")
print(df.describe())

# Check for missing values
print("\nMissing Values:")
print(df.isnull().sum())

# Distribution of the target variable (y)
sns.countplot(x="y", data=df)
plt.title("Target Variable Distribution")
plt.show()

# Correlation heatmap of features
correlation_matrix = df.iloc[:, :-1].corr()  # Exclude the target column
plt.figure(figsize=(12, 10))
sns.heatmap(correlation_matrix, cmap="coolwarm", center=0)
plt.title("Feature Correlation Heatmap")
plt.show()
# Out:
# Data Overview:
#    Feature_1  Feature_2  Feature_3  Feature_4  Feature_5  Feature_6  \
# 0        0.0        0.0   0.885327   0.716273   0.456092   0.808141
# 1        0.0        0.0   1.785427   1.364032   0.766123   1.917062
# 2        0.0        0.0   1.854444   1.335653   0.804599   2.030004
# 3        0.0        0.0   0.690323   0.617714   0.411132   0.561880
# 4        0.0        0.0   0.961497   0.595238   0.439818   0.997373
#
#    Feature_7  Feature_8  Feature_9  Feature_10  ...  Feature_248  Feature_249  \
# 0   0.389748   0.107943        0.0         0.0  ...     0.270664     0.024842
# 1   1.039945   0.000000        0.0         0.0  ...     0.252708    -0.149095
# 2   1.103763   0.000000        0.0         0.0  ...    -0.227108    -0.424185
# 3   0.223934   0.152276        0.0         0.0  ...    -7.156454     3.660750
# 4   0.519294   0.035166        0.0         0.0  ...    -0.100431    -0.294257
#
#    Feature_250  Feature_251  Feature_252  Feature_253  Feature_254  \
# 0    -1.076952    -0.529986    -0.903930    -0.572074    -0.792456
# 1    -0.735969    -0.623401    -0.578592    -0.609828     0.548424
# 2     0.238877     0.113626    -0.831830    -0.964168     2.557450
# 3     1.325553     0.337411    -7.220688    -4.296207     1.817713
# 4    -0.648166     0.106401    -0.459414    -0.259358     0.095467
#
#    Feature_255  Feature_256     y
# 0    -1.318562    -0.319528   7.0
# 1    -1.845531    -0.191677  16.0
# 2    -1.824514    -0.132469  17.0
# 3     0.676589     0.228467   2.0
# 4    -0.467735     0.232591  25.0
#
# [5 rows x 257 columns]
#
# Data Summary:
#        Feature_1  Feature_2   Feature_3   Feature_4   Feature_5   Feature_6  \
# count      342.0      342.0  342.000000  342.000000  342.000000  342.000000
# mean         0.0        0.0    1.200481    0.862600    0.545849    1.239629
# std          0.0        0.0    0.359492    0.299161    0.133938    0.428101
# min          0.0        0.0    0.683959    0.528406    0.403624    0.554753
# 25%          0.0        0.0    0.916019    0.614972    0.435497    0.914815
# 50%          0.0        0.0    1.108625    0.743994    0.493887    1.152244
# 75%          0.0        0.0    1.452524    1.035317    0.628424    1.558081
# max          0.0        0.0    2.056166    1.630042    0.912757    2.250869
#
#         Feature_7   Feature_8  Feature_9  Feature_10  ...  Feature_248  \
# count  342.000000  342.000000      342.0       342.0  ...   342.000000
# mean     0.651521    0.042390        0.0         0.0  ...    -0.284878
# std      0.250786    0.040270        0.0         0.0  ...     1.159527
# min      0.219668    0.000000        0.0         0.0  ...    -7.692655
# 25%      0.465265    0.005978        0.0         0.0  ...    -0.207463
# 50%      0.608093    0.035368        0.0         0.0  ...    -0.056301
# 75%      0.851370    0.058360        0.0         0.0  ...     0.131624
# max      1.233328    0.165615        0.0         0.0  ...     0.460914
#
#        Feature_249  Feature_250  Feature_251  Feature_252  Feature_253  \
# count   342.000000   342.000000   342.000000   342.000000   342.000000
# mean     -0.119893    -0.547717    -0.349805    -1.069940    -0.575147
# std       0.736965     0.627800     0.422362     1.071915     0.729843
# min      -1.015384    -1.790827    -1.564828    -7.733817    -4.559763
# 25%      -0.530908    -0.884130    -0.662081    -1.209548    -0.805891
# 50%      -0.298828    -0.648640    -0.323016    -0.734045    -0.575628
# 75%       0.068275    -0.291087     0.044148    -0.556532    -0.147690
# max       3.893389     2.272325     0.353145    -0.378435     0.610353
#
#        Feature_254  Feature_255  Feature_256           y
# count   342.000000   342.000000   342.000000  342.000000
# mean      0.495424    -1.196757     0.074331   14.976608
# std       0.865629     0.683933     0.561619    4.877326
# min      -1.381253    -3.058295    -1.540733    2.000000
# 25%       0.028295    -1.569769    -0.141128   14.000000
# 50%       0.377699    -1.171670     0.037165   16.000000
# 75%       0.928428    -0.695738     0.513825   17.000000
# max       3.560346     0.913419     1.189559   30.000000
#
# [8 rows x 257 columns]
#
# Missing Values:
# Feature_1      0
# Feature_2      0
# Feature_3      0
# Feature_4      0
# Feature_5      0
#               ..
# Feature_253    0
# Feature_254    0
# Feature_255    0
# Feature_256    0
# y              0
# Length: 257, dtype: int64

# %%
no_users = 20
# Define the Multinomial Logistic Regression model
class MultinomialLogisticRegression(nn.Module):
    def __init__(self, input_size, num_classes):
        super(MultinomialLogisticRegression, self).__init__()
        self.linear = nn.Linear(input_size, num_classes)

    def forward(self, x):
        return self.linear(x)

# Custom dataset to load the data from CSV
class CustomDataset(Dataset):
    def __init__(self,  csv_file, modality=["pos_height", "images"], scaler=None, zero_prob=0.5):
        self.data = pd.read_csv(csv_file)
        if "images" in modality and "pos_height" in modality:
            self.X = self.data.iloc[:, :-1].values  # Features
            mask = np.ones(self.X.shape)  # Initialize mask
            mask[:, 128:-1] = np.random.choice([0, 1], size=self.X[:, 128:-1].shape, p=[zero_prob, 1 - zero_prob])
            self.X *= mask  # Apply mask to zero out features
        elif "images" in modality:
            self.X = self.data.iloc[:, 128:-1].values  # Features
            mask = np.random.choice([0, 1], size=self.X.shape, p=[zero_prob, 1 - zero_prob])  # Create a binary mask
            self.X *= mask  # Apply mask
        else:
            self.X = self.data.iloc[:, 0:128].values  # Features

        self.y = self.data.iloc[:, -1].values   # Labels

        # If a scaler is provided, use it to transform the features
        if scaler:
            self.X = scaler.transform(self.X)
        else:
            # Fit the scaler on the training data and transform
            self.scaler = MinMaxScaler(feature_range=(-1, 1))
            self.X = self.scaler.fit_transform(self.X)

    def __len__(self):
        return len(self.data)

    def __getitem__(self, idx):
        X = torch.tensor(self.X[idx], dtype=torch.float32)
        y = torch.tensor(self.y[idx], dtype=torch.long)  # Use long for classification targets
        return X, y

# %%
# Configuration
no_users = 20  # Example: Number of users
available_modalities = ["pos_height", "images"]
modality_size = {"pos_height": 128, "images": 128}
group_definitions = {
    1: ["pos_height"],        # Group 1: Only pos_height
    2: ["images"],            # Group 2: Only images
    3: ["pos_height", "images"]  # Group 3: Both modalities
}

# Assign each user to a group randomly
user_groups = [random.choice([1, 2, 3]) for _ in range(no_users)]

# Assign modalities to users based on their group
user_modalities = [group_definitions[group] for group in user_groups]

# Compute output sizes for each user based on their modalities
output_sizes = [sum(modality_size[modality] for modality in user_modality) for user_modality in user_modalities]

# Store models (placeholders for actual models)
all_models = []

# Example output (for verification)
print(f"User Groups: {user_groups[:10]}")  # Show first 10 users' groups
print(f"User Modalities: {user_modalities[:10]}")  # Show first 10 users' modalities
print(f"Output Sizes: {output_sizes[:10]}")  # Show first 10 users' output sizes
# Out:
# User Groups: [3, 1, 1, 3, 2, 1, 1, 1, 3, 1]
# User Modalities: [['pos_height', 'images'], ['pos_height'], ['pos_height'], ['pos_height', 'images'], ['images'], ['pos_height'], ['pos_height'], ['pos_height'], ['pos_height', 'images'], ['pos_height']]
# Output Sizes: [256, 128, 128, 256, 128, 128, 128, 128, 256, 128]

# %%
no_users = 20
# List to store DataLoader objects for each user
train_loaders = []
val_loaders = []
test_loaders = []
scaler = None
# Loop over each user
zero_prob=0.9
dataset_dir = "datasets/no_comm_20/"
for user_idx in range(no_users):
    scaler = None
    # Define file paths for each user dynamically
    train_file = dataset_dir + f"training_outputs/user_{user_idx}_outputs.csv"
    val_file = dataset_dir + f"val_outputs/user_{user_idx}_outputs.csv"
    test_file = dataset_dir + f"test_outputs/user_{user_idx}_outputs.csv"

    # Load training data and fit the scaler on it (only once for each user)
    train_data = pd.read_csv(train_file)
    
    if scaler is None:
        scaler = MinMaxScaler(feature_range=(-1, 1))
        # Fit the scaler on the first user's training data
        if "images" in user_modalities[user_idx] and "pos_height" in user_modalities[user_idx]:
            temp = train_data.iloc[:, :-1].values  # Features
        elif "images" in user_modalities[user_idx]:
            temp = train_data.iloc[:, 128:-1].values  # Features
        else:
            temp = train_data.iloc[:, 0:128].values  # Features
        scaler.fit(temp)  # Fit scaler only on training features

    # Create datasets using the same scaler for all data
    train_dataset = CustomDataset(train_file, scaler=scaler, modality=user_modalities[user_idx], zero_prob=0.5)
    val_dataset = CustomDataset(val_file, scaler=scaler, modality=user_modalities[user_idx], zero_prob=0.5)
    test_dataset = CustomDataset(test_file, scaler=scaler, modality=user_modalities[user_idx], zero_prob=0.5)

    # Create DataLoader for training, validation, and testing for each user
    batch_size = 64
    train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=False)
    val_loader = DataLoader(val_dataset, batch_size=batch_size, shuffle=False)
    test_loader = DataLoader(test_dataset, batch_size=batch_size, shuffle=False)

    # Append each user's DataLoader to the respective lists
    train_loaders.append(train_loader)
    val_loaders.append(val_loader)
    test_loaders.append(test_loader)

# %%
# Initialize model, loss function, and optimizer for multiple users
input_sizes = output_sizes  # Number of features
num_classes = 64
classifiers = [MultinomialLogisticRegression(input_size, num_classes) for input_size, _ in zip(input_sizes, range(no_users))]
#classifiers = [MultinomialLogisticRegression(input_size, num_classes).cuda() for _ in range(no_users)]
optimizers = [optim.SGD(model.parameters(), lr=0.01) for model in classifiers]
criterion = nn.CrossEntropyLoss()
# Training parameters
num_epochs = 100

# %%
from utils import cross_entropy_loss_with_l2
loss_func = cross_entropy_loss_with_l2

# Group assignments (use the previously defined user_groups)
group_losses = {1: [], 2: [], 3: []}
group_accuracies = {1: [], 2: [], 3: []}

# Initialize dictionaries to track metrics for each group
group_train_loss_histories = {1: [], 2: [], 3: []}
group_train_accuracy_histories = {1: [], 2: [], 3: []}
group_val_loss_histories = {1: [], 2: [], 3: []}
group_val_accuracy_histories = {1: [], 2: [], 3: []}
lambda_reg = 0.01
eta = 0.01
from utils import cross_entropy_loss_with_l2
# Training loop
for epoch in range(num_epochs):
    # Temporary dictionaries for this epoch
    epoch_group_train_losses = {1: [], 2: [], 3: []}
    epoch_group_train_accuracies = {1: [], 2: [], 3: []}
    epoch_group_val_losses = {1: [], 2: [], 3: []}
    epoch_group_val_accuracies = {1: [], 2: [], 3: []}

    for user_id, (model, optimizer) in enumerate(zip(classifiers, optimizers)):
        group = user_groups[user_id]  # Get the group of the user

        # Training phase
        model.train()
        epoch_train_loss = 0.0
        correct_train_predictions = 0
        total_train_samples = 0

        for X_batch, y_batch in train_loaders[user_id]:
            #X_batch, y_batch = X_batch.cuda(), y_batch.cuda()
            outputs = model(X_batch)
            loss = loss_func(model, X_batch, y_batch, l2_strength=0.001)#criterion(outputs, y_batch)

            optimizer.zero_grad()
            loss.backward()
            optimizer.step()

            epoch_train_loss += loss.item()
            _, predicted = torch.max(outputs, dim=1)
            correct_train_predictions += (predicted == y_batch).sum().item()
            total_train_samples += y_batch.size(0)

        avg_train_loss = epoch_train_loss / len(train_loaders[user_id])
        train_accuracy = correct_train_predictions / total_train_samples

        # Validation phase
        model.eval()
        epoch_val_loss = 0.0
        correct_val_predictions = 0
        total_val_samples = 0

        with torch.no_grad():
            for X_batch, y_batch in val_loaders[user_id]:
                #X_batch, y_batch = X_batch.cuda(), y_batch.cuda()
                outputs = model(X_batch)
                loss = loss_func(model, X_batch, y_batch, l2_strength=0.001)#criterion(outputs, y_batch)

                epoch_val_loss += loss.item()
                _, predicted = torch.max(outputs, dim=1)
                correct_val_predictions += (predicted == y_batch).sum().item()
                total_val_samples += y_batch.size(0)

        avg_val_loss = epoch_val_loss / len(val_loaders[user_id])
        val_accuracy = correct_val_predictions / total_val_samples

        # Assign metrics to the respective group
        epoch_group_train_losses[group].append(avg_train_loss)
        epoch_group_train_accuracies[group].append(train_accuracy)
        epoch_group_val_losses[group].append(avg_val_loss)
        epoch_group_val_accuracies[group].append(val_accuracy)

    # Calculate averages for this epoch and store them
    for group in [1, 2, 3]:
        #group_train_loss_histories[group].append(np.mean(epoch_group_train_losses[group]))
        #group_train_accuracy_histories[group].append(np.mean(epoch_group_train_accuracies[group]))
        #group_val_loss_histories[group].append(np.mean(epoch_group_val_losses[group]))
        #group_val_accuracy_histories[group].append(np.mean(epoch_group_val_accuracies[group]))
        group_train_loss_histories[group].append(epoch_group_train_losses[group])
        group_train_accuracy_histories[group].append(epoch_group_train_accuracies[group])
        group_val_loss_histories[group].append(epoch_group_val_losses[group])
        group_val_accuracy_histories[group].append(epoch_group_val_accuracies[group])

    # Print group-wise average metrics
    print(f"Epoch [{epoch+1}/{num_epochs}] Group Metrics:")
    for group in [1, 2, 3]:
        print(f"  Group {group} - Train Loss: {np.mean(epoch_group_train_losses[group]):.4f}, Train Accuracy: {np.mean(epoch_group_train_accuracies[group]):.4f}")
        print(f"  Group {group} - Val Loss: {np.mean(epoch_group_val_losses[group]):.4f}, Val Accuracy: {np.mean(epoch_group_val_accuracies[group]):.4f}")
# Out:
# C:\Users\aghalkha21\AppData\Local\Temp\ipykernel_12468\3432764924.py:42: DeprecationWarning: an integer is required (got type numpy.float64).  Implicit conversion to integers using __int__ is deprecated, and may be removed in a future version of Python.
#   y = torch.tensor(self.y[idx], dtype=torch.long)  # Use long for classification targets
# Epoch [1/100] Group Metrics:
#   Group 1 - Train Loss: 4.3365, Train Accuracy: 0.0466
#   Group 1 - Val Loss: 4.1247, Val Accuracy: 0.1600
#   Group 2 - Train Loss: 4.3786, Train Accuracy: 0.0103
#   Group 2 - Val Loss: 4.2808, Val Accuracy: 0.0234
#   Group 3 - Train Loss: 4.2278, Train Accuracy: 0.0695
#   Group 3 - Val Loss: 3.8691, Val Accuracy: 0.2364
# Epoch [2/100] Group Metrics:
#   Group 1 - Train Loss: 3.9930, Train Accuracy: 0.1888
#   Group 1 - Val Loss: 3.8326, Val Accuracy: 0.2313
#   Group 2 - Train Loss: 4.1987, Train Accuracy: 0.0513
#   Group 2 - Val Loss: 4.1089, Val Accuracy: 0.1287
#   Group 3 - Train Loss: 3.6979, Train Accuracy: 0.2537
#   Group 3 - Val Loss: 3.4873, Val Accuracy: 0.2698
# Epoch [3/100] Group Metrics:
#   Group 1 - Train Loss: 3.7216, Train Accuracy: 0.2338
#   Group 1 - Val Loss: 3.6157, Val Accuracy: 0.2408
#   Group 2 - Train Loss: 4.0303, Train Accuracy: 0.1612
#   Group 2 - Val Loss: 3.9500, Val Accuracy: 0.2515
#   Group 3 - Train Loss: 3.3844, Train Accuracy: 0.2599
#   Group 3 - Val Loss: 3.2797, Val Accuracy: 0.2673
# Epoch [4/100] Group Metrics:
#   Group 1 - Train Loss: 3.5231, Train Accuracy: 0.2437
#   Group 1 - Val Loss: 3.4632, Val Accuracy: 0.2435
#   Group 2 - Train Loss: 3.8760, Train Accuracy: 0.2796
#   Group 2 - Val Loss: 3.8068, Val Accuracy: 0.2749
#   Group 3 - Train Loss: 3.1992, Train Accuracy: 0.2620
#   Group 3 - Val Loss: 3.1503, Val Accuracy: 0.2690
# Epoch [5/100] Group Metrics:
#   Group 1 - Train Loss: 3.3816, Train Accuracy: 0.2429
#   Group 1 - Val Loss: 3.3548, Val Accuracy: 0.2435
#   Group 2 - Train Loss: 3.7383, Train Accuracy: 0.2650
#   Group 2 - Val Loss: 3.6814, Val Accuracy: 0.2632
#   Group 3 - Train Loss: 3.0737, Train Accuracy: 0.2683
#   Group 3 - Val Loss: 3.0589, Val Accuracy: 0.2749
# Epoch [6/100] Group Metrics:
#   Group 1 - Train Loss: 3.2779, Train Accuracy: 0.2445
#   Group 1 - Val Loss: 3.2744, Val Accuracy: 0.2430
#   Group 2 - Train Loss: 3.6188, Train Accuracy: 0.2635
#   Group 2 - Val Loss: 3.5749, Val Accuracy: 0.2632
#   Group 3 - Train Loss: 2.9802, Train Accuracy: 0.2708
#   Group 3 - Val Loss: 2.9899, Val Accuracy: 0.2815
# Epoch [7/100] Group Metrics:
#   Group 1 - Train Loss: 3.1984, Train Accuracy: 0.2447
#   Group 1 - Val Loss: 3.2120, Val Accuracy: 0.2414
#   Group 2 - Train Loss: 3.5178, Train Accuracy: 0.2635
#   Group 2 - Val Loss: 3.4863, Val Accuracy: 0.2632
#   Group 3 - Train Loss: 2.9067, Train Accuracy: 0.2784
#   Group 3 - Val Loss: 2.9351, Val Accuracy: 0.2907
# Epoch [8/100] Group Metrics:
#   Group 1 - Train Loss: 3.1351, Train Accuracy: 0.2471
#   Group 1 - Val Loss: 3.1616, Val Accuracy: 0.2440
#   Group 2 - Train Loss: 3.4337, Train Accuracy: 0.2621
#   Group 2 - Val Loss: 3.4134, Val Accuracy: 0.2632
#   Group 3 - Train Loss: 2.8465, Train Accuracy: 0.2872
#   Group 3 - Val Loss: 2.8900, Val Accuracy: 0.3016
# Epoch [9/100] Group Metrics:
#   Group 1 - Train Loss: 3.0830, Train Accuracy: 0.2495
#   Group 1 - Val Loss: 3.1198, Val Accuracy: 0.2435
#   Group 2 - Train Loss: 3.3638, Train Accuracy: 0.2635
#   Group 2 - Val Loss: 3.3529, Val Accuracy: 0.2632
#   Group 3 - Train Loss: 2.7956, Train Accuracy: 0.2976
#   Group 3 - Val Loss: 2.8515, Val Accuracy: 0.3041
# Epoch [10/100] Group Metrics:
#   Group 1 - Train Loss: 3.0393, Train Accuracy: 0.2501
#   Group 1 - Val Loss: 3.0844, Val Accuracy: 0.2408
#   Group 2 - Train Loss: 3.3048, Train Accuracy: 0.2635
#   Group 2 - Val Loss: 3.3020, Val Accuracy: 0.2632
#   Group 3 - Train Loss: 2.7516, Train Accuracy: 0.3089
#   Group 3 - Val Loss: 2.8180, Val Accuracy: 0.3133
# Epoch [11/100] Group Metrics:
#   Group 1 - Train Loss: 3.0019, Train Accuracy: 0.2506
#   Group 1 - Val Loss: 3.0540, Val Accuracy: 0.2382
#   Group 2 - Train Loss: 3.2540, Train Accuracy: 0.2665
#   Group 2 - Val Loss: 3.2582, Val Accuracy: 0.2632
#   Group 3 - Train Loss: 2.7127, Train Accuracy: 0.3190
#   Group 3 - Val Loss: 2.7883, Val Accuracy: 0.3233
# Epoch [12/100] Group Metrics:
#   Group 1 - Train Loss: 2.9695, Train Accuracy: 0.2498
#   Group 1 - Val Loss: 3.0275, Val Accuracy: 0.2366
#   Group 2 - Train Loss: 3.2093, Train Accuracy: 0.2752
#   Group 2 - Val Loss: 3.2196, Val Accuracy: 0.2661
#   Group 3 - Train Loss: 2.6778, Train Accuracy: 0.3294
#   Group 3 - Val Loss: 2.7615, Val Accuracy: 0.3266
# Epoch [13/100] Group Metrics:
#   Group 1 - Train Loss: 2.9412, Train Accuracy: 0.2495
#   Group 1 - Val Loss: 3.0042, Val Accuracy: 0.2403
#   Group 2 - Train Loss: 3.1693, Train Accuracy: 0.2782
#   Group 2 - Val Loss: 3.1852, Val Accuracy: 0.2690
#   Group 3 - Train Loss: 2.6461, Train Accuracy: 0.3399
#   Group 3 - Val Loss: 2.7371, Val Accuracy: 0.3350
# Epoch [14/100] Group Metrics:
#   Group 1 - Train Loss: 2.9162, Train Accuracy: 0.2530
#   Group 1 - Val Loss: 2.9835, Val Accuracy: 0.2408
#   Group 2 - Train Loss: 3.1328, Train Accuracy: 0.2869
#   Group 2 - Val Loss: 3.1539, Val Accuracy: 0.2719
#   Group 3 - Train Loss: 2.6170, Train Accuracy: 0.3479
#   Group 3 - Val Loss: 2.7146, Val Accuracy: 0.3434
# Epoch [15/100] Group Metrics:
#   Group 1 - Train Loss: 2.8938, Train Accuracy: 0.2551
#   Group 1 - Val Loss: 2.9650, Val Accuracy: 0.2408
#   Group 2 - Train Loss: 3.0992, Train Accuracy: 0.2869
#   Group 2 - Val Loss: 3.1254, Val Accuracy: 0.2749
#   Group 3 - Train Loss: 2.5901, Train Accuracy: 0.3571
#   Group 3 - Val Loss: 2.6938, Val Accuracy: 0.3484
# Epoch [16/100] Group Metrics:
#   Group 1 - Train Loss: 2.8738, Train Accuracy: 0.2530
#   Group 1 - Val Loss: 2.9483, Val Accuracy: 0.2414
#   Group 2 - Train Loss: 3.0679, Train Accuracy: 0.2928
#   Group 2 - Val Loss: 3.0990, Val Accuracy: 0.2836
#   Group 3 - Train Loss: 2.5651, Train Accuracy: 0.3663
#   Group 3 - Val Loss: 2.6744, Val Accuracy: 0.3534
# Epoch [17/100] Group Metrics:
#   Group 1 - Train Loss: 2.8556, Train Accuracy: 0.2538
#   Group 1 - Val Loss: 2.9331, Val Accuracy: 0.2419
#   Group 2 - Train Loss: 3.0388, Train Accuracy: 0.3016
#   Group 2 - Val Loss: 3.0745, Val Accuracy: 0.2836
#   Group 3 - Train Loss: 2.5416, Train Accuracy: 0.3726
#   Group 3 - Val Loss: 2.6562, Val Accuracy: 0.3584
# Epoch [18/100] Group Metrics:
#   Group 1 - Train Loss: 2.8391, Train Accuracy: 0.2538
#   Group 1 - Val Loss: 2.9193, Val Accuracy: 0.2419
#   Group 2 - Train Loss: 3.0113, Train Accuracy: 0.3089
#   Group 2 - Val Loss: 3.0517, Val Accuracy: 0.2924
#   Group 3 - Train Loss: 2.5194, Train Accuracy: 0.3788
#   Group 3 - Val Loss: 2.6390, Val Accuracy: 0.3617
# Epoch [19/100] Group Metrics:
#   Group 1 - Train Loss: 2.8239, Train Accuracy: 0.2543
#   Group 1 - Val Loss: 2.9066, Val Accuracy: 0.2424
#   Group 2 - Train Loss: 2.9855, Train Accuracy: 0.3206
#   Group 2 - Val Loss: 3.0304, Val Accuracy: 0.3099
#   Group 3 - Train Loss: 2.4985, Train Accuracy: 0.3851
#   Group 3 - Val Loss: 2.6228, Val Accuracy: 0.3668
# Epoch [20/100] Group Metrics:
#   Group 1 - Train Loss: 2.8100, Train Accuracy: 0.2538
#   Group 1 - Val Loss: 2.8948, Val Accuracy: 0.2446
#   Group 2 - Train Loss: 2.9610, Train Accuracy: 0.3235
#   Group 2 - Val Loss: 3.0103, Val Accuracy: 0.3099
#   Group 3 - Train Loss: 2.4786, Train Accuracy: 0.3889
#   Group 3 - Val Loss: 2.6074, Val Accuracy: 0.3709
# Epoch [21/100] Group Metrics:
#   Group 1 - Train Loss: 2.7971, Train Accuracy: 0.2533
#   Group 1 - Val Loss: 2.8839, Val Accuracy: 0.2440
#   Group 2 - Train Loss: 2.9378, Train Accuracy: 0.3323
#   Group 2 - Val Loss: 2.9913, Val Accuracy: 0.3216
#   Group 3 - Train Loss: 2.4596, Train Accuracy: 0.3960
#   Group 3 - Val Loss: 2.5927, Val Accuracy: 0.3743
# Epoch [22/100] Group Metrics:
#   Group 1 - Train Loss: 2.7850, Train Accuracy: 0.2541
#   Group 1 - Val Loss: 2.8738, Val Accuracy: 0.2456
#   Group 2 - Train Loss: 2.9157, Train Accuracy: 0.3426
#   Group 2 - Val Loss: 2.9734, Val Accuracy: 0.3246
#   Group 3 - Train Loss: 2.4416, Train Accuracy: 0.4023
#   Group 3 - Val Loss: 2.5788, Val Accuracy: 0.3743
# Epoch [23/100] Group Metrics:
#   Group 1 - Train Loss: 2.7738, Train Accuracy: 0.2543
#   Group 1 - Val Loss: 2.8643, Val Accuracy: 0.2456
#   Group 2 - Train Loss: 2.8946, Train Accuracy: 0.3514
#   Group 2 - Val Loss: 2.9564, Val Accuracy: 0.3304
#   Group 3 - Train Loss: 2.4242, Train Accuracy: 0.4069
#   Group 3 - Val Loss: 2.5654, Val Accuracy: 0.3768
# Epoch [24/100] Group Metrics:
#   Group 1 - Train Loss: 2.7633, Train Accuracy: 0.2565
#   Group 1 - Val Loss: 2.8554, Val Accuracy: 0.2467
#   Group 2 - Train Loss: 2.8744, Train Accuracy: 0.3558
#   Group 2 - Val Loss: 2.9403, Val Accuracy: 0.3450
#   Group 3 - Train Loss: 2.4076, Train Accuracy: 0.4090
#   Group 3 - Val Loss: 2.5526, Val Accuracy: 0.3801
# Epoch [25/100] Group Metrics:
#   Group 1 - Train Loss: 2.7534, Train Accuracy: 0.2581
#   Group 1 - Val Loss: 2.8470, Val Accuracy: 0.2483
#   Group 2 - Train Loss: 2.8551, Train Accuracy: 0.3602
#   Group 2 - Val Loss: 2.9249, Val Accuracy: 0.3509
#   Group 3 - Train Loss: 2.3916, Train Accuracy: 0.4115
#   Group 3 - Val Loss: 2.5403, Val Accuracy: 0.3810
# Epoch [26/100] Group Metrics:
#   Group 1 - Train Loss: 2.7440, Train Accuracy: 0.2602
#   Group 1 - Val Loss: 2.8390, Val Accuracy: 0.2515
#   Group 2 - Train Loss: 2.8365, Train Accuracy: 0.3646
#   Group 2 - Val Loss: 2.9102, Val Accuracy: 0.3596
#   Group 3 - Train Loss: 2.3763, Train Accuracy: 0.4153
#   Group 3 - Val Loss: 2.5285, Val Accuracy: 0.3843
# Epoch [27/100] Group Metrics:
#   Group 1 - Train Loss: 2.7352, Train Accuracy: 0.2623
#   Group 1 - Val Loss: 2.8315, Val Accuracy: 0.2547
#   Group 2 - Train Loss: 2.8187, Train Accuracy: 0.3719
#   Group 2 - Val Loss: 2.8962, Val Accuracy: 0.3684
#   Group 3 - Train Loss: 2.3615, Train Accuracy: 0.4186
#   Group 3 - Val Loss: 2.5171, Val Accuracy: 0.3843
# Epoch [28/100] Group Metrics:
#   Group 1 - Train Loss: 2.7268, Train Accuracy: 0.2653
#   Group 1 - Val Loss: 2.8244, Val Accuracy: 0.2589
#   Group 2 - Train Loss: 2.8015, Train Accuracy: 0.3763
#   Group 2 - Val Loss: 2.8827, Val Accuracy: 0.3684
#   Group 3 - Train Loss: 2.3471, Train Accuracy: 0.4228
#   Group 3 - Val Loss: 2.5062, Val Accuracy: 0.3868
# Epoch [29/100] Group Metrics:
#   Group 1 - Train Loss: 2.7188, Train Accuracy: 0.2679
#   Group 1 - Val Loss: 2.8176, Val Accuracy: 0.2594
#   Group 2 - Train Loss: 2.7849, Train Accuracy: 0.3763
#   Group 2 - Val Loss: 2.8698, Val Accuracy: 0.3655
#   Group 3 - Train Loss: 2.3333, Train Accuracy: 0.4295
#   Group 3 - Val Loss: 2.4956, Val Accuracy: 0.3910
# Epoch [30/100] Group Metrics:
#   Group 1 - Train Loss: 2.7112, Train Accuracy: 0.2695
#   Group 1 - Val Loss: 2.8110, Val Accuracy: 0.2616
#   Group 2 - Train Loss: 2.7689, Train Accuracy: 0.3807
#   Group 2 - Val Loss: 2.8574, Val Accuracy: 0.3713
#   Group 3 - Train Loss: 2.3199, Train Accuracy: 0.4333
#   Group 3 - Val Loss: 2.4854, Val Accuracy: 0.3952
# Epoch [31/100] Group Metrics:
#   Group 1 - Train Loss: 2.7040, Train Accuracy: 0.2711
#   Group 1 - Val Loss: 2.8048, Val Accuracy: 0.2616
#   Group 2 - Train Loss: 2.7535, Train Accuracy: 0.3821
#   Group 2 - Val Loss: 2.8454, Val Accuracy: 0.3772
#   Group 3 - Train Loss: 2.3070, Train Accuracy: 0.4358
#   Group 3 - Val Loss: 2.4755, Val Accuracy: 0.3977
# Epoch [32/100] Group Metrics:
#   Group 1 - Train Loss: 2.6971, Train Accuracy: 0.2727
#   Group 1 - Val Loss: 2.7989, Val Accuracy: 0.2626
#   Group 2 - Train Loss: 2.7385, Train Accuracy: 0.3851
#   Group 2 - Val Loss: 2.8339, Val Accuracy: 0.3801
#   Group 3 - Train Loss: 2.2944, Train Accuracy: 0.4391
#   Group 3 - Val Loss: 2.4660, Val Accuracy: 0.3993
# Epoch [33/100] Group Metrics:
#   Group 1 - Train Loss: 2.6904, Train Accuracy: 0.2757
#   Group 1 - Val Loss: 2.7931, Val Accuracy: 0.2653
#   Group 2 - Train Loss: 2.7239, Train Accuracy: 0.3924
#   Group 2 - Val Loss: 2.8228, Val Accuracy: 0.3860
#   Group 3 - Train Loss: 2.2822, Train Accuracy: 0.4412
#   Group 3 - Val Loss: 2.4567, Val Accuracy: 0.4035
# Epoch [34/100] Group Metrics:
#   Group 1 - Train Loss: 2.6840, Train Accuracy: 0.2767
#   Group 1 - Val Loss: 2.7876, Val Accuracy: 0.2658
#   Group 2 - Train Loss: 2.7099, Train Accuracy: 0.3924
#   Group 2 - Val Loss: 2.8121, Val Accuracy: 0.3889
#   Group 3 - Train Loss: 2.2703, Train Accuracy: 0.4458
#   Group 3 - Val Loss: 2.4477, Val Accuracy: 0.4052
# Epoch [35/100] Group Metrics:
#   Group 1 - Train Loss: 2.6779, Train Accuracy: 0.2775
#   Group 1 - Val Loss: 2.7823, Val Accuracy: 0.2658
#   Group 2 - Train Loss: 2.6962, Train Accuracy: 0.3939
#   Group 2 - Val Loss: 2.8017, Val Accuracy: 0.3918
#   Group 3 - Train Loss: 2.2588, Train Accuracy: 0.4508
#   Group 3 - Val Loss: 2.4390, Val Accuracy: 0.4077
# Epoch [36/100] Group Metrics:
#   Group 1 - Train Loss: 2.6720, Train Accuracy: 0.2778
#   Group 1 - Val Loss: 2.7772, Val Accuracy: 0.2663
#   Group 2 - Train Loss: 2.6829, Train Accuracy: 0.3953
#   Group 2 - Val Loss: 2.7917, Val Accuracy: 0.3947
#   Group 3 - Train Loss: 2.2476, Train Accuracy: 0.4546
#   Group 3 - Val Loss: 2.4305, Val Accuracy: 0.4077
# Epoch [37/100] Group Metrics:
#   Group 1 - Train Loss: 2.6663, Train Accuracy: 0.2778
#   Group 1 - Val Loss: 2.7723, Val Accuracy: 0.2669
#   Group 2 - Train Loss: 2.6699, Train Accuracy: 0.3953
#   Group 2 - Val Loss: 2.7820, Val Accuracy: 0.4006
#   Group 3 - Train Loss: 2.2366, Train Accuracy: 0.4571
#   Group 3 - Val Loss: 2.4223, Val Accuracy: 0.4085
# Epoch [38/100] Group Metrics:
#   Group 1 - Train Loss: 2.6608, Train Accuracy: 0.2786
#   Group 1 - Val Loss: 2.7675, Val Accuracy: 0.2669
#   Group 2 - Train Loss: 2.6574, Train Accuracy: 0.3968
#   Group 2 - Val Loss: 2.7725, Val Accuracy: 0.4006
#   Group 3 - Train Loss: 2.2260, Train Accuracy: 0.4596
#   Group 3 - Val Loss: 2.4143, Val Accuracy: 0.4119
# Epoch [39/100] Group Metrics:
#   Group 1 - Train Loss: 2.6555, Train Accuracy: 0.2802
#   Group 1 - Val Loss: 2.7628, Val Accuracy: 0.2706
#   Group 2 - Train Loss: 2.6451, Train Accuracy: 0.3997
#   Group 2 - Val Loss: 2.7634, Val Accuracy: 0.4035
#   Group 3 - Train Loss: 2.2156, Train Accuracy: 0.4634
#   Group 3 - Val Loss: 2.4065, Val Accuracy: 0.4152
# Epoch [40/100] Group Metrics:
#   Group 1 - Train Loss: 2.6503, Train Accuracy: 0.2807
#   Group 1 - Val Loss: 2.7584, Val Accuracy: 0.2711
#   Group 2 - Train Loss: 2.6332, Train Accuracy: 0.4027
#   Group 2 - Val Loss: 2.7545, Val Accuracy: 0.4035
#   Group 3 - Train Loss: 2.2055, Train Accuracy: 0.4663
#   Group 3 - Val Loss: 2.3989, Val Accuracy: 0.4211
# Epoch [41/100] Group Metrics:
#   Group 1 - Train Loss: 2.6453, Train Accuracy: 0.2815
#   Group 1 - Val Loss: 2.7540, Val Accuracy: 0.2722
#   Group 2 - Train Loss: 2.6215, Train Accuracy: 0.4056
#   Group 2 - Val Loss: 2.7458, Val Accuracy: 0.4035
#   Group 3 - Train Loss: 2.1956, Train Accuracy: 0.4684
#   Group 3 - Val Loss: 2.3915, Val Accuracy: 0.4236
# Epoch [42/100] Group Metrics:
#   Group 1 - Train Loss: 2.6405, Train Accuracy: 0.2818
#   Group 1 - Val Loss: 2.7498, Val Accuracy: 0.2722
#   Group 2 - Train Loss: 2.6101, Train Accuracy: 0.4100
#   Group 2 - Val Loss: 2.7374, Val Accuracy: 0.4064
#   Group 3 - Train Loss: 2.1860, Train Accuracy: 0.4726
#   Group 3 - Val Loss: 2.3842, Val Accuracy: 0.4261
# Epoch [43/100] Group Metrics:
#   Group 1 - Train Loss: 2.6358, Train Accuracy: 0.2834
#   Group 1 - Val Loss: 2.7457, Val Accuracy: 0.2717
#   Group 2 - Train Loss: 2.5990, Train Accuracy: 0.4144
#   Group 2 - Val Loss: 2.7292, Val Accuracy: 0.4064
#   Group 3 - Train Loss: 2.1766, Train Accuracy: 0.4760
#   Group 3 - Val Loss: 2.3772, Val Accuracy: 0.4269
# Epoch [44/100] Group Metrics:
#   Group 1 - Train Loss: 2.6313, Train Accuracy: 0.2863
#   Group 1 - Val Loss: 2.7417, Val Accuracy: 0.2727
#   Group 2 - Train Loss: 2.5882, Train Accuracy: 0.4202
#   Group 2 - Val Loss: 2.7213, Val Accuracy: 0.4094
#   Group 3 - Train Loss: 2.1674, Train Accuracy: 0.4797
#   Group 3 - Val Loss: 2.3703, Val Accuracy: 0.4269
# Epoch [45/100] Group Metrics:
#   Group 1 - Train Loss: 2.6269, Train Accuracy: 0.2874
#   Group 1 - Val Loss: 2.7378, Val Accuracy: 0.2738
#   Group 2 - Train Loss: 2.5776, Train Accuracy: 0.4217
#   Group 2 - Val Loss: 2.7135, Val Accuracy: 0.4094
#   Group 3 - Train Loss: 2.1584, Train Accuracy: 0.4814
#   Group 3 - Val Loss: 2.3636, Val Accuracy: 0.4286
# Epoch [46/100] Group Metrics:
#   Group 1 - Train Loss: 2.6226, Train Accuracy: 0.2887
#   Group 1 - Val Loss: 2.7340, Val Accuracy: 0.2749
#   Group 2 - Train Loss: 2.5672, Train Accuracy: 0.4246
#   Group 2 - Val Loss: 2.7059, Val Accuracy: 0.4094
#   Group 3 - Train Loss: 2.1496, Train Accuracy: 0.4852
#   Group 3 - Val Loss: 2.3571, Val Accuracy: 0.4319
# Epoch [47/100] Group Metrics:
#   Group 1 - Train Loss: 2.6184, Train Accuracy: 0.2898
#   Group 1 - Val Loss: 2.7303, Val Accuracy: 0.2759
#   Group 2 - Train Loss: 2.5571, Train Accuracy: 0.4246
#   Group 2 - Val Loss: 2.6985, Val Accuracy: 0.4123
#   Group 3 - Train Loss: 2.1410, Train Accuracy: 0.4877
#   Group 3 - Val Loss: 2.3507, Val Accuracy: 0.4336
# Epoch [48/100] Group Metrics:
#   Group 1 - Train Loss: 2.6144, Train Accuracy: 0.2908
#   Group 1 - Val Loss: 2.7267, Val Accuracy: 0.2764
#   Group 2 - Train Loss: 2.5472, Train Accuracy: 0.4261
#   Group 2 - Val Loss: 2.6913, Val Accuracy: 0.4123
#   Group 3 - Train Loss: 2.1325, Train Accuracy: 0.4894
#   Group 3 - Val Loss: 2.3444, Val Accuracy: 0.4353
# Epoch [49/100] Group Metrics:
#   Group 1 - Train Loss: 2.6104, Train Accuracy: 0.2919
#   Group 1 - Val Loss: 2.7232, Val Accuracy: 0.2770
#   Group 2 - Train Loss: 2.5374, Train Accuracy: 0.4261
#   Group 2 - Val Loss: 2.6842, Val Accuracy: 0.4152
#   Group 3 - Train Loss: 2.1243, Train Accuracy: 0.4940
#   Group 3 - Val Loss: 2.3383, Val Accuracy: 0.4369
# Epoch [50/100] Group Metrics:
#   Group 1 - Train Loss: 2.6065, Train Accuracy: 0.2930
#   Group 1 - Val Loss: 2.7198, Val Accuracy: 0.2791
#   Group 2 - Train Loss: 2.5279, Train Accuracy: 0.4290
#   Group 2 - Val Loss: 2.6773, Val Accuracy: 0.4123
#   Group 3 - Train Loss: 2.1162, Train Accuracy: 0.4961
#   Group 3 - Val Loss: 2.3323, Val Accuracy: 0.4394
# Epoch [51/100] Group Metrics:
#   Group 1 - Train Loss: 2.6028, Train Accuracy: 0.2932
#   Group 1 - Val Loss: 2.7164, Val Accuracy: 0.2796
#   Group 2 - Train Loss: 2.5186, Train Accuracy: 0.4290
#   Group 2 - Val Loss: 2.6706, Val Accuracy: 0.4123
#   Group 3 - Train Loss: 2.1083, Train Accuracy: 0.4977
#   Group 3 - Val Loss: 2.3264, Val Accuracy: 0.4394
# Epoch [52/100] Group Metrics:
#   Group 1 - Train Loss: 2.5991, Train Accuracy: 0.2935
#   Group 1 - Val Loss: 2.7131, Val Accuracy: 0.2796
#   Group 2 - Train Loss: 2.5094, Train Accuracy: 0.4363
#   Group 2 - Val Loss: 2.6640, Val Accuracy: 0.4123
#   Group 3 - Train Loss: 2.1005, Train Accuracy: 0.4998
#   Group 3 - Val Loss: 2.3207, Val Accuracy: 0.4403
# Epoch [53/100] Group Metrics:
#   Group 1 - Train Loss: 2.5955, Train Accuracy: 0.2938
#   Group 1 - Val Loss: 2.7099, Val Accuracy: 0.2796
#   Group 2 - Train Loss: 2.5005, Train Accuracy: 0.4378
#   Group 2 - Val Loss: 2.6575, Val Accuracy: 0.4152
#   Group 3 - Train Loss: 2.0929, Train Accuracy: 0.5019
#   Group 3 - Val Loss: 2.3150, Val Accuracy: 0.4403
# Epoch [54/100] Group Metrics:
#   Group 1 - Train Loss: 2.5920, Train Accuracy: 0.2940
#   Group 1 - Val Loss: 2.7068, Val Accuracy: 0.2802
#   Group 2 - Train Loss: 2.4917, Train Accuracy: 0.4407
#   Group 2 - Val Loss: 2.6512, Val Accuracy: 0.4152
#   Group 3 - Train Loss: 2.0854, Train Accuracy: 0.5040
#   Group 3 - Val Loss: 2.3095, Val Accuracy: 0.4411
# Epoch [55/100] Group Metrics:
#   Group 1 - Train Loss: 2.5885, Train Accuracy: 0.2948
#   Group 1 - Val Loss: 2.7037, Val Accuracy: 0.2802
#   Group 2 - Train Loss: 2.4830, Train Accuracy: 0.4422
#   Group 2 - Val Loss: 2.6449, Val Accuracy: 0.4152
#   Group 3 - Train Loss: 2.0781, Train Accuracy: 0.5061
#   Group 3 - Val Loss: 2.3041, Val Accuracy: 0.4428
# Epoch [56/100] Group Metrics:
#   Group 1 - Train Loss: 2.5852, Train Accuracy: 0.2954
#   Group 1 - Val Loss: 2.7007, Val Accuracy: 0.2802
#   Group 2 - Train Loss: 2.4746, Train Accuracy: 0.4481
#   Group 2 - Val Loss: 2.6389, Val Accuracy: 0.4152
#   Group 3 - Train Loss: 2.0709, Train Accuracy: 0.5078
#   Group 3 - Val Loss: 2.2989, Val Accuracy: 0.4436
# Epoch [57/100] Group Metrics:
#   Group 1 - Train Loss: 2.5819, Train Accuracy: 0.2954
#   Group 1 - Val Loss: 2.6977, Val Accuracy: 0.2802
#   Group 2 - Train Loss: 2.4662, Train Accuracy: 0.4495
#   Group 2 - Val Loss: 2.6329, Val Accuracy: 0.4181
#   Group 3 - Train Loss: 2.0639, Train Accuracy: 0.5107
#   Group 3 - Val Loss: 2.2937, Val Accuracy: 0.4453
# Epoch [58/100] Group Metrics:
#   Group 1 - Train Loss: 2.5787, Train Accuracy: 0.2954
#   Group 1 - Val Loss: 2.6948, Val Accuracy: 0.2802
#   Group 2 - Train Loss: 2.4581, Train Accuracy: 0.4525
#   Group 2 - Val Loss: 2.6271, Val Accuracy: 0.4211
#   Group 3 - Train Loss: 2.0569, Train Accuracy: 0.5145
#   Group 3 - Val Loss: 2.2886, Val Accuracy: 0.4470
# Epoch [59/100] Group Metrics:
#   Group 1 - Train Loss: 2.5755, Train Accuracy: 0.2951
#   Group 1 - Val Loss: 2.6919, Val Accuracy: 0.2796
#   Group 2 - Train Loss: 2.4500, Train Accuracy: 0.4525
#   Group 2 - Val Loss: 2.6213, Val Accuracy: 0.4211
#   Group 3 - Train Loss: 2.0501, Train Accuracy: 0.5178
#   Group 3 - Val Loss: 2.2836, Val Accuracy: 0.4470
# Epoch [60/100] Group Metrics:
#   Group 1 - Train Loss: 2.5724, Train Accuracy: 0.2954
#   Group 1 - Val Loss: 2.6891, Val Accuracy: 0.2796
#   Group 2 - Train Loss: 2.4421, Train Accuracy: 0.4568
#   Group 2 - Val Loss: 2.6157, Val Accuracy: 0.4240
#   Group 3 - Train Loss: 2.0434, Train Accuracy: 0.5203
#   Group 3 - Val Loss: 2.2787, Val Accuracy: 0.4478
# Epoch [61/100] Group Metrics:
#   Group 1 - Train Loss: 2.5694, Train Accuracy: 0.2962
#   Group 1 - Val Loss: 2.6864, Val Accuracy: 0.2796
#   Group 2 - Train Loss: 2.4344, Train Accuracy: 0.4583
#   Group 2 - Val Loss: 2.6101, Val Accuracy: 0.4240
#   Group 3 - Train Loss: 2.0369, Train Accuracy: 0.5224
#   Group 3 - Val Loss: 2.2739, Val Accuracy: 0.4511
# Epoch [62/100] Group Metrics:
#   Group 1 - Train Loss: 2.5664, Train Accuracy: 0.2962
#   Group 1 - Val Loss: 2.6837, Val Accuracy: 0.2802
#   Group 2 - Train Loss: 2.4267, Train Accuracy: 0.4598
#   Group 2 - Val Loss: 2.6047, Val Accuracy: 0.4298
#   Group 3 - Train Loss: 2.0304, Train Accuracy: 0.5241
#   Group 3 - Val Loss: 2.2692, Val Accuracy: 0.4536
# Epoch [63/100] Group Metrics:
#   Group 1 - Train Loss: 2.5635, Train Accuracy: 0.2964
#   Group 1 - Val Loss: 2.6810, Val Accuracy: 0.2802
#   Group 2 - Train Loss: 2.4192, Train Accuracy: 0.4612
#   Group 2 - Val Loss: 2.5994, Val Accuracy: 0.4298
#   Group 3 - Train Loss: 2.0241, Train Accuracy: 0.5266
#   Group 3 - Val Loss: 2.2646, Val Accuracy: 0.4561
# Epoch [64/100] Group Metrics:
#   Group 1 - Train Loss: 2.5607, Train Accuracy: 0.2970
#   Group 1 - Val Loss: 2.6784, Val Accuracy: 0.2802
#   Group 2 - Train Loss: 2.4118, Train Accuracy: 0.4642
#   Group 2 - Val Loss: 2.5941, Val Accuracy: 0.4298
#   Group 3 - Train Loss: 2.0178, Train Accuracy: 0.5304
#   Group 3 - Val Loss: 2.2600, Val Accuracy: 0.4561
# Epoch [65/100] Group Metrics:
#   Group 1 - Train Loss: 2.5578, Train Accuracy: 0.2970
#   Group 1 - Val Loss: 2.6759, Val Accuracy: 0.2807
#   Group 2 - Train Loss: 2.4046, Train Accuracy: 0.4686
#   Group 2 - Val Loss: 2.5890, Val Accuracy: 0.4298
#   Group 3 - Train Loss: 2.0117, Train Accuracy: 0.5317
#   Group 3 - Val Loss: 2.2556, Val Accuracy: 0.4570
# Epoch [66/100] Group Metrics:
#   Group 1 - Train Loss: 2.5551, Train Accuracy: 0.2972
#   Group 1 - Val Loss: 2.6734, Val Accuracy: 0.2807
#   Group 2 - Train Loss: 2.3974, Train Accuracy: 0.4686
#   Group 2 - Val Loss: 2.5839, Val Accuracy: 0.4298
#   Group 3 - Train Loss: 2.0056, Train Accuracy: 0.5337
#   Group 3 - Val Loss: 2.2512, Val Accuracy: 0.4595
# Epoch [67/100] Group Metrics:
#   Group 1 - Train Loss: 2.5524, Train Accuracy: 0.2970
#   Group 1 - Val Loss: 2.6709, Val Accuracy: 0.2796
#   Group 2 - Train Loss: 2.3904, Train Accuracy: 0.4715
#   Group 2 - Val Loss: 2.5789, Val Accuracy: 0.4327
#   Group 3 - Train Loss: 1.9997, Train Accuracy: 0.5375
#   Group 3 - Val Loss: 2.2469, Val Accuracy: 0.4612
# Epoch [68/100] Group Metrics:
#   Group 1 - Train Loss: 2.5497, Train Accuracy: 0.2970
#   Group 1 - Val Loss: 2.6684, Val Accuracy: 0.2791
#   Group 2 - Train Loss: 2.3834, Train Accuracy: 0.4774
#   Group 2 - Val Loss: 2.5740, Val Accuracy: 0.4357
#   Group 3 - Train Loss: 1.9939, Train Accuracy: 0.5396
#   Group 3 - Val Loss: 2.2427, Val Accuracy: 0.4620
# Epoch [69/100] Group Metrics:
#   Group 1 - Train Loss: 2.5471, Train Accuracy: 0.2978
#   Group 1 - Val Loss: 2.6660, Val Accuracy: 0.2791
#   Group 2 - Train Loss: 2.3766, Train Accuracy: 0.4788
#   Group 2 - Val Loss: 2.5692, Val Accuracy: 0.4357
#   Group 3 - Train Loss: 1.9881, Train Accuracy: 0.5409
#   Group 3 - Val Loss: 2.2385, Val Accuracy: 0.4645
# Epoch [70/100] Group Metrics:
#   Group 1 - Train Loss: 2.5445, Train Accuracy: 0.2983
#   Group 1 - Val Loss: 2.6637, Val Accuracy: 0.2802
#   Group 2 - Train Loss: 2.3699, Train Accuracy: 0.4803
#   Group 2 - Val Loss: 2.5645, Val Accuracy: 0.4357
#   Group 3 - Train Loss: 1.9824, Train Accuracy: 0.5434
#   Group 3 - Val Loss: 2.2344, Val Accuracy: 0.4662
# Epoch [71/100] Group Metrics:
#   Group 1 - Train Loss: 2.5420, Train Accuracy: 0.2988
#   Group 1 - Val Loss: 2.6614, Val Accuracy: 0.2807
#   Group 2 - Train Loss: 2.3633, Train Accuracy: 0.4818
#   Group 2 - Val Loss: 2.5598, Val Accuracy: 0.4386
#   Group 3 - Train Loss: 1.9769, Train Accuracy: 0.5442
#   Group 3 - Val Loss: 2.2304, Val Accuracy: 0.4678
# Epoch [72/100] Group Metrics:
#   Group 1 - Train Loss: 2.5395, Train Accuracy: 0.2986
#   Group 1 - Val Loss: 2.6591, Val Accuracy: 0.2807
#   Group 2 - Train Loss: 2.3567, Train Accuracy: 0.4818
#   Group 2 - Val Loss: 2.5552, Val Accuracy: 0.4386
#   Group 3 - Train Loss: 1.9714, Train Accuracy: 0.5446
#   Group 3 - Val Loss: 2.2265, Val Accuracy: 0.4687
# Epoch [73/100] Group Metrics:
#   Group 1 - Train Loss: 2.5371, Train Accuracy: 0.2991
#   Group 1 - Val Loss: 2.6568, Val Accuracy: 0.2807
#   Group 2 - Train Loss: 2.3503, Train Accuracy: 0.4832
#   Group 2 - Val Loss: 2.5507, Val Accuracy: 0.4386
#   Group 3 - Train Loss: 1.9660, Train Accuracy: 0.5463
#   Group 3 - Val Loss: 2.2226, Val Accuracy: 0.4695
# Epoch [74/100] Group Metrics:
#   Group 1 - Train Loss: 2.5347, Train Accuracy: 0.2991
#   Group 1 - Val Loss: 2.6546, Val Accuracy: 0.2807
#   Group 2 - Train Loss: 2.3440, Train Accuracy: 0.4847
#   Group 2 - Val Loss: 2.5462, Val Accuracy: 0.4386
#   Group 3 - Train Loss: 1.9606, Train Accuracy: 0.5484
#   Group 3 - Val Loss: 2.2188, Val Accuracy: 0.4703
# Epoch [75/100] Group Metrics:
#   Group 1 - Train Loss: 2.5323, Train Accuracy: 0.2991
#   Group 1 - Val Loss: 2.6524, Val Accuracy: 0.2796
#   Group 2 - Train Loss: 2.3377, Train Accuracy: 0.4861
#   Group 2 - Val Loss: 2.5418, Val Accuracy: 0.4386
#   Group 3 - Train Loss: 1.9554, Train Accuracy: 0.5484
#   Group 3 - Val Loss: 2.2150, Val Accuracy: 0.4745
# Epoch [76/100] Group Metrics:
#   Group 1 - Train Loss: 2.5300, Train Accuracy: 0.2991
#   Group 1 - Val Loss: 2.6502, Val Accuracy: 0.2802
#   Group 2 - Train Loss: 2.3315, Train Accuracy: 0.4891
#   Group 2 - Val Loss: 2.5375, Val Accuracy: 0.4386
#   Group 3 - Train Loss: 1.9502, Train Accuracy: 0.5497
#   Group 3 - Val Loss: 2.2113, Val Accuracy: 0.4745
# Epoch [77/100] Group Metrics:
#   Group 1 - Train Loss: 2.5277, Train Accuracy: 0.2988
#   Group 1 - Val Loss: 2.6481, Val Accuracy: 0.2802
#   Group 2 - Train Loss: 2.3255, Train Accuracy: 0.4920
#   Group 2 - Val Loss: 2.5332, Val Accuracy: 0.4386
#   Group 3 - Train Loss: 1.9451, Train Accuracy: 0.5526
#   Group 3 - Val Loss: 2.2077, Val Accuracy: 0.4779
# Epoch [78/100] Group Metrics:
#   Group 1 - Train Loss: 2.5254, Train Accuracy: 0.2986
#   Group 1 - Val Loss: 2.6460, Val Accuracy: 0.2802
#   Group 2 - Train Loss: 2.3195, Train Accuracy: 0.4920
#   Group 2 - Val Loss: 2.5290, Val Accuracy: 0.4386
#   Group 3 - Train Loss: 1.9401, Train Accuracy: 0.5547
#   Group 3 - Val Loss: 2.2041, Val Accuracy: 0.4795
# Epoch [79/100] Group Metrics:
#   Group 1 - Train Loss: 2.5232, Train Accuracy: 0.2988
#   Group 1 - Val Loss: 2.6439, Val Accuracy: 0.2796
#   Group 2 - Train Loss: 2.3136, Train Accuracy: 0.4964
#   Group 2 - Val Loss: 2.5249, Val Accuracy: 0.4415
#   Group 3 - Train Loss: 1.9352, Train Accuracy: 0.5568
#   Group 3 - Val Loss: 2.2006, Val Accuracy: 0.4804
# Epoch [80/100] Group Metrics:
#   Group 1 - Train Loss: 2.5210, Train Accuracy: 0.2991
#   Group 1 - Val Loss: 2.6419, Val Accuracy: 0.2791
#   Group 2 - Train Loss: 2.3077, Train Accuracy: 0.4964
#   Group 2 - Val Loss: 2.5208, Val Accuracy: 0.4415
#   Group 3 - Train Loss: 1.9303, Train Accuracy: 0.5597
#   Group 3 - Val Loss: 2.1971, Val Accuracy: 0.4795
# Epoch [81/100] Group Metrics:
#   Group 1 - Train Loss: 2.5188, Train Accuracy: 0.2991
#   Group 1 - Val Loss: 2.6399, Val Accuracy: 0.2791
#   Group 2 - Train Loss: 2.3020, Train Accuracy: 0.4979
#   Group 2 - Val Loss: 2.5168, Val Accuracy: 0.4415
#   Group 3 - Train Loss: 1.9255, Train Accuracy: 0.5610
#   Group 3 - Val Loss: 2.1937, Val Accuracy: 0.4795
# Epoch [82/100] Group Metrics:
#   Group 1 - Train Loss: 2.5167, Train Accuracy: 0.2991
#   Group 1 - Val Loss: 2.6379, Val Accuracy: 0.2796
#   Group 2 - Train Loss: 2.2963, Train Accuracy: 0.4993
#   Group 2 - Val Loss: 2.5129, Val Accuracy: 0.4415
#   Group 3 - Train Loss: 1.9207, Train Accuracy: 0.5639
#   Group 3 - Val Loss: 2.1903, Val Accuracy: 0.4829
# Epoch [83/100] Group Metrics:
#   Group 1 - Train Loss: 2.5146, Train Accuracy: 0.2991
#   Group 1 - Val Loss: 2.6359, Val Accuracy: 0.2802
#   Group 2 - Train Loss: 2.2907, Train Accuracy: 0.5067
#   Group 2 - Val Loss: 2.5089, Val Accuracy: 0.4444
#   Group 3 - Train Loss: 1.9160, Train Accuracy: 0.5643
#   Group 3 - Val Loss: 2.1870, Val Accuracy: 0.4829
# Epoch [84/100] Group Metrics:
#   Group 1 - Train Loss: 2.5125, Train Accuracy: 0.2993
#   Group 1 - Val Loss: 2.6340, Val Accuracy: 0.2802
#   Group 2 - Train Loss: 2.2852, Train Accuracy: 0.5081
#   Group 2 - Val Loss: 2.5051, Val Accuracy: 0.4474
#   Group 3 - Train Loss: 1.9114, Train Accuracy: 0.5664
#   Group 3 - Val Loss: 2.1837, Val Accuracy: 0.4845
# Epoch [85/100] Group Metrics:
#   Group 1 - Train Loss: 2.5105, Train Accuracy: 0.2993
#   Group 1 - Val Loss: 2.6321, Val Accuracy: 0.2807
#   Group 2 - Train Loss: 2.2797, Train Accuracy: 0.5110
#   Group 2 - Val Loss: 2.5013, Val Accuracy: 0.4474
#   Group 3 - Train Loss: 1.9069, Train Accuracy: 0.5677
#   Group 3 - Val Loss: 2.1805, Val Accuracy: 0.4854
# Epoch [86/100] Group Metrics:
#   Group 1 - Train Loss: 2.5085, Train Accuracy: 0.2991
#   Group 1 - Val Loss: 2.6302, Val Accuracy: 0.2807
#   Group 2 - Train Loss: 2.2743, Train Accuracy: 0.5125
#   Group 2 - Val Loss: 2.4976, Val Accuracy: 0.4474
#   Group 3 - Train Loss: 1.9024, Train Accuracy: 0.5693
#   Group 3 - Val Loss: 2.1774, Val Accuracy: 0.4871
# Epoch [87/100] Group Metrics:
#   Group 1 - Train Loss: 2.5065, Train Accuracy: 0.2993
#   Group 1 - Val Loss: 2.6283, Val Accuracy: 0.2818
#   Group 2 - Train Loss: 2.2690, Train Accuracy: 0.5140
#   Group 2 - Val Loss: 2.4939, Val Accuracy: 0.4503
#   Group 3 - Train Loss: 1.8979, Train Accuracy: 0.5710
#   Group 3 - Val Loss: 2.1742, Val Accuracy: 0.4879
# Epoch [88/100] Group Metrics:
#   Group 1 - Train Loss: 2.5045, Train Accuracy: 0.2999
#   Group 1 - Val Loss: 2.6265, Val Accuracy: 0.2823
#   Group 2 - Train Loss: 2.2637, Train Accuracy: 0.5154
#   Group 2 - Val Loss: 2.4902, Val Accuracy: 0.4503
#   Group 3 - Train Loss: 1.8936, Train Accuracy: 0.5727
#   Group 3 - Val Loss: 2.1712, Val Accuracy: 0.4879
# Epoch [89/100] Group Metrics:
#   Group 1 - Train Loss: 2.5026, Train Accuracy: 0.2999
#   Group 1 - Val Loss: 2.6247, Val Accuracy: 0.2828
#   Group 2 - Train Loss: 2.2585, Train Accuracy: 0.5154
#   Group 2 - Val Loss: 2.4866, Val Accuracy: 0.4503
#   Group 3 - Train Loss: 1.8892, Train Accuracy: 0.5748
#   Group 3 - Val Loss: 2.1681, Val Accuracy: 0.4879
# Epoch [90/100] Group Metrics:
#   Group 1 - Train Loss: 2.5006, Train Accuracy: 0.2999
#   Group 1 - Val Loss: 2.6229, Val Accuracy: 0.2834
#   Group 2 - Train Loss: 2.2534, Train Accuracy: 0.5169
#   Group 2 - Val Loss: 2.4831, Val Accuracy: 0.4503
#   Group 3 - Train Loss: 1.8850, Train Accuracy: 0.5769
#   Group 3 - Val Loss: 2.1651, Val Accuracy: 0.4896
# Epoch [91/100] Group Metrics:
#   Group 1 - Train Loss: 2.4987, Train Accuracy: 0.3004
#   Group 1 - Val Loss: 2.6211, Val Accuracy: 0.2834
#   Group 2 - Train Loss: 2.2483, Train Accuracy: 0.5198
#   Group 2 - Val Loss: 2.4796, Val Accuracy: 0.4503
#   Group 3 - Train Loss: 1.8808, Train Accuracy: 0.5773
#   Group 3 - Val Loss: 2.1622, Val Accuracy: 0.4904
# Epoch [92/100] Group Metrics:
#   Group 1 - Train Loss: 2.4969, Train Accuracy: 0.3004
#   Group 1 - Val Loss: 2.6194, Val Accuracy: 0.2839
#   Group 2 - Train Loss: 2.2433, Train Accuracy: 0.5198
#   Group 2 - Val Loss: 2.4761, Val Accuracy: 0.4503
#   Group 3 - Train Loss: 1.8766, Train Accuracy: 0.5781
#   Group 3 - Val Loss: 2.1593, Val Accuracy: 0.4904
# Epoch [93/100] Group Metrics:
#   Group 1 - Train Loss: 2.4950, Train Accuracy: 0.3009
#   Group 1 - Val Loss: 2.6176, Val Accuracy: 0.2839
#   Group 2 - Train Loss: 2.2384, Train Accuracy: 0.5213
#   Group 2 - Val Loss: 2.4727, Val Accuracy: 0.4503
#   Group 3 - Train Loss: 1.8725, Train Accuracy: 0.5790
#   Group 3 - Val Loss: 2.1564, Val Accuracy: 0.4904
# Epoch [94/100] Group Metrics:
#   Group 1 - Train Loss: 2.4932, Train Accuracy: 0.3012
#   Group 1 - Val Loss: 2.6159, Val Accuracy: 0.2844
#   Group 2 - Train Loss: 2.2335, Train Accuracy: 0.5213
#   Group 2 - Val Loss: 2.4693, Val Accuracy: 0.4561
#   Group 3 - Train Loss: 1.8685, Train Accuracy: 0.5798
#   Group 3 - Val Loss: 2.1536, Val Accuracy: 0.4912
# Epoch [95/100] Group Metrics:
#   Group 1 - Train Loss: 2.4914, Train Accuracy: 0.3012
#   Group 1 - Val Loss: 2.6142, Val Accuracy: 0.2844
#   Group 2 - Train Loss: 2.2287, Train Accuracy: 0.5257
#   Group 2 - Val Loss: 2.4660, Val Accuracy: 0.4561
#   Group 3 - Train Loss: 1.8645, Train Accuracy: 0.5815
#   Group 3 - Val Loss: 2.1508, Val Accuracy: 0.4921
# Epoch [96/100] Group Metrics:
#   Group 1 - Train Loss: 2.4896, Train Accuracy: 0.3012
#   Group 1 - Val Loss: 2.6126, Val Accuracy: 0.2855
#   Group 2 - Train Loss: 2.2239, Train Accuracy: 0.5286
#   Group 2 - Val Loss: 2.4627, Val Accuracy: 0.4561
#   Group 3 - Train Loss: 1.8605, Train Accuracy: 0.5823
#   Group 3 - Val Loss: 2.1481, Val Accuracy: 0.4937
# Epoch [97/100] Group Metrics:
#   Group 1 - Train Loss: 2.4879, Train Accuracy: 0.3012
#   Group 1 - Val Loss: 2.6109, Val Accuracy: 0.2855
#   Group 2 - Train Loss: 2.2192, Train Accuracy: 0.5315
#   Group 2 - Val Loss: 2.4595, Val Accuracy: 0.4591
#   Group 3 - Train Loss: 1.8566, Train Accuracy: 0.5852
#   Group 3 - Val Loss: 2.1454, Val Accuracy: 0.4937
# Epoch [98/100] Group Metrics:
#   Group 1 - Train Loss: 2.4861, Train Accuracy: 0.3007
#   Group 1 - Val Loss: 2.6093, Val Accuracy: 0.2850
#   Group 2 - Train Loss: 2.2145, Train Accuracy: 0.5315
#   Group 2 - Val Loss: 2.4563, Val Accuracy: 0.4591
#   Group 3 - Train Loss: 1.8527, Train Accuracy: 0.5873
#   Group 3 - Val Loss: 2.1427, Val Accuracy: 0.4946
# Epoch [99/100] Group Metrics:
#   Group 1 - Train Loss: 2.4844, Train Accuracy: 0.3009
#   Group 1 - Val Loss: 2.6077, Val Accuracy: 0.2850
#   Group 2 - Train Loss: 2.2099, Train Accuracy: 0.5345
#   Group 2 - Val Loss: 2.4532, Val Accuracy: 0.4591
#   Group 3 - Train Loss: 1.8489, Train Accuracy: 0.5886
#   Group 3 - Val Loss: 2.1400, Val Accuracy: 0.4971
# Epoch [100/100] Group Metrics:
#   Group 1 - Train Loss: 2.4827, Train Accuracy: 0.3009
#   Group 1 - Val Loss: 2.6061, Val Accuracy: 0.2850
#   Group 2 - Train Loss: 2.2054, Train Accuracy: 0.5359
#   Group 2 - Val Loss: 2.4500, Val Accuracy: 0.4591
#   Group 3 - Train Loss: 1.8452, Train Accuracy: 0.5903
#   Group 3 - Val Loss: 2.1374, Val Accuracy: 0.4987

# %%
# Convert metrics to numpy arrays for easy manipulation
group_train_loss_histories = {k: np.array(v) for k, v in group_train_loss_histories.items()}
group_train_accuracy_histories = {k: np.array(v) for k, v in group_train_accuracy_histories.items()}
group_val_loss_histories = {k: np.array(v) for k, v in group_val_loss_histories.items()}
group_val_accuracy_histories = {k: np.array(v) for k, v in group_val_accuracy_histories.items()}

# Handle potential one-dimensional arrays
group_train_loss_mean = {k: v.mean(axis=1) if v.ndim > 1 else v for k, v in group_train_loss_histories.items()}
group_train_loss_std = {k: v.std(axis=1) if v.ndim > 1 else np.zeros_like(v) for k, v in group_train_loss_histories.items()}
group_val_loss_mean = {k: v.mean(axis=1) if v.ndim > 1 else v for k, v in group_val_loss_histories.items()}
group_val_loss_std = {k: v.std(axis=1) if v.ndim > 1 else np.zeros_like(v) for k, v in group_val_loss_histories.items()}

group_train_acc_mean = {k: v.mean(axis=1) if v.ndim > 1 else v for k, v in group_train_accuracy_histories.items()}
group_train_acc_std = {k: v.std(axis=1) if v.ndim > 1 else np.zeros_like(v) for k, v in group_train_accuracy_histories.items()}
group_val_acc_mean = {k: v.mean(axis=1) if v.ndim > 1 else v for k, v in group_val_accuracy_histories.items()}
group_val_acc_std = {k: v.std(axis=1) if v.ndim > 1 else np.zeros_like(v) for k, v in group_val_accuracy_histories.items()}

# Combined Plot for All Modalities
plt.figure(figsize=(12, 6))

# Loss Plot
plt.subplot(1, 2, 1)
for group in [1, 2, 3]:
    plt.plot(range(1, num_epochs + 1), group_train_loss_mean[group], label=f"Group {group} Train Loss")
    plt.fill_between(range(1, num_epochs + 1), 
                     group_train_loss_mean[group] - group_train_loss_std[group], 
                     group_train_loss_mean[group] + group_train_loss_std[group], 
                     alpha=0.2)
    plt.plot(range(1, num_epochs + 1), group_val_loss_mean[group], label=f"Group {group} Validation Loss", linestyle="dashed")
    plt.fill_between(range(1, num_epochs + 1), 
                     group_val_loss_mean[group] - group_val_loss_std[group], 
                     group_val_loss_mean[group] + group_val_loss_std[group], 
                     alpha=0.2)

plt.title("Loss over Epochs for All Groups")
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.legend()
plt.grid()

# Accuracy Plot
plt.subplot(1, 2, 2)
for group in [1, 2, 3]:
    plt.plot(range(1, num_epochs + 1), group_train_acc_mean[group], label=f"Group {group} Train Accuracy")
    plt.fill_between(range(1, num_epochs + 1), 
                     group_train_acc_mean[group] - group_train_acc_std[group], 
                     group_train_acc_mean[group] + group_train_acc_std[group], 
                     alpha=0.2)
    plt.plot(range(1, num_epochs + 1), group_val_acc_mean[group], label=f"Group {group} Validation Accuracy", linestyle="dashed")
    plt.fill_between(range(1, num_epochs + 1), 
                     group_val_acc_mean[group] - group_val_acc_std[group], 
                     group_val_acc_mean[group] + group_val_acc_std[group], 
                     alpha=0.2)

plt.title("Accuracy over Epochs for All Groups")
plt.xlabel("Epoch")
plt.ylabel("Accuracy")
plt.ylim([0, 1])  # Ensure y-axis is between 0 and 1 for accuracy
plt.legend()
plt.grid()

plt.tight_layout()
plt.show()

# %%
# Combined Plot for All Modalities
plt.figure(figsize=(12, 6))

# Loss Plot
plt.subplot(1, 2, 1)
for group in [1, 2, 3]:
    plt.plot(range(1, num_epochs + 1), group_train_loss_mean[group], label=f"Group {group} Train Loss")
    plt.fill_between(range(1, num_epochs + 1), 
                     group_train_loss_mean[group] - group_train_loss_std[group], 
                     group_train_loss_mean[group] + group_train_loss_std[group], 
                     alpha=0.2)
    plt.plot(range(1, num_epochs + 1), group_val_loss_mean[group], label=f"Group {group} Validation Loss", linestyle="dashed")
    plt.fill_between(range(1, num_epochs + 1), 
                     group_val_loss_mean[group] - group_val_loss_std[group], 
                     group_val_loss_mean[group] + group_val_loss_std[group], 
                     alpha=0.2)

plt.title("Loss over Epochs for All Groups")
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.legend()
plt.grid()

# Accuracy Plot
plt.subplot(1, 2, 2)
for group in [1, 2, 3]:
    plt.plot(range(1, num_epochs + 1), group_train_acc_mean[group], label=f"Group {group} Train Accuracy")
    plt.fill_between(range(1, num_epochs + 1), 
                     group_train_acc_mean[group] - group_train_acc_std[group], 
                     group_train_acc_mean[group] + group_train_acc_std[group], 
                     alpha=0.2)
    plt.plot(range(1, num_epochs + 1), group_val_acc_mean[group], label=f"Group {group} Validation Accuracy", linestyle="dashed")
    plt.fill_between(range(1, num_epochs + 1), 
                     group_val_acc_mean[group] - group_val_acc_std[group], 
                     group_val_acc_mean[group] + group_val_acc_std[group], 
                     alpha=0.2)

plt.title("Accuracy over Epochs for All Groups")
plt.xlabel("Epoch")
plt.ylabel("Accuracy")
plt.ylim([0, 1])  # Ensure y-axis is between 0 and 1 for accuracy
plt.legend()
plt.grid()

plt.tight_layout()
plt.show()

# %%
# Track metrics across all groups
'''
group_test_loss_histories = {group: [] for group in range(1, num_groups + 1)}
group_test_accuracy_histories = {group: [] for group in range(1, num_groups + 1)}
group_train_loss_histories = {group: [] for group in range(1, num_groups + 1)}
group_train_accuracy_histories = {group: [] for group in range(1, num_groups + 1)}

with torch.no_grad():  # Disable gradient computation for testing
    for group in range(1, num_groups + 1):
        user_test_losses = []
        user_test_accuracies = []
        user_train_losses = []
        user_train_accuracies = []

        for user_id, model in enumerate(classifiers_by_group[group]):
            model.eval()

            # Test metrics
            epoch_test_loss = 0.0
            correct_test_predictions = 0
            total_test_samples = 0

            # Train metrics (optional, for post-training evaluation on training data)
            epoch_train_loss = 0.0
            correct_train_predictions = 0
            total_train_samples = 0

            # Evaluate on test set
            for X_batch, y_batch in test_loaders_by_group[group][user_id]:
                X_batch, y_batch = X_batch.cuda(), y_batch.cuda()
                outputs = model(X_batch)
                loss = criterion(outputs, y_batch)

                epoch_test_loss += loss.item()
                _, predicted = torch.max(outputs, dim=1)
                correct_test_predictions += (predicted == y_batch).sum().item()
                total_test_samples += y_batch.size(0)

            # Evaluate on training set
            for X_batch, y_batch in train_loaders_by_group[group][user_id]:
                X_batch, y_batch = X_batch.cuda(), y_batch.cuda()
                outputs = model(X_batch)
                loss = criterion(outputs, y_batch)

                epoch_train_loss += loss.item()
                _, predicted = torch.max(outputs, dim=1)
                correct_train_predictions += (predicted == y_batch).sum().item()
                total_train_samples += y_batch.size(0)

            # Calculate averages
            avg_test_loss = epoch_test_loss / len(test_loaders_by_group[group][user_id])
            test_accuracy = correct_test_predictions / total_test_samples

            avg_train_loss = epoch_train_loss / len(train_loaders_by_group[group][user_id])
            train_accuracy = correct_train_predictions / total_train_samples

            # Store metrics for each user
            user_test_losses.append(avg_test_loss)
            user_test_accuracies.append(test_accuracy)
            user_train_losses.append(avg_train_loss)
            user_train_accuracies.append(train_accuracy)

        # Store group-level metrics
        group_test_loss_histories[group].append(np.mean(user_test_losses))
        group_test_accuracy_histories[group].append(np.mean(user_test_accuracies))
        group_train_loss_histories[group].append(np.mean(user_train_losses))
        group_train_accuracy_histories[group].append(np.mean(user_train_accuracies))

# Convert metrics to numpy arrays for plotting
group_test_loss_histories = {group: np.array(values) for group, values in group_test_loss_histories.items()}
group_test_accuracy_histories = {group: np.array(values) for group, values in group_test_accuracy_histories.items()}
group_train_loss_histories = {group: np.array(values) for group, values in group_train_loss_histories.items()}
group_train_accuracy_histories = {group: np.array(values) for group, values in group_train_accuracy_histories.items()}

# Plot results for all groups
plt.figure(figsize=(12, 6))

# Test Loss and Accuracy
plt.subplot(1, 2, 1)
for group in range(1, num_groups + 1):
    plt.plot(range(1, len(group_test_loss_histories[group]) + 1), group_test_loss_histories[group], label=f"Group {group} Test Loss")
plt.title("Test Loss Across Groups")
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.legend()
plt.grid()

plt.subplot(1, 2, 2)
for group in range(1, num_groups + 1):
    plt.plot(range(1, len(group_test_accuracy_histories[group]) + 1), group_test_accuracy_histories[group], label=f"Group {group} Test Accuracy")
plt.title("Test Accuracy Across Groups")
plt.xlabel("Epoch")
plt.ylabel("Accuracy")
plt.legend()
plt.grid()

plt.tight_layout()
plt.show()
'''
# Out:
# '\ngroup_test_loss_histories = {group: [] for group in range(1, num_groups + 1)}\ngroup_test_accuracy_histories = {group: [] for group in range(1, num_groups + 1)}\ngroup_train_loss_histories = {group: [] for group in range(1, num_groups + 1)}\ngroup_train_accuracy_histories = {group: [] for group in range(1, num_groups + 1)}\n\nwith torch.no_grad():  # Disable gradient computation for testing\n    for group in range(1, num_groups + 1):\n        user_test_losses = []\n        user_test_accuracies = []\n        user_train_losses = []\n        user_train_accuracies = []\n\n        for user_id, model in enumerate(classifiers_by_group[group]):\n            model.eval()\n\n            # Test metrics\n            epoch_test_loss = 0.0\n            correct_test_predictions = 0\n            total_test_samples = 0\n\n            # Train metrics (optional, for post-training evaluation on training data)\n            epoch_train_loss = 0.0\n            correct_train_predictions = 0\n            total_train_samples = 0\n\n            # Evaluate on test set\n            for X_batch, y_batch in test_loaders_by_group[group][user_id]:\n                X_batch, y_batch = X_batch.cuda(), y_batch.cuda()\n                outputs = model(X_batch)\n                loss = criterion(outputs, y_batch)\n\n                epoch_test_loss += loss.item()\n                _, predicted = torch.max(outputs, dim=1)\n                correct_test_predictions += (predicted == y_batch).sum().item()\n                total_test_samples += y_batch.size(0)\n\n            # Evaluate on training set\n            for X_batch, y_batch in train_loaders_by_group[group][user_id]:\n                X_batch, y_batch = X_batch.cuda(), y_batch.cuda()\n                outputs = model(X_batch)\n                loss = criterion(outputs, y_batch)\n\n                epoch_train_loss += loss.item()\n                _, predicted = torch.max(outputs, dim=1)\n                correct_train_predictions += (predicted == y_batch).sum().item()\n                total_train_samples += y_batch.size(0)\n\n            # Calculate averages\n            avg_test_loss = epoch_test_loss / len(test_loaders_by_group[group][user_id])\n            test_accuracy = correct_test_predictions / total_test_samples\n\n            avg_train_loss = epoch_train_loss / len(train_loaders_by_group[group][user_id])\n            train_accuracy = correct_train_predictions / total_train_samples\n\n            # Store metrics for each user\n            user_test_losses.append(avg_test_loss)\n            user_test_accuracies.append(test_accuracy)\n            user_train_losses.append(avg_train_loss)\n            user_train_accuracies.append(train_accuracy)\n\n        # Store group-level metrics\n        group_test_loss_histories[group].append(np.mean(user_test_losses))\n        group_test_accuracy_histories[group].append(np.mean(user_test_accuracies))\n        group_train_loss_histories[group].append(np.mean(user_train_losses))\n        group_train_accuracy_histories[group].append(np.mean(user_train_accuracies))\n\n# Convert metrics to numpy arrays for plotting\ngroup_test_loss_histories = {group: np.array(values) for group, values in group_test_loss_histories.items()}\ngroup_test_accuracy_histories = {group: np.array(values) for group, values in group_test_accuracy_histories.items()}\ngroup_train_loss_histories = {group: np.array(values) for group, values in group_train_loss_histories.items()}\ngroup_train_accuracy_histories = {group: np.array(values) for group, values in group_train_accuracy_histories.items()}\n\n# Plot results for all groups\nplt.figure(figsize=(12, 6))\n\n# Test Loss and Accuracy\nplt.subplot(1, 2, 1)\nfor group in range(1, num_groups + 1):\n    plt.plot(range(1, len(group_test_loss_histories[group]) + 1), group_test_loss_histories[group], label=f"Group {group} Test Loss")\nplt.title("Test Loss Across Groups")\nplt.xlabel("Epoch")\nplt.ylabel("Loss")\nplt.legend()\nplt.grid()\n\nplt.subplot(1, 2, 2)\nfor ...

# %%
# Images only
'''
Test Loss: 0.4364, Test Accuracy: 0.8521

Train Loss: 0.4047, Train Accuracy: 0.8687

'''
# Out:
# '\nTest Loss: 0.4364, Test Accuracy: 0.8521\n\nTrain Loss: 0.4047, Train Accuracy: 0.8687\n\n'

# %%
import json
import os

# Define the save directory


# Convert numpy arrays to lists for serialization
data_to_save = {
    "group_train_loss_mean": {k: v.tolist() for k, v in group_train_loss_mean.items()},
    "group_train_loss_std": {k: v.tolist() for k, v in group_train_loss_std.items()},
    "group_val_loss_mean": {k: v.tolist() for k, v in group_val_loss_mean.items()},
    "group_val_loss_std": {k: v.tolist() for k, v in group_val_loss_std.items()},
    "group_train_acc_mean": {k: v.tolist() for k, v in group_train_acc_mean.items()},
    "group_train_acc_std": {k: v.tolist() for k, v in group_train_acc_std.items()},
    "group_val_acc_mean": {k: v.tolist() for k, v in group_val_acc_mean.items()},
    "group_val_acc_std": {k: v.tolist() for k, v in group_val_acc_std.items()}
}

with open("No_Comm_Metrics_20.json", "w") as f:
    json.dump(data_to_save, f)
print("No_Comm_Metrics_20.json")
# Out:
# No_Comm_Metrics_20.json
