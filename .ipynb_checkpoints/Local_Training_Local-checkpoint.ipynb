# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader
import pandas as pd
from sklearn.preprocessing import MinMaxScaler
import matplotlib.pyplot as plt
import numpy as np
import random
import os
import seaborn as sns


# Set random seed for reproducibility
seed = 42  # You can choose any integer here

# Set seed for NumPy
np.random.seed(seed)

# Set seed for Python's random module
random.seed(seed)

# Set seed for PyTorch
torch.manual_seed(seed)

# For GPU (if using CUDA)
if torch.cuda.is_available():
    torch.cuda.manual_seed(seed)
    torch.cuda.manual_seed_all(seed)  # For multi-GPU setups

# Set deterministic behavior for reproducibility in case of CUDA operations
torch.backends.cudnn.deterministic = True
torch.backends.cudnn.benchmark = False




dataset_dir = "datasets/no_comm_20/"

# Directory containing the saved CSV files
output_dir = dataset_dir + "training_outputs/"

# Load one of the CSV files for EDA (e.g., user_0_outputs.csv)
csv_file = os.path.join(output_dir, "user_1_outputs.csv")
df = pd.read_csv(csv_file)

# Quick overview of the data
print("Data Overview:")
print(df.head())
print("\nData Summary:")
print(df.describe())

# Check for missing values
print("\nMissing Values:")
print(df.isnull().sum())

# Distribution of the target variable (y)
sns.countplot(x="y", data=df)
plt.title("Target Variable Distribution")
plt.show()

# Correlation heatmap of features
correlation_matrix = df.iloc[:, :-1].corr()  # Exclude the target column
plt.figure(figsize=(12, 10))
sns.heatmap(correlation_matrix, cmap="coolwarm", center=0)
plt.title("Feature Correlation Heatmap")
plt.show()
# Out:
# Data Overview:
#    Feature_1  Feature_2  Feature_3  Feature_4  Feature_5  Feature_6  \
# 0        0.0        0.0   0.885327   0.716273   0.456092   0.808141
# 1        0.0        0.0   1.785427   1.364032   0.766123   1.917062
# 2        0.0        0.0   1.854444   1.335653   0.804599   2.030004
# 3        0.0        0.0   0.690323   0.617714   0.411132   0.561880
# 4        0.0        0.0   0.961497   0.595238   0.439818   0.997373
#
#    Feature_7  Feature_8  Feature_9  Feature_10  ...  Feature_248  Feature_249  \
# 0   0.389748   0.107943        0.0         0.0  ...     0.270664     0.024842
# 1   1.039945   0.000000        0.0         0.0  ...     0.252708    -0.149095
# 2   1.103763   0.000000        0.0         0.0  ...    -0.227108    -0.424185
# 3   0.223934   0.152276        0.0         0.0  ...    -7.156454     3.660750
# 4   0.519294   0.035166        0.0         0.0  ...    -0.100431    -0.294257
#
#    Feature_250  Feature_251  Feature_252  Feature_253  Feature_254  \
# 0    -1.076952    -0.529986    -0.903930    -0.572074    -0.792456
# 1    -0.735969    -0.623401    -0.578592    -0.609828     0.548424
# 2     0.238877     0.113626    -0.831830    -0.964168     2.557450
# 3     1.325553     0.337411    -7.220688    -4.296207     1.817713
# 4    -0.648166     0.106401    -0.459414    -0.259358     0.095467
#
#    Feature_255  Feature_256     y
# 0    -1.318562    -0.319528   7.0
# 1    -1.845531    -0.191677  16.0
# 2    -1.824514    -0.132469  17.0
# 3     0.676589     0.228467   2.0
# 4    -0.467735     0.232591  25.0
#
# [5 rows x 257 columns]
#
# Data Summary:
#        Feature_1  Feature_2   Feature_3   Feature_4   Feature_5   Feature_6  \
# count      342.0      342.0  342.000000  342.000000  342.000000  342.000000
# mean         0.0        0.0    1.200481    0.862600    0.545849    1.239629
# std          0.0        0.0    0.359492    0.299161    0.133938    0.428101
# min          0.0        0.0    0.683959    0.528406    0.403624    0.554753
# 25%          0.0        0.0    0.916019    0.614972    0.435497    0.914815
# 50%          0.0        0.0    1.108625    0.743994    0.493887    1.152244
# 75%          0.0        0.0    1.452524    1.035317    0.628424    1.558081
# max          0.0        0.0    2.056166    1.630042    0.912757    2.250869
#
#         Feature_7   Feature_8  Feature_9  Feature_10  ...  Feature_248  \
# count  342.000000  342.000000      342.0       342.0  ...   342.000000
# mean     0.651521    0.042390        0.0         0.0  ...    -0.284878
# std      0.250786    0.040270        0.0         0.0  ...     1.159527
# min      0.219668    0.000000        0.0         0.0  ...    -7.692655
# 25%      0.465265    0.005978        0.0         0.0  ...    -0.207463
# 50%      0.608093    0.035368        0.0         0.0  ...    -0.056301
# 75%      0.851370    0.058360        0.0         0.0  ...     0.131624
# max      1.233328    0.165615        0.0         0.0  ...     0.460914
#
#        Feature_249  Feature_250  Feature_251  Feature_252  Feature_253  \
# count   342.000000   342.000000   342.000000   342.000000   342.000000
# mean     -0.119893    -0.547717    -0.349805    -1.069940    -0.575147
# std       0.736965     0.627800     0.422362     1.071915     0.729843
# min      -1.015384    -1.790827    -1.564828    -7.733817    -4.559763
# 25%      -0.530908    -0.884130    -0.662081    -1.209548    -0.805891
# 50%      -0.298828    -0.648640    -0.323016    -0.734045    -0.575628
# 75%       0.068275    -0.291087     0.044148    -0.556532    -0.147690
# max       3.893389     2.272325     0.353145    -0.378435     0.610353
#
#        Feature_254  Feature_255  Feature_256           y
# count   342.000000   342.000000   342.000000  342.000000
# mean      0.495424    -1.196757     0.074331   14.976608
# std       0.865629     0.683933     0.561619    4.877326
# min      -1.381253    -3.058295    -1.540733    2.000000
# 25%       0.028295    -1.569769    -0.141128   14.000000
# 50%       0.377699    -1.171670     0.037165   16.000000
# 75%       0.928428    -0.695738     0.513825   17.000000
# max       3.560346     0.913419     1.189559   30.000000
#
# [8 rows x 257 columns]
#
# Missing Values:
# Feature_1      0
# Feature_2      0
# Feature_3      0
# Feature_4      0
# Feature_5      0
#               ..
# Feature_253    0
# Feature_254    0
# Feature_255    0
# Feature_256    0
# y              0
# Length: 257, dtype: int64

# %%
no_users = 20
# Define the Multinomial Logistic Regression model
class MultinomialLogisticRegression(nn.Module):
    def __init__(self, input_size, num_classes):
        super(MultinomialLogisticRegression, self).__init__()
        self.linear = nn.Linear(input_size, num_classes)

    def forward(self, x):
        return self.linear(x)

# Custom dataset to load the data from CSV
class CustomDataset(Dataset):
    def __init__(self,  csv_file, modality=["pos_height", "images"], scaler=None, zero_prob=0.5):
        self.data = pd.read_csv(csv_file)
        if "images" in modality and "pos_height" in modality:
            self.X = self.data.iloc[:, :-1].values  # Features
            mask = np.ones(self.X.shape)  # Initialize mask
            mask[:, 128:-1] = np.random.choice([0, 1], size=self.X[:, 128:-1].shape, p=[zero_prob, 1 - zero_prob])
            self.X *= mask  # Apply mask to zero out features
        elif "images" in modality:
            self.X = self.data.iloc[:, 128:-1].values  # Features
            mask = np.random.choice([0, 1], size=self.X.shape, p=[zero_prob, 1 - zero_prob])  # Create a binary mask
            self.X *= mask  # Apply mask
        else:
            self.X = self.data.iloc[:, 0:128].values  # Features

        self.y = self.data.iloc[:, -1].values   # Labels

        # If a scaler is provided, use it to transform the features
        if scaler:
            self.X = scaler.transform(self.X)
        else:
            # Fit the scaler on the training data and transform
            self.scaler = MinMaxScaler(feature_range=(-1, 1))
            self.X = self.scaler.fit_transform(self.X)

    def __len__(self):
        return len(self.data)

    def __getitem__(self, idx):
        X = torch.tensor(self.X[idx], dtype=torch.float32)
        y = torch.tensor(self.y[idx], dtype=torch.long)  # Use long for classification targets
        return X, y

# %%
# Configuration
no_users = 20  # Example: Number of users
available_modalities = ["pos_height", "images"]
modality_size = {"pos_height": 128, "images": 128}
group_definitions = {
    1: ["pos_height"],        # Group 1: Only pos_height
    2: ["images"],            # Group 2: Only images
    3: ["pos_height", "images"]  # Group 3: Both modalities
}

# Assign each user to a group randomly
weights = [0.2, 0.3, 0.5]  # Probabilities for groups 1, 2, and 3

# Generate user_groups with weighted random choices
user_groups = random.choices([1, 2, 3], weights=weights, k=no_users)

# Assign modalities to users based on their group
user_modalities = [group_definitions[group] for group in user_groups]

# Compute output sizes for each user based on their modalities
output_sizes = [sum(modality_size[modality] for modality in user_modality) for user_modality in user_modalities]

# Store models (placeholders for actual models)
all_models = []

# Example output (for verification)
print(f"User Groups: {user_groups[:10]}")  # Show first 10 users' groups
print(f"User Modalities: {user_modalities[:10]}")  # Show first 10 users' modalities
print(f"Output Sizes: {output_sizes[:10]}")  # Show first 10 users' output sizes
# Out:
# User Groups: [3, 1, 2, 2, 3, 3, 3, 1, 2, 1]
# User Modalities: [['pos_height', 'images'], ['pos_height'], ['images'], ['images'], ['pos_height', 'images'], ['pos_height', 'images'], ['pos_height', 'images'], ['pos_height'], ['images'], ['pos_height']]
# Output Sizes: [256, 128, 128, 128, 256, 256, 256, 128, 128, 128]

# %%
no_users = 20
# List to store DataLoader objects for each user
train_loaders = []
val_loaders = []
test_loaders = []
scaler = None
# Loop over each user
zero_prob=0.1
dataset_dir = "datasets/no_comm_20/"
#dataset_dir = "datasets/FL_20/"
for user_idx in range(no_users):
    scaler = None
    # Define file paths for each user dynamically
    train_file = dataset_dir + f"training_outputs/user_{user_idx}_outputs.csv"
    val_file = dataset_dir + f"val_outputs/user_{user_idx}_outputs.csv"
    test_file = dataset_dir + f"test_outputs/user_{user_idx}_outputs.csv"

    # Load training data and fit the scaler on it (only once for each user)
    train_data = pd.read_csv(train_file)
    
    if scaler is None:
        scaler = MinMaxScaler(feature_range=(-1, 1))
        # Fit the scaler on the first user's training data
        if "images" in user_modalities[user_idx] and "pos_height" in user_modalities[user_idx]:
            temp = train_data.iloc[:, :-1].values  # Features
        elif "images" in user_modalities[user_idx]:
            temp = train_data.iloc[:, 128:-1].values  # Features
        else:
            temp = train_data.iloc[:, 0:128].values  # Features
        scaler.fit(temp)  # Fit scaler only on training features

    # Create datasets using the same scaler for all data
    train_dataset = CustomDataset(train_file, scaler=scaler, modality=user_modalities[user_idx], zero_prob=0.5)
    val_dataset = CustomDataset(val_file, scaler=scaler, modality=user_modalities[user_idx], zero_prob=0.5)
    test_dataset = CustomDataset(test_file, scaler=scaler, modality=user_modalities[user_idx], zero_prob=0.5)

    # Create DataLoader for training, validation, and testing for each user
    batch_size = 64
    train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=False)
    val_loader = DataLoader(val_dataset, batch_size=batch_size, shuffle=False)
    test_loader = DataLoader(test_dataset, batch_size=batch_size, shuffle=False)

    # Append each user's DataLoader to the respective lists
    train_loaders.append(train_loader)
    val_loaders.append(val_loader)
    test_loaders.append(test_loader)

# %%
# Initialize model, loss function, and optimizer for multiple users
input_sizes = output_sizes  # Number of features
num_classes = 64
classifiers = [MultinomialLogisticRegression(input_size, num_classes) for input_size, _ in zip(input_sizes, range(no_users))]
#classifiers = [MultinomialLogisticRegression(input_size, num_classes).cuda() for _ in range(no_users)]
optimizers = [optim.SGD(model.parameters(), lr=0.01) for model in classifiers]
criterion = nn.CrossEntropyLoss()
# Training parameters
num_epochs = 200

# %%
from utils import cross_entropy_loss_with_l2
loss_func = cross_entropy_loss_with_l2

# Group assignments (use the previously defined user_groups)
group_losses = {1: [], 2: [], 3: []}
group_accuracies = {1: [], 2: [], 3: []}

# Initialize dictionaries to track metrics for each group
group_train_loss_histories = {1: [], 2: [], 3: []}
group_train_accuracy_histories = {1: [], 2: [], 3: []}
group_val_loss_histories = {1: [], 2: [], 3: []}
group_val_accuracy_histories = {1: [], 2: [], 3: []}
lambda_reg = 0.01
eta = 0.01
from utils import cross_entropy_loss_with_l2
# Training loop
for epoch in range(num_epochs):
    # Temporary dictionaries for this epoch
    epoch_group_train_losses = {1: [], 2: [], 3: []}
    epoch_group_train_accuracies = {1: [], 2: [], 3: []}
    epoch_group_val_losses = {1: [], 2: [], 3: []}
    epoch_group_val_accuracies = {1: [], 2: [], 3: []}

    for user_id, (model, optimizer) in enumerate(zip(classifiers, optimizers)):
        group = user_groups[user_id]  # Get the group of the user

        # Training phase
        model.train()
        epoch_train_loss = 0.0
        correct_train_predictions = 0
        total_train_samples = 0

        for X_batch, y_batch in train_loaders[user_id]:
            #X_batch, y_batch = X_batch.cuda(), y_batch.cuda()
            outputs = model(X_batch)
            loss = loss_func(model, X_batch, y_batch, l2_strength=0.001)#criterion(outputs, y_batch)

            optimizer.zero_grad()
            loss.backward()
            optimizer.step()

            epoch_train_loss += loss.item()
            _, predicted = torch.max(outputs, dim=1)
            correct_train_predictions += (predicted == y_batch).sum().item()
            total_train_samples += y_batch.size(0)

        avg_train_loss = epoch_train_loss / len(train_loaders[user_id])
        train_accuracy = correct_train_predictions / total_train_samples

        # Validation phase
        model.eval()
        epoch_val_loss = 0.0
        correct_val_predictions = 0
        total_val_samples = 0

        with torch.no_grad():
            for X_batch, y_batch in val_loaders[user_id]:
                #X_batch, y_batch = X_batch.cuda(), y_batch.cuda()
                outputs = model(X_batch)
                loss = loss_func(model, X_batch, y_batch, l2_strength=0.001)#criterion(outputs, y_batch)

                epoch_val_loss += loss.item()
                _, predicted = torch.max(outputs, dim=1)
                correct_val_predictions += (predicted == y_batch).sum().item()
                total_val_samples += y_batch.size(0)

        avg_val_loss = epoch_val_loss / len(val_loaders[user_id])
        val_accuracy = correct_val_predictions / total_val_samples

        # Assign metrics to the respective group
        epoch_group_train_losses[group].append(avg_train_loss)
        epoch_group_train_accuracies[group].append(train_accuracy)
        epoch_group_val_losses[group].append(avg_val_loss)
        epoch_group_val_accuracies[group].append(val_accuracy)

    # Calculate averages for this epoch and store them
    for group in [1, 2, 3]:
        #group_train_loss_histories[group].append(np.mean(epoch_group_train_losses[group]))
        #group_train_accuracy_histories[group].append(np.mean(epoch_group_train_accuracies[group]))
        #group_val_loss_histories[group].append(np.mean(epoch_group_val_losses[group]))
        #group_val_accuracy_histories[group].append(np.mean(epoch_group_val_accuracies[group]))
        group_train_loss_histories[group].append(epoch_group_train_losses[group])
        group_train_accuracy_histories[group].append(epoch_group_train_accuracies[group])
        group_val_loss_histories[group].append(epoch_group_val_losses[group])
        group_val_accuracy_histories[group].append(epoch_group_val_accuracies[group])

    # Print group-wise average metrics
    print(f"Epoch [{epoch+1}/{num_epochs}] Group Metrics:")
    for group in [1, 2, 3]:
        print(f"  Group {group} - Train Loss: {np.mean(epoch_group_train_losses[group]):.4f}, Train Accuracy: {np.mean(epoch_group_train_accuracies[group]):.4f}")
        print(f"  Group {group} - Val Loss: {np.mean(epoch_group_val_losses[group]):.4f}, Val Accuracy: {np.mean(epoch_group_val_accuracies[group]):.4f}")
# Out:
# C:\Users\aghalkha21\AppData\Local\Temp\ipykernel_1916\3432764924.py:42: DeprecationWarning: an integer is required (got type numpy.float64).  Implicit conversion to integers using __int__ is deprecated, and may be removed in a future version of Python.
#   y = torch.tensor(self.y[idx], dtype=torch.long)  # Use long for classification targets
# Epoch [1/200] Group Metrics:
#   Group 1 - Train Loss: 4.1499, Train Accuracy: 0.0371
#   Group 1 - Val Loss: 3.9225, Val Accuracy: 0.1218
#   Group 2 - Train Loss: 4.1120, Train Accuracy: 0.0100
#   Group 2 - Val Loss: 3.8951, Val Accuracy: 0.0901
#   Group 3 - Train Loss: 4.0308, Train Accuracy: 0.0686
#   Group 3 - Val Loss: 3.7438, Val Accuracy: 0.2281
# Epoch [2/200] Group Metrics:
#   Group 1 - Train Loss: 3.8108, Train Accuracy: 0.1656
#   Group 1 - Val Loss: 3.6281, Val Accuracy: 0.2066
#   Group 2 - Train Loss: 3.7508, Train Accuracy: 0.1910
#   Group 2 - Val Loss: 3.5970, Val Accuracy: 0.2526
#   Group 3 - Train Loss: 3.5533, Train Accuracy: 0.2447
#   Group 3 - Val Loss: 3.3843, Val Accuracy: 0.2541
# Epoch [3/200] Group Metrics:
#   Group 1 - Train Loss: 3.5370, Train Accuracy: 0.2257
#   Group 1 - Val Loss: 3.4043, Val Accuracy: 0.2368
#   Group 2 - Train Loss: 3.4844, Train Accuracy: 0.2513
#   Group 2 - Val Loss: 3.3995, Val Accuracy: 0.2608
#   Group 3 - Train Loss: 3.2454, Train Accuracy: 0.2476
#   Group 3 - Val Loss: 3.1722, Val Accuracy: 0.2515
# Epoch [4/200] Group Metrics:
#   Group 1 - Train Loss: 3.3330, Train Accuracy: 0.2315
#   Group 1 - Val Loss: 3.2457, Val Accuracy: 0.2300
#   Group 2 - Train Loss: 3.3085, Train Accuracy: 0.2560
#   Group 2 - Val Loss: 3.2713, Val Accuracy: 0.2608
#   Group 3 - Train Loss: 3.0566, Train Accuracy: 0.2473
#   Group 3 - Val Loss: 3.0409, Val Accuracy: 0.2528
# Epoch [5/200] Group Metrics:
#   Group 1 - Train Loss: 3.1879, Train Accuracy: 0.2369
#   Group 1 - Val Loss: 3.1345, Val Accuracy: 0.2466
#   Group 2 - Train Loss: 3.1880, Train Accuracy: 0.2577
#   Group 2 - Val Loss: 3.1801, Val Accuracy: 0.2608
#   Group 3 - Train Loss: 2.9299, Train Accuracy: 0.2506
#   Group 3 - Val Loss: 2.9502, Val Accuracy: 0.2586
# Epoch [6/200] Group Metrics:
#   Group 1 - Train Loss: 3.0835, Train Accuracy: 0.2394
#   Group 1 - Val Loss: 3.0531, Val Accuracy: 0.2505
#   Group 2 - Train Loss: 3.0984, Train Accuracy: 0.2577
#   Group 2 - Val Loss: 3.1101, Val Accuracy: 0.2608
#   Group 3 - Train Loss: 2.8360, Train Accuracy: 0.2613
#   Group 3 - Val Loss: 2.8818, Val Accuracy: 0.2671
# Epoch [7/200] Group Metrics:
#   Group 1 - Train Loss: 3.0047, Train Accuracy: 0.2418
#   Group 1 - Val Loss: 2.9898, Val Accuracy: 0.2437
#   Group 2 - Train Loss: 3.0283, Train Accuracy: 0.2572
#   Group 2 - Val Loss: 3.0542, Val Accuracy: 0.2608
#   Group 3 - Train Loss: 2.7618, Train Accuracy: 0.2730
#   Group 3 - Val Loss: 2.8271, Val Accuracy: 0.2742
# Epoch [8/200] Group Metrics:
#   Group 1 - Train Loss: 2.9420, Train Accuracy: 0.2443
#   Group 1 - Val Loss: 2.9381, Val Accuracy: 0.2427
#   Group 2 - Train Loss: 2.9716, Train Accuracy: 0.2572
#   Group 2 - Val Loss: 3.0084, Val Accuracy: 0.2620
#   Group 3 - Train Loss: 2.7006, Train Accuracy: 0.2831
#   Group 3 - Val Loss: 2.7814, Val Accuracy: 0.2827
# Epoch [9/200] Group Metrics:
#   Group 1 - Train Loss: 2.8902, Train Accuracy: 0.2477
#   Group 1 - Val Loss: 2.8945, Val Accuracy: 0.2417
#   Group 2 - Train Loss: 2.9246, Train Accuracy: 0.2578
#   Group 2 - Val Loss: 2.9702, Val Accuracy: 0.2632
#   Group 3 - Train Loss: 2.6486, Train Accuracy: 0.2909
#   Group 3 - Val Loss: 2.7422, Val Accuracy: 0.2898
# Epoch [10/200] Group Metrics:
#   Group 1 - Train Loss: 2.8462, Train Accuracy: 0.2472
#   Group 1 - Val Loss: 2.8571, Val Accuracy: 0.2368
#   Group 2 - Train Loss: 2.8849, Train Accuracy: 0.2578
#   Group 2 - Val Loss: 2.9379, Val Accuracy: 0.2643
#   Group 3 - Train Loss: 2.6035, Train Accuracy: 0.2981
#   Group 3 - Val Loss: 2.7077, Val Accuracy: 0.2950
# Epoch [11/200] Group Metrics:
#   Group 1 - Train Loss: 2.8083, Train Accuracy: 0.2486
#   Group 1 - Val Loss: 2.8247, Val Accuracy: 0.2310
#   Group 2 - Train Loss: 2.8507, Train Accuracy: 0.2578
#   Group 2 - Val Loss: 2.9100, Val Accuracy: 0.2643
#   Group 3 - Train Loss: 2.5635, Train Accuracy: 0.3079
#   Group 3 - Val Loss: 2.6770, Val Accuracy: 0.2995
# Epoch [12/200] Group Metrics:
#   Group 1 - Train Loss: 2.7753, Train Accuracy: 0.2540
#   Group 1 - Val Loss: 2.7962, Val Accuracy: 0.2329
#   Group 2 - Train Loss: 2.8207, Train Accuracy: 0.2583
#   Group 2 - Val Loss: 2.8857, Val Accuracy: 0.2632
#   Group 3 - Train Loss: 2.5276, Train Accuracy: 0.3163
#   Group 3 - Val Loss: 2.6492, Val Accuracy: 0.3073
# Epoch [13/200] Group Metrics:
#   Group 1 - Train Loss: 2.7461, Train Accuracy: 0.2570
#   Group 1 - Val Loss: 2.7712, Val Accuracy: 0.2359
#   Group 2 - Train Loss: 2.7940, Train Accuracy: 0.2601
#   Group 2 - Val Loss: 2.8641, Val Accuracy: 0.2643
#   Group 3 - Train Loss: 2.4951, Train Accuracy: 0.3271
#   Group 3 - Val Loss: 2.6237, Val Accuracy: 0.3132
# Epoch [14/200] Group Metrics:
#   Group 1 - Train Loss: 2.7203, Train Accuracy: 0.2565
#   Group 1 - Val Loss: 2.7489, Val Accuracy: 0.2388
#   Group 2 - Train Loss: 2.7700, Train Accuracy: 0.2613
#   Group 2 - Val Loss: 2.8448, Val Accuracy: 0.2655
#   Group 3 - Train Loss: 2.4652, Train Accuracy: 0.3333
#   Group 3 - Val Loss: 2.6003, Val Accuracy: 0.3190
# Epoch [15/200] Group Metrics:
#   Group 1 - Train Loss: 2.6971, Train Accuracy: 0.2579
#   Group 1 - Val Loss: 2.7289, Val Accuracy: 0.2427
#   Group 2 - Train Loss: 2.7481, Train Accuracy: 0.2630
#   Group 2 - Val Loss: 2.8274, Val Accuracy: 0.2667
#   Group 3 - Train Loss: 2.4375, Train Accuracy: 0.3407
#   Group 3 - Val Loss: 2.5785, Val Accuracy: 0.3242
# Epoch [16/200] Group Metrics:
#   Group 1 - Train Loss: 2.6763, Train Accuracy: 0.2579
#   Group 1 - Val Loss: 2.7110, Val Accuracy: 0.2417
#   Group 2 - Train Loss: 2.7280, Train Accuracy: 0.2665
#   Group 2 - Val Loss: 2.8114, Val Accuracy: 0.2690
#   Group 3 - Train Loss: 2.4118, Train Accuracy: 0.3479
#   Group 3 - Val Loss: 2.5582, Val Accuracy: 0.3275
# Epoch [17/200] Group Metrics:
#   Group 1 - Train Loss: 2.6574, Train Accuracy: 0.2584
#   Group 1 - Val Loss: 2.6947, Val Accuracy: 0.2427
#   Group 2 - Train Loss: 2.7094, Train Accuracy: 0.2695
#   Group 2 - Val Loss: 2.7968, Val Accuracy: 0.2713
#   Group 3 - Train Loss: 2.3877, Train Accuracy: 0.3560
#   Group 3 - Val Loss: 2.5391, Val Accuracy: 0.3301
# Epoch [18/200] Group Metrics:
#   Group 1 - Train Loss: 2.6402, Train Accuracy: 0.2589
#   Group 1 - Val Loss: 2.6800, Val Accuracy: 0.2437
#   Group 2 - Train Loss: 2.6920, Train Accuracy: 0.2712
#   Group 2 - Val Loss: 2.7832, Val Accuracy: 0.2772
#   Group 3 - Train Loss: 2.3650, Train Accuracy: 0.3622
#   Group 3 - Val Loss: 2.5211, Val Accuracy: 0.3340
# Epoch [19/200] Group Metrics:
#   Group 1 - Train Loss: 2.6244, Train Accuracy: 0.2589
#   Group 1 - Val Loss: 2.6664, Val Accuracy: 0.2476
#   Group 2 - Train Loss: 2.6758, Train Accuracy: 0.2736
#   Group 2 - Val Loss: 2.7706, Val Accuracy: 0.2795
#   Group 3 - Train Loss: 2.3435, Train Accuracy: 0.3674
#   Group 3 - Val Loss: 2.5040, Val Accuracy: 0.3392
# Epoch [20/200] Group Metrics:
#   Group 1 - Train Loss: 2.6099, Train Accuracy: 0.2599
#   Group 1 - Val Loss: 2.6539, Val Accuracy: 0.2466
#   Group 2 - Train Loss: 2.6605, Train Accuracy: 0.2771
#   Group 2 - Val Loss: 2.7588, Val Accuracy: 0.2854
#   Group 3 - Train Loss: 2.3232, Train Accuracy: 0.3726
#   Group 3 - Val Loss: 2.4878, Val Accuracy: 0.3450
# Epoch [21/200] Group Metrics:
#   Group 1 - Train Loss: 2.5964, Train Accuracy: 0.2609
#   Group 1 - Val Loss: 2.6424, Val Accuracy: 0.2476
#   Group 2 - Train Loss: 2.6461, Train Accuracy: 0.2800
#   Group 2 - Val Loss: 2.7476, Val Accuracy: 0.2889
#   Group 3 - Train Loss: 2.3038, Train Accuracy: 0.3801
#   Group 3 - Val Loss: 2.4724, Val Accuracy: 0.3509
# Epoch [22/200] Group Metrics:
#   Group 1 - Train Loss: 2.5839, Train Accuracy: 0.2628
#   Group 1 - Val Loss: 2.6317, Val Accuracy: 0.2476
#   Group 2 - Train Loss: 2.6324, Train Accuracy: 0.2841
#   Group 2 - Val Loss: 2.7371, Val Accuracy: 0.2924
#   Group 3 - Train Loss: 2.2852, Train Accuracy: 0.3879
#   Group 3 - Val Loss: 2.4576, Val Accuracy: 0.3535
# Epoch [23/200] Group Metrics:
#   Group 1 - Train Loss: 2.5722, Train Accuracy: 0.2653
#   Group 1 - Val Loss: 2.6217, Val Accuracy: 0.2485
#   Group 2 - Train Loss: 2.6193, Train Accuracy: 0.2877
#   Group 2 - Val Loss: 2.7272, Val Accuracy: 0.2936
#   Group 3 - Train Loss: 2.2675, Train Accuracy: 0.3925
#   Group 3 - Val Loss: 2.4435, Val Accuracy: 0.3561
# Epoch [24/200] Group Metrics:
#   Group 1 - Train Loss: 2.5612, Train Accuracy: 0.2677
#   Group 1 - Val Loss: 2.6124, Val Accuracy: 0.2485
#   Group 2 - Train Loss: 2.6068, Train Accuracy: 0.2906
#   Group 2 - Val Loss: 2.7177, Val Accuracy: 0.2936
#   Group 3 - Train Loss: 2.2505, Train Accuracy: 0.3961
#   Group 3 - Val Loss: 2.4299, Val Accuracy: 0.3619
# Epoch [25/200] Group Metrics:
#   Group 1 - Train Loss: 2.5509, Train Accuracy: 0.2687
#   Group 1 - Val Loss: 2.6036, Val Accuracy: 0.2495
#   Group 2 - Train Loss: 2.5949, Train Accuracy: 0.2929
#   Group 2 - Val Loss: 2.7087, Val Accuracy: 0.2959
#   Group 3 - Train Loss: 2.2341, Train Accuracy: 0.4019
#   Group 3 - Val Loss: 2.4168, Val Accuracy: 0.3632
# Epoch [26/200] Group Metrics:
#   Group 1 - Train Loss: 2.5411, Train Accuracy: 0.2697
#   Group 1 - Val Loss: 2.5953, Val Accuracy: 0.2495
#   Group 2 - Train Loss: 2.5834, Train Accuracy: 0.2965
#   Group 2 - Val Loss: 2.7000, Val Accuracy: 0.3006
#   Group 3 - Train Loss: 2.2183, Train Accuracy: 0.4084
#   Group 3 - Val Loss: 2.4042, Val Accuracy: 0.3658
# Epoch [27/200] Group Metrics:
#   Group 1 - Train Loss: 2.5319, Train Accuracy: 0.2697
#   Group 1 - Val Loss: 2.5875, Val Accuracy: 0.2534
#   Group 2 - Train Loss: 2.5723, Train Accuracy: 0.2982
#   Group 2 - Val Loss: 2.6917, Val Accuracy: 0.3006
#   Group 3 - Train Loss: 2.2031, Train Accuracy: 0.4143
#   Group 3 - Val Loss: 2.3921, Val Accuracy: 0.3691
# Epoch [28/200] Group Metrics:
#   Group 1 - Train Loss: 2.5232, Train Accuracy: 0.2721
#   Group 1 - Val Loss: 2.5801, Val Accuracy: 0.2563
#   Group 2 - Train Loss: 2.5617, Train Accuracy: 0.3017
#   Group 2 - Val Loss: 2.6838, Val Accuracy: 0.3006
#   Group 3 - Train Loss: 2.1884, Train Accuracy: 0.4182
#   Group 3 - Val Loss: 2.3804, Val Accuracy: 0.3749
# Epoch [29/200] Group Metrics:
#   Group 1 - Train Loss: 2.5149, Train Accuracy: 0.2731
#   Group 1 - Val Loss: 2.5731, Val Accuracy: 0.2573
#   Group 2 - Train Loss: 2.5514, Train Accuracy: 0.3035
#   Group 2 - Val Loss: 2.6761, Val Accuracy: 0.3029
#   Group 3 - Train Loss: 2.1742, Train Accuracy: 0.4231
#   Group 3 - Val Loss: 2.3690, Val Accuracy: 0.3769
# Epoch [30/200] Group Metrics:
#   Group 1 - Train Loss: 2.5069, Train Accuracy: 0.2755
#   Group 1 - Val Loss: 2.5664, Val Accuracy: 0.2554
#   Group 2 - Train Loss: 2.5414, Train Accuracy: 0.3064
#   Group 2 - Val Loss: 2.6687, Val Accuracy: 0.3018
#   Group 3 - Train Loss: 2.1604, Train Accuracy: 0.4263
#   Group 3 - Val Loss: 2.3580, Val Accuracy: 0.3814
# Epoch [31/200] Group Metrics:
#   Group 1 - Train Loss: 2.4994, Train Accuracy: 0.2785
#   Group 1 - Val Loss: 2.5600, Val Accuracy: 0.2573
#   Group 2 - Train Loss: 2.5318, Train Accuracy: 0.3088
#   Group 2 - Val Loss: 2.6615, Val Accuracy: 0.3064
#   Group 3 - Train Loss: 2.1470, Train Accuracy: 0.4332
#   Group 3 - Val Loss: 2.3474, Val Accuracy: 0.3860
# Epoch [32/200] Group Metrics:
#   Group 1 - Train Loss: 2.4921, Train Accuracy: 0.2819
#   Group 1 - Val Loss: 2.5539, Val Accuracy: 0.2612
#   Group 2 - Train Loss: 2.5224, Train Accuracy: 0.3117
#   Group 2 - Val Loss: 2.6546, Val Accuracy: 0.3064
#   Group 3 - Train Loss: 2.1340, Train Accuracy: 0.4368
#   Group 3 - Val Loss: 2.3370, Val Accuracy: 0.3899
# Epoch [33/200] Group Metrics:
#   Group 1 - Train Loss: 2.4852, Train Accuracy: 0.2838
#   Group 1 - Val Loss: 2.5481, Val Accuracy: 0.2632
#   Group 2 - Train Loss: 2.5133, Train Accuracy: 0.3146
#   Group 2 - Val Loss: 2.6479, Val Accuracy: 0.3111
#   Group 3 - Train Loss: 2.1214, Train Accuracy: 0.4410
#   Group 3 - Val Loss: 2.3270, Val Accuracy: 0.3925
# Epoch [34/200] Group Metrics:
#   Group 1 - Train Loss: 2.4785, Train Accuracy: 0.2843
#   Group 1 - Val Loss: 2.5425, Val Accuracy: 0.2632
#   Group 2 - Train Loss: 2.5045, Train Accuracy: 0.3152
#   Group 2 - Val Loss: 2.6414, Val Accuracy: 0.3111
#   Group 3 - Train Loss: 2.1091, Train Accuracy: 0.4429
#   Group 3 - Val Loss: 2.3172, Val Accuracy: 0.3964
# Epoch [35/200] Group Metrics:
#   Group 1 - Train Loss: 2.4721, Train Accuracy: 0.2843
#   Group 1 - Val Loss: 2.5371, Val Accuracy: 0.2622
#   Group 2 - Train Loss: 2.4958, Train Accuracy: 0.3181
#   Group 2 - Val Loss: 2.6351, Val Accuracy: 0.3135
#   Group 3 - Train Loss: 2.0972, Train Accuracy: 0.4455
#   Group 3 - Val Loss: 2.3077, Val Accuracy: 0.4009
# Epoch [36/200] Group Metrics:
#   Group 1 - Train Loss: 2.4660, Train Accuracy: 0.2863
#   Group 1 - Val Loss: 2.5319, Val Accuracy: 0.2632
#   Group 2 - Train Loss: 2.4874, Train Accuracy: 0.3199
#   Group 2 - Val Loss: 2.6289, Val Accuracy: 0.3135
#   Group 3 - Train Loss: 2.0856, Train Accuracy: 0.4508
#   Group 3 - Val Loss: 2.2984, Val Accuracy: 0.4055
# Epoch [37/200] Group Metrics:
#   Group 1 - Train Loss: 2.4600, Train Accuracy: 0.2887
#   Group 1 - Val Loss: 2.5269, Val Accuracy: 0.2641
#   Group 2 - Train Loss: 2.4792, Train Accuracy: 0.3211
#   Group 2 - Val Loss: 2.6229, Val Accuracy: 0.3135
#   Group 3 - Train Loss: 2.0742, Train Accuracy: 0.4547
#   Group 3 - Val Loss: 2.2894, Val Accuracy: 0.4113
# Epoch [38/200] Group Metrics:
#   Group 1 - Train Loss: 2.4543, Train Accuracy: 0.2902
#   Group 1 - Val Loss: 2.5221, Val Accuracy: 0.2661
#   Group 2 - Train Loss: 2.4712, Train Accuracy: 0.3217
#   Group 2 - Val Loss: 2.6171, Val Accuracy: 0.3146
#   Group 3 - Train Loss: 2.0631, Train Accuracy: 0.4595
#   Group 3 - Val Loss: 2.2806, Val Accuracy: 0.4120
# Epoch [39/200] Group Metrics:
#   Group 1 - Train Loss: 2.4488, Train Accuracy: 0.2907
#   Group 1 - Val Loss: 2.5175, Val Accuracy: 0.2661
#   Group 2 - Train Loss: 2.4634, Train Accuracy: 0.3240
#   Group 2 - Val Loss: 2.6114, Val Accuracy: 0.3158
#   Group 3 - Train Loss: 2.0523, Train Accuracy: 0.4641
#   Group 3 - Val Loss: 2.2720, Val Accuracy: 0.4139
# Epoch [40/200] Group Metrics:
#   Group 1 - Train Loss: 2.4434, Train Accuracy: 0.2902
#   Group 1 - Val Loss: 2.5130, Val Accuracy: 0.2661
#   Group 2 - Train Loss: 2.4558, Train Accuracy: 0.3258
#   Group 2 - Val Loss: 2.6058, Val Accuracy: 0.3181
#   Group 3 - Train Loss: 2.0417, Train Accuracy: 0.4687
#   Group 3 - Val Loss: 2.2636, Val Accuracy: 0.4172
# Epoch [41/200] Group Metrics:
#   Group 1 - Train Loss: 2.4382, Train Accuracy: 0.2912
#   Group 1 - Val Loss: 2.5086, Val Accuracy: 0.2671
#   Group 2 - Train Loss: 2.4483, Train Accuracy: 0.3287
#   Group 2 - Val Loss: 2.6004, Val Accuracy: 0.3216
#   Group 3 - Train Loss: 2.0314, Train Accuracy: 0.4709
#   Group 3 - Val Loss: 2.2554, Val Accuracy: 0.4198
# Epoch [42/200] Group Metrics:
#   Group 1 - Train Loss: 2.4332, Train Accuracy: 0.2936
#   Group 1 - Val Loss: 2.5044, Val Accuracy: 0.2690
#   Group 2 - Train Loss: 2.4410, Train Accuracy: 0.3340
#   Group 2 - Val Loss: 2.5951, Val Accuracy: 0.3228
#   Group 3 - Train Loss: 2.0213, Train Accuracy: 0.4755
#   Group 3 - Val Loss: 2.2474, Val Accuracy: 0.4237
# Epoch [43/200] Group Metrics:
#   Group 1 - Train Loss: 2.4283, Train Accuracy: 0.2960
#   Group 1 - Val Loss: 2.5003, Val Accuracy: 0.2710
#   Group 2 - Train Loss: 2.4338, Train Accuracy: 0.3351
#   Group 2 - Val Loss: 2.5899, Val Accuracy: 0.3216
#   Group 3 - Train Loss: 2.0114, Train Accuracy: 0.4774
#   Group 3 - Val Loss: 2.2396, Val Accuracy: 0.4256
# Epoch [44/200] Group Metrics:
#   Group 1 - Train Loss: 2.4236, Train Accuracy: 0.2965
#   Group 1 - Val Loss: 2.4964, Val Accuracy: 0.2739
#   Group 2 - Train Loss: 2.4268, Train Accuracy: 0.3369
#   Group 2 - Val Loss: 2.5848, Val Accuracy: 0.3216
#   Group 3 - Train Loss: 2.0018, Train Accuracy: 0.4804
#   Group 3 - Val Loss: 2.2319, Val Accuracy: 0.4321
# Epoch [45/200] Group Metrics:
#   Group 1 - Train Loss: 2.4190, Train Accuracy: 0.2985
#   Group 1 - Val Loss: 2.4925, Val Accuracy: 0.2749
#   Group 2 - Train Loss: 2.4199, Train Accuracy: 0.3398
#   Group 2 - Val Loss: 2.5798, Val Accuracy: 0.3251
#   Group 3 - Train Loss: 1.9923, Train Accuracy: 0.4836
#   Group 3 - Val Loss: 2.2244, Val Accuracy: 0.4334
# Epoch [46/200] Group Metrics:
#   Group 1 - Train Loss: 2.4145, Train Accuracy: 0.3004
#   Group 1 - Val Loss: 2.4888, Val Accuracy: 0.2768
#   Group 2 - Train Loss: 2.4132, Train Accuracy: 0.3410
#   Group 2 - Val Loss: 2.5750, Val Accuracy: 0.3251
#   Group 3 - Train Loss: 1.9830, Train Accuracy: 0.4872
#   Group 3 - Val Loss: 2.2170, Val Accuracy: 0.4347
# Epoch [47/200] Group Metrics:
#   Group 1 - Train Loss: 2.4101, Train Accuracy: 0.3004
#   Group 1 - Val Loss: 2.4851, Val Accuracy: 0.2807
#   Group 2 - Train Loss: 2.4065, Train Accuracy: 0.3439
#   Group 2 - Val Loss: 2.5702, Val Accuracy: 0.3251
#   Group 3 - Train Loss: 1.9739, Train Accuracy: 0.4908
#   Group 3 - Val Loss: 2.2098, Val Accuracy: 0.4386
# Epoch [48/200] Group Metrics:
#   Group 1 - Train Loss: 2.4059, Train Accuracy: 0.3004
#   Group 1 - Val Loss: 2.4816, Val Accuracy: 0.2827
#   Group 2 - Train Loss: 2.4000, Train Accuracy: 0.3463
#   Group 2 - Val Loss: 2.5655, Val Accuracy: 0.3251
#   Group 3 - Train Loss: 1.9650, Train Accuracy: 0.4940
#   Group 3 - Val Loss: 2.2028, Val Accuracy: 0.4405
# Epoch [49/200] Group Metrics:
#   Group 1 - Train Loss: 2.4017, Train Accuracy: 0.2999
#   Group 1 - Val Loss: 2.4781, Val Accuracy: 0.2836
#   Group 2 - Train Loss: 2.3936, Train Accuracy: 0.3486
#   Group 2 - Val Loss: 2.5609, Val Accuracy: 0.3251
#   Group 3 - Train Loss: 1.9562, Train Accuracy: 0.4973
#   Group 3 - Val Loss: 2.1959, Val Accuracy: 0.4412
# Epoch [50/200] Group Metrics:
#   Group 1 - Train Loss: 2.3977, Train Accuracy: 0.3004
#   Group 1 - Val Loss: 2.4747, Val Accuracy: 0.2846
#   Group 2 - Train Loss: 2.3873, Train Accuracy: 0.3504
#   Group 2 - Val Loss: 2.5564, Val Accuracy: 0.3287
#   Group 3 - Train Loss: 1.9476, Train Accuracy: 0.4999
#   Group 3 - Val Loss: 2.1891, Val Accuracy: 0.4438
# Epoch [51/200] Group Metrics:
#   Group 1 - Train Loss: 2.3938, Train Accuracy: 0.3014
#   Group 1 - Val Loss: 2.4714, Val Accuracy: 0.2865
#   Group 2 - Train Loss: 2.3812, Train Accuracy: 0.3510
#   Group 2 - Val Loss: 2.5519, Val Accuracy: 0.3298
#   Group 3 - Train Loss: 1.9392, Train Accuracy: 0.5038
#   Group 3 - Val Loss: 2.1824, Val Accuracy: 0.4451
# Epoch [52/200] Group Metrics:
#   Group 1 - Train Loss: 2.3899, Train Accuracy: 0.3014
#   Group 1 - Val Loss: 2.4682, Val Accuracy: 0.2865
#   Group 2 - Train Loss: 2.3751, Train Accuracy: 0.3522
#   Group 2 - Val Loss: 2.5476, Val Accuracy: 0.3310
#   Group 3 - Train Loss: 1.9309, Train Accuracy: 0.5054
#   Group 3 - Val Loss: 2.1759, Val Accuracy: 0.4470
# Epoch [53/200] Group Metrics:
#   Group 1 - Train Loss: 2.3862, Train Accuracy: 0.3034
#   Group 1 - Val Loss: 2.4651, Val Accuracy: 0.2856
#   Group 2 - Train Loss: 2.3691, Train Accuracy: 0.3551
#   Group 2 - Val Loss: 2.5433, Val Accuracy: 0.3322
#   Group 3 - Train Loss: 1.9228, Train Accuracy: 0.5084
#   Group 3 - Val Loss: 2.1695, Val Accuracy: 0.4483
# Epoch [54/200] Group Metrics:
#   Group 1 - Train Loss: 2.3825, Train Accuracy: 0.3034
#   Group 1 - Val Loss: 2.4620, Val Accuracy: 0.2865
#   Group 2 - Train Loss: 2.3632, Train Accuracy: 0.3568
#   Group 2 - Val Loss: 2.5391, Val Accuracy: 0.3345
#   Group 3 - Train Loss: 1.9148, Train Accuracy: 0.5123
#   Group 3 - Val Loss: 2.1632, Val Accuracy: 0.4509
# Epoch [55/200] Group Metrics:
#   Group 1 - Train Loss: 2.3789, Train Accuracy: 0.3034
#   Group 1 - Val Loss: 2.4590, Val Accuracy: 0.2885
#   Group 2 - Train Loss: 2.3574, Train Accuracy: 0.3580
#   Group 2 - Val Loss: 2.5350, Val Accuracy: 0.3345
#   Group 3 - Train Loss: 1.9069, Train Accuracy: 0.5152
#   Group 3 - Val Loss: 2.1570, Val Accuracy: 0.4535
# Epoch [56/200] Group Metrics:
#   Group 1 - Train Loss: 2.3754, Train Accuracy: 0.3034
#   Group 1 - Val Loss: 2.4561, Val Accuracy: 0.2885
#   Group 2 - Train Loss: 2.3517, Train Accuracy: 0.3586
#   Group 2 - Val Loss: 2.5309, Val Accuracy: 0.3333
#   Group 3 - Train Loss: 1.8992, Train Accuracy: 0.5181
#   Group 3 - Val Loss: 2.1510, Val Accuracy: 0.4561
# Epoch [57/200] Group Metrics:
#   Group 1 - Train Loss: 2.3719, Train Accuracy: 0.3034
#   Group 1 - Val Loss: 2.4532, Val Accuracy: 0.2885
#   Group 2 - Train Loss: 2.3461, Train Accuracy: 0.3627
#   Group 2 - Val Loss: 2.5269, Val Accuracy: 0.3333
#   Group 3 - Train Loss: 1.8916, Train Accuracy: 0.5204
#   Group 3 - Val Loss: 2.1450, Val Accuracy: 0.4594
# Epoch [58/200] Group Metrics:
#   Group 1 - Train Loss: 2.3686, Train Accuracy: 0.3043
#   Group 1 - Val Loss: 2.4504, Val Accuracy: 0.2885
#   Group 2 - Train Loss: 2.3406, Train Accuracy: 0.3639
#   Group 2 - Val Loss: 2.5229, Val Accuracy: 0.3357
#   Group 3 - Train Loss: 1.8842, Train Accuracy: 0.5250
#   Group 3 - Val Loss: 2.1391, Val Accuracy: 0.4600
# Epoch [59/200] Group Metrics:
#   Group 1 - Train Loss: 2.3653, Train Accuracy: 0.3058
#   Group 1 - Val Loss: 2.4476, Val Accuracy: 0.2895
#   Group 2 - Train Loss: 2.3351, Train Accuracy: 0.3662
#   Group 2 - Val Loss: 2.5190, Val Accuracy: 0.3357
#   Group 3 - Train Loss: 1.8768, Train Accuracy: 0.5269
#   Group 3 - Val Loss: 2.1334, Val Accuracy: 0.4626
# Epoch [60/200] Group Metrics:
#   Group 1 - Train Loss: 2.3621, Train Accuracy: 0.3058
#   Group 1 - Val Loss: 2.4449, Val Accuracy: 0.2885
#   Group 2 - Train Loss: 2.3298, Train Accuracy: 0.3656
#   Group 2 - Val Loss: 2.5152, Val Accuracy: 0.3368
#   Group 3 - Train Loss: 1.8696, Train Accuracy: 0.5302
#   Group 3 - Val Loss: 2.1277, Val Accuracy: 0.4633
# Epoch [61/200] Group Metrics:
#   Group 1 - Train Loss: 2.3589, Train Accuracy: 0.3068
#   Group 1 - Val Loss: 2.4423, Val Accuracy: 0.2885
#   Group 2 - Train Loss: 2.3245, Train Accuracy: 0.3656
#   Group 2 - Val Loss: 2.5115, Val Accuracy: 0.3392
#   Group 3 - Train Loss: 1.8625, Train Accuracy: 0.5321
#   Group 3 - Val Loss: 2.1221, Val Accuracy: 0.4639
# Epoch [62/200] Group Metrics:
#   Group 1 - Train Loss: 2.3558, Train Accuracy: 0.3068
#   Group 1 - Val Loss: 2.4397, Val Accuracy: 0.2885
#   Group 2 - Train Loss: 2.3193, Train Accuracy: 0.3680
#   Group 2 - Val Loss: 2.5077, Val Accuracy: 0.3415
#   Group 3 - Train Loss: 1.8555, Train Accuracy: 0.5341
#   Group 3 - Val Loss: 2.1167, Val Accuracy: 0.4652
# Epoch [63/200] Group Metrics:
#   Group 1 - Train Loss: 2.3527, Train Accuracy: 0.3078
#   Group 1 - Val Loss: 2.4371, Val Accuracy: 0.2895
#   Group 2 - Train Loss: 2.3141, Train Accuracy: 0.3686
#   Group 2 - Val Loss: 2.5041, Val Accuracy: 0.3427
#   Group 3 - Train Loss: 1.8486, Train Accuracy: 0.5364
#   Group 3 - Val Loss: 2.1113, Val Accuracy: 0.4672
# Epoch [64/200] Group Metrics:
#   Group 1 - Train Loss: 2.3498, Train Accuracy: 0.3073
#   Group 1 - Val Loss: 2.4346, Val Accuracy: 0.2895
#   Group 2 - Train Loss: 2.3090, Train Accuracy: 0.3686
#   Group 2 - Val Loss: 2.5005, Val Accuracy: 0.3439
#   Group 3 - Train Loss: 1.8418, Train Accuracy: 0.5380
#   Group 3 - Val Loss: 2.1060, Val Accuracy: 0.4704
# Epoch [65/200] Group Metrics:
#   Group 1 - Train Loss: 2.3468, Train Accuracy: 0.3068
#   Group 1 - Val Loss: 2.4322, Val Accuracy: 0.2885
#   Group 2 - Train Loss: 2.3040, Train Accuracy: 0.3703
#   Group 2 - Val Loss: 2.4969, Val Accuracy: 0.3462
#   Group 3 - Train Loss: 1.8351, Train Accuracy: 0.5416
#   Group 3 - Val Loss: 2.1007, Val Accuracy: 0.4711
# Epoch [66/200] Group Metrics:
#   Group 1 - Train Loss: 2.3439, Train Accuracy: 0.3073
#   Group 1 - Val Loss: 2.4298, Val Accuracy: 0.2885
#   Group 2 - Train Loss: 2.2991, Train Accuracy: 0.3709
#   Group 2 - Val Loss: 2.4934, Val Accuracy: 0.3474
#   Group 3 - Train Loss: 1.8285, Train Accuracy: 0.5429
#   Group 3 - Val Loss: 2.0956, Val Accuracy: 0.4737
# Epoch [67/200] Group Metrics:
#   Group 1 - Train Loss: 2.3411, Train Accuracy: 0.3078
#   Group 1 - Val Loss: 2.4274, Val Accuracy: 0.2895
#   Group 2 - Train Loss: 2.2942, Train Accuracy: 0.3739
#   Group 2 - Val Loss: 2.4900, Val Accuracy: 0.3497
#   Group 3 - Train Loss: 1.8220, Train Accuracy: 0.5455
#   Group 3 - Val Loss: 2.0905, Val Accuracy: 0.4756
# Epoch [68/200] Group Metrics:
#   Group 1 - Train Loss: 2.3383, Train Accuracy: 0.3087
#   Group 1 - Val Loss: 2.4251, Val Accuracy: 0.2895
#   Group 2 - Train Loss: 2.2894, Train Accuracy: 0.3733
#   Group 2 - Val Loss: 2.4866, Val Accuracy: 0.3497
#   Group 3 - Train Loss: 1.8156, Train Accuracy: 0.5474
#   Group 3 - Val Loss: 2.0855, Val Accuracy: 0.4756
# Epoch [69/200] Group Metrics:
#   Group 1 - Train Loss: 2.3356, Train Accuracy: 0.3092
#   Group 1 - Val Loss: 2.4228, Val Accuracy: 0.2895
#   Group 2 - Train Loss: 2.2846, Train Accuracy: 0.3750
#   Group 2 - Val Loss: 2.4832, Val Accuracy: 0.3497
#   Group 3 - Train Loss: 1.8093, Train Accuracy: 0.5503
#   Group 3 - Val Loss: 2.0806, Val Accuracy: 0.4769
# Epoch [70/200] Group Metrics:
#   Group 1 - Train Loss: 2.3329, Train Accuracy: 0.3107
#   Group 1 - Val Loss: 2.4205, Val Accuracy: 0.2895
#   Group 2 - Train Loss: 2.2800, Train Accuracy: 0.3768
#   Group 2 - Val Loss: 2.4799, Val Accuracy: 0.3497
#   Group 3 - Train Loss: 1.8030, Train Accuracy: 0.5520
#   Group 3 - Val Loss: 2.0758, Val Accuracy: 0.4782
# Epoch [71/200] Group Metrics:
#   Group 1 - Train Loss: 2.3303, Train Accuracy: 0.3117
#   Group 1 - Val Loss: 2.4183, Val Accuracy: 0.2895
#   Group 2 - Train Loss: 2.2753, Train Accuracy: 0.3786
#   Group 2 - Val Loss: 2.4766, Val Accuracy: 0.3520
#   Group 3 - Train Loss: 1.7969, Train Accuracy: 0.5559
#   Group 3 - Val Loss: 2.0710, Val Accuracy: 0.4795
# Epoch [72/200] Group Metrics:
#   Group 1 - Train Loss: 2.3277, Train Accuracy: 0.3127
#   Group 1 - Val Loss: 2.4162, Val Accuracy: 0.2895
#   Group 2 - Train Loss: 2.2707, Train Accuracy: 0.3797
#   Group 2 - Val Loss: 2.4734, Val Accuracy: 0.3520
#   Group 3 - Train Loss: 1.7908, Train Accuracy: 0.5565
#   Group 3 - Val Loss: 2.0663, Val Accuracy: 0.4821
# Epoch [73/200] Group Metrics:
#   Group 1 - Train Loss: 2.3252, Train Accuracy: 0.3131
#   Group 1 - Val Loss: 2.4140, Val Accuracy: 0.2914
#   Group 2 - Train Loss: 2.2662, Train Accuracy: 0.3821
#   Group 2 - Val Loss: 2.4702, Val Accuracy: 0.3544
#   Group 3 - Train Loss: 1.7848, Train Accuracy: 0.5578
#   Group 3 - Val Loss: 2.0617, Val Accuracy: 0.4841
# Epoch [74/200] Group Metrics:
#   Group 1 - Train Loss: 2.3226, Train Accuracy: 0.3131
#   Group 1 - Val Loss: 2.4119, Val Accuracy: 0.2914
#   Group 2 - Train Loss: 2.2617, Train Accuracy: 0.3832
#   Group 2 - Val Loss: 2.4670, Val Accuracy: 0.3591
#   Group 3 - Train Loss: 1.7789, Train Accuracy: 0.5614
#   Group 3 - Val Loss: 2.0571, Val Accuracy: 0.4873
# Epoch [75/200] Group Metrics:
#   Group 1 - Train Loss: 2.3202, Train Accuracy: 0.3151
#   Group 1 - Val Loss: 2.4099, Val Accuracy: 0.2924
#   Group 2 - Train Loss: 2.2573, Train Accuracy: 0.3844
#   Group 2 - Val Loss: 2.4639, Val Accuracy: 0.3602
#   Group 3 - Train Loss: 1.7731, Train Accuracy: 0.5640
#   Group 3 - Val Loss: 2.0526, Val Accuracy: 0.4899
# Epoch [76/200] Group Metrics:
#   Group 1 - Train Loss: 2.3177, Train Accuracy: 0.3146
#   Group 1 - Val Loss: 2.4078, Val Accuracy: 0.2924
#   Group 2 - Train Loss: 2.2529, Train Accuracy: 0.3862
#   Group 2 - Val Loss: 2.4608, Val Accuracy: 0.3602
#   Group 3 - Train Loss: 1.7674, Train Accuracy: 0.5663
#   Group 3 - Val Loss: 2.0482, Val Accuracy: 0.4899
# Epoch [77/200] Group Metrics:
#   Group 1 - Train Loss: 2.3153, Train Accuracy: 0.3146
#   Group 1 - Val Loss: 2.4058, Val Accuracy: 0.2924
#   Group 2 - Train Loss: 2.2486, Train Accuracy: 0.3873
#   Group 2 - Val Loss: 2.4578, Val Accuracy: 0.3626
#   Group 3 - Train Loss: 1.7617, Train Accuracy: 0.5689
#   Group 3 - Val Loss: 2.0438, Val Accuracy: 0.4899
# Epoch [78/200] Group Metrics:
#   Group 1 - Train Loss: 2.3130, Train Accuracy: 0.3146
#   Group 1 - Val Loss: 2.4038, Val Accuracy: 0.2924
#   Group 2 - Train Loss: 2.2444, Train Accuracy: 0.3868
#   Group 2 - Val Loss: 2.4548, Val Accuracy: 0.3614
#   Group 3 - Train Loss: 1.7561, Train Accuracy: 0.5708
#   Group 3 - Val Loss: 2.0395, Val Accuracy: 0.4919
# Epoch [79/200] Group Metrics:
#   Group 1 - Train Loss: 2.3107, Train Accuracy: 0.3151
#   Group 1 - Val Loss: 2.4019, Val Accuracy: 0.2934
#   Group 2 - Train Loss: 2.2401, Train Accuracy: 0.3879
#   Group 2 - Val Loss: 2.4518, Val Accuracy: 0.3614
#   Group 3 - Train Loss: 1.7506, Train Accuracy: 0.5715
#   Group 3 - Val Loss: 2.0352, Val Accuracy: 0.4919
# Epoch [80/200] Group Metrics:
#   Group 1 - Train Loss: 2.3084, Train Accuracy: 0.3146
#   Group 1 - Val Loss: 2.4000, Val Accuracy: 0.2934
#   Group 2 - Train Loss: 2.2360, Train Accuracy: 0.3885
#   Group 2 - Val Loss: 2.4489, Val Accuracy: 0.3614
#   Group 3 - Train Loss: 1.7451, Train Accuracy: 0.5738
#   Group 3 - Val Loss: 2.0310, Val Accuracy: 0.4938
# Epoch [81/200] Group Metrics:
#   Group 1 - Train Loss: 2.3061, Train Accuracy: 0.3146
#   Group 1 - Val Loss: 2.3981, Val Accuracy: 0.2943
#   Group 2 - Train Loss: 2.2318, Train Accuracy: 0.3885
#   Group 2 - Val Loss: 2.4460, Val Accuracy: 0.3614
#   Group 3 - Train Loss: 1.7397, Train Accuracy: 0.5751
#   Group 3 - Val Loss: 2.0269, Val Accuracy: 0.4951
# Epoch [82/200] Group Metrics:
#   Group 1 - Train Loss: 2.3039, Train Accuracy: 0.3141
#   Group 1 - Val Loss: 2.3962, Val Accuracy: 0.2943
#   Group 2 - Train Loss: 2.2278, Train Accuracy: 0.3903
#   Group 2 - Val Loss: 2.4432, Val Accuracy: 0.3626
#   Group 3 - Train Loss: 1.7344, Train Accuracy: 0.5767
#   Group 3 - Val Loss: 2.0228, Val Accuracy: 0.4964
# Epoch [83/200] Group Metrics:
#   Group 1 - Train Loss: 2.3017, Train Accuracy: 0.3146
#   Group 1 - Val Loss: 2.3944, Val Accuracy: 0.2943
#   Group 2 - Train Loss: 2.2237, Train Accuracy: 0.3920
#   Group 2 - Val Loss: 2.4403, Val Accuracy: 0.3637
#   Group 3 - Train Loss: 1.7291, Train Accuracy: 0.5777
#   Group 3 - Val Loss: 2.0188, Val Accuracy: 0.4984
# Epoch [84/200] Group Metrics:
#   Group 1 - Train Loss: 2.2995, Train Accuracy: 0.3151
#   Group 1 - Val Loss: 2.3926, Val Accuracy: 0.2953
#   Group 2 - Train Loss: 2.2197, Train Accuracy: 0.3926
#   Group 2 - Val Loss: 2.4376, Val Accuracy: 0.3637
#   Group 3 - Train Loss: 1.7239, Train Accuracy: 0.5793
#   Group 3 - Val Loss: 2.0148, Val Accuracy: 0.4984
# Epoch [85/200] Group Metrics:
#   Group 1 - Train Loss: 2.2974, Train Accuracy: 0.3146
#   Group 1 - Val Loss: 2.3908, Val Accuracy: 0.2963
#   Group 2 - Train Loss: 2.2158, Train Accuracy: 0.3932
#   Group 2 - Val Loss: 2.4348, Val Accuracy: 0.3649
#   Group 3 - Train Loss: 1.7188, Train Accuracy: 0.5813
#   Group 3 - Val Loss: 2.0108, Val Accuracy: 0.5003
# Epoch [86/200] Group Metrics:
#   Group 1 - Train Loss: 2.2953, Train Accuracy: 0.3146
#   Group 1 - Val Loss: 2.3890, Val Accuracy: 0.2963
#   Group 2 - Train Loss: 2.2118, Train Accuracy: 0.3938
#   Group 2 - Val Loss: 2.4321, Val Accuracy: 0.3684
#   Group 3 - Train Loss: 1.7137, Train Accuracy: 0.5829
#   Group 3 - Val Loss: 2.0070, Val Accuracy: 0.5016
# Epoch [87/200] Group Metrics:
#   Group 1 - Train Loss: 2.2932, Train Accuracy: 0.3146
#   Group 1 - Val Loss: 2.3873, Val Accuracy: 0.2992
#   Group 2 - Train Loss: 2.2080, Train Accuracy: 0.3938
#   Group 2 - Val Loss: 2.4294, Val Accuracy: 0.3684
#   Group 3 - Train Loss: 1.7087, Train Accuracy: 0.5845
#   Group 3 - Val Loss: 2.0031, Val Accuracy: 0.5023
# Epoch [88/200] Group Metrics:
#   Group 1 - Train Loss: 2.2912, Train Accuracy: 0.3146
#   Group 1 - Val Loss: 2.3856, Val Accuracy: 0.2992
#   Group 2 - Train Loss: 2.2041, Train Accuracy: 0.3944
#   Group 2 - Val Loss: 2.4267, Val Accuracy: 0.3673
#   Group 3 - Train Loss: 1.7037, Train Accuracy: 0.5871
#   Group 3 - Val Loss: 1.9993, Val Accuracy: 0.5029
# Epoch [89/200] Group Metrics:
#   Group 1 - Train Loss: 2.2892, Train Accuracy: 0.3141
#   Group 1 - Val Loss: 2.3839, Val Accuracy: 0.2992
#   Group 2 - Train Loss: 2.2004, Train Accuracy: 0.3979
#   Group 2 - Val Loss: 2.4241, Val Accuracy: 0.3684
#   Group 3 - Train Loss: 1.6988, Train Accuracy: 0.5891
#   Group 3 - Val Loss: 1.9956, Val Accuracy: 0.5062
# Epoch [90/200] Group Metrics:
#   Group 1 - Train Loss: 2.2872, Train Accuracy: 0.3141
#   Group 1 - Val Loss: 2.3822, Val Accuracy: 0.3002
#   Group 2 - Train Loss: 2.1966, Train Accuracy: 0.3997
#   Group 2 - Val Loss: 2.4214, Val Accuracy: 0.3696
#   Group 3 - Train Loss: 1.6940, Train Accuracy: 0.5907
#   Group 3 - Val Loss: 1.9919, Val Accuracy: 0.5081
# Epoch [91/200] Group Metrics:
#   Group 1 - Train Loss: 2.2852, Train Accuracy: 0.3146
#   Group 1 - Val Loss: 2.3806, Val Accuracy: 0.3012
#   Group 2 - Train Loss: 2.1929, Train Accuracy: 0.4014
#   Group 2 - Val Loss: 2.4189, Val Accuracy: 0.3696
#   Group 3 - Train Loss: 1.6892, Train Accuracy: 0.5926
#   Group 3 - Val Loss: 1.9883, Val Accuracy: 0.5101
# Epoch [92/200] Group Metrics:
#   Group 1 - Train Loss: 2.2833, Train Accuracy: 0.3151
#   Group 1 - Val Loss: 2.3790, Val Accuracy: 0.3021
#   Group 2 - Train Loss: 2.1892, Train Accuracy: 0.4044
#   Group 2 - Val Loss: 2.4163, Val Accuracy: 0.3708
#   Group 3 - Train Loss: 1.6844, Train Accuracy: 0.5943
#   Group 3 - Val Loss: 1.9847, Val Accuracy: 0.5107
# Epoch [93/200] Group Metrics:
#   Group 1 - Train Loss: 2.2814, Train Accuracy: 0.3146
#   Group 1 - Val Loss: 2.3774, Val Accuracy: 0.3021
#   Group 2 - Train Loss: 2.1855, Train Accuracy: 0.4049
#   Group 2 - Val Loss: 2.4138, Val Accuracy: 0.3708
#   Group 3 - Train Loss: 1.6797, Train Accuracy: 0.5962
#   Group 3 - Val Loss: 1.9811, Val Accuracy: 0.5120
# Epoch [94/200] Group Metrics:
#   Group 1 - Train Loss: 2.2795, Train Accuracy: 0.3146
#   Group 1 - Val Loss: 2.3758, Val Accuracy: 0.3041
#   Group 2 - Train Loss: 2.1819, Train Accuracy: 0.4061
#   Group 2 - Val Loss: 2.4113, Val Accuracy: 0.3708
#   Group 3 - Train Loss: 1.6751, Train Accuracy: 0.5982
#   Group 3 - Val Loss: 1.9776, Val Accuracy: 0.5146
# Epoch [95/200] Group Metrics:
#   Group 1 - Train Loss: 2.2776, Train Accuracy: 0.3156
#   Group 1 - Val Loss: 2.3742, Val Accuracy: 0.3041
#   Group 2 - Train Loss: 2.1784, Train Accuracy: 0.4073
#   Group 2 - Val Loss: 2.4088, Val Accuracy: 0.3719
#   Group 3 - Train Loss: 1.6705, Train Accuracy: 0.5992
#   Group 3 - Val Loss: 1.9741, Val Accuracy: 0.5159
# Epoch [96/200] Group Metrics:
#   Group 1 - Train Loss: 2.2757, Train Accuracy: 0.3156
#   Group 1 - Val Loss: 2.3727, Val Accuracy: 0.3041
#   Group 2 - Train Loss: 2.1748, Train Accuracy: 0.4085
#   Group 2 - Val Loss: 2.4064, Val Accuracy: 0.3719
#   Group 3 - Train Loss: 1.6659, Train Accuracy: 0.6001
#   Group 3 - Val Loss: 1.9707, Val Accuracy: 0.5166
# Epoch [97/200] Group Metrics:
#   Group 1 - Train Loss: 2.2739, Train Accuracy: 0.3156
#   Group 1 - Val Loss: 2.3711, Val Accuracy: 0.3041
#   Group 2 - Train Loss: 2.1713, Train Accuracy: 0.4096
#   Group 2 - Val Loss: 2.4039, Val Accuracy: 0.3719
#   Group 3 - Train Loss: 1.6614, Train Accuracy: 0.6024
#   Group 3 - Val Loss: 1.9673, Val Accuracy: 0.5172
# Epoch [98/200] Group Metrics:
#   Group 1 - Train Loss: 2.2721, Train Accuracy: 0.3161
#   Group 1 - Val Loss: 2.3696, Val Accuracy: 0.3051
#   Group 2 - Train Loss: 2.1678, Train Accuracy: 0.4108
#   Group 2 - Val Loss: 2.4015, Val Accuracy: 0.3743
#   Group 3 - Train Loss: 1.6570, Train Accuracy: 0.6034
#   Group 3 - Val Loss: 1.9639, Val Accuracy: 0.5179
# Epoch [99/200] Group Metrics:
#   Group 1 - Train Loss: 2.2703, Train Accuracy: 0.3166
#   Group 1 - Val Loss: 2.3681, Val Accuracy: 0.3051
#   Group 2 - Train Loss: 2.1644, Train Accuracy: 0.4114
#   Group 2 - Val Loss: 2.3992, Val Accuracy: 0.3743
#   Group 3 - Train Loss: 1.6526, Train Accuracy: 0.6047
#   Group 3 - Val Loss: 1.9606, Val Accuracy: 0.5179
# Epoch [100/200] Group Metrics:
#   Group 1 - Train Loss: 2.2686, Train Accuracy: 0.3175
#   Group 1 - Val Loss: 2.3667, Val Accuracy: 0.3051
#   Group 2 - Train Loss: 2.1610, Train Accuracy: 0.4137
#   Group 2 - Val Loss: 2.3968, Val Accuracy: 0.3743
#   Group 3 - Train Loss: 1.6482, Train Accuracy: 0.6057
#   Group 3 - Val Loss: 1.9573, Val Accuracy: 0.5192
# Epoch [101/200] Group Metrics:
#   Group 1 - Train Loss: 2.2668, Train Accuracy: 0.3190
#   Group 1 - Val Loss: 2.3652, Val Accuracy: 0.3051
#   Group 2 - Train Loss: 2.1576, Train Accuracy: 0.4137
#   Group 2 - Val Loss: 2.3945, Val Accuracy: 0.3743
#   Group 3 - Train Loss: 1.6439, Train Accuracy: 0.6066
#   Group 3 - Val Loss: 1.9541, Val Accuracy: 0.5192
# Epoch [102/200] Group Metrics:
#   Group 1 - Train Loss: 2.2651, Train Accuracy: 0.3185
#   Group 1 - Val Loss: 2.3638, Val Accuracy: 0.3041
#   Group 2 - Train Loss: 2.1543, Train Accuracy: 0.4149
#   Group 2 - Val Loss: 2.3922, Val Accuracy: 0.3754
#   Group 3 - Train Loss: 1.6397, Train Accuracy: 0.6079
#   Group 3 - Val Loss: 1.9509, Val Accuracy: 0.5192
# Epoch [103/200] Group Metrics:
#   Group 1 - Train Loss: 2.2634, Train Accuracy: 0.3185
#   Group 1 - Val Loss: 2.3624, Val Accuracy: 0.3041
#   Group 2 - Train Loss: 2.1509, Train Accuracy: 0.4184
#   Group 2 - Val Loss: 2.3899, Val Accuracy: 0.3754
#   Group 3 - Train Loss: 1.6354, Train Accuracy: 0.6092
#   Group 3 - Val Loss: 1.9477, Val Accuracy: 0.5218
# Epoch [104/200] Group Metrics:
#   Group 1 - Train Loss: 2.2617, Train Accuracy: 0.3195
#   Group 1 - Val Loss: 2.3610, Val Accuracy: 0.3041
#   Group 2 - Train Loss: 2.1476, Train Accuracy: 0.4184
#   Group 2 - Val Loss: 2.3876, Val Accuracy: 0.3754
#   Group 3 - Train Loss: 1.6312, Train Accuracy: 0.6099
#   Group 3 - Val Loss: 1.9446, Val Accuracy: 0.5224
# Epoch [105/200] Group Metrics:
#   Group 1 - Train Loss: 2.2601, Train Accuracy: 0.3195
#   Group 1 - Val Loss: 2.3596, Val Accuracy: 0.3041
#   Group 2 - Train Loss: 2.1444, Train Accuracy: 0.4184
#   Group 2 - Val Loss: 2.3854, Val Accuracy: 0.3766
#   Group 3 - Train Loss: 1.6271, Train Accuracy: 0.6102
#   Group 3 - Val Loss: 1.9415, Val Accuracy: 0.5231
# Epoch [106/200] Group Metrics:
#   Group 1 - Train Loss: 2.2584, Train Accuracy: 0.3205
#   Group 1 - Val Loss: 2.3582, Val Accuracy: 0.3051
#   Group 2 - Train Loss: 2.1412, Train Accuracy: 0.4190
#   Group 2 - Val Loss: 2.3832, Val Accuracy: 0.3778
#   Group 3 - Train Loss: 1.6230, Train Accuracy: 0.6112
#   Group 3 - Val Loss: 1.9384, Val Accuracy: 0.5231
# Epoch [107/200] Group Metrics:
#   Group 1 - Train Loss: 2.2568, Train Accuracy: 0.3210
#   Group 1 - Val Loss: 2.3568, Val Accuracy: 0.3051
#   Group 2 - Train Loss: 2.1379, Train Accuracy: 0.4196
#   Group 2 - Val Loss: 2.3810, Val Accuracy: 0.3789
#   Group 3 - Train Loss: 1.6189, Train Accuracy: 0.6115
#   Group 3 - Val Loss: 1.9354, Val Accuracy: 0.5237
# Epoch [108/200] Group Metrics:
#   Group 1 - Train Loss: 2.2552, Train Accuracy: 0.3215
#   Group 1 - Val Loss: 2.3555, Val Accuracy: 0.3051
#   Group 2 - Train Loss: 2.1348, Train Accuracy: 0.4202
#   Group 2 - Val Loss: 2.3788, Val Accuracy: 0.3789
#   Group 3 - Train Loss: 1.6149, Train Accuracy: 0.6135
#   Group 3 - Val Loss: 1.9324, Val Accuracy: 0.5250
# Epoch [109/200] Group Metrics:
#   Group 1 - Train Loss: 2.2536, Train Accuracy: 0.3215
#   Group 1 - Val Loss: 2.3542, Val Accuracy: 0.3051
#   Group 2 - Train Loss: 2.1316, Train Accuracy: 0.4202
#   Group 2 - Val Loss: 2.3766, Val Accuracy: 0.3813
#   Group 3 - Train Loss: 1.6109, Train Accuracy: 0.6161
#   Group 3 - Val Loss: 1.9294, Val Accuracy: 0.5250
# Epoch [110/200] Group Metrics:
#   Group 1 - Train Loss: 2.2520, Train Accuracy: 0.3215
#   Group 1 - Val Loss: 2.3529, Val Accuracy: 0.3041
#   Group 2 - Train Loss: 2.1285, Train Accuracy: 0.4214
#   Group 2 - Val Loss: 2.3745, Val Accuracy: 0.3801
#   Group 3 - Train Loss: 1.6070, Train Accuracy: 0.6171
#   Group 3 - Val Loss: 1.9265, Val Accuracy: 0.5244
# Epoch [111/200] Group Metrics:
#   Group 1 - Train Loss: 2.2504, Train Accuracy: 0.3219
#   Group 1 - Val Loss: 2.3516, Val Accuracy: 0.3041
#   Group 2 - Train Loss: 2.1254, Train Accuracy: 0.4225
#   Group 2 - Val Loss: 2.3724, Val Accuracy: 0.3813
#   Group 3 - Train Loss: 1.6031, Train Accuracy: 0.6177
#   Group 3 - Val Loss: 1.9235, Val Accuracy: 0.5244
# Epoch [112/200] Group Metrics:
#   Group 1 - Train Loss: 2.2489, Train Accuracy: 0.3229
#   Group 1 - Val Loss: 2.3503, Val Accuracy: 0.3041
#   Group 2 - Train Loss: 2.1223, Train Accuracy: 0.4225
#   Group 2 - Val Loss: 2.3703, Val Accuracy: 0.3836
#   Group 3 - Train Loss: 1.5992, Train Accuracy: 0.6184
#   Group 3 - Val Loss: 1.9207, Val Accuracy: 0.5250
# Epoch [113/200] Group Metrics:
#   Group 1 - Train Loss: 2.2474, Train Accuracy: 0.3229
#   Group 1 - Val Loss: 2.3490, Val Accuracy: 0.3031
#   Group 2 - Train Loss: 2.1193, Train Accuracy: 0.4237
#   Group 2 - Val Loss: 2.3682, Val Accuracy: 0.3848
#   Group 3 - Train Loss: 1.5954, Train Accuracy: 0.6193
#   Group 3 - Val Loss: 1.9178, Val Accuracy: 0.5250
# Epoch [114/200] Group Metrics:
#   Group 1 - Train Loss: 2.2459, Train Accuracy: 0.3229
#   Group 1 - Val Loss: 2.3478, Val Accuracy: 0.3031
#   Group 2 - Train Loss: 2.1163, Train Accuracy: 0.4255
#   Group 2 - Val Loss: 2.3661, Val Accuracy: 0.3848
#   Group 3 - Train Loss: 1.5916, Train Accuracy: 0.6206
#   Group 3 - Val Loss: 1.9150, Val Accuracy: 0.5276
# Epoch [115/200] Group Metrics:
#   Group 1 - Train Loss: 2.2444, Train Accuracy: 0.3229
#   Group 1 - Val Loss: 2.3465, Val Accuracy: 0.3031
#   Group 2 - Train Loss: 2.1133, Train Accuracy: 0.4260
#   Group 2 - Val Loss: 2.3641, Val Accuracy: 0.3825
#   Group 3 - Train Loss: 1.5878, Train Accuracy: 0.6219
#   Group 3 - Val Loss: 1.9122, Val Accuracy: 0.5289
# Epoch [116/200] Group Metrics:
#   Group 1 - Train Loss: 2.2429, Train Accuracy: 0.3229
#   Group 1 - Val Loss: 2.3453, Val Accuracy: 0.3031
#   Group 2 - Train Loss: 2.1103, Train Accuracy: 0.4278
#   Group 2 - Val Loss: 2.3621, Val Accuracy: 0.3848
#   Group 3 - Train Loss: 1.5841, Train Accuracy: 0.6226
#   Group 3 - Val Loss: 1.9095, Val Accuracy: 0.5296
# Epoch [117/200] Group Metrics:
#   Group 1 - Train Loss: 2.2414, Train Accuracy: 0.3239
#   Group 1 - Val Loss: 2.3441, Val Accuracy: 0.3041
#   Group 2 - Train Loss: 2.1074, Train Accuracy: 0.4284
#   Group 2 - Val Loss: 2.3601, Val Accuracy: 0.3848
#   Group 3 - Train Loss: 1.5804, Train Accuracy: 0.6236
#   Group 3 - Val Loss: 1.9067, Val Accuracy: 0.5309
# Epoch [118/200] Group Metrics:
#   Group 1 - Train Loss: 2.2400, Train Accuracy: 0.3244
#   Group 1 - Val Loss: 2.3429, Val Accuracy: 0.3041
#   Group 2 - Train Loss: 2.1044, Train Accuracy: 0.4284
#   Group 2 - Val Loss: 2.3581, Val Accuracy: 0.3848
#   Group 3 - Train Loss: 1.5767, Train Accuracy: 0.6245
#   Group 3 - Val Loss: 1.9040, Val Accuracy: 0.5322
# Epoch [119/200] Group Metrics:
#   Group 1 - Train Loss: 2.2385, Train Accuracy: 0.3234
#   Group 1 - Val Loss: 2.3417, Val Accuracy: 0.3041
#   Group 2 - Train Loss: 2.1015, Train Accuracy: 0.4284
#   Group 2 - Val Loss: 2.3561, Val Accuracy: 0.3848
#   Group 3 - Train Loss: 1.5731, Train Accuracy: 0.6262
#   Group 3 - Val Loss: 1.9013, Val Accuracy: 0.5328
# Epoch [120/200] Group Metrics:
#   Group 1 - Train Loss: 2.2371, Train Accuracy: 0.3239
#   Group 1 - Val Loss: 2.3405, Val Accuracy: 0.3041
#   Group 2 - Train Loss: 2.0987, Train Accuracy: 0.4296
#   Group 2 - Val Loss: 2.3542, Val Accuracy: 0.3848
#   Group 3 - Train Loss: 1.5695, Train Accuracy: 0.6271
#   Group 3 - Val Loss: 1.8987, Val Accuracy: 0.5354
# Epoch [121/200] Group Metrics:
#   Group 1 - Train Loss: 2.2357, Train Accuracy: 0.3239
#   Group 1 - Val Loss: 2.3393, Val Accuracy: 0.3041
#   Group 2 - Train Loss: 2.0958, Train Accuracy: 0.4307
#   Group 2 - Val Loss: 2.3522, Val Accuracy: 0.3860
#   Group 3 - Train Loss: 1.5659, Train Accuracy: 0.6288
#   Group 3 - Val Loss: 1.8961, Val Accuracy: 0.5361
# Epoch [122/200] Group Metrics:
#   Group 1 - Train Loss: 2.2343, Train Accuracy: 0.3239
#   Group 1 - Val Loss: 2.3381, Val Accuracy: 0.3041
#   Group 2 - Train Loss: 2.0930, Train Accuracy: 0.4319
#   Group 2 - Val Loss: 2.3503, Val Accuracy: 0.3883
#   Group 3 - Train Loss: 1.5624, Train Accuracy: 0.6307
#   Group 3 - Val Loss: 1.8935, Val Accuracy: 0.5361
# Epoch [123/200] Group Metrics:
#   Group 1 - Train Loss: 2.2329, Train Accuracy: 0.3239
#   Group 1 - Val Loss: 2.3370, Val Accuracy: 0.3041
#   Group 2 - Train Loss: 2.0902, Train Accuracy: 0.4325
#   Group 2 - Val Loss: 2.3484, Val Accuracy: 0.3895
#   Group 3 - Train Loss: 1.5588, Train Accuracy: 0.6320
#   Group 3 - Val Loss: 1.8909, Val Accuracy: 0.5354
# Epoch [124/200] Group Metrics:
#   Group 1 - Train Loss: 2.2315, Train Accuracy: 0.3239
#   Group 1 - Val Loss: 2.3359, Val Accuracy: 0.3051
#   Group 2 - Train Loss: 2.0874, Train Accuracy: 0.4337
#   Group 2 - Val Loss: 2.3465, Val Accuracy: 0.3895
#   Group 3 - Train Loss: 1.5554, Train Accuracy: 0.6333
#   Group 3 - Val Loss: 1.8884, Val Accuracy: 0.5361
# Epoch [125/200] Group Metrics:
#   Group 1 - Train Loss: 2.2302, Train Accuracy: 0.3254
#   Group 1 - Val Loss: 2.3347, Val Accuracy: 0.3041
#   Group 2 - Train Loss: 2.0846, Train Accuracy: 0.4348
#   Group 2 - Val Loss: 2.3446, Val Accuracy: 0.3895
#   Group 3 - Train Loss: 1.5519, Train Accuracy: 0.6340
#   Group 3 - Val Loss: 1.8858, Val Accuracy: 0.5361
# Epoch [126/200] Group Metrics:
#   Group 1 - Train Loss: 2.2288, Train Accuracy: 0.3259
#   Group 1 - Val Loss: 2.3336, Val Accuracy: 0.3041
#   Group 2 - Train Loss: 2.0819, Train Accuracy: 0.4360
#   Group 2 - Val Loss: 2.3428, Val Accuracy: 0.3895
#   Group 3 - Train Loss: 1.5485, Train Accuracy: 0.6353
#   Group 3 - Val Loss: 1.8833, Val Accuracy: 0.5367
# Epoch [127/200] Group Metrics:
#   Group 1 - Train Loss: 2.2275, Train Accuracy: 0.3259
#   Group 1 - Val Loss: 2.3325, Val Accuracy: 0.3051
#   Group 2 - Train Loss: 2.0791, Train Accuracy: 0.4360
#   Group 2 - Val Loss: 2.3409, Val Accuracy: 0.3895
#   Group 3 - Train Loss: 1.5451, Train Accuracy: 0.6356
#   Group 3 - Val Loss: 1.8809, Val Accuracy: 0.5361
# Epoch [128/200] Group Metrics:
#   Group 1 - Train Loss: 2.2261, Train Accuracy: 0.3263
#   Group 1 - Val Loss: 2.3314, Val Accuracy: 0.3041
#   Group 2 - Train Loss: 2.0764, Train Accuracy: 0.4384
#   Group 2 - Val Loss: 2.3391, Val Accuracy: 0.3895
#   Group 3 - Train Loss: 1.5417, Train Accuracy: 0.6369
#   Group 3 - Val Loss: 1.8784, Val Accuracy: 0.5361
# Epoch [129/200] Group Metrics:
#   Group 1 - Train Loss: 2.2248, Train Accuracy: 0.3259
#   Group 1 - Val Loss: 2.3303, Val Accuracy: 0.3041
#   Group 2 - Train Loss: 2.0737, Train Accuracy: 0.4384
#   Group 2 - Val Loss: 2.3373, Val Accuracy: 0.3906
#   Group 3 - Train Loss: 1.5384, Train Accuracy: 0.6376
#   Group 3 - Val Loss: 1.8760, Val Accuracy: 0.5367
# Epoch [130/200] Group Metrics:
#   Group 1 - Train Loss: 2.2235, Train Accuracy: 0.3259
#   Group 1 - Val Loss: 2.3293, Val Accuracy: 0.3051
#   Group 2 - Train Loss: 2.0711, Train Accuracy: 0.4395
#   Group 2 - Val Loss: 2.3355, Val Accuracy: 0.3906
#   Group 3 - Train Loss: 1.5351, Train Accuracy: 0.6398
#   Group 3 - Val Loss: 1.8736, Val Accuracy: 0.5374
# Epoch [131/200] Group Metrics:
#   Group 1 - Train Loss: 2.2222, Train Accuracy: 0.3259
#   Group 1 - Val Loss: 2.3282, Val Accuracy: 0.3051
#   Group 2 - Train Loss: 2.0684, Train Accuracy: 0.4407
#   Group 2 - Val Loss: 2.3337, Val Accuracy: 0.3918
#   Group 3 - Train Loss: 1.5318, Train Accuracy: 0.6411
#   Group 3 - Val Loss: 1.8712, Val Accuracy: 0.5374
# Epoch [132/200] Group Metrics:
#   Group 1 - Train Loss: 2.2210, Train Accuracy: 0.3259
#   Group 1 - Val Loss: 2.3271, Val Accuracy: 0.3051
#   Group 2 - Train Loss: 2.0658, Train Accuracy: 0.4430
#   Group 2 - Val Loss: 2.3320, Val Accuracy: 0.3918
#   Group 3 - Train Loss: 1.5286, Train Accuracy: 0.6434
#   Group 3 - Val Loss: 1.8688, Val Accuracy: 0.5374
# Epoch [133/200] Group Metrics:
#   Group 1 - Train Loss: 2.2197, Train Accuracy: 0.3263
#   Group 1 - Val Loss: 2.3261, Val Accuracy: 0.3051
#   Group 2 - Train Loss: 2.0632, Train Accuracy: 0.4442
#   Group 2 - Val Loss: 2.3302, Val Accuracy: 0.3918
#   Group 3 - Train Loss: 1.5253, Train Accuracy: 0.6441
#   Group 3 - Val Loss: 1.8665, Val Accuracy: 0.5374
# Epoch [134/200] Group Metrics:
#   Group 1 - Train Loss: 2.2184, Train Accuracy: 0.3268
#   Group 1 - Val Loss: 2.3251, Val Accuracy: 0.3060
#   Group 2 - Train Loss: 2.0606, Train Accuracy: 0.4448
#   Group 2 - Val Loss: 2.3285, Val Accuracy: 0.3918
#   Group 3 - Train Loss: 1.5221, Train Accuracy: 0.6460
#   Group 3 - Val Loss: 1.8642, Val Accuracy: 0.5367
# Epoch [135/200] Group Metrics:
#   Group 1 - Train Loss: 2.2172, Train Accuracy: 0.3278
#   Group 1 - Val Loss: 2.3240, Val Accuracy: 0.3060
#   Group 2 - Train Loss: 2.0580, Train Accuracy: 0.4448
#   Group 2 - Val Loss: 2.3267, Val Accuracy: 0.3918
#   Group 3 - Train Loss: 1.5190, Train Accuracy: 0.6470
#   Group 3 - Val Loss: 1.8619, Val Accuracy: 0.5374
# Epoch [136/200] Group Metrics:
#   Group 1 - Train Loss: 2.2160, Train Accuracy: 0.3283
#   Group 1 - Val Loss: 2.3230, Val Accuracy: 0.3060
#   Group 2 - Train Loss: 2.0555, Train Accuracy: 0.4448
#   Group 2 - Val Loss: 2.3250, Val Accuracy: 0.3918
#   Group 3 - Train Loss: 1.5158, Train Accuracy: 0.6473
#   Group 3 - Val Loss: 1.8596, Val Accuracy: 0.5374
# Epoch [137/200] Group Metrics:
#   Group 1 - Train Loss: 2.2147, Train Accuracy: 0.3278
#   Group 1 - Val Loss: 2.3220, Val Accuracy: 0.3060
#   Group 2 - Train Loss: 2.0530, Train Accuracy: 0.4454
#   Group 2 - Val Loss: 2.3233, Val Accuracy: 0.3930
#   Group 3 - Train Loss: 1.5127, Train Accuracy: 0.6486
# ...
#   Group 1 - Val Loss: 2.3053, Val Accuracy: 0.3090
#   Group 2 - Train Loss: 2.0102, Train Accuracy: 0.4577
#   Group 2 - Val Loss: 2.2948, Val Accuracy: 0.4023
#   Group 3 - Train Loss: 1.4603, Train Accuracy: 0.6623
#   Group 3 - Val Loss: 1.8200, Val Accuracy: 0.5478
# Epoch [156/200] Group Metrics:
#   Group 1 - Train Loss: 2.1932, Train Accuracy: 0.3361
#   Group 1 - Val Loss: 2.3044, Val Accuracy: 0.3090
#   Group 2 - Train Loss: 2.0080, Train Accuracy: 0.4583
#   Group 2 - Val Loss: 2.2933, Val Accuracy: 0.4023
#   Group 3 - Train Loss: 1.4576, Train Accuracy: 0.6626
#   Group 3 - Val Loss: 1.8181, Val Accuracy: 0.5478
# Epoch [157/200] Group Metrics:
#   Group 1 - Train Loss: 2.1922, Train Accuracy: 0.3361
#   Group 1 - Val Loss: 2.3035, Val Accuracy: 0.3090
#   Group 2 - Train Loss: 2.0058, Train Accuracy: 0.4595
#   Group 2 - Val Loss: 2.2918, Val Accuracy: 0.4035
#   Group 3 - Train Loss: 1.4549, Train Accuracy: 0.6629
#   Group 3 - Val Loss: 1.8162, Val Accuracy: 0.5478
# Epoch [158/200] Group Metrics:
#   Group 1 - Train Loss: 2.1911, Train Accuracy: 0.3361
#   Group 1 - Val Loss: 2.3027, Val Accuracy: 0.3090
#   Group 2 - Train Loss: 2.0036, Train Accuracy: 0.4595
#   Group 2 - Val Loss: 2.2904, Val Accuracy: 0.4023
#   Group 3 - Train Loss: 1.4522, Train Accuracy: 0.6639
#   Group 3 - Val Loss: 1.8143, Val Accuracy: 0.5491
# Epoch [159/200] Group Metrics:
#   Group 1 - Train Loss: 2.1901, Train Accuracy: 0.3376
#   Group 1 - Val Loss: 2.3018, Val Accuracy: 0.3090
#   Group 2 - Train Loss: 2.0014, Train Accuracy: 0.4595
#   Group 2 - Val Loss: 2.2889, Val Accuracy: 0.4023
#   Group 3 - Train Loss: 1.4495, Train Accuracy: 0.6646
#   Group 3 - Val Loss: 1.8124, Val Accuracy: 0.5497
# Epoch [160/200] Group Metrics:
#   Group 1 - Train Loss: 2.1891, Train Accuracy: 0.3386
#   Group 1 - Val Loss: 2.3010, Val Accuracy: 0.3090
#   Group 2 - Train Loss: 1.9992, Train Accuracy: 0.4606
#   Group 2 - Val Loss: 2.2875, Val Accuracy: 0.4023
#   Group 3 - Train Loss: 1.4469, Train Accuracy: 0.6652
#   Group 3 - Val Loss: 1.8106, Val Accuracy: 0.5504
# Epoch [161/200] Group Metrics:
#   Group 1 - Train Loss: 2.1880, Train Accuracy: 0.3390
#   Group 1 - Val Loss: 2.3002, Val Accuracy: 0.3090
#   Group 2 - Train Loss: 1.9970, Train Accuracy: 0.4618
#   Group 2 - Val Loss: 2.2860, Val Accuracy: 0.4023
#   Group 3 - Train Loss: 1.4443, Train Accuracy: 0.6655
#   Group 3 - Val Loss: 1.8087, Val Accuracy: 0.5504
# Epoch [162/200] Group Metrics:
#   Group 1 - Train Loss: 2.1870, Train Accuracy: 0.3390
#   Group 1 - Val Loss: 2.2993, Val Accuracy: 0.3099
#   Group 2 - Train Loss: 1.9949, Train Accuracy: 0.4624
#   Group 2 - Val Loss: 2.2846, Val Accuracy: 0.4023
#   Group 3 - Train Loss: 1.4417, Train Accuracy: 0.6659
#   Group 3 - Val Loss: 1.8069, Val Accuracy: 0.5510
# Epoch [163/200] Group Metrics:
#   Group 1 - Train Loss: 2.1860, Train Accuracy: 0.3390
#   Group 1 - Val Loss: 2.2985, Val Accuracy: 0.3119
#   Group 2 - Train Loss: 1.9928, Train Accuracy: 0.4624
#   Group 2 - Val Loss: 2.2832, Val Accuracy: 0.4023
#   Group 3 - Train Loss: 1.4391, Train Accuracy: 0.6662
#   Group 3 - Val Loss: 1.8051, Val Accuracy: 0.5510
# Epoch [164/200] Group Metrics:
#   Group 1 - Train Loss: 2.1850, Train Accuracy: 0.3390
#   Group 1 - Val Loss: 2.2977, Val Accuracy: 0.3119
#   Group 2 - Train Loss: 1.9906, Train Accuracy: 0.4636
#   Group 2 - Val Loss: 2.2818, Val Accuracy: 0.4035
#   Group 3 - Train Loss: 1.4365, Train Accuracy: 0.6672
#   Group 3 - Val Loss: 1.8033, Val Accuracy: 0.5517
# Epoch [165/200] Group Metrics:
#   Group 1 - Train Loss: 2.1840, Train Accuracy: 0.3386
#   Group 1 - Val Loss: 2.2969, Val Accuracy: 0.3119
#   Group 2 - Train Loss: 1.9885, Train Accuracy: 0.4641
#   Group 2 - Val Loss: 2.2804, Val Accuracy: 0.4035
#   Group 3 - Train Loss: 1.4340, Train Accuracy: 0.6678
#   Group 3 - Val Loss: 1.8015, Val Accuracy: 0.5523
# Epoch [166/200] Group Metrics:
#   Group 1 - Train Loss: 2.1830, Train Accuracy: 0.3386
#   Group 1 - Val Loss: 2.2961, Val Accuracy: 0.3129
#   Group 2 - Train Loss: 1.9864, Train Accuracy: 0.4647
#   Group 2 - Val Loss: 2.2790, Val Accuracy: 0.4035
#   Group 3 - Train Loss: 1.4314, Train Accuracy: 0.6678
#   Group 3 - Val Loss: 1.7997, Val Accuracy: 0.5523
# Epoch [167/200] Group Metrics:
#   Group 1 - Train Loss: 2.1821, Train Accuracy: 0.3395
#   Group 1 - Val Loss: 2.2953, Val Accuracy: 0.3129
#   Group 2 - Train Loss: 1.9843, Train Accuracy: 0.4641
#   Group 2 - Val Loss: 2.2777, Val Accuracy: 0.4035
#   Group 3 - Train Loss: 1.4289, Train Accuracy: 0.6691
#   Group 3 - Val Loss: 1.7980, Val Accuracy: 0.5523
# Epoch [168/200] Group Metrics:
#   Group 1 - Train Loss: 2.1811, Train Accuracy: 0.3400
#   Group 1 - Val Loss: 2.2945, Val Accuracy: 0.3129
#   Group 2 - Train Loss: 1.9823, Train Accuracy: 0.4647
#   Group 2 - Val Loss: 2.2763, Val Accuracy: 0.4035
#   Group 3 - Train Loss: 1.4264, Train Accuracy: 0.6691
#   Group 3 - Val Loss: 1.7962, Val Accuracy: 0.5523
# Epoch [169/200] Group Metrics:
#   Group 1 - Train Loss: 2.1801, Train Accuracy: 0.3400
#   Group 1 - Val Loss: 2.2937, Val Accuracy: 0.3129
#   Group 2 - Train Loss: 1.9802, Train Accuracy: 0.4653
#   Group 2 - Val Loss: 2.2749, Val Accuracy: 0.4035
#   Group 3 - Train Loss: 1.4239, Train Accuracy: 0.6701
#   Group 3 - Val Loss: 1.7945, Val Accuracy: 0.5523
# Epoch [170/200] Group Metrics:
#   Group 1 - Train Loss: 2.1792, Train Accuracy: 0.3415
#   Group 1 - Val Loss: 2.2930, Val Accuracy: 0.3119
#   Group 2 - Train Loss: 1.9782, Train Accuracy: 0.4659
#   Group 2 - Val Loss: 2.2736, Val Accuracy: 0.4035
#   Group 3 - Train Loss: 1.4215, Train Accuracy: 0.6701
#   Group 3 - Val Loss: 1.7928, Val Accuracy: 0.5523
# Epoch [171/200] Group Metrics:
#   Group 1 - Train Loss: 2.1782, Train Accuracy: 0.3420
#   Group 1 - Val Loss: 2.2922, Val Accuracy: 0.3119
#   Group 2 - Train Loss: 1.9761, Train Accuracy: 0.4671
#   Group 2 - Val Loss: 2.2722, Val Accuracy: 0.4035
#   Group 3 - Train Loss: 1.4190, Train Accuracy: 0.6701
#   Group 3 - Val Loss: 1.7911, Val Accuracy: 0.5523
# Epoch [172/200] Group Metrics:
#   Group 1 - Train Loss: 2.1773, Train Accuracy: 0.3420
#   Group 1 - Val Loss: 2.2914, Val Accuracy: 0.3119
#   Group 2 - Train Loss: 1.9741, Train Accuracy: 0.4682
#   Group 2 - Val Loss: 2.2709, Val Accuracy: 0.4047
#   Group 3 - Train Loss: 1.4166, Train Accuracy: 0.6714
#   Group 3 - Val Loss: 1.7894, Val Accuracy: 0.5523
# Epoch [173/200] Group Metrics:
#   Group 1 - Train Loss: 2.1763, Train Accuracy: 0.3420
#   Group 1 - Val Loss: 2.2907, Val Accuracy: 0.3129
#   Group 2 - Train Loss: 1.9721, Train Accuracy: 0.4688
#   Group 2 - Val Loss: 2.2696, Val Accuracy: 0.4058
#   Group 3 - Train Loss: 1.4142, Train Accuracy: 0.6717
#   Group 3 - Val Loss: 1.7877, Val Accuracy: 0.5536
# Epoch [174/200] Group Metrics:
#   Group 1 - Train Loss: 2.1754, Train Accuracy: 0.3420
#   Group 1 - Val Loss: 2.2899, Val Accuracy: 0.3129
#   Group 2 - Train Loss: 1.9701, Train Accuracy: 0.4700
#   Group 2 - Val Loss: 2.2683, Val Accuracy: 0.4058
#   Group 3 - Train Loss: 1.4118, Train Accuracy: 0.6724
#   Group 3 - Val Loss: 1.7861, Val Accuracy: 0.5536
# Epoch [175/200] Group Metrics:
#   Group 1 - Train Loss: 2.1745, Train Accuracy: 0.3425
#   Group 1 - Val Loss: 2.2892, Val Accuracy: 0.3119
#   Group 2 - Train Loss: 1.9681, Train Accuracy: 0.4700
#   Group 2 - Val Loss: 2.2670, Val Accuracy: 0.4058
#   Group 3 - Train Loss: 1.4094, Train Accuracy: 0.6727
#   Group 3 - Val Loss: 1.7844, Val Accuracy: 0.5536
# Epoch [176/200] Group Metrics:
#   Group 1 - Train Loss: 2.1735, Train Accuracy: 0.3425
#   Group 1 - Val Loss: 2.2884, Val Accuracy: 0.3119
#   Group 2 - Train Loss: 1.9661, Train Accuracy: 0.4700
#   Group 2 - Val Loss: 2.2657, Val Accuracy: 0.4070
#   Group 3 - Train Loss: 1.4070, Train Accuracy: 0.6737
#   Group 3 - Val Loss: 1.7828, Val Accuracy: 0.5536
# Epoch [177/200] Group Metrics:
#   Group 1 - Train Loss: 2.1726, Train Accuracy: 0.3425
#   Group 1 - Val Loss: 2.2877, Val Accuracy: 0.3129
#   Group 2 - Train Loss: 1.9642, Train Accuracy: 0.4706
#   Group 2 - Val Loss: 2.2644, Val Accuracy: 0.4082
#   Group 3 - Train Loss: 1.4046, Train Accuracy: 0.6737
#   Group 3 - Val Loss: 1.7812, Val Accuracy: 0.5543
# Epoch [178/200] Group Metrics:
#   Group 1 - Train Loss: 2.1717, Train Accuracy: 0.3425
#   Group 1 - Val Loss: 2.2869, Val Accuracy: 0.3148
#   Group 2 - Train Loss: 1.9622, Train Accuracy: 0.4712
#   Group 2 - Val Loss: 2.2631, Val Accuracy: 0.4082
#   Group 3 - Train Loss: 1.4023, Train Accuracy: 0.6743
#   Group 3 - Val Loss: 1.7796, Val Accuracy: 0.5543
# Epoch [179/200] Group Metrics:
#   Group 1 - Train Loss: 2.1708, Train Accuracy: 0.3425
#   Group 1 - Val Loss: 2.2862, Val Accuracy: 0.3158
#   Group 2 - Train Loss: 1.9603, Train Accuracy: 0.4712
#   Group 2 - Val Loss: 2.2618, Val Accuracy: 0.4082
#   Group 3 - Train Loss: 1.4000, Train Accuracy: 0.6750
#   Group 3 - Val Loss: 1.7780, Val Accuracy: 0.5536
# Epoch [180/200] Group Metrics:
#   Group 1 - Train Loss: 2.1699, Train Accuracy: 0.3425
#   Group 1 - Val Loss: 2.2855, Val Accuracy: 0.3168
#   Group 2 - Train Loss: 1.9583, Train Accuracy: 0.4712
#   Group 2 - Val Loss: 2.2606, Val Accuracy: 0.4082
#   Group 3 - Train Loss: 1.3976, Train Accuracy: 0.6760
#   Group 3 - Val Loss: 1.7764, Val Accuracy: 0.5543
# Epoch [181/200] Group Metrics:
#   Group 1 - Train Loss: 2.1690, Train Accuracy: 0.3420
#   Group 1 - Val Loss: 2.2848, Val Accuracy: 0.3168
#   Group 2 - Train Loss: 1.9564, Train Accuracy: 0.4735
#   Group 2 - Val Loss: 2.2593, Val Accuracy: 0.4094
#   Group 3 - Train Loss: 1.3953, Train Accuracy: 0.6760
#   Group 3 - Val Loss: 1.7748, Val Accuracy: 0.5549
# Epoch [182/200] Group Metrics:
#   Group 1 - Train Loss: 2.1681, Train Accuracy: 0.3425
#   Group 1 - Val Loss: 2.2840, Val Accuracy: 0.3177
#   Group 2 - Train Loss: 1.9545, Train Accuracy: 0.4741
#   Group 2 - Val Loss: 2.2581, Val Accuracy: 0.4105
#   Group 3 - Train Loss: 1.3931, Train Accuracy: 0.6763
#   Group 3 - Val Loss: 1.7732, Val Accuracy: 0.5549
# Epoch [183/200] Group Metrics:
#   Group 1 - Train Loss: 2.1673, Train Accuracy: 0.3430
#   Group 1 - Val Loss: 2.2833, Val Accuracy: 0.3177
#   Group 2 - Train Loss: 1.9526, Train Accuracy: 0.4741
#   Group 2 - Val Loss: 2.2568, Val Accuracy: 0.4105
#   Group 3 - Train Loss: 1.3908, Train Accuracy: 0.6766
#   Group 3 - Val Loss: 1.7717, Val Accuracy: 0.5562
# Epoch [184/200] Group Metrics:
#   Group 1 - Train Loss: 2.1664, Train Accuracy: 0.3430
#   Group 1 - Val Loss: 2.2826, Val Accuracy: 0.3177
#   Group 2 - Train Loss: 1.9507, Train Accuracy: 0.4747
#   Group 2 - Val Loss: 2.2556, Val Accuracy: 0.4117
#   Group 3 - Train Loss: 1.3885, Train Accuracy: 0.6773
#   Group 3 - Val Loss: 1.7701, Val Accuracy: 0.5569
# Epoch [185/200] Group Metrics:
#   Group 1 - Train Loss: 2.1655, Train Accuracy: 0.3430
#   Group 1 - Val Loss: 2.2819, Val Accuracy: 0.3177
#   Group 2 - Train Loss: 1.9488, Train Accuracy: 0.4747
#   Group 2 - Val Loss: 2.2543, Val Accuracy: 0.4129
#   Group 3 - Train Loss: 1.3863, Train Accuracy: 0.6779
#   Group 3 - Val Loss: 1.7686, Val Accuracy: 0.5575
# Epoch [186/200] Group Metrics:
#   Group 1 - Train Loss: 2.1646, Train Accuracy: 0.3430
#   Group 1 - Val Loss: 2.2812, Val Accuracy: 0.3187
#   Group 2 - Train Loss: 1.9470, Train Accuracy: 0.4741
#   Group 2 - Val Loss: 2.2531, Val Accuracy: 0.4129
#   Group 3 - Train Loss: 1.3840, Train Accuracy: 0.6792
#   Group 3 - Val Loss: 1.7671, Val Accuracy: 0.5575
# Epoch [187/200] Group Metrics:
#   Group 1 - Train Loss: 2.1638, Train Accuracy: 0.3434
#   Group 1 - Val Loss: 2.2805, Val Accuracy: 0.3187
#   Group 2 - Train Loss: 1.9451, Train Accuracy: 0.4741
#   Group 2 - Val Loss: 2.2519, Val Accuracy: 0.4129
#   Group 3 - Train Loss: 1.3818, Train Accuracy: 0.6792
#   Group 3 - Val Loss: 1.7656, Val Accuracy: 0.5582
# Epoch [188/200] Group Metrics:
#   Group 1 - Train Loss: 2.1629, Train Accuracy: 0.3439
#   Group 1 - Val Loss: 2.2798, Val Accuracy: 0.3197
#   Group 2 - Train Loss: 1.9433, Train Accuracy: 0.4747
#   Group 2 - Val Loss: 2.2507, Val Accuracy: 0.4140
#   Group 3 - Train Loss: 1.3796, Train Accuracy: 0.6795
#   Group 3 - Val Loss: 1.7641, Val Accuracy: 0.5582
# Epoch [189/200] Group Metrics:
#   Group 1 - Train Loss: 2.1621, Train Accuracy: 0.3444
#   Group 1 - Val Loss: 2.2791, Val Accuracy: 0.3187
#   Group 2 - Train Loss: 1.9414, Train Accuracy: 0.4759
#   Group 2 - Val Loss: 2.2495, Val Accuracy: 0.4152
#   Group 3 - Train Loss: 1.3774, Train Accuracy: 0.6799
#   Group 3 - Val Loss: 1.7626, Val Accuracy: 0.5601
# Epoch [190/200] Group Metrics:
#   Group 1 - Train Loss: 2.1612, Train Accuracy: 0.3444
#   Group 1 - Val Loss: 2.2785, Val Accuracy: 0.3187
#   Group 2 - Train Loss: 1.9396, Train Accuracy: 0.4759
#   Group 2 - Val Loss: 2.2483, Val Accuracy: 0.4152
#   Group 3 - Train Loss: 1.3753, Train Accuracy: 0.6805
#   Group 3 - Val Loss: 1.7611, Val Accuracy: 0.5595
# Epoch [191/200] Group Metrics:
#   Group 1 - Train Loss: 2.1604, Train Accuracy: 0.3444
#   Group 1 - Val Loss: 2.2778, Val Accuracy: 0.3187
#   Group 2 - Train Loss: 1.9378, Train Accuracy: 0.4770
#   Group 2 - Val Loss: 2.2471, Val Accuracy: 0.4164
#   Group 3 - Train Loss: 1.3731, Train Accuracy: 0.6821
#   Group 3 - Val Loss: 1.7597, Val Accuracy: 0.5595
# Epoch [192/200] Group Metrics:
#   Group 1 - Train Loss: 2.1596, Train Accuracy: 0.3444
#   Group 1 - Val Loss: 2.2771, Val Accuracy: 0.3187
#   Group 2 - Train Loss: 1.9360, Train Accuracy: 0.4776
#   Group 2 - Val Loss: 2.2460, Val Accuracy: 0.4164
#   Group 3 - Train Loss: 1.3709, Train Accuracy: 0.6825
#   Group 3 - Val Loss: 1.7582, Val Accuracy: 0.5595
# Epoch [193/200] Group Metrics:
#   Group 1 - Train Loss: 2.1587, Train Accuracy: 0.3444
#   Group 1 - Val Loss: 2.2764, Val Accuracy: 0.3187
#   Group 2 - Train Loss: 1.9342, Train Accuracy: 0.4776
#   Group 2 - Val Loss: 2.2448, Val Accuracy: 0.4164
#   Group 3 - Train Loss: 1.3688, Train Accuracy: 0.6825
#   Group 3 - Val Loss: 1.7567, Val Accuracy: 0.5595
# Epoch [194/200] Group Metrics:
#   Group 1 - Train Loss: 2.1579, Train Accuracy: 0.3449
#   Group 1 - Val Loss: 2.2758, Val Accuracy: 0.3187
#   Group 2 - Train Loss: 1.9324, Train Accuracy: 0.4776
#   Group 2 - Val Loss: 2.2436, Val Accuracy: 0.4164
#   Group 3 - Train Loss: 1.3667, Train Accuracy: 0.6828
#   Group 3 - Val Loss: 1.7553, Val Accuracy: 0.5601
# Epoch [195/200] Group Metrics:
#   Group 1 - Train Loss: 2.1571, Train Accuracy: 0.3449
#   Group 1 - Val Loss: 2.2751, Val Accuracy: 0.3187
#   Group 2 - Train Loss: 1.9306, Train Accuracy: 0.4782
#   Group 2 - Val Loss: 2.2425, Val Accuracy: 0.4175
#   Group 3 - Train Loss: 1.3645, Train Accuracy: 0.6834
#   Group 3 - Val Loss: 1.7539, Val Accuracy: 0.5608
# Epoch [196/200] Group Metrics:
#   Group 1 - Train Loss: 2.1563, Train Accuracy: 0.3454
#   Group 1 - Val Loss: 2.2745, Val Accuracy: 0.3187
#   Group 2 - Train Loss: 1.9288, Train Accuracy: 0.4782
#   Group 2 - Val Loss: 2.2413, Val Accuracy: 0.4187
#   Group 3 - Train Loss: 1.3624, Train Accuracy: 0.6841
#   Group 3 - Val Loss: 1.7525, Val Accuracy: 0.5608
# Epoch [197/200] Group Metrics:
#   Group 1 - Train Loss: 2.1554, Train Accuracy: 0.3459
#   Group 1 - Val Loss: 2.2738, Val Accuracy: 0.3187
#   Group 2 - Train Loss: 1.9271, Train Accuracy: 0.4782
#   Group 2 - Val Loss: 2.2402, Val Accuracy: 0.4187
#   Group 3 - Train Loss: 1.3604, Train Accuracy: 0.6847
#   Group 3 - Val Loss: 1.7511, Val Accuracy: 0.5621
# Epoch [198/200] Group Metrics:
#   Group 1 - Train Loss: 2.1546, Train Accuracy: 0.3459
#   Group 1 - Val Loss: 2.2732, Val Accuracy: 0.3177
#   Group 2 - Train Loss: 1.9253, Train Accuracy: 0.4788
#   Group 2 - Val Loss: 2.2390, Val Accuracy: 0.4199
#   Group 3 - Train Loss: 1.3583, Train Accuracy: 0.6851
#   Group 3 - Val Loss: 1.7497, Val Accuracy: 0.5614
# Epoch [199/200] Group Metrics:
#   Group 1 - Train Loss: 2.1538, Train Accuracy: 0.3459
#   Group 1 - Val Loss: 2.2725, Val Accuracy: 0.3177
#   Group 2 - Train Loss: 1.9236, Train Accuracy: 0.4800
#   Group 2 - Val Loss: 2.2379, Val Accuracy: 0.4199
#   Group 3 - Train Loss: 1.3562, Train Accuracy: 0.6854
#   Group 3 - Val Loss: 1.7483, Val Accuracy: 0.5614
# Epoch [200/200] Group Metrics:
#   Group 1 - Train Loss: 2.1530, Train Accuracy: 0.3464
#   Group 1 - Val Loss: 2.2719, Val Accuracy: 0.3187
#   Group 2 - Train Loss: 1.9218, Train Accuracy: 0.4806
#   Group 2 - Val Loss: 2.2368, Val Accuracy: 0.4211
#   Group 3 - Train Loss: 1.3542, Train Accuracy: 0.6857
#   Group 3 - Val Loss: 1.7469, Val Accuracy: 0.5621

# %%
# Convert metrics to numpy arrays for easy manipulation
group_train_loss_histories = {k: np.array(v) for k, v in group_train_loss_histories.items()}
group_train_accuracy_histories = {k: np.array(v) for k, v in group_train_accuracy_histories.items()}
group_val_loss_histories = {k: np.array(v) for k, v in group_val_loss_histories.items()}
group_val_accuracy_histories = {k: np.array(v) for k, v in group_val_accuracy_histories.items()}

# Handle potential one-dimensional arrays
group_train_loss_mean = {k: v.mean(axis=1) if v.ndim > 1 else v for k, v in group_train_loss_histories.items()}
group_train_loss_std = {k: v.std(axis=1) if v.ndim > 1 else np.zeros_like(v) for k, v in group_train_loss_histories.items()}
group_val_loss_mean = {k: v.mean(axis=1) if v.ndim > 1 else v for k, v in group_val_loss_histories.items()}
group_val_loss_std = {k: v.std(axis=1) if v.ndim > 1 else np.zeros_like(v) for k, v in group_val_loss_histories.items()}

group_train_acc_mean = {k: v.mean(axis=1) if v.ndim > 1 else v for k, v in group_train_accuracy_histories.items()}
group_train_acc_std = {k: v.std(axis=1) if v.ndim > 1 else np.zeros_like(v) for k, v in group_train_accuracy_histories.items()}
group_val_acc_mean = {k: v.mean(axis=1) if v.ndim > 1 else v for k, v in group_val_accuracy_histories.items()}
group_val_acc_std = {k: v.std(axis=1) if v.ndim > 1 else np.zeros_like(v) for k, v in group_val_accuracy_histories.items()}

# Combined Plot for All Modalities
plt.figure(figsize=(12, 6))

# Loss Plot
plt.subplot(1, 2, 1)
for group in [1, 2, 3]:
    plt.plot(range(1, num_epochs + 1), group_train_loss_mean[group], label=f"Group {group} Train Loss")
    plt.fill_between(range(1, num_epochs + 1), 
                     group_train_loss_mean[group] - group_train_loss_std[group], 
                     group_train_loss_mean[group] + group_train_loss_std[group], 
                     alpha=0.2)
    plt.plot(range(1, num_epochs + 1), group_val_loss_mean[group], label=f"Group {group} Validation Loss", linestyle="dashed")
    plt.fill_between(range(1, num_epochs + 1), 
                     group_val_loss_mean[group] - group_val_loss_std[group], 
                     group_val_loss_mean[group] + group_val_loss_std[group], 
                     alpha=0.2)

plt.title("Loss over Epochs for All Groups")
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.legend()
plt.grid()

# Accuracy Plot
plt.subplot(1, 2, 2)
for group in [1, 2, 3]:
    plt.plot(range(1, num_epochs + 1), group_train_acc_mean[group], label=f"Group {group} Train Accuracy")
    plt.fill_between(range(1, num_epochs + 1), 
                     group_train_acc_mean[group] - group_train_acc_std[group], 
                     group_train_acc_mean[group] + group_train_acc_std[group], 
                     alpha=0.2)
    plt.plot(range(1, num_epochs + 1), group_val_acc_mean[group], label=f"Group {group} Validation Accuracy", linestyle="dashed")
    plt.fill_between(range(1, num_epochs + 1), 
                     group_val_acc_mean[group] - group_val_acc_std[group], 
                     group_val_acc_mean[group] + group_val_acc_std[group], 
                     alpha=0.2)

plt.title("Accuracy over Epochs for All Groups")
plt.xlabel("Epoch")
plt.ylabel("Accuracy")
plt.ylim([0, 1])  # Ensure y-axis is between 0 and 1 for accuracy
plt.legend()
plt.grid()

plt.tight_layout()
plt.show()

# %%
# Combined Plot for All Modalities
plt.figure(figsize=(12, 6))

# Loss Plot
plt.subplot(1, 2, 1)
for group in [1, 2, 3]:
    plt.plot(range(1, num_epochs + 1), group_train_loss_mean[group], label=f"Group {group} Train Loss")
    plt.fill_between(range(1, num_epochs + 1), 
                     group_train_loss_mean[group] - group_train_loss_std[group], 
                     group_train_loss_mean[group] + group_train_loss_std[group], 
                     alpha=0.2)
    plt.plot(range(1, num_epochs + 1), group_val_loss_mean[group], label=f"Group {group} Validation Loss", linestyle="dashed")
    plt.fill_between(range(1, num_epochs + 1), 
                     group_val_loss_mean[group] - group_val_loss_std[group], 
                     group_val_loss_mean[group] + group_val_loss_std[group], 
                     alpha=0.2)

plt.title("Loss over Epochs for All Groups")
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.legend()
plt.grid()

# Accuracy Plot
plt.subplot(1, 2, 2)
for group in [1, 2, 3]:
    plt.plot(range(1, num_epochs + 1), group_train_acc_mean[group], label=f"Group {group} Train Accuracy")
    plt.fill_between(range(1, num_epochs + 1), 
                     group_train_acc_mean[group] - group_train_acc_std[group], 
                     group_train_acc_mean[group] + group_train_acc_std[group], 
                     alpha=0.2)
    plt.plot(range(1, num_epochs + 1), group_val_acc_mean[group], label=f"Group {group} Validation Accuracy", linestyle="dashed")
    plt.fill_between(range(1, num_epochs + 1), 
                     group_val_acc_mean[group] - group_val_acc_std[group], 
                     group_val_acc_mean[group] + group_val_acc_std[group], 
                     alpha=0.2)

plt.title("Accuracy over Epochs for All Groups")
plt.xlabel("Epoch")
plt.ylabel("Accuracy")
plt.ylim([0, 1])  # Ensure y-axis is between 0 and 1 for accuracy
plt.legend()
plt.grid()

plt.tight_layout()
plt.show()

# %%
# Track metrics across all groups
'''
group_test_loss_histories = {group: [] for group in range(1, num_groups + 1)}
group_test_accuracy_histories = {group: [] for group in range(1, num_groups + 1)}
group_train_loss_histories = {group: [] for group in range(1, num_groups + 1)}
group_train_accuracy_histories = {group: [] for group in range(1, num_groups + 1)}

with torch.no_grad():  # Disable gradient computation for testing
    for group in range(1, num_groups + 1):
        user_test_losses = []
        user_test_accuracies = []
        user_train_losses = []
        user_train_accuracies = []

        for user_id, model in enumerate(classifiers_by_group[group]):
            model.eval()

            # Test metrics
            epoch_test_loss = 0.0
            correct_test_predictions = 0
            total_test_samples = 0

            # Train metrics (optional, for post-training evaluation on training data)
            epoch_train_loss = 0.0
            correct_train_predictions = 0
            total_train_samples = 0

            # Evaluate on test set
            for X_batch, y_batch in test_loaders_by_group[group][user_id]:
                X_batch, y_batch = X_batch.cuda(), y_batch.cuda()
                outputs = model(X_batch)
                loss = criterion(outputs, y_batch)

                epoch_test_loss += loss.item()
                _, predicted = torch.max(outputs, dim=1)
                correct_test_predictions += (predicted == y_batch).sum().item()
                total_test_samples += y_batch.size(0)

            # Evaluate on training set
            for X_batch, y_batch in train_loaders_by_group[group][user_id]:
                X_batch, y_batch = X_batch.cuda(), y_batch.cuda()
                outputs = model(X_batch)
                loss = criterion(outputs, y_batch)

                epoch_train_loss += loss.item()
                _, predicted = torch.max(outputs, dim=1)
                correct_train_predictions += (predicted == y_batch).sum().item()
                total_train_samples += y_batch.size(0)

            # Calculate averages
            avg_test_loss = epoch_test_loss / len(test_loaders_by_group[group][user_id])
            test_accuracy = correct_test_predictions / total_test_samples

            avg_train_loss = epoch_train_loss / len(train_loaders_by_group[group][user_id])
            train_accuracy = correct_train_predictions / total_train_samples

            # Store metrics for each user
            user_test_losses.append(avg_test_loss)
            user_test_accuracies.append(test_accuracy)
            user_train_losses.append(avg_train_loss)
            user_train_accuracies.append(train_accuracy)

        # Store group-level metrics
        group_test_loss_histories[group].append(np.mean(user_test_losses))
        group_test_accuracy_histories[group].append(np.mean(user_test_accuracies))
        group_train_loss_histories[group].append(np.mean(user_train_losses))
        group_train_accuracy_histories[group].append(np.mean(user_train_accuracies))

# Convert metrics to numpy arrays for plotting
group_test_loss_histories = {group: np.array(values) for group, values in group_test_loss_histories.items()}
group_test_accuracy_histories = {group: np.array(values) for group, values in group_test_accuracy_histories.items()}
group_train_loss_histories = {group: np.array(values) for group, values in group_train_loss_histories.items()}
group_train_accuracy_histories = {group: np.array(values) for group, values in group_train_accuracy_histories.items()}

# Plot results for all groups
plt.figure(figsize=(12, 6))

# Test Loss and Accuracy
plt.subplot(1, 2, 1)
for group in range(1, num_groups + 1):
    plt.plot(range(1, len(group_test_loss_histories[group]) + 1), group_test_loss_histories[group], label=f"Group {group} Test Loss")
plt.title("Test Loss Across Groups")
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.legend()
plt.grid()

plt.subplot(1, 2, 2)
for group in range(1, num_groups + 1):
    plt.plot(range(1, len(group_test_accuracy_histories[group]) + 1), group_test_accuracy_histories[group], label=f"Group {group} Test Accuracy")
plt.title("Test Accuracy Across Groups")
plt.xlabel("Epoch")
plt.ylabel("Accuracy")
plt.legend()
plt.grid()

plt.tight_layout()
plt.show()
'''
# Out:
# '\ngroup_test_loss_histories = {group: [] for group in range(1, num_groups + 1)}\ngroup_test_accuracy_histories = {group: [] for group in range(1, num_groups + 1)}\ngroup_train_loss_histories = {group: [] for group in range(1, num_groups + 1)}\ngroup_train_accuracy_histories = {group: [] for group in range(1, num_groups + 1)}\n\nwith torch.no_grad():  # Disable gradient computation for testing\n    for group in range(1, num_groups + 1):\n        user_test_losses = []\n        user_test_accuracies = []\n        user_train_losses = []\n        user_train_accuracies = []\n\n        for user_id, model in enumerate(classifiers_by_group[group]):\n            model.eval()\n\n            # Test metrics\n            epoch_test_loss = 0.0\n            correct_test_predictions = 0\n            total_test_samples = 0\n\n            # Train metrics (optional, for post-training evaluation on training data)\n            epoch_train_loss = 0.0\n            correct_train_predictions = 0\n            total_train_samples = 0\n\n            # Evaluate on test set\n            for X_batch, y_batch in test_loaders_by_group[group][user_id]:\n                X_batch, y_batch = X_batch.cuda(), y_batch.cuda()\n                outputs = model(X_batch)\n                loss = criterion(outputs, y_batch)\n\n                epoch_test_loss += loss.item()\n                _, predicted = torch.max(outputs, dim=1)\n                correct_test_predictions += (predicted == y_batch).sum().item()\n                total_test_samples += y_batch.size(0)\n\n            # Evaluate on training set\n            for X_batch, y_batch in train_loaders_by_group[group][user_id]:\n                X_batch, y_batch = X_batch.cuda(), y_batch.cuda()\n                outputs = model(X_batch)\n                loss = criterion(outputs, y_batch)\n\n                epoch_train_loss += loss.item()\n                _, predicted = torch.max(outputs, dim=1)\n                correct_train_predictions += (predicted == y_batch).sum().item()\n                total_train_samples += y_batch.size(0)\n\n            # Calculate averages\n            avg_test_loss = epoch_test_loss / len(test_loaders_by_group[group][user_id])\n            test_accuracy = correct_test_predictions / total_test_samples\n\n            avg_train_loss = epoch_train_loss / len(train_loaders_by_group[group][user_id])\n            train_accuracy = correct_train_predictions / total_train_samples\n\n            # Store metrics for each user\n            user_test_losses.append(avg_test_loss)\n            user_test_accuracies.append(test_accuracy)\n            user_train_losses.append(avg_train_loss)\n            user_train_accuracies.append(train_accuracy)\n\n        # Store group-level metrics\n        group_test_loss_histories[group].append(np.mean(user_test_losses))\n        group_test_accuracy_histories[group].append(np.mean(user_test_accuracies))\n        group_train_loss_histories[group].append(np.mean(user_train_losses))\n        group_train_accuracy_histories[group].append(np.mean(user_train_accuracies))\n\n# Convert metrics to numpy arrays for plotting\ngroup_test_loss_histories = {group: np.array(values) for group, values in group_test_loss_histories.items()}\ngroup_test_accuracy_histories = {group: np.array(values) for group, values in group_test_accuracy_histories.items()}\ngroup_train_loss_histories = {group: np.array(values) for group, values in group_train_loss_histories.items()}\ngroup_train_accuracy_histories = {group: np.array(values) for group, values in group_train_accuracy_histories.items()}\n\n# Plot results for all groups\nplt.figure(figsize=(12, 6))\n\n# Test Loss and Accuracy\nplt.subplot(1, 2, 1)\nfor group in range(1, num_groups + 1):\n    plt.plot(range(1, len(group_test_loss_histories[group]) + 1), group_test_loss_histories[group], label=f"Group {group} Test Loss")\nplt.title("Test Loss Across Groups")\nplt.xlabel("Epoch")\nplt.ylabel("Loss")\nplt.legend()\nplt.grid()\n\nplt.subplot(1, 2, 2)\nfor ...

# %%
# Images only
'''
Test Loss: 0.4364, Test Accuracy: 0.8521

Train Loss: 0.4047, Train Accuracy: 0.8687

'''
# Out:
# '\nTest Loss: 0.4364, Test Accuracy: 0.8521\n\nTrain Loss: 0.4047, Train Accuracy: 0.8687\n\n'

# %%
import json
import os

# Define the save directory


# Convert numpy arrays to lists for serialization
data_to_save = {
    "group_train_loss_mean": {k: v.tolist() for k, v in group_train_loss_mean.items()},
    "group_train_loss_std": {k: v.tolist() for k, v in group_train_loss_std.items()},
    "group_val_loss_mean": {k: v.tolist() for k, v in group_val_loss_mean.items()},
    "group_val_loss_std": {k: v.tolist() for k, v in group_val_loss_std.items()},
    "group_train_acc_mean": {k: v.tolist() for k, v in group_train_acc_mean.items()},
    "group_train_acc_std": {k: v.tolist() for k, v in group_train_acc_std.items()},
    "group_val_acc_mean": {k: v.tolist() for k, v in group_val_acc_mean.items()},
    "group_val_acc_std": {k: v.tolist() for k, v in group_val_acc_std.items()}
}

#with open("No_Comm_Metrics_20.json", "w") as f:
#    json.dump(data_to_save, f)
print("No_Comm_Metrics_20.json")
# Out:
# No_Comm_Metrics_20.json

# %%
import cvxpy as cp
import numpy as np

# Constants
h = np.array([4, 2, 1])  # Channel gains
N0 = 2                 # Noise power (example value)
P = 0,2                       # Total power constraint (example value)

# Optimization variables
p = cp.Variable(3, nonneg=True)  # Power allocation for 3 channels

# Objective function
rate = cp.log(1 + cp.sum(cp.multiply(h, p)) / N0) / cp.log(2)  # Convert log to base 2

# Constraints
constraints = [
    cp.sum(p) <= P,  # Total power constraint
    p >= 0           # Non-negativity constraint
]

# Define the problem
problem = cp.Problem(cp.Maximize(rate), constraints)

# Solve the problem
problem.solve()

# Output the results
print("Optimal power allocation:", p.value)
print("Maximum achievable rate:", problem.value)
# Out:
# ---------------------------------------------------------------------------
# DCPError                                  Traceback (most recent call last)
# Cell In[12], line 25
#      22 problem = cp.Problem(cp.Maximize(rate), constraints)
#      24 # Solve the problem
# ---> 25 problem.solve()
#      27 # Output the results
#      28 print("Optimal power allocation:", p.value)
#
# File ~\AppData\Local\anaconda3\envs\fmtl_sheaves\lib\site-packages\cvxpy\problems\problem.py:503, in Problem.solve(self, *args, **kwargs)
#     501 else:
#     502     solve_func = Problem._solve
# --> 503 return solve_func(self, *args, **kwargs)
#
# File ~\AppData\Local\anaconda3\envs\fmtl_sheaves\lib\site-packages\cvxpy\problems\problem.py:1073, in Problem._solve(self, solver, warm_start, verbose, gp, qcp, requires_grad, enforce_dpp, ignore_dpp, canon_backend, **kwargs)
#    1070         self.unpack(chain.retrieve(soln))
#    1071         return self.value
# -> 1073 data, solving_chain, inverse_data = self.get_problem_data(
#    1074     solver, gp, enforce_dpp, ignore_dpp, verbose, canon_backend, kwargs
#    1075 )
#    1077 if verbose:
#    1078     print(_NUM_SOLVER_STR)
#
# File ~\AppData\Local\anaconda3\envs\fmtl_sheaves\lib\site-packages\cvxpy\problems\problem.py:646, in Problem.get_problem_data(self, solver, gp, enforce_dpp, ignore_dpp, verbose, canon_backend, solver_opts)
#     644 if key != self._cache.key:
#     645     self._cache.invalidate()
# --> 646     solving_chain = self._construct_chain(
#     647         solver=solver, gp=gp,
#     648         enforce_dpp=enforce_dpp,
#     649         ignore_dpp=ignore_dpp,
#     650         canon_backend=canon_backend,
#     651         solver_opts=solver_opts)
#     652     self._cache.key = key
#     653     self._cache.solving_chain = solving_chain
#
# File ~\AppData\Local\anaconda3\envs\fmtl_sheaves\lib\site-packages\cvxpy\problems\problem.py:898, in Problem._construct_chain(self, solver, gp, enforce_dpp, ignore_dpp, canon_backend, solver_opts)
#     896 candidate_solvers = self._find_candidate_solvers(solver=solver, gp=gp)
#     897 self._sort_candidate_solvers(candidate_solvers)
# --> 898 return construct_solving_chain(self, candidate_solvers, gp=gp,
#     899                                enforce_dpp=enforce_dpp,
#     900                                ignore_dpp=ignore_dpp,
#     901                                canon_backend=canon_backend,
#     902                                solver_opts=solver_opts,
#     903                                specified_solver=solver)
#
# File ~\AppData\Local\anaconda3\envs\fmtl_sheaves\lib\site-packages\cvxpy\reductions\solvers\solving_chain.py:228, in construct_solving_chain(problem, candidates, gp, enforce_dpp, ignore_dpp, canon_backend, solver_opts, specified_solver)
#     226 if len(problem.variables()) == 0:
#     227     return SolvingChain(reductions=[ConstantSolver()])
# --> 228 reductions = _reductions_for_problem_class(problem, candidates, gp, solver_opts)
#     230 # Process DPP status of the problem.
#     231 dpp_context = 'dcp' if not gp else 'dgp'
#
# File ~\AppData\Local\anaconda3\envs\fmtl_sheaves\lib\site-packages\cvxpy\reductions\solvers\solving_chain.py:143, in _reductions_for_problem_class(problem, candidates, gp, solver_opts)
#     140     elif problem.is_dqcp():
#     141         append += ("\nHowever, the problem does follow DQCP rules. "
#     142                    "Consider calling solve() with `qcp=True`.")
# --> 143     raise DCPError(
#     144         "Problem does not follow DCP rules. Specifically:\n" + append)
#     145 elif gp and not problem.is_dgp():
#     146     append = build_non_disciplined_error_msg(problem, 'DGP')
#
# DCPError: Problem does not follow DCP rules. Specifically:
# The objective is not DCP. Its following subexpressions are not:
# log(1.0 + Sum([4. 2. 1.] @ var1, None, False) / 2.0) / log(2.0)
